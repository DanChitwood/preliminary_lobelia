# %%
#######################
### LOAD IN MODULES ###
#######################

import cv2 # to install on mac: pip install opencv-python
from scipy.interpolate import interp1d # for interpolating points
from sklearn.decomposition import PCA # for principal component analysis
from scipy.spatial import procrustes # for Procrustes analysis
from scipy.spatial import ConvexHull # for convex hull
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis # for LDA
from sklearn.metrics import confusion_matrix # for confusion matrix
from os import listdir # for retrieving files from directory
from os.path import isfile, join # for retrieving files from directory
import matplotlib.pyplot as plt # for plotting
import numpy as np # for using arrays
import math # for mathematical operations
import pandas as pd # for using pandas dataframes
import seaborn as sns # for plotting in seaborn
from matplotlib.colors import LogNorm
from sklearn.model_selection import StratifiedKFold
import itertools # for pairwise combinations
import scipy.stats as stats # for kruskal wallis test
import statsmodels.stats.multitest as multitest # multiple test adjustment

# %%
#################
### FUNCTIONS ###
#################

def angle_between(p1, p2, p3):
    """
    define a function to find the angle between 3 points anti-clockwise in degrees, p2 being the vertex
    inputs: three angle points, as tuples
    output: angle in degrees
    """
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    deg1 = (360 + math.degrees(math.atan2(x1 - x2, y1 - y2))) % 360
    deg2 = (360 + math.degrees(math.atan2(x3 - x2, y3 - y2))) % 360
    return deg2 - deg1 if deg1 <= deg2 else 360 - (deg1 - deg2)

def rotate_points(xvals, yvals, degrees):
    """"
    define a function to rotate 2D x and y coordinate points around the origin
    inputs: x and y vals (can take pandas dataframe columns) and the degrees (positive, anticlockwise) to rotate
    outputs: rotated and y vals
    """
    angle_to_move = 90-degrees
    rads = np.deg2rad(angle_to_move)
    
    new_xvals = xvals*np.cos(rads)-yvals*np.sin(rads)
    new_yvals = xvals*np.sin(rads)+yvals*np.cos(rads)
    
    return new_xvals, new_yvals

def interpolation(x, y, number): 
    """
    define a function to return equally spaced, interpolated points for a given polyline
    inputs: arrays of x and y values for a polyline, number of points to interpolate
    ouputs: interpolated points along the polyline, inclusive of start and end points
    """
    distance = np.cumsum(np.sqrt( np.ediff1d(x, to_begin=0)**2 + np.ediff1d(y, to_begin=0)**2 ))
    distance = distance/distance[-1]

    fx, fy = interp1d( distance, x ), interp1d( distance, y )

    alpha = np.linspace(0, 1, number)
    x_regular, y_regular = fx(alpha), fy(alpha)
    
    return x_regular, y_regular

def euclid_dist(x1, y1, x2, y2):
    """
    define a function to return the euclidean distance between two points
    inputs: x and y values of the two points
    output: the eulidean distance
    """
    return np.sqrt((x2-x1)**2 + (y2-y1)**2)

def poly_area(x,y):
    """
    define a function to calculate the area of a polygon using the shoelace algorithm
    inputs: separate numpy arrays of x and y coordinate values
    outputs: the area of the polygon
    """
    return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))

def gpa_mean(leaf_arr, landmark_num, dim_num):
    
    """
    define a function that given an array of landmark data returns the Generalized Procrustes Analysis mean
    inputs: a 3 dimensional array of samples by landmarks by coordinate values, number of landmarks, number of dimensions
    output: an array of the Generalized Procrustes Analysis mean shape
    
    """

    ref_ind = 0 # select arbitrary reference index to calculate procrustes distances to
    ref_shape = leaf_arr[ref_ind, :, :] # select the reference shape

    mean_diff = 10**(-30) # set a distance between means to stop the algorithm

    old_mean = ref_shape # for the first comparison between means, set old_mean to an arbitrary reference shape

    d = 1000000 # set d initially arbitraily high

    while d > mean_diff: # set boolean criterion for Procrustes distance between mean to stop calculations

        arr = np.zeros( ((len(leaf_arr)),landmark_num,dim_num) ) # empty 3D array: # samples, landmarks, coord vals

        for i in range(len(leaf_arr)): # for each leaf shape 

            s1, s2, distance = procrustes(old_mean, leaf_arr[i]) # calculate procrustes adjusted shape to ref for current leaf
            arr[i] = s2 # store procrustes adjusted shape to array

        new_mean = np.mean(arr, axis=(0)) # calculate mean of all shapes adjusted to reference

        s1, s2, d = procrustes(old_mean, new_mean) # calculate procrustes distance of new mean to old mean

        old_mean = new_mean # set the old_mean to the new_mea before beginning another iteration

    return new_mean

def polygon_perimeter(vertices):
    # Ensure the polygon is closed: append the first point to the end
    closed_vertices = np.vstack([vertices, vertices[0]])
    # Compute pairwise distances
    diffs = np.diff(closed_vertices, axis=0)
    segment_lengths = np.linalg.norm(diffs, axis=1)
    return segment_lengths.sum()

# %% [markdown]
# # Read in data

# %% [markdown]
# Notes:
#
# Column names:
# `file` (not file_name)
# `include` (not shape_leaf)
# some `node` values are `r`, they need to be excluded

# %%
########################
### READ IN METADATA ###
########################

mdata = pd.read_csv("./metadata_v4.csv") # read in csv

mdata.head() # head data to check

# drop any row with NaN
mdata = mdata.dropna().reset_index(drop=True)

# drop rows with "r" for node value
mdata = mdata[mdata['node'] != "r"].reset_index(drop=True)

# replace species mis-spellings
mdata['species'] = mdata['species'].replace({'apalacnicolensis': 'apalachicolensis'}) 
mdata['species'] = mdata['species'].replace({'canybi': 'canbyi'}) 

# make sure variables are floats
mdata["node"] = mdata["node"].astype(float)
mdata["count"] = mdata["count"].astype(float)
mdata['px_cm'] = mdata['px_cm'].astype(float)

# %%
#######################################
### MAKE A LIST OF IMAGE FILE NAMES ###
#######################################

data_dir = "./binary_leaves_v3/" # set data directory

file_names = [f for f in listdir(data_dir) if isfile(join(data_dir, f))] # create a list of file names

file_names.remove('.DS_Store') # remove .DS_Store file

file_names.sort() # sort the list of file names

file_names # check list of file names
# Out:
# ['LAMOEWC23246-1_10_13.tif',
#  'LAMOEWC23246-1_11_13.tif',
#  'LAMOEWC23246-1_12_13.tif',
#  'LAMOEWC23246-1_13_13.tif',
#  'LAMOEWC23246-1_1_13.tif',
#  'LAMOEWC23246-1_2_13.tif',
#  'LAMOEWC23246-1_3_13.tif',
#  'LAMOEWC23246-1_4_13.tif',
#  'LAMOEWC23246-1_5_13.tif',
#  'LAMOEWC23246-1_6_13.tif',
#  'LAMOEWC23246-1_7_13.tif',
#  'LAMOEWC23246-1_8_13.tif',
#  'LAMOEWC23246-1_9_13.tif',
#  'LAMOEWC23246-2_1_5.tif',
#  'LAMOEWC23246-2_2_5.tif',
#  'LAMOEWC23246-2_3_5.tif',
#  'LAMOEWC23246-2_4_5.tif',
#  'LAMOEWC23246-2_5_5.tif',
#  'LAPALBS17132-1_10_28.tif',
#  'LAPALBS17132-1_11_28.tif',
#  'LAPALBS17132-1_12_28.tif',
#  'LAPALBS17132-1_13_28.tif',
#  'LAPALBS17132-1_14_28.tif',
#  'LAPALBS17132-1_15_28.tif',
#  'LAPALBS17132-1_16_28.tif',
#  'LAPALBS17132-1_17_28.tif',
#  'LAPALBS17132-1_18_28.tif',
#  'LAPALBS17132-1_19_28.tif',
#  'LAPALBS17132-1_1_28.tif',
#  'LAPALBS17132-1_20_28.tif',
#  'LAPALBS17132-1_21_28.tif',
#  'LAPALBS17132-1_22_28.tif',
#  'LAPALBS17132-1_23_28.tif',
#  'LAPALBS17132-1_24_28.tif',
#  'LAPALBS17132-1_25_28.tif',
#  'LAPALBS17132-1_26_28.tif',
#  'LAPALBS17132-1_27_28.tif',
#  'LAPALBS17132-1_28_28.tif',
#  'LAPALBS17132-1_2_28.tif',
#  'LAPALBS17132-1_3_28.tif',
#  'LAPALBS17132-1_4_28.tif',
#  'LAPALBS17132-1_5_28.tif',
#  'LAPALBS17132-1_6_28.tif',
#  'LAPALBS17132-1_7_28.tif',
#  'LAPALBS17132-1_8_28.tif',
#  'LAPALBS17132-1_9_28.tif',
#  'LAPALBS17133-1_10_25.tif',
#  'LAPALBS17133-1_11_25.tif',
#  'LAPALBS17133-1_12_25.tif',
#  'LAPALBS17133-1_13_25.tif',
#  'LAPALBS17133-1_14_25.tif',
#  'LAPALBS17133-1_15_25.tif',
#  'LAPALBS17133-1_16_25.tif',
#  'LAPALBS17133-1_17_25.tif',
#  'LAPALBS17133-1_18_25.tif',
#  'LAPALBS17133-1_19_25.tif',
#  'LAPALBS17133-1_1_25.tif',
#  'LAPALBS17133-1_20_25.tif',
#  'LAPALBS17133-1_21_25.tif',
#  'LAPALBS17133-1_22_25.tif',
#  'LAPALBS17133-1_23_25.tif',
#  'LAPALBS17133-1_24_25.tif',
#  'LAPALBS17133-1_25_25.tif',
#  'LAPALBS17133-1_2_25.tif',
#  'LAPALBS17133-1_3_25.tif',
#  'LAPALBS17133-1_4_25.tif',
#  'LAPALBS17133-1_5_25.tif',
#  'LAPALBS17133-1_6_25.tif',
#  'LAPALBS17133-1_7_25.tif',
#  'LAPALBS17133-1_8_25.tif',
#  'LAPALBS17133-1_9_25.tif',
#  'LAPALMJ21170-1_10_10.tif',
#  'LAPALMJ21170-1_1_10.tif',
#  'LAPALMJ21170-1_2_10.tif',
#  'LAPALMJ21170-1_3_10.tif',
#  'LAPALMJ21170-1_4_10.tif',
#  'LAPALMJ21170-1_5_10.tif',
#  'LAPALMJ21170-1_6_10.tif',
#  'LAPALMJ21170-1_7_10.tif',
#  'LAPALMJ21170-1_8_10.tif',
#  'LAPALMJ21170-1_9_10.tif',
#  'LAPPEAC21008-1_1_5.tif',
#  'LAPPEAC21008-1_2_5.tif',
#  'LAPPEAC21008-1_3_5.tif',
#  'LAPPEAC21008-1_4_5.tif',
#  'LAPPEAC21008-1_5_5.tif',
#  'LAPPEAC21008-2_10_13.tif',
#  'LAPPEAC21008-2_11_13.tif',
#  'LAPPEAC21008-2_12_13.tif',
#  'LAPPEAC21008-2_13_13.tif',
#  'LAPPEAC21008-2_1_13.tif',
#  'LAPPEAC21008-2_2_13.tif',
#  'LAPPEAC21008-2_3_13.tif',
#  'LAPPEAC21008-2_4_13.tif',
#  'LAPPEAC21008-2_5_13.tif',
#  'LAPPEAC21008-2_6_13.tif',
#  'LAPPEAC21008-2_7_13.tif',
#  'LAPPEAC21008-2_8_13.tif',
#  'LAPPEAC21008-2_9_13.tif',
#  'LAPPEAC21008-3_1_8.tif',
#  'LAPPEAC21008-3_2_8.tif',
#  'LAPPEAC21008-3_3_8.tif',
#  'LAPPEAC21008-3_4_8.tif',
#  'LAPPEAC21008-3_5_8.tif',
#  'LAPPEAC21008-3_6_8.tif',
#  'LAPPEAC21008-3_7_8.tif',
#  'LAPPEAC21008-3_8_8.tif',
#  'LAPPEAC21010-1_1_3.tif',
#  'LAPPEAC21010-1_2_3.tif',
#  'LAPPEAC21010-1_3_3.tif',
#  'LAPPEAC21010-2_10_15.tif',
#  'LAPPEAC21010-2_11_15.tif',
#  'LAPPEAC21010-2_12_15.tif',
#  'LAPPEAC21010-2_13_15.tif',
#  'LAPPEAC21010-2_14_15.tif',
#  'LAPPEAC21010-2_15_15.tif',
#  'LAPPEAC21010-2_1_15.tif',
#  'LAPPEAC21010-2_2_15.tif',
#  'LAPPEAC21010-2_3_15.tif',
#  'LAPPEAC21010-2_4_15.tif',
#  'LAPPEAC21010-2_5_15.tif',
#  'LAPPEAC21010-2_6_15.tif',
#  'LAPPEAC21010-2_7_15.tif',
#  'LAPPEAC21010-2_8_15.tif',
#  'LAPPEAC21010-2_9_15.tif',
#  'LAPPEAC21010-3_10_16.tif',
#  'LAPPEAC21010-3_11_16.tif',
#  'LAPPEAC21010-3_12_16.tif',
#  'LAPPEAC21010-3_13_16.tif',
#  'LAPPEAC21010-3_14_16.tif',
#  'LAPPEAC21010-3_15_16.tif',
#  'LAPPEAC21010-3_16_16.tif',
#  'LAPPEAC21010-3_1_16.tif',
#  'LAPPEAC21010-3_2_16.tif',
#  'LAPPEAC21010-3_3_16.tif',
#  'LAPPEAC21010-3_4_16.tif',
#  'LAPPEAC21010-3_5_16.tif',
#  'LAPPEAC21010-3_6_16.tif',
#  'LAPPEAC21010-3_7_16.tif',
#  'LAPPEAC21010-3_8_16.tif',
#  'LAPPEAC21010-3_9_16.tif',
#  'LAPPEAC21010-4_1_7.tif',
#  'LAPPEAC21010-4_2_7.tif',
#  'LAPPEAC21010-4_3_7.tif',
#  'LAPPEAC21010-4_4_7.tif',
#  'LAPPEAC21010-4_5_7.tif',
#  'LAPPEAC21010-4_6_7.tif',
#  'LAPPEAC21010-4_7_7.tif',
#  'LAPPEAC21010-5_1_8.tif',
#  'LAPPEAC21010-5_2_8.tif',
#  'LAPPEAC21010-5_3_8.tif',
#  'LAPPEAC21010-5_4_8.tif',
#  'LAPPEAC21010-5_5_8.tif',
#  'LAPPEAC21010-5_6_8.tif',
#  'LAPPEAC21010-5_7_8.tif',
#  'LAPPEAC21010-5_8_8.tif',
#  'LAPPEAC21010-6_1_6.tif',
#  'LAPPEAC21010-6_2_6.tif',
#  'LAPPEAC21010-6_3_6.tif',
#  'LAPPEAC21010-6_4_6.tif',
#  'LAPPEAC21010-6_5_6.tif',
#  'LAPPEAC21010-6_6_6.tif',
#  'LAPPEAC21010-8_10_17.tif',
#  'LAPPEAC21010-8_11_17.tif',
#  'LAPPEAC21010-8_12_17.tif',
#  'LAPPEAC21010-8_13_17.tif',
#  'LAPPEAC21010-8_14_17.tif',
#  'LAPPEAC21010-8_15_17.tif',
#  'LAPPEAC21010-8_16_17.tif',
#  'LAPPEAC21010-8_17_17.tif',
#  'LAPPEAC21010-8_1_17.tif',
#  'LAPPEAC21010-8_2_17.tif',
#  'LAPPEAC21010-8_3_17.tif',
#  'LAPPEAC21010-8_4_17.tif',
#  'LAPPEAC21010-8_5_17.tif',
#  'LAPPEAC21010-8_6_17.tif',
#  'LAPPEAC21010-8_7_17.tif',
#  'LAPPEAC21010-8_8_17.tif',
#  'LAPPEAC21010-8_9_17.tif',
#  'LBATSPA21164-1_10_42.tif',
#  'LBATSPA21164-1_11_42.tif',
#  'LBATSPA21164-1_12_42.tif',
#  'LBATSPA21164-1_13_42.tif',
#  'LBATSPA21164-1_14_42.tif',
#  'LBATSPA21164-1_15_42.tif',
#  'LBATSPA21164-1_16_42.tif',
#  'LBATSPA21164-1_17_42.tif',
#  'LBATSPA21164-1_18_42.tif',
#  'LBATSPA21164-1_19_42.tif',
#  'LBATSPA21164-1_1_42.tif',
#  'LBATSPA21164-1_20_42.tif',
#  'LBATSPA21164-1_21_42.tif',
#  'LBATSPA21164-1_22_42.tif',
#  'LBATSPA21164-1_23_42.tif',
#  'LBATSPA21164-1_24_42.tif',
#  'LBATSPA21164-1_25_42.tif',
#  'LBATSPA21164-1_26_42.tif',
#  'LBATSPA21164-1_27_42.tif',
#  'LBATSPA21164-1_28_42.tif',
#  'LBATSPA21164-1_29_42.tif',
#  'LBATSPA21164-1_2_42.tif',
#  'LBATSPA21164-1_30_42.tif',
#  'LBATSPA21164-1_31_42.tif',
#  'LBATSPA21164-1_32_42.tif',
#  'LBATSPA21164-1_33_42.tif',
#  'LBATSPA21164-1_34_42.tif',
#  'LBATSPA21164-1_35_42.tif',
#  'LBATSPA21164-1_36_42.tif',
#  'LBATSPA21164-1_37_42.tif',
#  'LBATSPA21164-1_38_42.tif',
#  'LBATSPA21164-1_39_42.tif',
#  'LBATSPA21164-1_3_42.tif',
#  'LBATSPA21164-1_40_42.tif',
#  'LBATSPA21164-1_41_42.tif',
#  'LBATSPA21164-1_42_42.tif',
#  'LBATSPA21164-1_4_42.tif',
#  'LBATSPA21164-1_5_42.tif',
#  'LBATSPA21164-1_6_42.tif',
#  'LBATSPA21164-1_7_42.tif',
#  'LBATSPA21164-1_8_42.tif',
#  'LBATSPA21164-1_9_42.tif',
#  'LBREVAC21171-1_10_89.tif',
#  'LBREVAC21171-1_11_89.tif',
#  'LBREVAC21171-1_12_89.tif',
#  'LBREVAC21171-1_13_89.tif',
#  'LBREVAC21171-1_14_89.tif',
#  'LBREVAC21171-1_15_89.tif',
#  'LBREVAC21171-1_16_89.tif',
#  'LBREVAC21171-1_17_89.tif',
#  'LBREVAC21171-1_18_89.tif',
#  'LBREVAC21171-1_19_89.tif',
#  'LBREVAC21171-1_1_89.tif',
#  'LBREVAC21171-1_20_89.tif',
#  'LBREVAC21171-1_21_89.tif',
#  'LBREVAC21171-1_22_89.tif',
#  'LBREVAC21171-1_23_89.tif',
#  'LBREVAC21171-1_24_89.tif',
#  'LBREVAC21171-1_25_89.tif',
#  'LBREVAC21171-1_26_89.tif',
#  'LBREVAC21171-1_27_89.tif',
#  'LBREVAC21171-1_28_89.tif',
#  'LBREVAC21171-1_29_89.tif',
#  'LBREVAC21171-1_2_89.tif',
#  'LBREVAC21171-1_30_89.tif',
#  'LBREVAC21171-1_31_89.tif',
#  'LBREVAC21171-1_32_89.tif',
#  'LBREVAC21171-1_33_89.tif',
#  'LBREVAC21171-1_34_89.tif',
#  'LBREVAC21171-1_35_89.tif',
#  'LBREVAC21171-1_36_89.tif',
#  'LBREVAC21171-1_37_89.tif',
#  'LBREVAC21171-1_38_89.tif',
#  'LBREVAC21171-1_39_89.tif',
#  'LBREVAC21171-1_3_89.tif',
#  'LBREVAC21171-1_40_89.tif',
#  'LBREVAC21171-1_41_89.tif',
#  'LBREVAC21171-1_42_89.tif',
#  'LBREVAC21171-1_43_89.tif',
#  'LBREVAC21171-1_44_89.tif',
#  'LBREVAC21171-1_45_89.tif',
#  'LBREVAC21171-1_46_89.tif',
#  'LBREVAC21171-1_47_89.tif',
#  'LBREVAC21171-1_48_89.tif',
#  'LBREVAC21171-1_49_89.tif',
#  'LBREVAC21171-1_4_89.tif',
#  'LBREVAC21171-1_50_89.tif',
#  'LBREVAC21171-1_51_89.tif',
#  'LBREVAC21171-1_52_89.tif',
#  'LBREVAC21171-1_53_89.tif',
#  'LBREVAC21171-1_54_89.tif',
#  'LBREVAC21171-1_55_89.tif',
#  'LBREVAC21171-1_56_89.tif',
#  'LBREVAC21171-1_57_89.tif',
#  'LBREVAC21171-1_58_89.tif',
#  'LBREVAC21171-1_59_89.tif',
#  'LBREVAC21171-1_5_89.tif',
#  'LBREVAC21171-1_60_89.tif',
#  'LBREVAC21171-1_61_89.tif',
#  'LBREVAC21171-1_62_89.tif',
#  'LBREVAC21171-1_63_89.tif',
#  'LBREVAC21171-1_64_89.tif',
#  'LBREVAC21171-1_65_89.tif',
#  'LBREVAC21171-1_66_89.tif',
#  'LBREVAC21171-1_67_89.tif',
#  'LBREVAC21171-1_68_89.tif',
#  'LBREVAC21171-1_69_89.tif',
#  'LBREVAC21171-1_6_89.tif',
#  'LBREVAC21171-1_70_89.tif',
#  'LBREVAC21171-1_71_89.tif',
#  'LBREVAC21171-1_72_89.tif',
#  'LBREVAC21171-1_73_89.tif',
#  'LBREVAC21171-1_74_89.tif',
#  'LBREVAC21171-1_75_89.tif',
#  'LBREVAC21171-1_76_89.tif',
#  'LBREVAC21171-1_77_89.tif',
#  'LBREVAC21171-1_78_89.tif',
#  'LBREVAC21171-1_79_89.tif',
#  'LBREVAC21171-1_7_89.tif',
#  'LBREVAC21171-1_80_89.tif',
#  'LBREVAC21171-1_81_89.tif',
#  'LBREVAC21171-1_82_89.tif',
#  'LBREVAC21171-1_83_89.tif',
#  'LBREVAC21171-1_84_89.tif',
#  'LBREVAC21171-1_85_89.tif',
#  'LBREVAC21171-1_86_89.tif',
#  'LBREVAC21171-1_87_89.tif',
#  'LBREVAC21171-1_88_89.tif',
#  'LBREVAC21171-1_89_89.tif',
#  'LBREVAC21171-1_8_89.tif',
#  'LBREVAC21171-1_9_89.tif',
#  'LBREVBS17075-2A_10_37.tif',
#  'LBREVBS17075-2A_11_37.tif',
#  'LBREVBS17075-2A_12_37.tif',
#  'LBREVBS17075-2A_13_37.tif',
#  'LBREVBS17075-2A_14_37.tif',
#  'LBREVBS17075-2A_15_37.tif',
#  'LBREVBS17075-2A_16_37.tif',
#  'LBREVBS17075-2A_17_37.tif',
#  'LBREVBS17075-2A_18_37.tif',
#  'LBREVBS17075-2A_19_37.tif',
#  'LBREVBS17075-2A_1_37.tif',
#  'LBREVBS17075-2A_20_37.tif',
#  'LBREVBS17075-2A_21_37.tif',
#  'LBREVBS17075-2A_22_37.tif',
#  'LBREVBS17075-2A_23_37.tif',
#  'LBREVBS17075-2A_24_37.tif',
#  'LBREVBS17075-2A_25_37.tif',
#  'LBREVBS17075-2A_26_37.tif',
#  'LBREVBS17075-2A_27_37.tif',
#  'LBREVBS17075-2A_28_37.tif',
#  'LBREVBS17075-2A_29_37.tif',
#  'LBREVBS17075-2A_2_37.tif',
#  'LBREVBS17075-2A_30_37.tif',
#  'LBREVBS17075-2A_31_37.tif',
#  'LBREVBS17075-2A_32_37.tif',
#  'LBREVBS17075-2A_33_37.tif',
#  'LBREVBS17075-2A_34_37.tif',
#  'LBREVBS17075-2A_35_37.tif',
#  'LBREVBS17075-2A_36_37.tif',
#  'LBREVBS17075-2A_37_37.tif',
#  'LBREVBS17075-2A_3_37.tif',
#  'LBREVBS17075-2A_4_37.tif',
#  'LBREVBS17075-2A_5_37.tif',
#  'LBREVBS17075-2A_6_37.tif',
#  'LBREVBS17075-2A_7_37.tif',
#  'LBREVBS17075-2A_8_37.tif',
#  'LBREVBS17075-2A_9_37.tif',
#  'LCANBAC21060-1_1_6.tif',
#  'LCANBAC21060-1_2_6.tif',
#  'LCANBAC21060-1_3_6.tif',
#  'LCANBAC21060-1_4_6.tif',
#  'LCANBAC21060-1_5_6.tif',
#  'LCANBAC21060-1_6_6.tif',
#  'LCANBGG21059-1_10_45.tif',
#  'LCANBGG21059-1_11_45.tif',
#  'LCANBGG21059-1_12_45.tif',
#  'LCANBGG21059-1_13_45.tif',
#  'LCANBGG21059-1_14_45.tif',
#  'LCANBGG21059-1_15_45.tif',
#  'LCANBGG21059-1_16_45.tif',
#  'LCANBGG21059-1_17_45.tif',
#  'LCANBGG21059-1_18_45.tif',
#  'LCANBGG21059-1_19_45.tif',
#  'LCANBGG21059-1_1_45.tif',
#  'LCANBGG21059-1_20_45.tif',
#  'LCANBGG21059-1_21_45.tif',
#  'LCANBGG21059-1_22_45.tif',
#  'LCANBGG21059-1_23_45.tif',
#  'LCANBGG21059-1_24_45.tif',
#  'LCANBGG21059-1_25_45.tif',
#  'LCANBGG21059-1_26_45.tif',
#  'LCANBGG21059-1_27_45.tif',
#  'LCANBGG21059-1_28_45.tif',
#  'LCANBGG21059-1_29_45.tif',
#  'LCANBGG21059-1_2_45.tif',
#  'LCANBGG21059-1_30_45.tif',
#  'LCANBGG21059-1_31_45.tif',
#  'LCANBGG21059-1_32_45.tif',
#  'LCANBGG21059-1_33_45.tif',
#  'LCANBGG21059-1_34_45.tif',
#  'LCANBGG21059-1_35_45.tif',
#  'LCANBGG21059-1_36_45.tif',
#  'LCANBGG21059-1_37_45.tif',
#  'LCANBGG21059-1_38_45.tif',
#  'LCANBGG21059-1_39_45.tif',
#  'LCANBGG21059-1_3_45.tif',
#  'LCANBGG21059-1_40_45.tif',
#  'LCANBGG21059-1_41_45.tif',
#  'LCANBGG21059-1_42_45.tif',
#  'LCANBGG21059-1_43_45.tif',
#  'LCANBGG21059-1_44_45.tif',
#  'LCANBGG21059-1_45_45.tif',
#  'LCANBGG21059-1_4_45.tif',
#  'LCANBGG21059-1_5_45.tif',
#  'LCANBGG21059-1_6_45.tif',
#  'LCANBGG21059-1_7_45.tif',
#  'LCANBGG21059-1_8_45.tif',
#  'LCANBGG21059-1_9_45.tif',
#  'LCANBGG21059-3_10_18.tif',
#  'LCANBGG21059-3_11_18.tif',
#  'LCANBGG21059-3_12_18.tif',
#  'LCANBGG21059-3_13_18.tif',
#  'LCANBGG21059-3_14_18.tif',
#  'LCANBGG21059-3_15_18.tif',
#  'LCANBGG21059-3_16_18.tif',
#  'LCANBGG21059-3_17_18.tif',
#  'LCANBGG21059-3_18_18.tif',
#  'LCANBGG21059-3_1_18.tif',
#  'LCANBGG21059-3_2_18.tif',
#  'LCANBGG21059-3_3_18.tif',
#  'LCANBGG21059-3_4_18.tif',
#  'LCANBGG21059-3_5_18.tif',
#  'LCANBGG21059-3_6_18.tif',
#  'LCANBGG21059-3_7_18.tif',
#  'LCANBGG21059-3_8_18.tif',
#  'LCANBGG21059-3_9_18.tif',
#  'LCARDAC23254-1_10_23.tif',
#  'LCARDAC23254-1_11_23.tif',
#  'LCARDAC23254-1_12_23.tif',
#  'LCARDAC23254-1_13_23.tif',
#  'LCARDAC23254-1_14_23.tif',
#  'LCARDAC23254-1_15_23.tif',
#  'LCARDAC23254-1_16_23.tif',
#  'LCARDAC23254-1_17_23.tif',
#  'LCARDAC23254-1_18_23.tif',
#  'LCARDAC23254-1_19_23.tif',
#  'LCARDAC23254-1_1_23.tif',
#  'LCARDAC23254-1_20_23.tif',
#  'LCARDAC23254-1_21_23.tif',
#  'LCARDAC23254-1_22_23.tif',
#  'LCARDAC23254-1_23_23.tif',
#  'LCARDAC23254-1_2_23.tif',
#  'LCARDAC23254-1_3_23.tif',
#  'LCARDAC23254-1_4_23.tif',
#  'LCARDAC23254-1_5_23.tif',
#  'LCARDAC23254-1_6_23.tif',
#  'LCARDAC23254-1_7_23.tif',
#  'LCARDAC23254-1_8_23.tif',
#  'LCARDAC23254-1_9_23.tif',
#  'LCARDAC23254-2_10_29.tif',
#  'LCARDAC23254-2_11_29.tif',
#  'LCARDAC23254-2_12_29.tif',
#  'LCARDAC23254-2_13_29.tif',
#  'LCARDAC23254-2_14_29.tif',
#  'LCARDAC23254-2_15_29.tif',
#  'LCARDAC23254-2_16_29.tif',
#  'LCARDAC23254-2_17_29.tif',
#  'LCARDAC23254-2_18_29.tif',
#  'LCARDAC23254-2_19_29.tif',
#  'LCARDAC23254-2_1_29.tif',
#  'LCARDAC23254-2_20_29.tif',
#  'LCARDAC23254-2_21_29.tif',
#  'LCARDAC23254-2_22_29.tif',
#  'LCARDAC23254-2_23_29.tif',
#  'LCARDAC23254-2_24_29.tif',
#  'LCARDAC23254-2_25_29.tif',
#  'LCARDAC23254-2_26_29.tif',
#  'LCARDAC23254-2_27_29.tif',
#  'LCARDAC23254-2_28_29.tif',
#  'LCARDAC23254-2_29_29.tif',
#  'LCARDAC23254-2_2_29.tif',
#  'LCARDAC23254-2_3_29.tif',
#  'LCARDAC23254-2_4_29.tif',
#  'LCARDAC23254-2_5_29.tif',
#  'LCARDAC23254-2_6_29.tif',
#  'LCARDAC23254-2_7_29.tif',
#  'LCARDAC23254-2_8_29.tif',
#  'LCARDAC23254-2_9_29.tif',
#  'LCARDBS17083-4_10_17.tif',
#  'LCARDBS17083-4_11_17.tif',
#  'LCARDBS17083-4_12_17.tif',
#  'LCARDBS17083-4_13_17.tif',
#  'LCARDBS17083-4_14_17.tif',
#  'LCARDBS17083-4_15_17.tif',
#  'LCARDBS17083-4_16_17.tif',
#  'LCARDBS17083-4_17_17.tif',
#  'LCARDBS17083-4_1_17.tif',
#  'LCARDBS17083-4_2_17.tif',
#  'LCARDBS17083-4_3_17.tif',
#  'LCARDBS17083-4_4_17.tif',
#  'LCARDBS17083-4_5_17.tif',
#  'LCARDBS17083-4_6_17.tif',
#  'LCARDBS17083-4_7_17.tif',
#  'LCARDBS17083-4_8_17.tif',
#  'LCARDBS17083-4_9_17.tif',
#  'LCARDPA23225 (A-L)-1_10_48.tif',
#  'LCARDPA23225 (A-L)-1_11_48.tif',
#  'LCARDPA23225 (A-L)-1_12_48.tif',
#  'LCARDPA23225 (A-L)-1_13_48.tif',
#  'LCARDPA23225 (A-L)-1_14_48.tif',
#  'LCARDPA23225 (A-L)-1_15_48.tif',
#  'LCARDPA23225 (A-L)-1_16_48.tif',
#  'LCARDPA23225 (A-L)-1_17_48.tif',
#  'LCARDPA23225 (A-L)-1_18_48.tif',
#  'LCARDPA23225 (A-L)-1_19_48.tif',
#  'LCARDPA23225 (A-L)-1_1_48.tif',
#  'LCARDPA23225 (A-L)-1_20_48.tif',
#  'LCARDPA23225 (A-L)-1_21_48.tif',
#  'LCARDPA23225 (A-L)-1_22_48.tif',
#  'LCARDPA23225 (A-L)-1_23_48.tif',
#  'LCARDPA23225 (A-L)-1_24_48.tif',
#  'LCARDPA23225 (A-L)-1_25_48.tif',
#  'LCARDPA23225 (A-L)-1_26_48.tif',
#  'LCARDPA23225 (A-L)-1_27_48.tif',
#  'LCARDPA23225 (A-L)-1_28_48.tif',
#  'LCARDPA23225 (A-L)-1_29_48.tif',
#  'LCARDPA23225 (A-L)-1_2_48.tif',
#  'LCARDPA23225 (A-L)-1_30_48.tif',
#  'LCARDPA23225 (A-L)-1_31_48.tif',
#  'LCARDPA23225 (A-L)-1_32_48.tif',
#  'LCARDPA23225 (A-L)-1_33_48.tif',
#  'LCARDPA23225 (A-L)-1_34_48.tif',
#  'LCARDPA23225 (A-L)-1_35_48.tif',
#  'LCARDPA23225 (A-L)-1_36_48.tif',
#  'LCARDPA23225 (A-L)-1_37_48.tif',
#  'LCARDPA23225 (A-L)-1_38_48.tif',
#  'LCARDPA23225 (A-L)-1_39_48.tif',
#  'LCARDPA23225 (A-L)-1_3_48.tif',
#  'LCARDPA23225 (A-L)-1_40_48.tif',
#  'LCARDPA23225 (A-L)-1_41_48.tif',
#  'LCARDPA23225 (A-L)-1_42_48.tif',
#  'LCARDPA23225 (A-L)-1_43_48.tif',
#  'LCARDPA23225 (A-L)-1_44_48.tif',
#  'LCARDPA23225 (A-L)-1_45_48.tif',
#  'LCARDPA23225 (A-L)-1_46_48.tif',
#  'LCARDPA23225 (A-L)-1_47_48.tif',
#  'LCARDPA23225 (A-L)-1_48_48.tif',
#  'LCARDPA23225 (A-L)-1_4_48.tif',
#  'LCARDPA23225 (A-L)-1_5_48.tif',
#  'LCARDPA23225 (A-L)-1_6_48.tif',
#  'LCARDPA23225 (A-L)-1_7_48.tif',
#  'LCARDPA23225 (A-L)-1_8_48.tif',
#  'LCARDPA23225 (A-L)-1_9_48.tif',
#  'LCARDPA23225 (A-L)-2_10_23.tif',
#  'LCARDPA23225 (A-L)-2_11_23.tif',
#  'LCARDPA23225 (A-L)-2_12_23.tif',
#  'LCARDPA23225 (A-L)-2_13_23.tif',
#  'LCARDPA23225 (A-L)-2_14_23.tif',
#  'LCARDPA23225 (A-L)-2_15_23.tif',
#  'LCARDPA23225 (A-L)-2_16_23.tif',
#  'LCARDPA23225 (A-L)-2_17_23.tif',
#  'LCARDPA23225 (A-L)-2_18_23.tif',
#  'LCARDPA23225 (A-L)-2_19_23.tif',
#  'LCARDPA23225 (A-L)-2_1_23.tif',
#  'LCARDPA23225 (A-L)-2_20_23.tif',
#  'LCARDPA23225 (A-L)-2_21_23.tif',
#  'LCARDPA23225 (A-L)-2_22_23.tif',
#  'LCARDPA23225 (A-L)-2_23_23.tif',
#  'LCARDPA23225 (A-L)-2_2_23.tif',
#  'LCARDPA23225 (A-L)-2_3_23.tif',
#  'LCARDPA23225 (A-L)-2_4_23.tif',
#  'LCARDPA23225 (A-L)-2_5_23.tif',
#  'LCARDPA23225 (A-L)-2_6_23.tif',
#  'LCARDPA23225 (A-L)-2_7_23.tif',
#  'LCARDPA23225 (A-L)-2_8_23.tif',
#  'LCARDPA23225 (A-L)-2_9_23.tif',
#  'LCARDPA23225 (A-L)-3_10_45.tif',
#  'LCARDPA23225 (A-L)-3_11_45.tif',
#  'LCARDPA23225 (A-L)-3_12_45.tif',
#  'LCARDPA23225 (A-L)-3_13_45.tif',
#  'LCARDPA23225 (A-L)-3_14_45.tif',
#  'LCARDPA23225 (A-L)-3_15_45.tif',
#  'LCARDPA23225 (A-L)-3_16_45.tif',
#  'LCARDPA23225 (A-L)-3_17_45.tif',
#  'LCARDPA23225 (A-L)-3_18_45.tif',
#  'LCARDPA23225 (A-L)-3_19_45.tif',
#  'LCARDPA23225 (A-L)-3_1_45.tif',
#  'LCARDPA23225 (A-L)-3_20_45.tif',
#  'LCARDPA23225 (A-L)-3_21_45.tif',
#  'LCARDPA23225 (A-L)-3_22_45.tif',
#  'LCARDPA23225 (A-L)-3_23_45.tif',
#  'LCARDPA23225 (A-L)-3_24_45.tif',
#  'LCARDPA23225 (A-L)-3_25_45.tif',
#  'LCARDPA23225 (A-L)-3_26_45.tif',
#  'LCARDPA23225 (A-L)-3_27_45.tif',
#  'LCARDPA23225 (A-L)-3_28_45.tif',
#  'LCARDPA23225 (A-L)-3_29_45.tif',
#  'LCARDPA23225 (A-L)-3_2_45.tif',
#  'LCARDPA23225 (A-L)-3_30_45.tif',
#  'LCARDPA23225 (A-L)-3_31_45.tif',
#  'LCARDPA23225 (A-L)-3_32_45.tif',
#  'LCARDPA23225 (A-L)-3_33_45.tif',
#  'LCARDPA23225 (A-L)-3_34_45.tif',
#  'LCARDPA23225 (A-L)-3_35_45.tif',
#  'LCARDPA23225 (A-L)-3_36_45.tif',
#  'LCARDPA23225 (A-L)-3_37_45.tif',
#  'LCARDPA23225 (A-L)-3_38_45.tif',
#  'LCARDPA23225 (A-L)-3_39_45.tif',
#  'LCARDPA23225 (A-L)-3_3_45.tif',
#  'LCARDPA23225 (A-L)-3_40_45.tif',
#  'LCARDPA23225 (A-L)-3_41_45.tif',
#  'LCARDPA23225 (A-L)-3_42_45.tif',
#  'LCARDPA23225 (A-L)-3_43_45.tif',
#  'LCARDPA23225 (A-L)-3_44_45.tif',
#  'LCARDPA23225 (A-L)-3_45_45.tif',
#  'LCARDPA23225 (A-L)-3_4_45.tif',
#  'LCARDPA23225 (A-L)-3_5_45.tif',
#  'LCARDPA23225 (A-L)-3_6_45.tif',
#  'LCARDPA23225 (A-L)-3_7_45.tif',
#  'LCARDPA23225 (A-L)-3_8_45.tif',
#  'LCARDPA23225 (A-L)-3_9_45.tif',
#  'LCARDPA23225 (A-R)-1_10_19.tif',
#  'LCARDPA23225 (A-R)-1_11_19.tif',
#  'LCARDPA23225 (A-R)-1_12_19.tif',
#  'LCARDPA23225 (A-R)-1_13_19.tif',
#  'LCARDPA23225 (A-R)-1_14_19.tif',
#  'LCARDPA23225 (A-R)-1_15_19.tif',
#  'LCARDPA23225 (A-R)-1_16_19.tif',
#  'LCARDPA23225 (A-R)-1_17_19.tif',
#  'LCARDPA23225 (A-R)-1_18_19.tif',
#  'LCARDPA23225 (A-R)-1_19_19.tif',
#  'LCARDPA23225 (A-R)-1_1_19.tif',
#  'LCARDPA23225 (A-R)-1_2_19.tif',
#  'LCARDPA23225 (A-R)-1_3_19.tif',
#  'LCARDPA23225 (A-R)-1_4_19.tif',
#  'LCARDPA23225 (A-R)-1_5_19.tif',
#  'LCARDPA23225 (A-R)-1_6_19.tif',
#  'LCARDPA23225 (A-R)-1_7_19.tif',
#  'LCARDPA23225 (A-R)-1_8_19.tif',
#  'LCARDPA23225 (A-R)-1_9_19.tif',
#  'LCARDPA23225 (S)-1_10_16.tif',
#  'LCARDPA23225 (S)-1_11_16.tif',
#  'LCARDPA23225 (S)-1_12_16.tif',
#  'LCARDPA23225 (S)-1_13_16.tif',
#  'LCARDPA23225 (S)-1_14_16.tif',
#  'LCARDPA23225 (S)-1_15_16.tif',
#  'LCARDPA23225 (S)-1_16_16.tif',
#  'LCARDPA23225 (S)-1_1_16.tif',
#  'LCARDPA23225 (S)-1_2_16.tif',
#  'LCARDPA23225 (S)-1_3_16.tif',
#  'LCARDPA23225 (S)-1_4_16.tif',
#  'LCARDPA23225 (S)-1_5_16.tif',
#  'LCARDPA23225 (S)-1_6_16.tif',
#  'LCARDPA23225 (S)-1_7_16.tif',
#  'LCARDPA23225 (S)-1_8_16.tif',
#  'LCARDPA23225 (S)-1_9_16.tif',
#  'LCARDST17131-1_1_3.tif',
#  'LCARDST17131-1_2_3.tif',
#  'LCARDST17131-1_3_3.tif',
#  'LDORTCB21050-1_10_33.tif',
#  'LDORTCB21050-1_11_33.tif',
#  'LDORTCB21050-1_12_33.tif',
#  'LDORTCB21050-1_13_33.tif',
#  'LDORTCB21050-1_14_33.tif',
#  'LDORTCB21050-1_15_33.tif',
#  'LDORTCB21050-1_16_33.tif',
#  'LDORTCB21050-1_17_33.tif',
#  'LDORTCB21050-1_18_33.tif',
#  'LDORTCB21050-1_19_33.tif',
#  'LDORTCB21050-1_1_33.tif',
#  'LDORTCB21050-1_20_33.tif',
#  'LDORTCB21050-1_21_33.tif',
#  'LDORTCB21050-1_22_33.tif',
#  'LDORTCB21050-1_23_33.tif',
#  'LDORTCB21050-1_24_33.tif',
#  'LDORTCB21050-1_25_33.tif',
#  'LDORTCB21050-1_26_33.tif',
#  'LDORTCB21050-1_27_33.tif',
#  'LDORTCB21050-1_28_33.tif',
#  'LDORTCB21050-1_29_33.tif',
#  'LDORTCB21050-1_2_33.tif',
#  'LDORTCB21050-1_30_33.tif',
#  'LDORTCB21050-1_31_33.tif',
#  'LDORTCB21050-1_32_33.tif',
#  'LDORTCB21050-1_33_33.tif',
#  'LDORTCB21050-1_3_33.tif',
#  'LDORTCB21050-1_4_33.tif',
#  'LDORTCB21050-1_5_33.tif',
#  'LDORTCB21050-1_6_33.tif',
#  'LDORTCB21050-1_7_33.tif',
#  'LDORTCB21050-1_8_33.tif',
#  'LDORTCB21050-1_9_33.tif',
#  'LDORTCB21050-2_10_20.tif',
#  'LDORTCB21050-2_11_20.tif',
#  'LDORTCB21050-2_12_20.tif',
#  'LDORTCB21050-2_13_20.tif',
#  'LDORTCB21050-2_14_20.tif',
#  'LDORTCB21050-2_15_20.tif',
#  'LDORTCB21050-2_16_20.tif',
#  'LDORTCB21050-2_17_20.tif',
#  'LDORTCB21050-2_18_20.tif',
#  'LDORTCB21050-2_19_20.tif',
#  'LDORTCB21050-2_1_20.tif',
#  'LDORTCB21050-2_20_20.tif',
#  'LDORTCB21050-2_2_20.tif',
#  'LDORTCB21050-2_3_20.tif',
#  'LDORTCB21050-2_4_20.tif',
#  'LDORTCB21050-2_5_20.tif',
#  'LDORTCB21050-2_6_20.tif',
#  'LDORTCB21050-2_7_20.tif',
#  'LDORTCB21050-2_8_20.tif',
#  'LDORTCB21050-2_9_20.tif',
#  'LDORTCB21050-3_10_49.tif',
#  'LDORTCB21050-3_11_49.tif',
#  'LDORTCB21050-3_12_49.tif',
#  'LDORTCB21050-3_13_49.tif',
#  'LDORTCB21050-3_14_49.tif',
#  'LDORTCB21050-3_15_49.tif',
#  'LDORTCB21050-3_16_49.tif',
#  'LDORTCB21050-3_17_49.tif',
#  'LDORTCB21050-3_18_49.tif',
#  'LDORTCB21050-3_19_49.tif',
#  'LDORTCB21050-3_1_49.tif',
#  'LDORTCB21050-3_20_49.tif',
#  'LDORTCB21050-3_21_49.tif',
#  'LDORTCB21050-3_22_49.tif',
#  'LDORTCB21050-3_23_49.tif',
#  'LDORTCB21050-3_24_49.tif',
#  'LDORTCB21050-3_25_49.tif',
#  'LDORTCB21050-3_26_49.tif',
#  'LDORTCB21050-3_27_49.tif',
#  'LDORTCB21050-3_28_49.tif',
#  'LDORTCB21050-3_29_49.tif',
#  'LDORTCB21050-3_2_49.tif',
#  'LDORTCB21050-3_30_49.tif',
#  'LDORTCB21050-3_31_49.tif',
#  'LDORTCB21050-3_32_49.tif',
#  'LDORTCB21050-3_33_49.tif',
#  'LDORTCB21050-3_34_49.tif',
#  'LDORTCB21050-3_35_49.tif',
#  'LDORTCB21050-3_36_49.tif',
#  'LDORTCB21050-3_37_49.tif',
#  'LDORTCB21050-3_38_49.tif',
#  'LDORTCB21050-3_39_49.tif',
#  'LDORTCB21050-3_3_49.tif',
#  'LDORTCB21050-3_40_49.tif',
#  'LDORTCB21050-3_41_49.tif',
#  'LDORTCB21050-3_42_49.tif',
#  'LDORTCB21050-3_43_49.tif',
#  'LDORTCB21050-3_44_49.tif',
#  'LDORTCB21050-3_45_49.tif',
#  'LDORTCB21050-3_46_49.tif',
#  'LDORTCB21050-3_47_49.tif',
#  'LDORTCB21050-3_48_49.tif',
#  'LDORTCB21050-3_49_49.tif',
#  'LDORTCB21050-3_4_49.tif',
#  'LDORTCB21050-3_5_49.tif',
#  'LDORTCB21050-3_6_49.tif',
#  'LDORTCB21050-3_7_49.tif',
#  'LDORTCB21050-3_8_49.tif',
#  'LDORTCB21050-3_9_49.tif',
#  'LDORTCB21050-4_10_18.tif',
#  'LDORTCB21050-4_11_18.tif',
#  'LDORTCB21050-4_12_18.tif',
#  'LDORTCB21050-4_13_18.tif',
#  'LDORTCB21050-4_14_18.tif',
#  'LDORTCB21050-4_15_18.tif',
#  'LDORTCB21050-4_16_18.tif',
#  'LDORTCB21050-4_17_18.tif',
#  'LDORTCB21050-4_18_18.tif',
#  'LDORTCB21050-4_1_18.tif',
#  'LDORTCB21050-4_2_18.tif',
#  'LDORTCB21050-4_3_18.tif',
#  'LDORTCB21050-4_4_18.tif',
#  'LDORTCB21050-4_5_18.tif',
#  'LDORTCB21050-4_6_18.tif',
#  'LDORTCB21050-4_7_18.tif',
#  'LDORTCB21050-4_8_18.tif',
#  'LDORTCB21050-4_9_18.tif',
#  'LDORTCB21050-5_10_12.tif',
#  'LDORTCB21050-5_11_12.tif',
#  'LDORTCB21050-5_12_12.tif',
#  'LDORTCB21050-5_1_12.tif',
#  'LDORTCB21050-5_2_12.tif',
#  'LDORTCB21050-5_3_12.tif',
#  'LDORTCB21050-5_4_12.tif',
#  'LDORTCB21050-5_5_12.tif',
#  'LDORTCB21050-5_6_12.tif',
#  'LDORTCB21050-5_7_12.tif',
#  'LDORTCB21050-5_8_12.tif',
#  'LDORTCB21050-5_9_12.tif',
#  'LDORTCB21050-7_10_17.tif',
#  'LDORTCB21050-7_11_17.tif',
#  'LDORTCB21050-7_12_17.tif',
#  'LDORTCB21050-7_13_17.tif',
#  'LDORTCB21050-7_14_17.tif',
#  'LDORTCB21050-7_15_17.tif',
#  'LDORTCB21050-7_16_17.tif',
#  'LDORTCB21050-7_17_17.tif',
#  'LDORTCB21050-7_1_17.tif',
#  'LDORTCB21050-7_2_17.tif',
#  'LDORTCB21050-7_3_17.tif',
#  'LDORTCB21050-7_4_17.tif',
#  'LDORTCB21050-7_5_17.tif',
#  'LDORTCB21050-7_6_17.tif',
#  'LDORTCB21050-7_7_17.tif',
#  'LDORTCB21050-7_8_17.tif',
#  'LDORTCB21050-7_9_17.tif',
#  'LELONAC21058-2_10_10.tif',
#  'LELONAC21058-2_1_10.tif',
#  'LELONAC21058-2_2_10.tif',
#  'LELONAC21058-2_3_10.tif',
#  'LELONAC21058-2_4_10.tif',
#  'LELONAC21058-2_5_10.tif',
#  'LELONAC21058-2_6_10.tif',
#  'LELONAC21058-2_7_10.tif',
#  'LELONAC21058-2_8_10.tif',
#  'LELONAC21058-2_9_10.tif',
#  'LELONAC21058-3_10_21.tif',
#  'LELONAC21058-3_11_21.tif',
#  'LELONAC21058-3_12_21.tif',
#  'LELONAC21058-3_13_21.tif',
#  'LELONAC21058-3_14_21.tif',
#  'LELONAC21058-3_15_21.tif',
#  'LELONAC21058-3_16_21.tif',
#  'LELONAC21058-3_17_21.tif',
#  'LELONAC21058-3_18_21.tif',
#  'LELONAC21058-3_19_21.tif',
#  'LELONAC21058-3_1_21.tif',
#  'LELONAC21058-3_20_21.tif',
#  'LELONAC21058-3_21_21.tif',
#  'LELONAC21058-3_2_21.tif',
#  'LELONAC21058-3_3_21.tif',
#  'LELONAC21058-3_4_21.tif',
#  'LELONAC21058-3_5_21.tif',
#  'LELONAC21058-3_6_21.tif',
#  'LELONAC21058-3_7_21.tif',
#  'LELONAC21058-3_8_21.tif',
#  'LELONAC21058-3_9_21.tif',
#  'LELONAC21058-4_10_13.tif',
#  'LELONAC21058-4_11_13.tif',
#  'LELONAC21058-4_12_13.tif',
#  'LELONAC21058-4_13_13.tif',
#  'LELONAC21058-4_1_13.tif',
#  'LELONAC21058-4_2_13.tif',
#  'LELONAC21058-4_3_13.tif',
#  'LELONAC21058-4_4_13.tif',
#  'LELONAC21058-4_5_13.tif',
#  'LELONAC21058-4_6_13.tif',
#  'LELONAC21058-4_7_13.tif',
#  'LELONAC21058-4_8_13.tif',
#  'LELONAC21058-4_9_13.tif',
#  'LELONAC21060-1_10_13.tif',
#  'LELONAC21060-1_11_13.tif',
#  'LELONAC21060-1_12_13.tif',
#  'LELONAC21060-1_13_13.tif',
#  'LELONAC21060-1_1_13.tif',
#  'LELONAC21060-1_2_13.tif',
#  'LELONAC21060-1_3_13.tif',
#  'LELONAC21060-1_4_13.tif',
#  'LELONAC21060-1_5_13.tif',
#  'LELONAC21060-1_6_13.tif',
#  'LELONAC21060-1_7_13.tif',
#  'LELONAC21060-1_8_13.tif',
#  'LELONAC21060-1_9_13.tif',
#  'LELONAC21060-3_10_17.tif',
#  'LELONAC21060-3_11_17.tif',
#  'LELONAC21060-3_12_17.tif',
#  'LELONAC21060-3_13_17.tif',
#  'LELONAC21060-3_14_17.tif',
#  'LELONAC21060-3_15_17.tif',
#  'LELONAC21060-3_16_17.tif',
#  'LELONAC21060-3_17_17.tif',
#  'LELONAC21060-3_1_17.tif',
#  'LELONAC21060-3_2_17.tif',
#  'LELONAC21060-3_3_17.tif',
#  'LELONAC21060-3_4_17.tif',
#  'LELONAC21060-3_5_17.tif',
#  'LELONAC21060-3_6_17.tif',
#  'LELONAC21060-3_7_17.tif',
#  'LELONAC21060-3_8_17.tif',
#  'LELONAC21060-3_9_17.tif',
#  'LELONAC21060-4_10_14.tif',
#  'LELONAC21060-4_11_14.tif',
#  'LELONAC21060-4_12_14.tif',
#  'LELONAC21060-4_13_14.tif',
#  'LELONAC21060-4_14_14.tif',
#  'LELONAC21060-4_1_14.tif',
#  'LELONAC21060-4_2_14.tif',
#  'LELONAC21060-4_3_14.tif',
#  'LELONAC21060-4_4_14.tif',
#  'LELONAC21060-4_5_14.tif',
#  'LELONAC21060-4_6_14.tif',
#  'LELONAC21060-4_7_14.tif',
#  'LELONAC21060-4_8_14.tif',
#  'LELONAC21060-4_9_14.tif',
#  'LELONAC21060-5_10_20.tif',
#  'LELONAC21060-5_11_20.tif',
#  'LELONAC21060-5_12_20.tif',
#  'LELONAC21060-5_13_20.tif',
#  'LELONAC21060-5_14_20.tif',
#  'LELONAC21060-5_15_20.tif',
#  'LELONAC21060-5_16_20.tif',
#  'LELONAC21060-5_17_20.tif',
#  'LELONAC21060-5_18_20.tif',
#  'LELONAC21060-5_19_20.tif',
#  'LELONAC21060-5_1_20.tif',
#  'LELONAC21060-5_20_20.tif',
#  'LELONAC21060-5_2_20.tif',
#  'LELONAC21060-5_3_20.tif',
#  'LELONAC21060-5_4_20.tif',
#  'LELONAC21060-5_5_20.tif',
#  'LELONAC21060-5_6_20.tif',
#  'LELONAC21060-5_7_20.tif',
#  'LELONAC21060-5_8_20.tif',
#  'LELONAC21060-5_9_20.tif',
#  'LELONAC21060-6_10_13.tif',
#  'LELONAC21060-6_11_13.tif',
#  'LELONAC21060-6_12_13.tif',
#  'LELONAC21060-6_13_13.tif',
#  'LELONAC21060-6_1_13.tif',
#  'LELONAC21060-6_2_13.tif',
#  'LELONAC21060-6_3_13.tif',
#  'LELONAC21060-6_4_13.tif',
#  'LELONAC21060-6_5_13.tif',
#  'LELONAC21060-6_6_13.tif',
#  'LELONAC21060-6_7_13.tif',
#  'LELONAC21060-6_8_13.tif',
#  'LELONAC21060-6_9_13.tif',
#  'LELONAC21060-7_10_22.tif',
#  'LELONAC21060-7_11_22.tif',
#  'LELONAC21060-7_12_22.tif',
#  'LELONAC21060-7_13_22.tif',
#  'LELONAC21060-7_14_22.tif',
#  'LELONAC21060-7_15_22.tif',
#  'LELONAC21060-7_16_22.tif',
#  'LELONAC21060-7_17_22.tif',
#  'LELONAC21060-7_18_22.tif',
#  'LELONAC21060-7_19_22.tif',
#  'LELONAC21060-7_1_22.tif',
#  'LELONAC21060-7_20_22.tif',
#  'LELONAC21060-7_21_22.tif',
#  'LELONAC21060-7_22_22.tif',
#  'LELONAC21060-7_2_22.tif',
#  'LELONAC21060-7_3_22.tif',
#  'LELONAC21060-7_4_22.tif',
#  'LELONAC21060-7_5_22.tif',
#  'LELONAC21060-7_6_22.tif',
#  'LELONAC21060-7_7_22.tif',
#  'LELONAC21060-7_8_22.tif',
#  'LELONAC21060-7_9_22.tif',
#  'LELONAC21060-8_10_14.tif',
#  'LELONAC21060-8_11_14.tif',
#  'LELONAC21060-8_12_14.tif',
#  'LELONAC21060-8_13_14.tif',
#  'LELONAC21060-8_14_14.tif',
#  'LELONAC21060-8_1_14.tif',
#  'LELONAC21060-8_2_14.tif',
#  'LELONAC21060-8_3_14.tif',
#  'LELONAC21060-8_4_14.tif',
#  'LELONAC21060-8_5_14.tif',
#  'LELONAC21060-8_6_14.tif',
#  'LELONAC21060-8_7_14.tif',
#  'LELONAC21060-8_8_14.tif',
#  'LELONAC21060-8_9_14.tif',
#  'LELONAC21063-1_10_10.tif',
#  'LELONAC21063-1_1_10.tif',
#  'LELONAC21063-1_2_10.tif',
#  'LELONAC21063-1_3_10.tif',
#  'LELONAC21063-1_4_10.tif',
#  'LELONAC21063-1_5_10.tif',
#  'LELONAC21063-1_6_10.tif',
#  'LELONAC21063-1_7_10.tif',
#  'LELONAC21063-1_8_10.tif',
#  'LELONAC21063-1_9_10.tif',
#  'LELONAC21065-2_10_13.tif',
#  'LELONAC21065-2_11_13.tif',
#  'LELONAC21065-2_12_13.tif',
#  'LELONAC21065-2_13_13.tif',
#  'LELONAC21065-2_1_13.tif',
#  'LELONAC21065-2_2_13.tif',
#  'LELONAC21065-2_3_13.tif',
#  'LELONAC21065-2_4_13.tif',
#  'LELONAC21065-2_5_13.tif',
#  'LELONAC21065-2_6_13.tif',
#  'LELONAC21065-2_7_13.tif',
#  'LELONAC21065-2_8_13.tif',
#  'LELONAC21065-2_9_13.tif',
#  'LELONAC21065-3_10_10.tif',
#  'LELONAC21065-3_1_10.tif',
#  'LELONAC21065-3_2_10.tif',
#  'LELONAC21065-3_3_10.tif',
#  'LELONAC21065-3_4_10.tif',
#  'LELONAC21065-3_5_10.tif',
#  'LELONAC21065-3_6_10.tif',
#  'LELONAC21065-3_7_10.tif',
#  'LELONAC21065-3_8_10.tif',
#  'LELONAC21065-3_9_10.tif',
#  'LFEAYAC21001-12_10_17.tif',
#  'LFEAYAC21001-12_11_17.tif',
#  'LFEAYAC21001-12_12_17.tif',
#  'LFEAYAC21001-12_13_17.tif',
#  'LFEAYAC21001-12_14_17.tif',
#  'LFEAYAC21001-12_15_17.tif',
#  'LFEAYAC21001-12_16_17.tif',
#  'LFEAYAC21001-12_17_17.tif',
#  'LFEAYAC21001-12_1_17.tif',
#  'LFEAYAC21001-12_2_17.tif',
#  'LFEAYAC21001-12_3_17.tif',
#  'LFEAYAC21001-12_4_17.tif',
#  'LFEAYAC21001-12_5_17.tif',
#  'LFEAYAC21001-12_6_17.tif',
#  'LFEAYAC21001-12_7_17.tif',
#  'LFEAYAC21001-12_8_17.tif',
#  'LFEAYAC21001-12_9_17.tif',
#  'LFEAYAC21001-4_1_1.tif',
#  'LFEAYAC21001-5_1_5.tif',
#  'LFEAYAC21001-5_2_5.tif',
#  'LFEAYAC21001-5_3_5.tif',
#  'LFEAYAC21001-5_4_5.tif',
#  ...]

# %% [markdown]
# # Process and landmark data
#
# - Read in image in grayscale
# - Select the contour of the largest object (the leaf)
# - Interpolate with a high resolution of pseudo-landmarks
# - Find the base and tip index point on the high resolution contour
# - Reset the base index to zero
# - Interpolate each side with desired number of equidistant pseudo-landmarks
# - Rotate leaves and scale to centimeters
# - Save pseudo-landmarks scaled to centimeters in an array
#
# PARAMETERS AND INDEXING:
# - `high_res_pts` is an arbitrarily high number of points to initially interpolate
# - `res` is the desired number of points to interpolate on each side of the leaf
# - The total number of pseudo-landmarks will be `2*res - 1`
# - The base index will be `0`
# - The tip index will be `res-1`
# - The returned leaves in `cm_arr` are scaled in size to centimeters

# %% [markdown]
# First, find excluded and missing leaves where the metadata file name is not found in the binary files

# %%
exclude_leaves = [] # leaf names to exclude
exclude_inds = [] # indices of leaf names to exclude

missing_leaves = [] # metadata leaf name not in files
missing_inds = [] # indices of metadata leaf names not in files

# for each leaf . . .
for lf in range(len(mdata)):
    if mdata["include"][lf]=="N":
        exclude_leaves.append(mdata["file"][lf])
        exclude_inds.append(lf)

    elif mdata["file"][lf]+".tif" not in file_names:
        missing_leaves.append(mdata["file"][lf])
        missing_inds.append(lf)
        
print("There are", len(exclude_inds), "excluded leaves")
print("There are", len(missing_inds), "missing leaves")

# save the missing leaves
file_path = "missing_leaves.txt"
with open(file_path, 'w') as file:
    for item in missing_leaves:
        file.write(item + '\n')
# Out:
# There are 939 excluded leaves
# There are 992 missing leaves

# %% [markdown]
# Next, remove the indices of excluded or missing leaves before analysis

# %%
remove_inds = exclude_inds + missing_inds # create list of indices to remove from mdata

mdata = mdata.drop(remove_inds, axis=0)

mdata = mdata.reset_index(drop=True) # Reset the index

print(len(mdata), "leaves will be analyzed") # how many leaves are being analyzed?
# Out:
# 2075 leaves will be analyzed

# %%
######################
### SET PARAMETERS ###
######################

# the number of equidistant points to create
# an initial high resolution outline of the leaf
high_res_pts = 10000

# the ultimate number of equidistant points on each side of the leaf
# (-1 for the tip)
# the leaf will have res*2-1 pseudo-landmarks
#################
#################
#################
res = 50 ########
#################
#################
#################

# an array to store pseudo-landmarks
cm_arr = np.zeros((len(mdata),(res*2)-1,2))

# for each leaf . . .
for lf in range(len(mdata)):

    ###############################
    ### READ IN GRAYSCALE IMAGE ###
    ###############################

    curr_image = mdata["file"][lf]+".tif" # select the current image

    if mdata["include"][lf]=="N":
        continue

    print(lf, curr_image) # print each leaf in case there are problems later

    # read in image
    # convert to grayscale
    # invert the binary
    img = cv2.bitwise_not(cv2.cvtColor(cv2.imread(data_dir + curr_image),cv2.COLOR_BGR2GRAY))

    # find contours of binary objects
    contours, hierarchy = cv2.findContours(img,  
        cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    ##############################
    ### SELECT LARGEST CONTOUR ###
    ##############################

    # ideally there is only one leaf in the image
    # in the case there are smaller objects
    # this code selects the largest object (the leaf)
    # if there is one and only one object in the image
    # then the following code is not necessary

    x_conts = [] # list of lists of contour x vals
    y_conts = [] # list of lists of contour y vals
    areas_conts = [] # list of bounding box areas of contours
    for c in contours: # for each contour
        x_vals = [] # store x vals for current contour 
        y_vals = [] # store y vals for current contour
        for i in range(len(c)): # for each point in current contour
            x_vals.append(c[i][0][0]) # isolate x val
            y_vals.append(c[i][0][1]) # isolate y val
        area = (max(x_vals) - min(x_vals))*(max(y_vals) - min(y_vals)) # calculate bounding box area of contour
        x_conts.append(x_vals) # append the current contour x vals
        y_conts.append(y_vals) # append the current contour y vals
        areas_conts.append(area) # append the current contour bounding box areas

    area_inds = np.flip(np.argsort(areas_conts)) # get indices to sort contours by area
    sorted_x_conts = np.array(x_conts, dtype=object)[area_inds][0:] # areas sorted largest to smallest, x vals
    sorted_y_conts = np.array(y_conts, dtype=object)[area_inds][0:] # areas sorted largest to smallest, y vals

    ################################################
    ### INTERPOLATE HIGH RES NUMBER OF LANDMARKS ###
    ################################################

    # convert the leaf to high resolution number of landmarks
    # using high_res_pt value
    # need to convert arrays of pixel int to floats first
    high_res_x, high_res_y = interpolation(np.array(sorted_x_conts[0], dtype=np.float32), 
                                           np.array(sorted_y_conts[0], dtype=np.float32), high_res_pts)

    ###############################
    ### FIND BASE AND TIP INDEX ###
    ###############################

    # get the base and tip landmark point values
    base_pt = np.array((mdata["base_x"][lf], mdata["base_y"][lf]))
    tip_pt = np.array((mdata["tip_x"][lf], mdata["tip_y"][lf]))

    base_dists = [] # store distance of each high res point to base
    tip_dists = [] # store distance of each high res point to tip

    for pt in range(len(high_res_x)): # for each of the high resolution points

        # euclidean distance of the current point from the base and tip landmark
        ed_base = euclid_dist(base_pt[0], base_pt[1], high_res_x[pt], high_res_y[pt])
        ed_tip = euclid_dist(tip_pt[0], tip_pt[1], high_res_x[pt], high_res_y[pt])

        # store distance of current point from base/tip
        base_dists.append(ed_base)
        tip_dists.append(ed_tip)

    # get index of base and tip points
    base_ind = np.argmin(base_dists)
    tip_ind = np.argmin(tip_dists)

    ################################
    ### RESET BASE INDEX TO ZERO ###
    ################################

    # reset base index position to zero
    high_res_x = np.concatenate((high_res_x[base_ind:],high_res_x[:base_ind]))
    high_res_y = np.concatenate((high_res_y[base_ind:],high_res_y[:base_ind]))

    # recalculate indices with new indexing
    tip_ind = tip_ind-base_ind # note: negative index if tip_ind<base_ind
    base_ind = base_ind-base_ind

    # create single array for leaf coordinates
    lf_contour = np.column_stack((high_res_x, high_res_y))

    ##############################################################
    ### INTERPOLATE EACH SIDE WITH DESIRED NUMBER OF LANDMARKS ###
    ##############################################################

    # interpolate at desired resolution the left and right sides of the leaf
    left_inter_x, left_inter_y = interpolation(lf_contour[base_ind:tip_ind+1,0],lf_contour[base_ind:tip_ind+1,1],res)
    right_inter_x, right_inter_y = interpolation(lf_contour[tip_ind:,0],lf_contour[tip_ind:,1],res)

    # the start of the right side and end of the left side
    # both contain the tip landmark
    # delete the last point on the left side
    left_inter_x = np.delete(left_inter_x, -1)
    left_inter_y = np.delete(left_inter_y, -1)

    # BASE OF LEAF IS INDEX 0
    # TIP INDEX IS RES-1 IF BOTH LEFT & RIGHT POINTS
    # TOTAL PSEUDOLANDMARKS IS 2*RES-1
    lf_pts_left = np.column_stack((left_inter_x, left_inter_y))
    lf_pts_right = np.column_stack((right_inter_x, right_inter_y))
    lf_pts = np.row_stack((lf_pts_left, lf_pts_right))

    ##########################################################
    ### ROTATE LEAVES UPWARD AND SCALE SIZE TO CENTIMETERS ###
    ##########################################################

    tip_point = lf_pts[res-1,:] # get tip point
    base_point = lf_pts[0,:] # get base point

    # calculate angle between tip. base, and an arbitrary reference
    ang = angle_between(tip_point, base_point, (base_point[0]+1,base_point[1]) )

    # rotate points upwards
    rot_x, rot_y = rotate_points(lf_pts[:,0], lf_pts[:,1], ang) 
    rot_pts = np.column_stack((rot_x, rot_y))
    
    # calculate leaf area in pixels^2
    lf_area_px2 = poly_area(rot_pts[:,0], rot_pts[:,1])
    
    # get px_cm
    px_cm = mdata["px_cm"][lf]

    # scale leaf into cm
    cm_lf = rot_pts/(px_cm)
    
    # store the leaf scaled into cm into the cm_arr
    cm_arr[lf,:,:] = cm_lf
# Out:
# 0 LAMOEWC23246-1_1_13.tif
# 1 LAMOEWC23246-1_2_13.tif
# 2 LAMOEWC23246-1_3_13.tif
# 3 LAMOEWC23246-1_6_13.tif
# 4 LAMOEWC23246-2_3_5.tif
# 5 LAMOEWC23246-2_5_5.tif
# 6 LAPALBS17132-1_1_28.tif
# 7 LAPALBS17132-1_10_28.tif
# 8 LAPALBS17132-1_2_28.tif
# 9 LAPALBS17132-1_25_28.tif
# 10 LAPALBS17132-1_26_28.tif
# 11 LAPALBS17132-1_27_28.tif
# 12 LAPALBS17132-1_28_28.tif
# 13 LAPALBS17132-1_3_28.tif
# 14 LAPALBS17132-1_4_28.tif
# 15 LAPALBS17132-1_8_28.tif
# 16 LAPALBS17132-1_9_28.tif
# 17 LAPALBS17133-1_17_25.tif
# 18 LAPALBS17133-1_18_25.tif
# 19 LAPALBS17133-1_19_25.tif
# 20 LAPALBS17133-1_20_25.tif
# 21 LAPALBS17133-1_21_25.tif
# 22 LAPALBS17133-1_22_25.tif
# 23 LAPALBS17133-1_25_25.tif
# 24 LAPALBS17133-1_4_25.tif
# 25 LAPPEAC21008-1_1_5.tif
# 26 LAPPEAC21008-1_2_5.tif
# 27 LAPPEAC21008-1_3_5.tif
# 28 LAPPEAC21008-1_4_5.tif
# 29 LAPPEAC21008-2_4_13.tif
# 30 LAPPEAC21008-2_6_13.tif
# 31 LAPPEAC21008-3_1_8.tif
# 32 LAPPEAC21008-3_4_8.tif
# 33 LAPPEAC21008-3_8_8.tif
# 34 LAPPEAC21010-1_1_3.tif
# 35 LAPPEAC21010-1_2_3.tif
# 36 LAPPEAC21010-1_3_3.tif
# 37 LAPPEAC21010-2_1_15.tif
# 38 LAPPEAC21010-2_10_15.tif
# 39 LAPPEAC21010-2_11_15.tif
# 40 LAPPEAC21010-2_12_15.tif
# 41 LAPPEAC21010-2_14_15.tif
# 42 LAPPEAC21010-2_15_15.tif
# 43 LAPPEAC21010-2_2_15.tif
# 44 LAPPEAC21010-2_3_15.tif
# 45 LAPPEAC21010-2_4_15.tif
# 46 LAPPEAC21010-2_5_15.tif
# 47 LAPPEAC21010-2_6_15.tif
# 48 LAPPEAC21010-2_7_15.tif
# 49 LAPPEAC21010-2_8_15.tif
# 50 LAPPEAC21010-2_9_15.tif
# 51 LAPPEAC21010-3_1_16.tif
# 52 LAPPEAC21010-3_10_16.tif
# 53 LAPPEAC21010-3_11_16.tif
# 54 LAPPEAC21010-3_13_16.tif
# 55 LAPPEAC21010-3_2_16.tif
# 56 LAPPEAC21010-3_4_16.tif
# 57 LAPPEAC21010-3_5_16.tif
# 58 LAPPEAC21010-3_6_16.tif
# 59 LAPPEAC21010-3_7_16.tif
# 60 LAPPEAC21010-3_8_16.tif
# 61 LAPPEAC21010-3_9_16.tif
# 62 LAPPEAC21010-4_1_7.tif
# 63 LAPPEAC21010-4_2_7.tif
# 64 LAPPEAC21010-4_3_7.tif
# 65 LAPPEAC21010-4_4_7.tif
# 66 LAPPEAC21010-4_5_7.tif
# 67 LAPPEAC21010-4_6_7.tif
# 68 LAPPEAC21010-4_7_7.tif
# 69 LAPPEAC21010-5_1_8.tif
# 70 LAPPEAC21010-5_7_8.tif
# 71 LAPPEAC21010-6_4_6.tif
# 72 LAPPEAC21010-6_6_6.tif
# 73 LAPPEAC21010-8_11_17.tif
# 74 LAPPEAC21010-8_13_17.tif
# 75 LAPPEAC21010-8_15_17.tif
# 76 LAPPEAC21010-8_16_17.tif
# 77 LAPPEAC21010-8_3_17.tif
# 78 LAPPEAC21010-8_7_17.tif
# 79 LAPPEAC21010-8_8_17.tif
# 80 LBATSPA21164-1_1_42.tif
# 81 LBATSPA21164-1_10_42.tif
# 82 LBATSPA21164-1_18_42.tif
# 83 LBATSPA21164-1_19_42.tif
# 84 LBATSPA21164-1_2_42.tif
# 85 LBATSPA21164-1_20_42.tif
# 86 LBATSPA21164-1_29_42.tif
# 87 LBATSPA21164-1_3_42.tif
# 88 LBATSPA21164-1_30_42.tif
# 89 LBATSPA21164-1_5_42.tif
# 90 LBATSPA21164-1_6_42.tif
# 91 LBREVAC21171-1_10_89.tif
# 92 LBREVAC21171-1_11_89.tif
# 93 LBREVAC21171-1_12_89.tif
# 94 LBREVAC21171-1_15_89.tif
# 95 LBREVAC21171-1_17_89.tif
# 96 LBREVAC21171-1_18_89.tif
# 97 LBREVAC21171-1_24_89.tif
# 98 LBREVAC21171-1_26_89.tif
# 99 LBREVAC21171-1_27_89.tif
# 100 LBREVAC21171-1_31_89.tif
# 101 LBREVAC21171-1_32_89.tif
# 102 LBREVAC21171-1_35_89.tif
# 103 LBREVAC21171-1_36_89.tif
# 104 LBREVAC21171-1_38_89.tif
# 105 LBREVAC21171-1_4_89.tif
# 106 LBREVAC21171-1_47_89.tif
# 107 LBREVAC21171-1_5_89.tif
# 108 LBREVAC21171-1_52_89.tif
# 109 LBREVAC21171-1_6_89.tif
# 110 LBREVAC21171-1_8_89.tif
# 111 LBREVBS17075-2A_1_37.tif
# 112 LBREVBS17075-2A_10_37.tif
# 113 LBREVBS17075-2A_11_37.tif
# 114 LBREVBS17075-2A_12_37.tif
# 115 LBREVBS17075-2A_13_37.tif
# 116 LBREVBS17075-2A_14_37.tif
# 117 LBREVBS17075-2A_15_37.tif
# 118 LBREVBS17075-2A_16_37.tif
# 119 LBREVBS17075-2A_17_37.tif
# 120 LBREVBS17075-2A_18_37.tif
# 121 LBREVBS17075-2A_19_37.tif
# 122 LBREVBS17075-2A_2_37.tif
# 123 LBREVBS17075-2A_20_37.tif
# 124 LBREVBS17075-2A_21_37.tif
# 125 LBREVBS17075-2A_22_37.tif
# 126 LBREVBS17075-2A_23_37.tif
# 127 LBREVBS17075-2A_24_37.tif
# 128 LBREVBS17075-2A_25_37.tif
# 129 LBREVBS17075-2A_26_37.tif
# 130 LBREVBS17075-2A_27_37.tif
# 131 LBREVBS17075-2A_28_37.tif
# 132 LBREVBS17075-2A_29_37.tif
# 133 LBREVBS17075-2A_3_37.tif
# 134 LBREVBS17075-2A_30_37.tif
# 135 LBREVBS17075-2A_31_37.tif
# 136 LBREVBS17075-2A_32_37.tif
# 137 LBREVBS17075-2A_33_37.tif
# 138 LBREVBS17075-2A_34_37.tif
# 139 LBREVBS17075-2A_35_37.tif
# 140 LBREVBS17075-2A_36_37.tif
# 141 LBREVBS17075-2A_37_37.tif
# 142 LBREVBS17075-2A_4_37.tif
# 143 LBREVBS17075-2A_5_37.tif
# 144 LBREVBS17075-2A_6_37.tif
# 145 LBREVBS17075-2A_7_37.tif
# 146 LBREVBS17075-2A_8_37.tif
# 147 LBREVBS17075-2A_9_37.tif
# 148 LCANBAC21060-1_1_6.tif
# 149 LCANBAC21060-1_2_6.tif
# 150 LCANBAC21060-1_3_6.tif
# 151 LCANBAC21060-1_4_6.tif
# 152 LCANBAC21060-1_5_6.tif
# 153 LCANBAC21060-1_6_6.tif
# 154 LCANBGG21059-1_11_45.tif
# 155 LCANBGG21059-1_2_45.tif
# 156 LCANBGG21059-1_22_45.tif
# 157 LCANBGG21059-1_25_45.tif
# 158 LCANBGG21059-1_4_45.tif
# 159 LCANBGG21059-1_41_45.tif
# 160 LCANBGG21059-1_42_45.tif
# 161 LCANBGG21059-1_6_45.tif
# 162 LCANBGG21059-3_1_18.tif
# 163 LCANBGG21059-3_10_18.tif
# 164 LCANBGG21059-3_11_18.tif
# 165 LCANBGG21059-3_12_18.tif
# 166 LCANBGG21059-3_15_18.tif
# 167 LCANBGG21059-3_16_18.tif
# 168 LCANBGG21059-3_17_18.tif
# 169 LCANBGG21059-3_18_18.tif
# 170 LCANBGG21059-3_2_18.tif
# 171 LCANBGG21059-3_3_18.tif
# 172 LCANBGG21059-3_4_18.tif
# 173 LCANBGG21059-3_5_18.tif
# 174 LCANBGG21059-3_6_18.tif
# 175 LCANBGG21059-3_7_18.tif
# 176 LCANBGG21059-3_8_18.tif
# 177 LCANBGG21059-3_9_18.tif
# 178 LCARDAC23254-1_18_23.tif
# 179 LCARDAC23254-1_21_23.tif
# 180 LCARDAC23254-1_22_23.tif
# 181 LCARDAC23254-2_12_29.tif
# 182 LCARDAC23254-2_13_29.tif
# 183 LCARDAC23254-2_23_29.tif
# 184 LCARDAC23254-2_25_29.tif
# 185 LCARDAC23254-2_26_29.tif
# 186 LCARDAC23254-2_28_29.tif
# 187 LCARDAC23254-2_4_29.tif
# 188 LCARDAC23254-2_8_29.tif
# 189 LCARDPA23225 (A-L)-1_11_48.tif
# 190 LCARDPA23225 (A-L)-1_14_48.tif
# 191 LCARDPA23225 (A-L)-1_16_48.tif
# 192 LCARDPA23225 (A-L)-1_18_48.tif
# 193 LCARDPA23225 (A-L)-1_20_48.tif
# 194 LCARDPA23225 (A-L)-1_21_48.tif
# 195 LCARDPA23225 (A-L)-1_23_48.tif
# 196 LCARDPA23225 (A-L)-1_25_48.tif
# 197 LCARDPA23225 (A-L)-1_26_48.tif
# 198 LCARDPA23225 (A-L)-1_3_48.tif
# 199 LCARDPA23225 (A-L)-1_33_48.tif
# 200 LCARDPA23225 (A-L)-1_36_48.tif
# 201 LCARDPA23225 (A-L)-1_39_48.tif
# 202 LCARDPA23225 (A-L)-1_4_48.tif
# 203 LCARDPA23225 (A-L)-1_48_48.tif
# 204 LCARDPA23225 (A-L)-1_6_48.tif
# 205 LCARDPA23225 (A-L)-1_7_48.tif
# 206 LCARDPA23225 (A-L)-1_9_48.tif
# 207 LCARDPA23225 (A-L)-2_1_23.tif
# 208 LCARDPA23225 (A-L)-2_16_23.tif
# 209 LCARDPA23225 (A-L)-2_17_23.tif
# 210 LCARDPA23225 (A-L)-2_2_23.tif
# 211 LCARDPA23225 (A-L)-2_20_23.tif
# 212 LCARDPA23225 (A-L)-2_21_23.tif
# 213 LCARDPA23225 (A-L)-2_22_23.tif
# 214 LCARDPA23225 (A-L)-2_23_23.tif
# 215 LCARDPA23225 (A-L)-2_3_23.tif
# 216 LCARDPA23225 (A-L)-2_7_23.tif
# 217 LCARDPA23225 (A-L)-3_10_45.tif
# 218 LCARDPA23225 (A-L)-3_11_45.tif
# 219 LCARDPA23225 (A-L)-3_13_45.tif
# 220 LCARDPA23225 (A-L)-3_14_45.tif
# 221 LCARDPA23225 (A-L)-3_18_45.tif
# 222 LCARDPA23225 (A-L)-3_21_45.tif
# 223 LCARDPA23225 (A-L)-3_23_45.tif
# 224 LCARDPA23225 (A-L)-3_24_45.tif
# 225 LCARDPA23225 (A-L)-3_25_45.tif
# 226 LCARDPA23225 (A-L)-3_26_45.tif
# 227 LCARDPA23225 (A-L)-3_28_45.tif
# 228 LCARDPA23225 (A-L)-3_29_45.tif
# 229 LCARDPA23225 (A-L)-3_30_45.tif
# 230 LCARDPA23225 (A-L)-3_36_45.tif
# 231 LCARDPA23225 (A-L)-3_37_45.tif
# 232 LCARDPA23225 (A-L)-3_38_45.tif
# 233 LCARDPA23225 (A-L)-3_39_45.tif
# 234 LCARDPA23225 (A-L)-3_40_45.tif
# 235 LCARDPA23225 (A-L)-3_42_45.tif
# 236 LCARDPA23225 (A-L)-3_43_45.tif
# 237 LCARDPA23225 (A-L)-3_45_45.tif
# 238 LCARDPA23225 (A-L)-3_9_45.tif
# 239 LCARDPA23225 (A-R)-1_1_19.tif
# 240 LCARDPA23225 (A-R)-1_10_19.tif
# 241 LCARDPA23225 (A-R)-1_15_19.tif
# 242 LCARDPA23225 (A-R)-1_17_19.tif
# 243 LCARDPA23225 (A-R)-1_19_19.tif
# 244 LCARDPA23225 (A-R)-1_2_19.tif
# 245 LCARDPA23225 (A-R)-1_3_19.tif
# 246 LCARDPA23225 (A-R)-1_4_19.tif
# 247 LCARDPA23225 (A-R)-1_6_19.tif
# 248 LCARDPA23225 (A-R)-1_9_19.tif
# 249 LCARDPA23225 (S)-1_1_16.tif
# 250 LCARDPA23225 (S)-1_12_16.tif
# 251 LCARDPA23225 (S)-1_13_16.tif
# 252 LCARDPA23225 (S)-1_15_16.tif
# 253 LCARDPA23225 (S)-1_2_16.tif
# 254 LCARDPA23225 (S)-1_3_16.tif
# 255 LCARDPA23225 (S)-1_4_16.tif
# 256 LCARDPA23225 (S)-1_6_16.tif
# 257 LCARDPA23225 (S)-1_7_16.tif
# 258 LCARDPA23225 (S)-1_8_16.tif
# 259 LCARDPA23225 (S)-1_9_16.tif
# 260 LCARDST17131-1_1_3.tif
# 261 LCARDST17131-1_2_3.tif
# 262 LCARDST17131-1_3_3.tif
# 263 LDORTCB21050-1_1_33.tif
# 264 LDORTCB21050-1_10_33.tif
# 265 LDORTCB21050-1_11_33.tif
# 266 LDORTCB21050-1_12_33.tif
# 267 LDORTCB21050-1_13_33.tif
# 268 LDORTCB21050-1_14_33.tif
# 269 LDORTCB21050-1_15_33.tif
# 270 LDORTCB21050-1_16_33.tif
# 271 LDORTCB21050-1_17_33.tif
# 272 LDORTCB21050-1_18_33.tif
# 273 LDORTCB21050-1_19_33.tif
# 274 LDORTCB21050-1_2_33.tif
# 275 LDORTCB21050-1_20_33.tif
# 276 LDORTCB21050-1_21_33.tif
# 277 LDORTCB21050-1_22_33.tif
# 278 LDORTCB21050-1_23_33.tif
# 279 LDORTCB21050-1_24_33.tif
# 280 LDORTCB21050-1_25_33.tif
# 281 LDORTCB21050-1_26_33.tif
# 282 LDORTCB21050-1_27_33.tif
# 283 LDORTCB21050-1_28_33.tif
# 284 LDORTCB21050-1_29_33.tif
# 285 LDORTCB21050-1_3_33.tif
# 286 LDORTCB21050-1_30_33.tif
# 287 LDORTCB21050-1_31_33.tif
# 288 LDORTCB21050-1_32_33.tif
# 289 LDORTCB21050-1_33_33.tif
# 290 LDORTCB21050-1_4_33.tif
# 291 LDORTCB21050-1_5_33.tif
# 292 LDORTCB21050-1_6_33.tif
# 293 LDORTCB21050-1_7_33.tif
# 294 LDORTCB21050-1_8_33.tif
# 295 LDORTCB21050-1_9_33.tif
# 296 LDORTCB21050-2_1_20.tif
# 297 LDORTCB21050-2_10_20.tif
# 298 LDORTCB21050-2_11_20.tif
# 299 LDORTCB21050-2_12_20.tif
# 300 LDORTCB21050-2_13_20.tif
# 301 LDORTCB21050-2_14_20.tif
# 302 LDORTCB21050-2_15_20.tif
# 303 LDORTCB21050-2_16_20.tif
# 304 LDORTCB21050-2_17_20.tif
# 305 LDORTCB21050-2_18_20.tif
# 306 LDORTCB21050-2_19_20.tif
# 307 LDORTCB21050-2_2_20.tif
# 308 LDORTCB21050-2_20_20.tif
# 309 LDORTCB21050-2_3_20.tif
# 310 LDORTCB21050-2_4_20.tif
# 311 LDORTCB21050-2_5_20.tif
# 312 LDORTCB21050-2_6_20.tif
# 313 LDORTCB21050-2_7_20.tif
# 314 LDORTCB21050-2_8_20.tif
# 315 LDORTCB21050-2_9_20.tif
# 316 LDORTCB21050-3_1_49.tif
# 317 LDORTCB21050-3_10_49.tif
# 318 LDORTCB21050-3_11_49.tif
# 319 LDORTCB21050-3_12_49.tif
# 320 LDORTCB21050-3_13_49.tif
# 321 LDORTCB21050-3_14_49.tif
# 322 LDORTCB21050-3_15_49.tif
# 323 LDORTCB21050-3_16_49.tif
# 324 LDORTCB21050-3_17_49.tif
# 325 LDORTCB21050-3_18_49.tif
# 326 LDORTCB21050-3_19_49.tif
# 327 LDORTCB21050-3_2_49.tif
# 328 LDORTCB21050-3_20_49.tif
# 329 LDORTCB21050-3_21_49.tif
# 330 LDORTCB21050-3_22_49.tif
# 331 LDORTCB21050-3_23_49.tif
# 332 LDORTCB21050-3_24_49.tif
# 333 LDORTCB21050-3_25_49.tif
# 334 LDORTCB21050-3_26_49.tif
# 335 LDORTCB21050-3_27_49.tif
# 336 LDORTCB21050-3_28_49.tif
# 337 LDORTCB21050-3_29_49.tif
# 338 LDORTCB21050-3_3_49.tif
# 339 LDORTCB21050-3_30_49.tif
# 340 LDORTCB21050-3_31_49.tif
# 341 LDORTCB21050-3_32_49.tif
# 342 LDORTCB21050-3_33_49.tif
# 343 LDORTCB21050-3_34_49.tif
# 344 LDORTCB21050-3_35_49.tif
# 345 LDORTCB21050-3_36_49.tif
# 346 LDORTCB21050-3_37_49.tif
# 347 LDORTCB21050-3_38_49.tif
# 348 LDORTCB21050-3_39_49.tif
# 349 LDORTCB21050-3_4_49.tif
# 350 LDORTCB21050-3_40_49.tif
# 351 LDORTCB21050-3_41_49.tif
# 352 LDORTCB21050-3_42_49.tif
# 353 LDORTCB21050-3_43_49.tif
# 354 LDORTCB21050-3_44_49.tif
# 355 LDORTCB21050-3_45_49.tif
# 356 LDORTCB21050-3_46_49.tif
# 357 LDORTCB21050-3_47_49.tif
# 358 LDORTCB21050-3_48_49.tif
# 359 LDORTCB21050-3_49_49.tif
# 360 LDORTCB21050-3_5_49.tif
# 361 LDORTCB21050-3_6_49.tif
# 362 LDORTCB21050-3_7_49.tif
# 363 LDORTCB21050-3_8_49.tif
# 364 LDORTCB21050-3_9_49.tif
# 365 LDORTCB21050-4_1_18.tif
# 366 LDORTCB21050-4_10_18.tif
# 367 LDORTCB21050-4_11_18.tif
# 368 LDORTCB21050-4_12_18.tif
# 369 LDORTCB21050-4_13_18.tif
# 370 LDORTCB21050-4_14_18.tif
# 371 LDORTCB21050-4_15_18.tif
# 372 LDORTCB21050-4_16_18.tif
# 373 LDORTCB21050-4_17_18.tif
# 374 LDORTCB21050-4_18_18.tif
# 375 LDORTCB21050-4_2_18.tif
# 376 LDORTCB21050-4_3_18.tif
# 377 LDORTCB21050-4_4_18.tif
# 378 LDORTCB21050-4_5_18.tif
# 379 LDORTCB21050-4_6_18.tif
# 380 LDORTCB21050-4_7_18.tif
# 381 LDORTCB21050-4_8_18.tif
# 382 LDORTCB21050-4_9_18.tif
# 383 LDORTCB21050-5_1_12.tif
# 384 LDORTCB21050-5_10_12.tif
# 385 LDORTCB21050-5_11_12.tif
# 386 LDORTCB21050-5_12_12.tif
# 387 LDORTCB21050-5_2_12.tif
# 388 LDORTCB21050-5_3_12.tif
# 389 LDORTCB21050-5_4_12.tif
# 390 LDORTCB21050-5_5_12.tif
# 391 LDORTCB21050-5_6_12.tif
# 392 LDORTCB21050-5_7_12.tif
# 393 LDORTCB21050-5_8_12.tif
# 394 LDORTCB21050-5_9_12.tif
# 395 LDORTCB21050-7_1_17.tif
# 396 LDORTCB21050-7_10_17.tif
# 397 LDORTCB21050-7_11_17.tif
# 398 LDORTCB21050-7_12_17.tif
# 399 LDORTCB21050-7_13_17.tif
# 400 LDORTCB21050-7_14_17.tif
# 401 LDORTCB21050-7_15_17.tif
# 402 LDORTCB21050-7_16_17.tif
# 403 LDORTCB21050-7_17_17.tif
# 404 LDORTCB21050-7_2_17.tif
# 405 LDORTCB21050-7_3_17.tif
# 406 LDORTCB21050-7_4_17.tif
# 407 LDORTCB21050-7_5_17.tif
# 408 LDORTCB21050-7_6_17.tif
# 409 LDORTCB21050-7_7_17.tif
# 410 LDORTCB21050-7_8_17.tif
# 411 LDORTCB21050-7_9_17.tif
# 412 LELONAC21058-2_1_10.tif
# 413 LELONAC21058-2_10_10.tif
# 414 LELONAC21058-2_2_10.tif
# 415 LELONAC21058-2_3_10.tif
# 416 LELONAC21058-2_4_10.tif
# 417 LELONAC21058-2_5_10.tif
# 418 LELONAC21058-2_6_10.tif
# 419 LELONAC21058-2_7_10.tif
# 420 LELONAC21058-2_8_10.tif
# 421 LELONAC21058-2_9_10.tif
# 422 LELONAC21058-3_1_21.tif
# 423 LELONAC21058-3_10_21.tif
# 424 LELONAC21058-3_11_21.tif
# 425 LELONAC21058-3_12_21.tif
# 426 LELONAC21058-3_13_21.tif
# 427 LELONAC21058-3_14_21.tif
# 428 LELONAC21058-3_15_21.tif
# 429 LELONAC21058-3_16_21.tif
# 430 LELONAC21058-3_17_21.tif
# 431 LELONAC21058-3_18_21.tif
# 432 LELONAC21058-3_19_21.tif
# 433 LELONAC21058-3_2_21.tif
# 434 LELONAC21058-3_20_21.tif
# 435 LELONAC21058-3_21_21.tif
# 436 LELONAC21058-3_3_21.tif
# 437 LELONAC21058-3_4_21.tif
# 438 LELONAC21058-3_5_21.tif
# 439 LELONAC21058-3_6_21.tif
# 440 LELONAC21058-3_7_21.tif
# 441 LELONAC21058-3_8_21.tif
# 442 LELONAC21058-3_9_21.tif
# 443 LELONAC21058-4_1_13.tif
# 444 LELONAC21058-4_10_13.tif
# 445 LELONAC21058-4_11_13.tif
# 446 LELONAC21058-4_12_13.tif
# 447 LELONAC21058-4_13_13.tif
# 448 LELONAC21058-4_2_13.tif
# 449 LELONAC21058-4_3_13.tif
# 450 LELONAC21058-4_4_13.tif
# 451 LELONAC21058-4_5_13.tif
# 452 LELONAC21058-4_6_13.tif
# 453 LELONAC21058-4_7_13.tif
# 454 LELONAC21058-4_8_13.tif
# 455 LELONAC21058-4_9_13.tif
# 456 LELONAC21060-1_1_13.tif
# 457 LELONAC21060-1_10_13.tif
# 458 LELONAC21060-1_11_13.tif
# 459 LELONAC21060-1_12_13.tif
# 460 LELONAC21060-1_13_13.tif
# 461 LELONAC21060-1_2_13.tif
# 462 LELONAC21060-1_3_13.tif
# 463 LELONAC21060-1_4_13.tif
# 464 LELONAC21060-1_5_13.tif
# 465 LELONAC21060-1_6_13.tif
# 466 LELONAC21060-1_7_13.tif
# 467 LELONAC21060-1_8_13.tif
# 468 LELONAC21060-1_9_13.tif
# 469 LELONAC21060-3_1_17.tif
# 470 LELONAC21060-3_10_17.tif
# 471 LELONAC21060-3_11_17.tif
# 472 LELONAC21060-3_12_17.tif
# 473 LELONAC21060-3_13_17.tif
# 474 LELONAC21060-3_14_17.tif
# 475 LELONAC21060-3_15_17.tif
# 476 LELONAC21060-3_16_17.tif
# 477 LELONAC21060-3_17_17.tif
# 478 LELONAC21060-3_2_17.tif
# 479 LELONAC21060-3_3_17.tif
# 480 LELONAC21060-3_4_17.tif
# 481 LELONAC21060-3_5_17.tif
# 482 LELONAC21060-3_6_17.tif
# 483 LELONAC21060-3_7_17.tif
# 484 LELONAC21060-3_8_17.tif
# 485 LELONAC21060-3_9_17.tif
# 486 LELONAC21060-4_1_14.tif
# 487 LELONAC21060-4_10_14.tif
# 488 LELONAC21060-4_11_14.tif
# 489 LELONAC21060-4_12_14.tif
# 490 LELONAC21060-4_13_14.tif
# 491 LELONAC21060-4_14_14.tif
# 492 LELONAC21060-4_2_14.tif
# 493 LELONAC21060-4_3_14.tif
# 494 LELONAC21060-4_4_14.tif
# 495 LELONAC21060-4_5_14.tif
# 496 LELONAC21060-4_6_14.tif
# 497 LELONAC21060-4_7_14.tif
# 498 LELONAC21060-4_8_14.tif
# 499 LELONAC21060-4_9_14.tif
# 500 LELONAC21060-5_1_20.tif
# 501 LELONAC21060-5_10_20.tif
# 502 LELONAC21060-5_11_20.tif
# 503 LELONAC21060-5_12_20.tif
# 504 LELONAC21060-5_13_20.tif
# 505 LELONAC21060-5_14_20.tif
# 506 LELONAC21060-5_15_20.tif
# 507 LELONAC21060-5_16_20.tif
# 508 LELONAC21060-5_17_20.tif
# 509 LELONAC21060-5_18_20.tif
# 510 LELONAC21060-5_19_20.tif
# 511 LELONAC21060-5_2_20.tif
# 512 LELONAC21060-5_20_20.tif
# 513 LELONAC21060-5_3_20.tif
# 514 LELONAC21060-5_4_20.tif
# 515 LELONAC21060-5_5_20.tif
# 516 LELONAC21060-5_6_20.tif
# 517 LELONAC21060-5_7_20.tif
# 518 LELONAC21060-5_8_20.tif
# 519 LELONAC21060-5_9_20.tif
# 520 LELONAC21060-6_1_13.tif
# 521 LELONAC21060-6_10_13.tif
# 522 LELONAC21060-6_11_13.tif
# 523 LELONAC21060-6_12_13.tif
# 524 LELONAC21060-6_13_13.tif
# 525 LELONAC21060-6_2_13.tif
# 526 LELONAC21060-6_3_13.tif
# 527 LELONAC21060-6_4_13.tif
# 528 LELONAC21060-6_5_13.tif
# 529 LELONAC21060-6_6_13.tif
# 530 LELONAC21060-6_7_13.tif
# 531 LELONAC21060-6_8_13.tif
# 532 LELONAC21060-6_9_13.tif
# 533 LELONAC21060-7_1_22.tif
# 534 LELONAC21060-7_10_22.tif
# 535 LELONAC21060-7_11_22.tif
# 536 LELONAC21060-7_12_22.tif
# 537 LELONAC21060-7_13_22.tif
# 538 LELONAC21060-7_14_22.tif
# 539 LELONAC21060-7_15_22.tif
# 540 LELONAC21060-7_16_22.tif
# 541 LELONAC21060-7_17_22.tif
# 542 LELONAC21060-7_18_22.tif
# 543 LELONAC21060-7_19_22.tif
# 544 LELONAC21060-7_2_22.tif
# 545 LELONAC21060-7_20_22.tif
# 546 LELONAC21060-7_21_22.tif
# 547 LELONAC21060-7_22_22.tif
# 548 LELONAC21060-7_3_22.tif
# 549 LELONAC21060-7_4_22.tif
# 550 LELONAC21060-7_5_22.tif
# 551 LELONAC21060-7_6_22.tif
# 552 LELONAC21060-7_7_22.tif
# 553 LELONAC21060-7_8_22.tif
# 554 LELONAC21060-7_9_22.tif
# 555 LELONAC21060-8_1_14.tif
# 556 LELONAC21060-8_10_14.tif
# 557 LELONAC21060-8_11_14.tif
# 558 LELONAC21060-8_12_14.tif
# 559 LELONAC21060-8_13_14.tif
# 560 LELONAC21060-8_14_14.tif
# 561 LELONAC21060-8_2_14.tif
# 562 LELONAC21060-8_3_14.tif
# 563 LELONAC21060-8_4_14.tif
# 564 LELONAC21060-8_5_14.tif
# 565 LELONAC21060-8_6_14.tif
# 566 LELONAC21060-8_7_14.tif
# 567 LELONAC21060-8_8_14.tif
# 568 LELONAC21060-8_9_14.tif
# 569 LELONAC21063-1_1_10.tif
# 570 LELONAC21063-1_10_10.tif
# 571 LELONAC21063-1_2_10.tif
# 572 LELONAC21063-1_3_10.tif
# 573 LELONAC21063-1_4_10.tif
# 574 LELONAC21063-1_5_10.tif
# 575 LELONAC21063-1_6_10.tif
# 576 LELONAC21063-1_7_10.tif
# 577 LELONAC21063-1_8_10.tif
# 578 LELONAC21063-1_9_10.tif
# 579 LELONAC21065-2_1_13.tif
# 580 LELONAC21065-2_10_13.tif
# 581 LELONAC21065-2_11_13.tif
# 582 LELONAC21065-2_12_13.tif
# 583 LELONAC21065-2_13_13.tif
# 584 LELONAC21065-2_2_13.tif
# 585 LELONAC21065-2_3_13.tif
# 586 LELONAC21065-2_4_13.tif
# 587 LELONAC21065-2_5_13.tif
# 588 LELONAC21065-2_6_13.tif
# 589 LELONAC21065-2_7_13.tif
# 590 LELONAC21065-2_8_13.tif
# 591 LELONAC21065-2_9_13.tif
# 592 LELONAC21065-3_1_10.tif
# 593 LELONAC21065-3_10_10.tif
# 594 LELONAC21065-3_2_10.tif
# 595 LELONAC21065-3_3_10.tif
# 596 LELONAC21065-3_4_10.tif
# 597 LELONAC21065-3_5_10.tif
# 598 LELONAC21065-3_6_10.tif
# 599 LELONAC21065-3_7_10.tif
# 600 LELONAC21065-3_8_10.tif
# 601 LELONAC21065-3_9_10.tif
# 602 LFEAYAC21001-4_1_1.tif
# 603 LFEAYAC21001-5_1_5.tif
# 604 LFEAYAC21001-6_1_16.tif
# 605 LFEAYAC21001-6_4_16.tif
# 606 LFEAYAC21001-6_8_16.tif
# 607 LFEAYAC21001-6_9_16.tif
# 608 LFEAYAC21001-7_2_3.tif
# 609 LFEAYAC21002-10_2_7.tif
# 610 LFEAYAC21002-10_3_7.tif
# 611 LFEAYAC21002-10_5_7.tif
# 612 LFEAYAC21002-11_4_7.tif
# 613 LFEAYAC21002-12_1_2.tif
# 614 LFEAYAC21002-3_10_11.tif
# 615 LFEAYAC21002-8_2_16.tif
# 616 LFEAYAC21002-8_3_16.tif
# 617 LFEAYAC21002-8_6_16.tif
# 618 LFEAYAC21002-9_1_3.tif
# 619 LFEAYAC21005-4_2_5.tif
# 620 LFEAYAC21005-6_1_7.tif
# 621 LFEAYAC21005-6_3_7.tif
# 622 LFEAYAC21005-6_5_7.tif
# 623 LFEAYAC21005-7_5_6.tif
# 624 LFEAYAC21005-7_6_6.tif
# 625 LFEAYAC21005-8_1_5.tif
# 626 LFEAYAC21005-9_1_5.tif
# 627 LFEAYAC21005-9_2_5.tif
# 628 LFEAYAC21005-9_3_5.tif
# 629 LFEAYAC21005-9_5_5.tif
# 630 LFEAYLD21004-6_1_2.tif
# 631 LFEAYLD21004-6_2_2.tif
# 632 LFLACCB21015-1_1_18.tif
# 633 LFLACCB21015-1_10_18.tif
# 634 LFLACCB21015-1_11_18.tif
# 635 LFLACCB21015-1_12_18.tif
# 636 LFLACCB21015-1_13_18.tif
# 637 LFLACCB21015-1_14_18.tif
# 638 LFLACCB21015-1_15_18.tif
# 639 LFLACCB21015-1_16_18.tif
# 640 LFLACCB21015-1_17_18.tif
# 641 LFLACCB21015-1_18_18.tif
# 642 LFLACCB21015-1_2_18.tif
# 643 LFLACCB21015-1_3_18.tif
# 644 LFLACCB21015-1_4_18.tif
# 645 LFLACCB21015-1_5_18.tif
# 646 LFLACCB21015-1_6_18.tif
# 647 LFLACCB21015-1_7_18.tif
# 648 LFLACCB21015-1_8_18.tif
# 649 LFLACCB21015-1_9_18.tif
# 650 LFLACCB21015-10_1_24.tif
# 651 LFLACCB21015-10_10_24.tif
# 652 LFLACCB21015-10_11_24.tif
# 653 LFLACCB21015-10_12_24.tif
# 654 LFLACCB21015-10_13_24.tif
# 655 LFLACCB21015-10_14_24.tif
# 656 LFLACCB21015-10_15_24.tif
# 657 LFLACCB21015-10_16_24.tif
# 658 LFLACCB21015-10_17_24.tif
# 659 LFLACCB21015-10_18_24.tif
# 660 LFLACCB21015-10_19_24.tif
# 661 LFLACCB21015-10_2_24.tif
# 662 LFLACCB21015-10_20_24.tif
# 663 LFLACCB21015-10_21_24.tif
# 664 LFLACCB21015-10_22_24.tif
# 665 LFLACCB21015-10_23_24.tif
# 666 LFLACCB21015-10_24_24.tif
# 667 LFLACCB21015-10_3_24.tif
# 668 LFLACCB21015-10_4_24.tif
# 669 LFLACCB21015-10_5_24.tif
# 670 LFLACCB21015-10_6_24.tif
# 671 LFLACCB21015-10_7_24.tif
# 672 LFLACCB21015-10_8_24.tif
# 673 LFLACCB21015-10_9_24.tif
# 674 LFLACCB21015-2_1_19.tif
# 675 LFLACCB21015-2_10_19.tif
# 676 LFLACCB21015-2_11_19.tif
# 677 LFLACCB21015-2_12_19.tif
# 678 LFLACCB21015-2_13_19.tif
# 679 LFLACCB21015-2_14_19.tif
# 680 LFLACCB21015-2_18_19.tif
# 681 LFLACCB21015-2_19_19.tif
# 682 LFLACCB21015-2_2_19.tif
# 683 LFLACCB21015-2_3_19.tif
# 684 LFLACCB21015-2_4_19.tif
# 685 LFLACCB21015-2_5_19.tif
# 686 LFLACCB21015-2_6_19.tif
# 687 LFLACCB21015-2_7_19.tif
# 688 LFLACCB21015-2_8_19.tif
# 689 LFLACCB21015-2_9_19.tif
# 690 LFLACCB21015-3_1_6.tif
# 691 LFLACCB21015-3_2_6.tif
# 692 LFLACCB21015-3_3_6.tif
# 693 LFLACCB21015-3_4_6.tif
# 694 LFLACCB21015-3_5_6.tif
# 695 LFLACCB21015-3_6_6.tif
# 696 LFLACCB21015-5_1_9.tif
# 697 LFLACCB21015-5_2_9.tif
# 698 LFLACCB21015-5_3_9.tif
# 699 LFLACCB21015-5_4_9.tif
# 700 LFLACCB21015-5_5_9.tif
# 701 LFLACCB21015-5_6_9.tif
# 702 LFLACCB21015-5_7_9.tif
# 703 LFLACCB21015-5_8_9.tif
# 704 LFLACCB21015-5_9_9.tif
# 705 LFLACCB21015-8_1_5.tif
# 706 LFLACCB21015-8_2_5.tif
# 707 LFLACCB21015-8_3_5.tif
# 708 LFLACCB21015-8_4_5.tif
# 709 LFLACCB21015-8_5_5.tif
# 710 LFLACCB21015-9_1_9.tif
# 711 LFLACCB21015-9_2_9.tif
# 712 LFLACCB21015-9_3_9.tif
# 713 LFLACCB21015-9_4_9.tif
# 714 LFLACCB21015-9_5_9.tif
# 715 LFLACCB21015-9_6_9.tif
# 716 LFLACCB21015-9_7_9.tif
# 717 LFLACCB21015-9_8_9.tif
# 718 LFLACCB21015-9_9_9.tif
# 719 LFLACCB21018-1_1_6.tif
# 720 LFLACCB21018-1_2_6.tif
# 721 LFLACCB21018-1_3_6.tif
# 722 LFLACCB21018-1_4_6.tif
# 723 LFLACCB21018-1_5_6.tif
# 724 LFLACCB21018-1_6_6.tif
# 725 LFLACCB21018-2_1_13.tif
# 726 LFLACCB21018-2_10_13.tif
# 727 LFLACCB21018-2_11_13.tif
# 728 LFLACCB21018-2_12_13.tif
# 729 LFLACCB21018-2_2_13.tif
# 730 LFLACCB21018-2_3_13.tif
# 731 LFLACCB21018-2_4_13.tif
# 732 LFLACCB21018-2_5_13.tif
# 733 LFLACCB21018-2_6_13.tif
# 734 LFLACCB21018-2_7_13.tif
# 735 LFLACCB21018-2_8_13.tif
# 736 LFLACCB21018-2_9_13.tif
# 737 LFLACCB21018-4_1_5.tif
# 738 LFLACCB21018-4_2_5.tif
# 739 LFLACCB21018-4_3_5.tif
# 740 LFLACCB21018-4_4_5.tif
# 741 LFLACCB21018-4_5_5.tif
# 742 LFLACCB21018-5_1_8.tif
# 743 LFLACCB21018-5_2_8.tif
# 744 LFLACCB21018-5_3_8.tif
# 745 LFLACCB21018-5_4_8.tif
# 746 LFLACCB21018-5_5_8.tif
# 747 LFLACCB21018-5_6_8.tif
# 748 LFLACCB21018-5_7_8.tif
# 749 LFLACCB21018-5_8_8.tif
# 750 LFLACCB21018-7_1_15.tif
# 751 LFLACCB21018-7_10_15.tif
# 752 LFLACCB21018-7_11_15.tif
# 753 LFLACCB21018-7_12_15.tif
# 754 LFLACCB21018-7_13_15.tif
# 755 LFLACCB21018-7_14_15.tif
# 756 LFLACCB21018-7_15_15.tif
# 757 LFLACCB21018-7_2_15.tif
# 758 LFLACCB21018-7_3_15.tif
# 759 LFLACCB21018-7_4_15.tif
# 760 LFLACCB21018-7_5_15.tif
# 761 LFLACCB21018-7_6_15.tif
# 762 LFLACCB21018-7_7_15.tif
# 763 LFLACCB21018-7_8_15.tif
# 764 LFLACCB21018-7_9_15.tif
# 765 LFLACCB21018-8_1_13.tif
# 766 LFLACCB21018-8_10_13.tif
# 767 LFLACCB21018-8_11_13.tif
# 768 LFLACCB21018-8_12_13.tif
# 769 LFLACCB21018-8_13_13.tif
# 770 LFLACCB21018-8_2_13.tif
# 771 LFLACCB21018-8_3_13.tif
# 772 LFLACCB21018-8_4_13.tif
# 773 LFLACCB21018-8_5_13.tif
# 774 LFLACCB21018-8_6_13.tif
# 775 LFLACCB21018-8_7_13.tif
# 776 LFLACCB21018-8_8_13.tif
# 777 LFLACCB21018-8_9_13.tif
# 778 LFLACLD17116-1_1_4.tif
# 779 LFLACLD17116-1_2_4.tif
# 780 LFLACLD17116-1_3_4.tif
# 781 LFLACLD17116-1_4_4.tif
# 782 LFLORBS17124-1_1_1.tif
# 783 LFLORBS17124-3_1_6.tif
# 784 LGATTCH17078-14_1_1.tif
# 785 LGATTCH17078-15_1_1.tif
# 786 LGEORAC17140-1_1_1.tif
# 787 LGEORAC17140-2_1_2.tif
# 788 LGEORAC17140-2_2_2.tif
# 789 LGLANAC21060-2_10_12.tif
# 790 LGLANAC21060-2_11_12.tif
# 791 LGLANAC21060-2_12_12.tif
# 792 LGLANAC21060-2_2_12.tif
# 793 LGLANAC21060-2_3_12.tif
# 794 LGLANAC21060-2_4_12.tif
# 795 LGLANAC21060-2_5_12.tif
# 796 LGLANAC21060-2_6_12.tif
# 797 LGLANAC21060-2_7_12.tif
# 798 LGLANAC21060-2_8_12.tif
# 799 LGLANAC21060-2_9_12.tif
# 800 LGLANAC21060-3_1_3.tif
# 801 LGLANAC21060-3_2_3.tif
# 802 LGLANAC21060-3_3_3.tif
# 803 LGLANAC21060-4_10_16.tif
# 804 LGLANAC21060-4_11_16.tif
# 805 LGLANAC21060-4_12_16.tif
# 806 LGLANAC21060-4_13_16.tif
# 807 LGLANAC21060-4_14_16.tif
# 808 LGLANAC21060-4_15_16.tif
# 809 LGLANAC21060-4_16_16.tif
# 810 LGLANAC21060-4_6_16.tif
# 811 LGLANAC21060-4_7_16.tif
# 812 LGLANAC21060-4_8_16.tif
# 813 LGLANAC21060-4_9_16.tif
# 814 LGLANAC21165-1_1_10.tif
# 815 LGLANAC21165-1_10_10.tif
# 816 LGLANAC21165-1_2_10.tif
# 817 LGLANAC21165-1_3_10.tif
# 818 LGLANAC21165-1_4_10.tif
# 819 LGLANAC21165-1_5_10.tif
# 820 LGLANAC21165-1_6_10.tif
# 821 LGLANAC21165-1_7_10.tif
# 822 LGLANAC21165-1_8_10.tif
# 823 LGLANAC21165-1_9_10.tif
# 824 LGLANAC21165-3_1_7.tif
# 825 LGLANAC21165-3_2_7.tif
# 826 LGLANAC21165-3_3_7.tif
# 827 LGLANAC21165-3_4_7.tif
# 828 LGLANAC21165-3_5_7.tif
# 829 LGLANAC21165-3_6_7.tif
# 830 LGLANAC21165-3_7_7.tif
# 831 LGLANAC21165-4_1_10.tif
# 832 LGLANAC21165-4_10_10.tif
# 833 LGLANAC21165-4_2_10.tif
# 834 LGLANAC21165-4_3_10.tif
# 835 LGLANAC21165-4_4_10.tif
# 836 LGLANAC21165-4_5_10.tif
# 837 LGLANAC21165-4_6_10.tif
# 838 LGLANAC21165-4_7_10.tif
# 839 LGLANAC21165-4_8_10.tif
# 840 LGLANAC21165-4_9_10.tif
# 841 LGLANAC21165-5_1_26.tif
# 842 LGLANAC21165-5_10_26.tif
# 843 LGLANAC21165-5_11_26.tif
# 844 LGLANAC21165-5_12_26.tif
# 845 LGLANAC21165-5_13_26.tif
# 846 LGLANAC21165-5_14_26.tif
# 847 LGLANAC21165-5_15_26.tif
# 848 LGLANAC21165-5_16_26.tif
# 849 LGLANAC21165-5_17_26.tif
# 850 LGLANAC21165-5_18_26.tif
# 851 LGLANAC21165-5_19_26.tif
# 852 LGLANAC21165-5_2_26.tif
# 853 LGLANAC21165-5_20_26.tif
# 854 LGLANAC21165-5_21_26.tif
# 855 LGLANAC21165-5_22_26.tif
# 856 LGLANAC21165-5_23_26.tif
# 857 LGLANAC21165-5_24_26.tif
# 858 LGLANAC21165-5_25_26.tif
# 859 LGLANAC21165-5_26_26.tif
# 860 LGLANAC21165-5_3_26.tif
# 861 LGLANAC21165-5_4_26.tif
# 862 LGLANAC21165-5_5_26.tif
# 863 LGLANAC21165-5_6_26.tif
# 864 LGLANAC21165-5_7_26.tif
# 865 LGLANAC21165-5_8_26.tif
# 866 LGLANAC21165-5_9_26.tif
# 867 LGLANAC21165-6_1_20.tif
# 868 LGLANAC21165-6_10_20.tif
# 869 LGLANAC21165-6_11_20.tif
# 870 LGLANAC21165-6_12_20.tif
# 871 LGLANAC21165-6_13_20.tif
# 872 LGLANAC21165-6_14_20.tif
# 873 LGLANAC21165-6_15_20.tif
# 874 LGLANAC21165-6_16_20.tif
# 875 LGLANAC21165-6_17_20.tif
# 876 LGLANAC21165-6_18_20.tif
# 877 LGLANAC21165-6_19_20.tif
# 878 LGLANAC21165-6_2_20.tif
# 879 LGLANAC21165-6_20_20.tif
# 880 LGLANAC21165-6_3_20.tif
# 881 LGLANAC21165-6_4_20.tif
# 882 LGLANAC21165-6_5_20.tif
# 883 LGLANAC21165-6_6_20.tif
# 884 LGLANAC21165-6_7_20.tif
# 885 LGLANAC21165-6_8_20.tif
# 886 LGLANAC21165-6_9_20.tif
# 887 LGLANAC21165-7_1_10.tif
# 888 LGLANAC21165-7_10_10.tif
# 889 LGLANAC21165-7_2_10.tif
# 890 LGLANAC21165-7_3_10.tif
# 891 LGLANAC21165-7_4_10.tif
# 892 LGLANAC21165-7_5_10.tif
# 893 LGLANAC21165-7_6_10.tif
# 894 LGLANAC21165-7_7_10.tif
# 895 LGLANAC21165-7_8_10.tif
# 896 LGLANAC21165-7_9_10.tif
# 897 LGLANAC21166-2_1_21.tif
# 898 LGLANAC21166-2_10_21.tif
# 899 LGLANAC21166-2_11_21.tif
# 900 LGLANAC21166-2_12_21.tif
# 901 LGLANAC21166-2_13_21.tif
# 902 LGLANAC21166-2_14_21.tif
# 903 LGLANAC21166-2_15_21.tif
# 904 LGLANAC21166-2_16_21.tif
# 905 LGLANAC21166-2_17_21.tif
# 906 LGLANAC21166-2_18_21.tif
# 907 LGLANAC21166-2_19_21.tif
# 908 LGLANAC21166-2_2_21.tif
# 909 LGLANAC21166-2_20_21.tif
# 910 LGLANAC21166-2_21_21.tif
# 911 LGLANAC21166-2_3_21.tif
# 912 LGLANAC21166-2_4_21.tif
# 913 LGLANAC21166-2_5_21.tif
# 914 LGLANAC21166-2_6_21.tif
# 915 LGLANAC21166-2_7_21.tif
# 916 LGLANAC21166-2_8_21.tif
# 917 LGLANAC21166-2_9_21.tif
# 918 LGLANAC21166-3_1_22.tif
# 919 LGLANAC21166-3_10_22.tif
# 920 LGLANAC21166-3_11_22.tif
# 921 LGLANAC21166-3_12_22.tif
# 922 LGLANAC21166-3_13_22.tif
# 923 LGLANAC21166-3_14_22.tif
# 924 LGLANAC21166-3_15_22.tif
# 925 LGLANAC21166-3_16_22.tif
# 926 LGLANAC21166-3_17_22.tif
# 927 LGLANAC21166-3_18_22.tif
# 928 LGLANAC21166-3_19_22.tif
# 929 LGLANAC21166-3_2_22.tif
# 930 LGLANAC21166-3_20_22.tif
# 931 LGLANAC21166-3_21_22.tif
# 932 LGLANAC21166-3_22_22.tif
# 933 LGLANAC21166-3_3_22.tif
# 934 LGLANAC21166-3_4_22.tif
# 935 LGLANAC21166-3_5_22.tif
# 936 LGLANAC21166-3_6_22.tif
# 937 LGLANAC21166-3_7_22.tif
# 938 LGLANAC21166-3_8_22.tif
# 939 LGLANAC21166-3_9_22.tif
# 940 LGLANAC21167-1_1_49.tif
# 941 LGLANAC21167-1_10_49.tif
# 942 LGLANAC21167-1_11_49.tif
# 943 LGLANAC21167-1_12_49.tif
# 944 LGLANAC21167-1_13_49.tif
# 945 LGLANAC21167-1_14_49.tif
# 946 LGLANAC21167-1_15_49.tif
# 947 LGLANAC21167-1_16_49.tif
# 948 LGLANAC21167-1_17_49.tif
# 949 LGLANAC21167-1_18_49.tif
# 950 LGLANAC21167-1_19_49.tif
# 951 LGLANAC21167-1_2_49.tif
# 952 LGLANAC21167-1_20_49.tif
# 953 LGLANAC21167-1_21_49.tif
# 954 LGLANAC21167-1_22_49.tif
# 955 LGLANAC21167-1_27_49.tif
# 956 LGLANAC21167-1_29_49.tif
# 957 LGLANAC21167-1_3_49.tif
# 958 LGLANAC21167-1_30_49.tif
# 959 LGLANAC21167-1_31_49.tif
# 960 LGLANAC21167-1_32_49.tif
# 961 LGLANAC21167-1_33_49.tif
# 962 LGLANAC21167-1_34_49.tif
# 963 LGLANAC21167-1_35_49.tif
# 964 LGLANAC21167-1_36_49.tif
# 965 LGLANAC21167-1_37_49.tif
# 966 LGLANAC21167-1_38_49.tif
# 967 LGLANAC21167-1_39_49.tif
# 968 LGLANAC21167-1_4_49.tif
# 969 LGLANAC21167-1_40_49.tif
# 970 LGLANAC21167-1_41_49.tif
# 971 LGLANAC21167-1_42_49.tif
# 972 LGLANAC21167-1_45_49.tif
# 973 LGLANAC21167-1_46_49.tif
# 974 LGLANAC21167-1_47_49.tif
# 975 LGLANAC21167-1_48_49.tif
# 976 LGLANAC21167-1_49_49.tif
# 977 LGLANAC21167-1_5_49.tif
# 978 LGLANAC21167-1_6_49.tif
# 979 LGLANAC21167-1_7_49.tif
# 980 LGLANAC21167-1_8_49.tif
# 981 LGLANAC21167-1_9_49.tif
# 982 LGLANAC21167-3_1_18.tif
# 983 LGLANAC21167-3_10_18.tif
# 984 LGLANAC21167-3_11_18.tif
# 985 LGLANAC21167-3_12_18.tif
# 986 LGLANAC21167-3_13_18.tif
# 987 LGLANAC21167-3_14_18.tif
# 988 LGLANAC21167-3_15_18.tif
# 989 LGLANAC21167-3_16_18.tif
# 990 LGLANAC21167-3_17_18.tif
# 991 LGLANAC21167-3_18_18.tif
# 992 LGLANAC21167-3_2_18.tif
# 993 LGLANAC21167-3_3_18.tif
# 994 LGLANAC21167-3_4_18.tif
# 995 LGLANAC21167-3_5_18.tif
# 996 LGLANAC21167-3_6_18.tif
# 997 LGLANAC21167-3_7_18.tif
# 998 LGLANAC21167-3_8_18.tif
# 999 LGLANAC21167-3_9_18.tif
# 1000 LGLANAC21169-10_1_12.tif
# 1001 LGLANAC21169-10_10_12.tif
# 1002 LGLANAC21169-10_11_12.tif
# 1003 LGLANAC21169-10_12_12.tif
# 1004 LGLANAC21169-10_2_12.tif
# 1005 LGLANAC21169-10_3_12.tif
# 1006 LGLANAC21169-10_4_12.tif
# 1007 LGLANAC21169-10_5_12.tif
# 1008 LGLANAC21169-10_6_12.tif
# 1009 LGLANAC21169-10_7_12.tif
# 1010 LGLANAC21169-10_8_12.tif
# 1011 LGLANAC21169-10_9_12.tif
# 1012 LGLANAC21169-12_1_11.tif
# 1013 LGLANAC21169-12_10_11.tif
# 1014 LGLANAC21169-12_11_11.tif
# 1015 LGLANAC21169-12_2_11.tif
# 1016 LGLANAC21169-12_3_11.tif
# 1017 LGLANAC21169-12_4_11.tif
# 1018 LGLANAC21169-12_5_11.tif
# 1019 LGLANAC21169-12_6_11.tif
# 1020 LGLANAC21169-12_7_11.tif
# 1021 LGLANAC21169-12_8_11.tif
# 1022 LGLANAC21169-12_9_11.tif
# 1023 LGLANAC21169-2_1_15.tif
# 1024 LGLANAC21169-2_10_15.tif
# 1025 LGLANAC21169-2_11_15.tif
# 1026 LGLANAC21169-2_12_15.tif
# 1027 LGLANAC21169-2_13_15.tif
# 1028 LGLANAC21169-2_14_15.tif
# 1029 LGLANAC21169-2_15_15.tif
# 1030 LGLANAC21169-2_2_15.tif
# 1031 LGLANAC21169-2_3_15.tif
# 1032 LGLANAC21169-2_4_15.tif
# 1033 LGLANAC21169-2_5_15.tif
# 1034 LGLANAC21169-2_6_15.tif
# 1035 LGLANAC21169-2_7_15.tif
# 1036 LGLANAC21169-2_8_15.tif
# 1037 LGLANAC21169-2_9_15.tif
# 1038 LGLANAC21169-3_1_8.tif
# 1039 LGLANAC21169-3_2_8.tif
# 1040 LGLANAC21169-3_3_8.tif
# 1041 LGLANAC21169-3_4_8.tif
# 1042 LGLANAC21169-3_5_8.tif
# 1043 LGLANAC21169-3_6_8.tif
# 1044 LGLANAC21169-3_7_8.tif
# 1045 LGLANAC21169-3_8_8.tif
# 1046 LGLANAC21169-4_1_13.tif
# 1047 LGLANAC21169-4_10_13.tif
# 1048 LGLANAC21169-4_11_13.tif
# 1049 LGLANAC21169-4_12_13.tif
# 1050 LGLANAC21169-4_13_13.tif
# 1051 LGLANAC21169-4_2_13.tif
# 1052 LGLANAC21169-4_3_13.tif
# 1053 LGLANAC21169-4_4_13.tif
# 1054 LGLANAC21169-4_5_13.tif
# 1055 LGLANAC21169-4_6_13.tif
# 1056 LGLANAC21169-4_7_13.tif
# 1057 LGLANAC21169-4_8_13.tif
# 1058 LGLANAC21169-4_9_13.tif
# 1059 LGLANAC21169-5_1_18.tif
# 1060 LGLANAC21169-5_10_18.tif
# 1061 LGLANAC21169-5_11_18.tif
# 1062 LGLANAC21169-5_12_18.tif
# 1063 LGLANAC21169-5_13_18.tif
# 1064 LGLANAC21169-5_14_18.tif
# 1065 LGLANAC21169-5_15_18.tif
# 1066 LGLANAC21169-5_16_18.tif
# 1067 LGLANAC21169-5_17_18.tif
# 1068 LGLANAC21169-5_18_18.tif
# 1069 LGLANAC21169-5_2_18.tif
# 1070 LGLANAC21169-5_3_18.tif
# 1071 LGLANAC21169-5_4_18.tif
# 1072 LGLANAC21169-5_5_18.tif
# 1073 LGLANAC21169-5_6_18.tif
# 1074 LGLANAC21169-5_7_18.tif
# 1075 LGLANAC21169-5_8_18.tif
# 1076 LGLANAC21169-5_9_18.tif
# 1077 LGLANAC21169-6_1_10.tif
# 1078 LGLANAC21169-6_10_10.tif
# 1079 LGLANAC21169-6_2_10.tif
# 1080 LGLANAC21169-6_3_10.tif
# 1081 LGLANAC21169-6_4_10.tif
# 1082 LGLANAC21169-6_5_10.tif
# 1083 LGLANAC21169-6_6_10.tif
# 1084 LGLANAC21169-6_7_10.tif
# 1085 LGLANAC21169-6_8_10.tif
# 1086 LGLANAC21169-6_9_10.tif
# 1087 LGLANAC21169-8_1_9.tif
# 1088 LGLANAC21169-8_2_9.tif
# 1089 LGLANAC21169-8_3_9.tif
# 1090 LGLANAC21169-8_4_9.tif
# 1091 LGLANAC21169-8_5_9.tif
# 1092 LGLANAC21169-8_6_9.tif
# 1093 LGLANAC21169-8_7_9.tif
# 1094 LGLANAC21169-8_8_9.tif
# 1095 LGLANAC21169-8_9_9.tif
# 1096 LGLANAC21171-1_1_7.tif
# 1097 LGLANAC21171-1_2_7.tif
# 1098 LGLANAC21171-1_3_7.tif
# 1099 LGLANAC21171-1_4_7.tif
# 1100 LGLANAC21171-1_5_7.tif
# 1101 LGLANAC21171-1_6_7.tif
# 1102 LGLANAC21171-1_7_7.tif
# 1103 LGLANAC21171-2_1_11.tif
# 1104 LGLANAC21171-2_10_11.tif
# 1105 LGLANAC21171-2_11_11.tif
# 1106 LGLANAC21171-2_2_11.tif
# 1107 LGLANAC21171-2_3_11.tif
# 1108 LGLANAC21171-2_4_11.tif
# 1109 LGLANAC21171-2_5_11.tif
# 1110 LGLANAC21171-2_6_11.tif
# 1111 LGLANAC21171-2_7_11.tif
# 1112 LGLANAC21171-2_8_11.tif
# 1113 LGLANAC21171-2_9_11.tif
# 1114 LGLANAC21171-3_1_12.tif
# 1115 LGLANAC21171-3_10_12.tif
# 1116 LGLANAC21171-3_11_12.tif
# 1117 LGLANAC21171-3_2_12.tif
# 1118 LGLANAC21171-3_3_12.tif
# 1119 LGLANAC21171-3_4_12.tif
# 1120 LGLANAC21171-3_5_12.tif
# 1121 LGLANAC21171-3_6_12.tif
# 1122 LGLANAC21171-3_7_12.tif
# 1123 LGLANAC21171-3_8_12.tif
# 1124 LGLANAC21171-3_9_12.tif
# 1125 LGLANAC21171-6_1_11.tif
# 1126 LGLANAC21171-6_10_11.tif
# 1127 LGLANAC21171-6_11_11.tif
# 1128 LGLANAC21171-6_2_11.tif
# 1129 LGLANAC21171-6_3_11.tif
# 1130 LGLANAC21171-6_4_11.tif
# 1131 LGLANAC21171-6_5_11.tif
# 1132 LGLANAC21171-6_6_11.tif
# 1133 LGLANAC21171-6_7_11.tif
# 1134 LGLANAC21171-6_8_11.tif
# 1135 LGLANAC21171-6_9_11.tif
# 1136 LGLANBS17147-1_1_4.tif
# 1137 LGLANBS17147-1_2_4.tif
# 1138 LGLANBS17147-1_3_4.tif
# 1139 LGLANBS17147-1_4_4.tif
# 1140 LGLANBS17148-1_1_12.tif
# 1141 LGLANBS17148-1_11_12.tif
# 1142 LGLANBS17148-1_12_12.tif
# 1143 LGLANBS17148-1_2_12.tif
# 1144 LGLANBS17148-1_3_12.tif
# 1145 LGLANBS17148-1_4_12.tif
# 1146 LGLANBS17148-1_5_12.tif
# 1147 LGLANBS17148-1_6_12.tif
# 1148 LGLANBS17148-1_7_12.tif
# 1149 LGLANBS17148-1_8_12.tif
# 1150 LGLANBS17148-1_9_12.tif
# 1151 LGLANPA21029-2_1_23.tif
# 1152 LGLANPA21029-2_10_23.tif
# 1153 LGLANPA21029-2_11_23.tif
# 1154 LGLANPA21029-2_12_23.tif
# 1155 LGLANPA21029-2_13_23.tif
# 1156 LGLANPA21029-2_14_23.tif
# 1157 LGLANPA21029-2_15_23.tif
# 1158 LGLANPA21029-2_16_23.tif
# 1159 LGLANPA21029-2_17_23.tif
# 1160 LGLANPA21029-2_18_23.tif
# 1161 LGLANPA21029-2_19_23.tif
# 1162 LGLANPA21029-2_2_23.tif
# 1163 LGLANPA21029-2_20_23.tif
# 1164 LGLANPA21029-2_21_23.tif
# 1165 LGLANPA21029-2_22_23.tif
# 1166 LGLANPA21029-2_23_23.tif
# 1167 LGLANPA21029-2_3_23.tif
# 1168 LGLANPA21029-2_4_23.tif
# 1169 LGLANPA21029-2_5_23.tif
# 1170 LGLANPA21029-2_6_23.tif
# 1171 LGLANPA21029-2_7_23.tif
# 1172 LGLANPA21029-2_8_23.tif
# 1173 LGLANPA21029-2_9_23.tif
# 1174 LGLANPA21029-3_1_15.tif
# 1175 LGLANPA21029-3_10_15.tif
# 1176 LGLANPA21029-3_11_15.tif
# 1177 LGLANPA21029-3_12_15.tif
# 1178 LGLANPA21029-3_13_15.tif
# 1179 LGLANPA21029-3_14_15.tif
# 1180 LGLANPA21029-3_15_15.tif
# 1181 LGLANPA21029-3_2_15.tif
# 1182 LGLANPA21029-3_3_15.tif
# 1183 LGLANPA21029-3_4_15.tif
# 1184 LGLANPA21029-3_5_15.tif
# 1185 LGLANPA21029-3_6_15.tif
# 1186 LGLANPA21029-3_7_15.tif
# 1187 LGLANPA21029-3_8_15.tif
# 1188 LGLANPA21029-3_9_15.tif
# 1189 LGLANPA21029-4_1_16.tif
# 1190 LGLANPA21029-4_10_16.tif
# 1191 LGLANPA21029-4_11_16.tif
# 1192 LGLANPA21029-4_12_16.tif
# 1193 LGLANPA21029-4_13_16.tif
# 1194 LGLANPA21029-4_14_16.tif
# 1195 LGLANPA21029-4_15_16.tif
# 1196 LGLANPA21029-4_16_16.tif
# 1197 LGLANPA21029-4_2_16.tif
# 1198 LGLANPA21029-4_3_16.tif
# 1199 LGLANPA21029-4_4_16.tif
# 1200 LGLANPA21029-4_5_16.tif
# 1201 LGLANPA21029-4_6_16.tif
# 1202 LGLANPA21029-4_7_16.tif
# 1203 LGLANPA21029-4_8_16.tif
# 1204 LGLANPA21029-4_9_16.tif
# 1205 LINFLAC17091-2_1_19.tif
# 1206 LINFLAC17091-2_10_19.tif
# 1207 LINFLAC17091-2_11_19.tif
# 1208 LINFLAC17091-2_13_19.tif
# 1209 LINFLAC17091-2_14_19.tif
# 1210 LINFLAC17091-2_15_19.tif
# 1211 LINFLAC17091-2_16_19.tif
# 1212 LINFLAC17091-2_17_19.tif
# 1213 LINFLAC17091-2_18_19.tif
# 1214 LINFLAC17091-2_19_19.tif
# 1215 LINFLAC17091-2_2_19.tif
# 1216 LINFLAC17091-2_3_19.tif
# 1217 LINFLAC17091-2_4_19.tif
# 1218 LINFLAC17091-2_5_19.tif
# 1219 LINFLAC17091-2_6_19.tif
# 1220 LINFLAC17091-2_7_19.tif
# 1221 LINFLAC17091-2_8_19.tif
# 1222 LINFLAC17091-2_9_19.tif
# 1223 LINFLBS17089-2_1_3.tif
# 1224 LINFLBS17089-2_2_3.tif
# 1225 LINFLBS17089-2_3_3.tif
# 1226 LINFLSH21042-2_1_12.tif
# 1227 LINFLSH21042-2_10_12.tif
# 1228 LINFLSH21042-2_11_12.tif
# 1229 LINFLSH21042-2_12_12.tif
# 1230 LINFLSH21042-2_2_12.tif
# 1231 LINFLSH21042-2_3_12.tif
# 1232 LINFLSH21042-2_4_12.tif
# 1233 LINFLSH21042-2_5_12.tif
# 1234 LINFLSH21042-2_6_12.tif
# 1235 LINFLSH21042-2_7_12.tif
# 1236 LINFLSH21042-2_8_12.tif
# 1237 LINFLSH21042-2_9_12.tif
# 1238 LKALMSH21040-2_1_2.tif
# 1239 LKALMSH21040-2_2_2.tif
# 1240 LKALMSH21040-3_1_28.tif
# 1241 LKALMSH21040-3_10_28.tif
# 1242 LKALMSH21040-3_11_28.tif
# 1243 LKALMSH21040-3_12_28.tif
# 1244 LKALMSH21040-3_13_28.tif
# 1245 LKALMSH21040-3_14_28.tif
# 1246 LKALMSH21040-3_15_28.tif
# 1247 LKALMSH21040-3_16_28.tif
# 1248 LKALMSH21040-3_17_28.tif
# 1249 LKALMSH21040-3_18_28.tif
# 1250 LKALMSH21040-3_19_28.tif
# 1251 LKALMSH21040-3_2_28.tif
# 1252 LKALMSH21040-3_20_28.tif
# 1253 LKALMSH21040-3_21_28.tif
# 1254 LKALMSH21040-3_22_28.tif
# 1255 LKALMSH21040-3_23_28.tif
# 1256 LKALMSH21040-3_24_28.tif
# 1257 LKALMSH21040-3_25_28.tif
# 1258 LKALMSH21040-3_26_28.tif
# 1259 LKALMSH21040-3_27_28.tif
# 1260 LKALMSH21040-3_28_28.tif
# 1261 LKALMSH21040-3_3_28.tif
# 1262 LKALMSH21040-3_4_28.tif
# 1263 LKALMSH21040-3_5_28.tif
# 1264 LKALMSH21040-3_6_28.tif
# 1265 LKALMSH21040-3_7_28.tif
# 1266 LKALMSH21040-3_8_28.tif
# 1267 LKALMSH21040-3_9_28.tif
# 1268 LKALMSH21040-4_1_7.tif
# 1269 LKALMSH21040-4_2_7.tif
# 1270 LKALMSH21040-4_3_7.tif
# 1271 LKALMSH21040-4_4_7.tif
# 1272 LKALMSH21040-4_5_7.tif
# 1273 LKALMSH21040-4_6_7.tif
# 1274 LKALMSH21040-4_7_7.tif
# 1275 LKALMSH21040-5_1_52.tif
# 1276 LKALMSH21040-5_10_52.tif
# 1277 LKALMSH21040-5_11_52.tif
# 1278 LKALMSH21040-5_12_52.tif
# 1279 LKALMSH21040-5_13_52.tif
# 1280 LKALMSH21040-5_14_52.tif
# 1281 LKALMSH21040-5_15_52.tif
# 1282 LKALMSH21040-5_16_52.tif
# 1283 LKALMSH21040-5_17_52.tif
# 1284 LKALMSH21040-5_18_52.tif
# 1285 LKALMSH21040-5_2_52.tif
# 1286 LKALMSH21040-5_20_52.tif
# 1287 LKALMSH21040-5_21_52.tif
# 1288 LKALMSH21040-5_22_52.tif
# 1289 LKALMSH21040-5_23_52.tif
# 1290 LKALMSH21040-5_24_52.tif
# 1291 LKALMSH21040-5_25_52.tif
# 1292 LKALMSH21040-5_26_52.tif
# 1293 LKALMSH21040-5_27_52.tif
# 1294 LKALMSH21040-5_28_52.tif
# 1295 LKALMSH21040-5_29_52.tif
# 1296 LKALMSH21040-5_3_52.tif
# 1297 LKALMSH21040-5_30_52.tif
# 1298 LKALMSH21040-5_31_52.tif
# 1299 LKALMSH21040-5_32_52.tif
# 1300 LKALMSH21040-5_33_52.tif
# 1301 LKALMSH21040-5_34_52.tif
# 1302 LKALMSH21040-5_35_52.tif
# 1303 LKALMSH21040-5_36_52.tif
# 1304 LKALMSH21040-5_37_52.tif
# 1305 LKALMSH21040-5_38_52.tif
# 1306 LKALMSH21040-5_39_52.tif
# 1307 LKALMSH21040-5_4_52.tif
# 1308 LKALMSH21040-5_40_52.tif
# 1309 LKALMSH21040-5_41_52.tif
# 1310 LKALMSH21040-5_42_52.tif
# 1311 LKALMSH21040-5_43_52.tif
# 1312 LKALMSH21040-5_44_52.tif
# 1313 LKALMSH21040-5_45_52.tif
# 1314 LKALMSH21040-5_46_52.tif
# 1315 LKALMSH21040-5_47_52.tif
# 1316 LKALMSH21040-5_48_52.tif
# 1317 LKALMSH21040-5_49_52.tif
# 1318 LKALMSH21040-5_5_52.tif
# 1319 LKALMSH21040-5_50_52.tif
# 1320 LKALMSH21040-5_51_52.tif
# 1321 LKALMSH21040-5_52_52.tif
# 1322 LKALMSH21040-5_6_52.tif
# 1323 LKALMSH21040-5_7_52.tif
# 1324 LKALMSH21040-5_8_52.tif
# 1325 LKALMSH21040-5_9_52.tif
# 1326 LNUTTAC17136-1_1_3.tif
# 1327 LNUTTAC17136-1_2_3.tif
# 1328 LNUTTAC17136-1_3_3.tif
# 1329 LNUTTAC17136-2_1_2.tif
# 1330 LNUTTAC17136-2_2_2.tif
# 1331 LNUTTAC17136-3_1_1.tif
# 1332 LNUTTAC21048-1_1_11.tif
# 1333 LNUTTAC21048-1_10_11.tif
# 1334 LNUTTAC21048-1_11_11.tif
# 1335 LNUTTAC21048-1_2_11.tif
# 1336 LNUTTAC21048-1_3_11.tif
# 1337 LNUTTAC21048-1_4_11.tif
# 1338 LNUTTAC21048-1_5_11.tif
# 1339 LNUTTAC21048-1_6_11.tif
# 1340 LNUTTAC21048-1_7_11.tif
# 1341 LNUTTAC21048-1_8_11.tif
# 1342 LNUTTAC21048-1_9_11.tif
# 1343 LNUTTAC21048-2_1_6.tif
# 1344 LNUTTAC21048-2_2_6.tif
# 1345 LNUTTAC21048-2_3_6.tif
# 1346 LNUTTAC21048-2_4_6.tif
# 1347 LNUTTAC21048-2_5_6.tif
# 1348 LNUTTAC21048-2_6_6.tif
# 1349 LNUTTAC21048-4_1_6.tif
# 1350 LNUTTAC21048-4_2_6.tif
# 1351 LNUTTAC21048-4_3_6.tif
# 1352 LNUTTAC21048-4_4_6.tif
# 1353 LNUTTAC21048-4_5_6.tif
# 1354 LNUTTAC21048-4_6_6.tif
# 1355 LNUTTAC21048-5_1_5.tif
# 1356 LNUTTAC21048-5_2_5.tif
# 1357 LNUTTAC21048-5_3_5.tif
# 1358 LNUTTAC21048-5_4_5.tif
# 1359 LNUTTAC21048-5_5_5.tif
# 1360 LNUTTAC21048-6_1_8.tif
# 1361 LNUTTAC21048-6_2_8.tif
# 1362 LNUTTAC21048-6_3_8.tif
# 1363 LNUTTAC21048-6_4_8.tif
# 1364 LNUTTAC21048-6_5_8.tif
# 1365 LNUTTAC21048-6_6_8.tif
# 1366 LNUTTAC21048-6_7_8.tif
# 1367 LNUTTAC21048-6_8_8.tif
# 1368 LNUTTAC21048-7_1_5.tif
# 1369 LNUTTAC21048-7_2_5.tif
# 1370 LNUTTAC21048-7_3_5.tif
# 1371 LNUTTAC21048-7_4_5.tif
# 1372 LNUTTAC21048-7_5_5.tif
# 1373 LNUTTGG21062-1_1_1.tif
# 1374 LNUTTSH21045-1_1_11.tif
# 1375 LNUTTSH21045-1_11_11.tif
# 1376 LNUTTSH21045-1_2_11.tif
# 1377 LNUTTSH21045-1_3_11.tif
# 1378 LNUTTSH21045-1_4_11.tif
# 1379 LNUTTSH21045-1_5_11.tif
# 1380 LNUTTSH21045-1_6_11.tif
# 1381 LNUTTSH21045-1_7_11.tif
# 1382 LNUTTSH21045-1_8_11.tif
# 1383 LNUTTSH21045-1_9_11.tif
# 1384 LNUTTSH21045-2_1_6.tif
# 1385 LNUTTSH21045-2_2_6.tif
# 1386 LNUTTSH21045-2_3_6.tif
# 1387 LNUTTSH21045-2_4_6.tif
# 1388 LNUTTSH21045-2_5_6.tif
# 1389 LNUTTSH21045-2_6_6.tif
# 1390 LNUTTSH21045-3_1_8.tif
# 1391 LNUTTSH21045-3_2_8.tif
# 1392 LNUTTSH21045-3_3_8.tif
# 1393 LNUTTSH21045-3_4_8.tif
# 1394 LNUTTSH21045-3_5_8.tif
# 1395 LNUTTSH21045-3_6_8.tif
# 1396 LNUTTSH21045-3_7_8.tif
# 1397 LNUTTSH21045-3_8_8.tif
# 1398 LNUTTSH21045-4_1_8.tif
# 1399 LNUTTSH21045-4_2_8.tif
# 1400 LNUTTSH21045-4_3_8.tif
# 1401 LNUTTSH21045-4_4_8.tif
# 1402 LNUTTSH21045-4_5_8.tif
# 1403 LNUTTSH21045-4_6_8.tif
# 1404 LNUTTSH21045-4_7_8.tif
# 1405 LNUTTSH21045-4_8_8.tif
# 1406 LNUTTSH21045-5_1_5.tif
# 1407 LNUTTSH21045-5_2_5.tif
# 1408 LNUTTSH21045-5_3_5.tif
# 1409 LNUTTSH21045-5_4_5.tif
# 1410 LNUTTSH21045-6_10_10.tif
# 1411 LNUTTSH21045-6_2_10.tif
# 1412 LNUTTSH21045-6_5_10.tif
# 1413 LNUTTSH21045-6_6_10.tif
# 1414 LNUTTSH21045-6_7_10.tif
# 1415 LNUTTSH21045-6_8_10.tif
# 1416 LNUTTSH21045-6_9_10.tif
# 1417 LNUTTSH21045-7_1_10.tif
# 1418 LNUTTSH21045-7_10_10.tif
# 1419 LNUTTSH21045-7_2_10.tif
# 1420 LNUTTSH21045-7_3_10.tif
# 1421 LNUTTSH21045-7_4_10.tif
# 1422 LNUTTSH21045-7_5_10.tif
# 1423 LNUTTSH21045-7_6_10.tif
# 1424 LNUTTSH21045-7_7_10.tif
# 1425 LNUTTSH21045-7_8_10.tif
# 1426 LNUTTSH21045-7_9_10.tif
# 1427 LNUTTSH21045-9_1_5.tif
# 1428 LNUTTSH21045-9_2_5.tif
# 1429 LNUTTSH21045-9_3_5.tif
# 1430 LNUTTSH21045-9_4_5.tif
# 1431 LNUTTSH21045-9_5_5.tif
# 1432 LPALUAC21026-1_1_3.tif
# 1433 LPALUAC21026-1_2_3.tif
# 1434 LPALUAC21026-1_3_3.tif
# 1435 LPALUAC21026-3_1_6.tif
# 1436 LPALUAC21026-3_2_6.tif
# 1437 LPALUAC21026-3_3_6.tif
# 1438 LPALUAC21026-3_4_6.tif
# 1439 LPALUAC21026-3_5_6.tif
# 1440 LPALUAC21026-3_6_6.tif
# 1441 LPALUAC21026-4_1_2.tif
# 1442 LPALUAC21026-4_2_2.tif
# 1443 LPALUBS17067-1_1_7.tif
# 1444 LPALUBS17067-1_2_7.tif
# 1445 LPALUBS17067-1_3_7.tif
# 1446 LPALUBS17067-1_4_7.tif
# 1447 LPALUBS17067-1_5_7.tif
# 1448 LPALUBS17067-1_6_7.tif
# 1449 LPALUBS17067-1_7_7.tif
# 1450 LPALUBS17067-2_1_3.tif
# 1451 LPALUBS17067-2_2_3.tif
# 1452 LPALUBS17067-2_3_3.tif
# 1453 LPALUBS17067-3_1_4.tif
# 1454 LPALUBS17067-3_2_4.tif
# 1455 LPALUBS17067-3_3_4.tif
# 1456 LPALUBS17067-3_4_4.tif
# 1457 LPALUBS17067-4_1_4.tif
# 1458 LPALUBS17067-4_2_4.tif
# 1459 LPALUBS17067-4_3_4.tif
# 1460 LPALUBS17067-4_4_4.tif
# 1461 LPALUBS17067-5_1_5.tif
# 1462 LPALUBS17067-5_2_5.tif
# 1463 LPALUBS17067-5_3_5.tif
# 1464 LPALUBS17067-5_4_5.tif
# 1465 LPALUBS17067-5_5_5.tif
# 1466 LPALUBS17068-3_1_4.tif
# 1467 LPALUBS17068-3_2_4.tif
# 1468 LPALUBS17068-3_3_4.tif
# 1469 LPALUBS17068-3_4_4.tif
# 1470 LPALUBS17068-4_1_4.tif
# 1471 LPALUBS17068-4_2_4.tif
# 1472 LPALUBS17068-4_3_4.tif
# 1473 LPALUBS17068-4_4_4.tif
# 1474 LPALUBS17068-5_1_7.tif
# 1475 LPALUBS17068-5_2_7.tif
# 1476 LPALUBS17068-5_3_7.tif
# 1477 LPALUBS17068-5_4_7.tif
# 1478 LPALUBS17068-5_5_7.tif
# 1479 LPALUBS17068-5_6_7.tif
# 1480 LPALUBS17068-5_7_7.tif
# 1481 LPALUBS17068-6_1_2.tif
# 1482 LPALUBS17068-6_2_2.tif
# 1483 LPALUBS17068-7_1_3.tif
# 1484 LPALUBS17068-7_2_3.tif
# 1485 LPALUBS17068-7_3_3.tif
# 1486 LPALUBS17068-8_1_3.tif
# 1487 LPALUBS17068-8_2_3.tif
# 1488 LPALUBS17068-8_3_3.tif
# 1489 LPALUBS17068-9_1_5.tif
# 1490 LPALUBS17068-9_2_5.tif
# 1491 LPALUBS17069-1_1_3.tif
# 1492 LPALUBS17069-1_2_3.tif
# 1493 LPALUBS17069-1_3_3.tif
# 1494 LPALUBS17069-3_3_6.tif
# 1495 LPALUBS17069-4_1_7.tif
# 1496 LPALUBS17069-4_2_7.tif
# 1497 LPALUBS17069-4_3_7.tif
# 1498 LPALUBS17069-4_5_7.tif
# 1499 LPALUBS17069-4_6_7.tif
# 1500 LPALUBS17069-4_7_7.tif
# 1501 LPUBEAC17103-1_1_20.tif
# 1502 LPUBEAC17103-1_10_20.tif
# 1503 LPUBEAC17103-1_11_20.tif
# 1504 LPUBEAC17103-1_12_20.tif
# 1505 LPUBEAC17103-1_13_20.tif
# 1506 LPUBEAC17103-1_14_20.tif
# 1507 LPUBEAC17103-1_15_20.tif
# 1508 LPUBEAC17103-1_16_20.tif
# 1509 LPUBEAC17103-1_17_20.tif
# 1510 LPUBEAC17103-1_18_20.tif
# 1511 LPUBEAC17103-1_19_20.tif
# 1512 LPUBEAC17103-1_2_20.tif
# 1513 LPUBEAC17103-1_20_20.tif
# 1514 LPUBEAC17103-1_3_20.tif
# 1515 LPUBEAC17103-1_4_20.tif
# 1516 LPUBEAC17103-1_5_20.tif
# 1517 LPUBEAC17103-1_6_20.tif
# 1518 LPUBEAC17103-1_7_20.tif
# 1519 LPUBEAC17103-1_8_20.tif
# 1520 LPUBEAC17103-1_9_20.tif
# 1521 LPUBEAC17141-1_1_6.tif
# 1522 LPUBEAC17141-1_2_6.tif
# 1523 LPUBEAC17141-1_3_6.tif
# 1524 LPUBEAC17141-1_4_6.tif
# 1525 LPUBEAC17141-1_5_6.tif
# 1526 LPUBEAC17141-1_6_6.tif
# 1527 LPUBEAC17141-2_1_17.tif
# 1528 LPUBEAC17141-2_10_17.tif
# 1529 LPUBEAC17141-2_11_17.tif
# 1530 LPUBEAC17141-2_12_17.tif
# 1531 LPUBEAC17141-2_13_17.tif
# 1532 LPUBEAC17141-2_14_17.tif
# 1533 LPUBEAC17141-2_15_17.tif
# 1534 LPUBEAC17141-2_16_17.tif
# 1535 LPUBEAC17141-2_17_17.tif
# 1536 LPUBEAC17141-2_2_17.tif
# 1537 LPUBEAC17141-2_3_17.tif
# 1538 LPUBEAC17141-2_4_17.tif
# 1539 LPUBEAC17141-2_5_17.tif
# 1540 LPUBEAC17141-2_6_17.tif
# 1541 LPUBEAC17141-2_7_17.tif
# 1542 LPUBEAC17141-2_8_17.tif
# 1543 LPUBEAC17141-2_9_17.tif
# 1544 LPUBEAC17141-3_1_12.tif
# 1545 LPUBEAC17141-3_10_12.tif
# 1546 LPUBEAC17141-3_11_12.tif
# 1547 LPUBEAC17141-3_12_12.tif
# 1548 LPUBEAC17141-3_2_12.tif
# 1549 LPUBEAC17141-3_3_12.tif
# 1550 LPUBEAC17141-3_4_12.tif
# 1551 LPUBEAC17141-3_5_12.tif
# 1552 LPUBEAC17141-3_6_12.tif
# 1553 LPUBEAC17141-3_7_12.tif
# 1554 LPUBEAC17141-3_8_12.tif
# 1555 LPUBEAC17141-3_9_12.tif
# 1556 LPUBEAC21051-2_1_11.tif
# 1557 LPUBEAC21051-2_10_11.tif
# 1558 LPUBEAC21051-2_11_11.tif
# 1559 LPUBEAC21051-2_2_11.tif
# 1560 LPUBEAC21051-2_3_11.tif
# 1561 LPUBEAC21051-2_4_11.tif
# 1562 LPUBEAC21051-2_5_11.tif
# 1563 LPUBEAC21051-2_6_11.tif
# 1564 LPUBEAC21051-2_7_11.tif
# 1565 LPUBEAC21051-2_8_11.tif
# 1566 LPUBEAC21051-2_9_11.tif
# 1567 LPUBEAC21051-3_1_5.tif
# 1568 LPUBEAC21051-3_2_5.tif
# 1569 LPUBEAC21051-3_3_5.tif
# 1570 LPUBEAC21051-3_4_5.tif
# 1571 LPUBEAC21051-3_5_5.tif
# 1572 LPUBEAC21054-1_1_11.tif
# 1573 LPUBEAC21054-1_10_11.tif
# 1574 LPUBEAC21054-1_11_11.tif
# 1575 LPUBEAC21054-1_2_11.tif
# 1576 LPUBEAC21054-1_3_11.tif
# 1577 LPUBEAC21054-1_4_11.tif
# 1578 LPUBEAC21054-1_5_11.tif
# 1579 LPUBEAC21054-1_6_11.tif
# 1580 LPUBEAC21054-1_7_11.tif
# 1581 LPUBEAC21054-1_8_11.tif
# 1582 LPUBEAC21054-1_9_11.tif
# 1583 LPUBEAC21054-3_1_15.tif
# 1584 LPUBEAC21054-3_10_15.tif
# 1585 LPUBEAC21054-3_11_15.tif
# 1586 LPUBEAC21054-3_12_15.tif
# 1587 LPUBEAC21054-3_13_15.tif
# 1588 LPUBEAC21054-3_14_15.tif
# 1589 LPUBEAC21054-3_15_15.tif
# 1590 LPUBEAC21054-3_2_15.tif
# 1591 LPUBEAC21054-3_3_15.tif
# 1592 LPUBEAC21054-3_4_15.tif
# 1593 LPUBEAC21054-3_5_15.tif
# 1594 LPUBEAC21054-3_6_15.tif
# 1595 LPUBEAC21054-3_7_15.tif
# 1596 LPUBEAC21054-3_8_15.tif
# 1597 LPUBEAC21054-3_9_15.tif
# 1598 LPUBEAC21163-1_1_13.tif
# 1599 LPUBEAC21163-1_10_13.tif
# 1600 LPUBEAC21163-1_11_13.tif
# 1601 LPUBEAC21163-1_12_13.tif
# 1602 LPUBEAC21163-1_13_13.tif
# 1603 LPUBEAC21163-1_2_13.tif
# 1604 LPUBEAC21163-1_3_13.tif
# 1605 LPUBEAC21163-1_4_13.tif
# 1606 LPUBEAC21163-1_5_13.tif
# 1607 LPUBEAC21163-1_6_13.tif
# 1608 LPUBEAC21163-1_7_13.tif
# 1609 LPUBEAC21163-1_8_13.tif
# 1610 LPUBEAC21163-1_9_13.tif
# 1611 LPUBEAC21163-4_1_6.tif
# 1612 LPUBEAC21163-4_2_6.tif
# 1613 LPUBEAC21163-4_3_6.tif
# 1614 LPUBEAC21163-4_4_6.tif
# 1615 LPUBEAC21163-4_5_6.tif
# 1616 LPUBEAC21163-4_6_6.tif
# 1617 LPUBECB21052-1_1_24.tif
# 1618 LPUBECB21052-1_10_24.tif
# 1619 LPUBECB21052-1_11_24.tif
# 1620 LPUBECB21052-1_12_24.tif
# 1621 LPUBECB21052-1_13_24.tif
# 1622 LPUBECB21052-1_14_24.tif
# 1623 LPUBECB21052-1_15_24.tif
# 1624 LPUBECB21052-1_16_24.tif
# 1625 LPUBECB21052-1_17_24.tif
# 1626 LPUBECB21052-1_18_24.tif
# 1627 LPUBECB21052-1_19_24.tif
# 1628 LPUBECB21052-1_2_24.tif
# 1629 LPUBECB21052-1_20_24.tif
# 1630 LPUBECB21052-1_21_24.tif
# 1631 LPUBECB21052-1_22_24.tif
# 1632 LPUBECB21052-1_23_24.tif
# 1633 LPUBECB21052-1_24_24.tif
# 1634 LPUBECB21052-1_3_24.tif
# 1635 LPUBECB21052-1_4_24.tif
# 1636 LPUBECB21052-1_5_24.tif
# 1637 LPUBECB21052-1_6_24.tif
# 1638 LPUBECB21052-1_7_24.tif
# 1639 LPUBECB21052-1_8_24.tif
# 1640 LPUBECB21052-1_9_24.tif
# 1641 LPUBECB21061-1_1_24.tif
# 1642 LPUBECB21061-1_10_24.tif
# 1643 LPUBECB21061-1_11_24.tif
# 1644 LPUBECB21061-1_12_24.tif
# 1645 LPUBECB21061-1_13_24.tif
# 1646 LPUBECB21061-1_14_24.tif
# 1647 LPUBECB21061-1_15_24.tif
# 1648 LPUBECB21061-1_16_24.tif
# 1649 LPUBECB21061-1_17_24.tif
# 1650 LPUBECB21061-1_18_24.tif
# 1651 LPUBECB21061-1_19_24.tif
# 1652 LPUBECB21061-1_2_24.tif
# 1653 LPUBECB21061-1_20_24.tif
# 1654 LPUBECB21061-1_21_24.tif
# 1655 LPUBECB21061-1_22_24.tif
# 1656 LPUBECB21061-1_23_24.tif
# 1657 LPUBECB21061-1_24_24.tif
# 1658 LPUBECB21061-1_3_24.tif
# 1659 LPUBECB21061-1_4_24.tif
# 1660 LPUBECB21061-1_5_24.tif
# 1661 LPUBECB21061-1_6_24.tif
# 1662 LPUBECB21061-1_7_24.tif
# 1663 LPUBECB21061-1_8_24.tif
# 1664 LPUBECB21061-1_9_24.tif
# 1665 LPUBECB21061-3_1_13.tif
# 1666 LPUBECB21061-3_10_13.tif
# 1667 LPUBECB21061-3_11_13.tif
# 1668 LPUBECB21061-3_12_13.tif
# 1669 LPUBECB21061-3_13_13.tif
# 1670 LPUBECB21061-3_2_13.tif
# 1671 LPUBECB21061-3_3_13.tif
# 1672 LPUBECB21061-3_4_13.tif
# 1673 LPUBECB21061-3_5_13.tif
# 1674 LPUBECB21061-3_6_13.tif
# 1675 LPUBECB21061-3_7_13.tif
# 1676 LPUBECB21061-3_8_13.tif
# 1677 LPUBECB21061-3_9_13.tif
# 1678 LPUBECH17102-1_1_103.tif
# 1679 LPUBECH17102-1_10_103.tif
# 1680 LPUBECH17102-1_100_103.tif
# 1681 LPUBECH17102-1_101_103.tif
# 1682 LPUBECH17102-1_102_103.tif
# 1683 LPUBECH17102-1_103_103.tif
# 1684 LPUBECH17102-1_11_103.tif
# 1685 LPUBECH17102-1_12_103.tif
# 1686 LPUBECH17102-1_13_103.tif
# 1687 LPUBECH17102-1_14_103.tif
# 1688 LPUBECH17102-1_15_103.tif
# 1689 LPUBECH17102-1_16_103.tif
# 1690 LPUBECH17102-1_17_103.tif
# 1691 LPUBECH17102-1_18_103.tif
# 1692 LPUBECH17102-1_19_103.tif
# 1693 LPUBECH17102-1_2_103.tif
# 1694 LPUBECH17102-1_20_103.tif
# 1695 LPUBECH17102-1_21_103.tif
# 1696 LPUBECH17102-1_22_103.tif
# 1697 LPUBECH17102-1_23_103.tif
# 1698 LPUBECH17102-1_24_103.tif
# 1699 LPUBECH17102-1_25_103.tif
# 1700 LPUBECH17102-1_26_103.tif
# 1701 LPUBECH17102-1_27_103.tif
# 1702 LPUBECH17102-1_28_103.tif
# 1703 LPUBECH17102-1_29_103.tif
# 1704 LPUBECH17102-1_3_103.tif
# 1705 LPUBECH17102-1_30_103.tif
# 1706 LPUBECH17102-1_31_103.tif
# 1707 LPUBECH17102-1_32_103.tif
# 1708 LPUBECH17102-1_33_103.tif
# 1709 LPUBECH17102-1_34_103.tif
# 1710 LPUBECH17102-1_35_103.tif
# 1711 LPUBECH17102-1_36_103.tif
# 1712 LPUBECH17102-1_37_103.tif
# 1713 LPUBECH17102-1_38_103.tif
# 1714 LPUBECH17102-1_39_103.tif
# 1715 LPUBECH17102-1_4_103.tif
# 1716 LPUBECH17102-1_40_103.tif
# 1717 LPUBECH17102-1_41_103.tif
# 1718 LPUBECH17102-1_42_103.tif
# 1719 LPUBECH17102-1_43_103.tif
# 1720 LPUBECH17102-1_44_103.tif
# 1721 LPUBECH17102-1_45_103.tif
# 1722 LPUBECH17102-1_46_103.tif
# 1723 LPUBECH17102-1_47_103.tif
# 1724 LPUBECH17102-1_48_103.tif
# 1725 LPUBECH17102-1_49_103.tif
# 1726 LPUBECH17102-1_5_103.tif
# 1727 LPUBECH17102-1_50_103.tif
# 1728 LPUBECH17102-1_51_103.tif
# 1729 LPUBECH17102-1_52_103.tif
# 1730 LPUBECH17102-1_53_103.tif
# 1731 LPUBECH17102-1_54_103.tif
# 1732 LPUBECH17102-1_55_103.tif
# 1733 LPUBECH17102-1_56_103.tif
# 1734 LPUBECH17102-1_57_103.tif
# 1735 LPUBECH17102-1_58_103.tif
# 1736 LPUBECH17102-1_59_103.tif
# 1737 LPUBECH17102-1_6_103.tif
# 1738 LPUBECH17102-1_60_103.tif
# 1739 LPUBECH17102-1_61_103.tif
# 1740 LPUBECH17102-1_62_103.tif
# 1741 LPUBECH17102-1_63_103.tif
# 1742 LPUBECH17102-1_64_103.tif
# 1743 LPUBECH17102-1_65_103.tif
# 1744 LPUBECH17102-1_66_103.tif
# 1745 LPUBECH17102-1_67_103.tif
# 1746 LPUBECH17102-1_68_103.tif
# 1747 LPUBECH17102-1_69_103.tif
# 1748 LPUBECH17102-1_7_103.tif
# 1749 LPUBECH17102-1_70_103.tif
# 1750 LPUBECH17102-1_71_103.tif
# 1751 LPUBECH17102-1_72_103.tif
# 1752 LPUBECH17102-1_73_103.tif
# 1753 LPUBECH17102-1_74_103.tif
# 1754 LPUBECH17102-1_75_103.tif
# 1755 LPUBECH17102-1_76_103.tif
# 1756 LPUBECH17102-1_77_103.tif
# 1757 LPUBECH17102-1_78_103.tif
# 1758 LPUBECH17102-1_79_103.tif
# 1759 LPUBECH17102-1_8_103.tif
# 1760 LPUBECH17102-1_80_103.tif
# 1761 LPUBECH17102-1_81_103.tif
# 1762 LPUBECH17102-1_82_103.tif
# 1763 LPUBECH17102-1_83_103.tif
# 1764 LPUBECH17102-1_84_103.tif
# 1765 LPUBECH17102-1_85_103.tif
# 1766 LPUBECH17102-1_86_103.tif
# 1767 LPUBECH17102-1_87_103.tif
# 1768 LPUBECH17102-1_88_103.tif
# 1769 LPUBECH17102-1_89_103.tif
# 1770 LPUBECH17102-1_9_103.tif
# 1771 LPUBECH17102-1_90_103.tif
# 1772 LPUBECH17102-1_91_103.tif
# 1773 LPUBECH17102-1_92_103.tif
# 1774 LPUBECH17102-1_93_103.tif
# 1775 LPUBECH17102-1_94_103.tif
# 1776 LPUBECH17102-1_95_103.tif
# 1777 LPUBECH17102-1_96_103.tif
# 1778 LPUBECH17102-1_97_103.tif
# 1779 LPUBECH17102-1_98_103.tif
# 1780 LPUBECH17102-1_99_103.tif
# 1781 LPUBEGG21062-1_1_16.tif
# 1782 LPUBEGG21062-1_10_16.tif
# 1783 LPUBEGG21062-1_11_16.tif
# 1784 LPUBEGG21062-1_12_16.tif
# 1785 LPUBEGG21062-1_13_16.tif
# 1786 LPUBEGG21062-1_14_16.tif
# 1787 LPUBEGG21062-1_15_16.tif
# 1788 LPUBEGG21062-1_16_16.tif
# 1789 LPUBEGG21062-1_2_16.tif
# 1790 LPUBEGG21062-1_3_16.tif
# 1791 LPUBEGG21062-1_4_16.tif
# 1792 LPUBEGG21062-1_5_16.tif
# 1793 LPUBEGG21062-1_6_16.tif
# 1794 LPUBEGG21062-1_7_16.tif
# 1795 LPUBEGG21062-1_8_16.tif
# 1796 LPUBEGG21062-1_9_16.tif
# 1797 LPUBEMJ21175-2_1_13.tif
# 1798 LPUBEMJ21175-2_10_13.tif
# 1799 LPUBEMJ21175-2_11_13.tif
# 1800 LPUBEMJ21175-2_12_13.tif
# 1801 LPUBEMJ21175-2_13_13.tif
# 1802 LPUBEMJ21175-2_2_13.tif
# 1803 LPUBEMJ21175-2_3_13.tif
# 1804 LPUBEMJ21175-2_4_13.tif
# 1805 LPUBEMJ21175-2_5_13.tif
# 1806 LPUBEMJ21175-2_6_13.tif
# 1807 LPUBEMJ21175-2_7_13.tif
# 1808 LPUBEMJ21175-2_8_13.tif
# 1809 LPUBEMJ21175-2_9_13.tif
# 1810 LPUBEMJ21185-2_1_16.tif
# 1811 LPUBEMJ21185-2_10_16.tif
# 1812 LPUBEMJ21185-2_11_16.tif
# 1813 LPUBEMJ21185-2_12_16.tif
# 1814 LPUBEMJ21185-2_13_16.tif
# 1815 LPUBEMJ21185-2_13_16.tif
# 1816 LPUBEMJ21185-2_13_16.tif
# 1817 LPUBEMJ21185-2_13_16.tif
# 1818 LPUBEMJ21185-2_2_16.tif
# 1819 LPUBEMJ21185-2_3_16.tif
# 1820 LPUBEMJ21185-2_4_16.tif
# 1821 LPUBEMJ21185-2_5_16.tif
# 1822 LPUBEMJ21185-2_6_16.tif
# 1823 LPUBEMJ21185-2_7_16.tif
# 1824 LPUBEMJ21185-2_8_16.tif
# 1825 LPUBEMJ21185-2_9_16.tif
# 1826 LPUBEMJ21185-3_1_9.tif
# 1827 LPUBEMJ21185-3_2_9.tif
# 1828 LPUBEMJ21185-3_3_9.tif
# 1829 LPUBEMJ21185-3_4_9.tif
# 1830 LPUBEMJ21185-3_5_9.tif
# 1831 LPUBEMJ21185-3_6_9.tif
# 1832 LPUBEMJ21185-3_7_9.tif
# 1833 LPUBEMJ21185-3_8_9.tif
# 1834 LPUBEMJ21185-3_9_9.tif
# 1835 LROGEAC21176-1_1_2.tif
# 1836 LROGEAC21176-1_2_2.tif
# 1837 LROGEAC21176-2_1_8.tif
# 1838 LROGEAC21176-2_2_8.tif
# 1839 LROGEAC21176-2_3_8.tif
# 1840 LROGEAC21176-2_4_8.tif
# 1841 LROGEAC21176-2_6_8.tif
# 1842 LROGEAC21176-3_1_8.tif
# 1843 LROGEAC21176-3_4_8.tif
# 1844 LROGEAC21176-3_5_8.tif
# 1845 LROGEAC21176-3_6_8.tif
# 1846 LROGEAC21176-3_7_8.tif
# 1847 LROGEAC21176-3_8_8.tif
# 1848 LROGEAC21176-4_1_5.tif
# 1849 LROGEAC21176-4_3_5.tif
# 1850 LROGEAC21176-4_5_5.tif
# 1851 LSIPHAC17142-1_1_8.tif
# 1852 LSIPHAC17142-1_2_8.tif
# 1853 LSIPHAC17142-1_3_8.tif
# 1854 LSIPHAC17142-1_4_8.tif
# 1855 LSIPHAC17142-1_5_8.tif
# 1856 LSIPHAC17142-1_6_8.tif
# 1857 LSIPHAC17142-1_7_8.tif
# 1858 LSIPHAC17142-1_8_8.tif
# 1859 LSIPHAC21046-2_1_22.tif
# 1860 LSIPHAC21046-2_10_22.tif
# 1861 LSIPHAC21046-2_11_22.tif
# 1862 LSIPHAC21046-2_12_22.tif
# 1863 LSIPHAC21046-2_13_22.tif
# 1864 LSIPHAC21046-2_14_22.tif
# 1865 LSIPHAC21046-2_15_22.tif
# 1866 LSIPHAC21046-2_16_22.tif
# 1867 LSIPHAC21046-2_17_22.tif
# 1868 LSIPHAC21046-2_18_22.tif
# 1869 LSIPHAC21046-2_2_22.tif
# 1870 LSIPHAC21046-2_3_22.tif
# 1871 LSIPHAC21046-2_4_22.tif
# 1872 LSIPHAC21046-2_5_22.tif
# 1873 LSIPHAC21046-2_6_22.tif
# 1874 LSIPHAC21046-2_7_22.tif
# 1875 LSIPHAC21046-2_8_22.tif
# 1876 LSIPHAC21046-2_9_22.tif
# 1877 LSIPHPA22126-1_1_112.tif
# 1878 LSIPHPA22126-1_10_112.tif
# 1879 LSIPHPA22126-1_11_112.tif
# 1880 LSIPHPA22126-1_12_112.tif
# 1881 LSIPHPA22126-1_13_112.tif
# 1882 LSIPHPA22126-1_14_112.tif
# 1883 LSIPHPA22126-1_15_112.tif
# 1884 LSIPHPA22126-1_16_112.tif
# 1885 LSIPHPA22126-1_17_112.tif
# 1886 LSIPHPA22126-1_18_112.tif
# 1887 LSIPHPA22126-1_19_112.tif
# 1888 LSIPHPA22126-1_2_112.tif
# 1889 LSIPHPA22126-1_20_112.tif
# 1890 LSIPHPA22126-1_21_112.tif
# 1891 LSIPHPA22126-1_22_112.tif
# 1892 LSIPHPA22126-1_23_112.tif
# 1893 LSIPHPA22126-1_24_112.tif
# 1894 LSIPHPA22126-1_25_112.tif
# 1895 LSIPHPA22126-1_26_112.tif
# 1896 LSIPHPA22126-1_27_112.tif
# 1897 LSIPHPA22126-1_29_112.tif
# 1898 LSIPHPA22126-1_3_112.tif
# 1899 LSIPHPA22126-1_30_112.tif
# 1900 LSIPHPA22126-1_4_112.tif
# 1901 LSIPHPA22126-1_5_112.tif
# 1902 LSIPHPA22126-1_6_112.tif
# 1903 LSIPHPA22126-1_7_112.tif
# 1904 LSIPHPA22126-1_8_112.tif
# 1905 LSIPHPA22126-1_9_112.tif
# 1906 LSIPHPA22126-2_1_35.tif
# 1907 LSIPHPA22126-2_10_35.tif
# 1908 LSIPHPA22126-2_12_35.tif
# 1909 LSIPHPA22126-2_13_35.tif
# 1910 LSIPHPA22126-2_14_35.tif
# 1911 LSIPHPA22126-2_15_35.tif
# 1912 LSIPHPA22126-2_16_35.tif
# 1913 LSIPHPA22126-2_18_35.tif
# 1914 LSIPHPA22126-2_19_35.tif
# 1915 LSIPHPA22126-2_2_35.tif
# 1916 LSIPHPA22126-2_20_35.tif
# 1917 LSIPHPA22126-2_21_35.tif
# 1918 LSIPHPA22126-2_22_35.tif
# 1919 LSIPHPA22126-2_23_35.tif
# 1920 LSIPHPA22126-2_24_35.tif
# 1921 LSIPHPA22126-2_25_35.tif
# 1922 LSIPHPA22126-2_26_35.tif
# 1923 LSIPHPA22126-2_27_35.tif
# 1924 LSIPHPA22126-2_28_35.tif
# 1925 LSIPHPA22126-2_29_35.tif
# 1926 LSIPHPA22126-2_3_35.tif
# 1927 LSIPHPA22126-2_30_35.tif
# 1928 LSIPHPA22126-2_31_35.tif
# 1929 LSIPHPA22126-2_32_35.tif
# 1930 LSIPHPA22126-2_33_35.tif
# 1931 LSIPHPA22126-2_34_35.tif
# 1932 LSIPHPA22126-2_4_35.tif
# 1933 LSIPHPA22126-2_5_35.tif
# 1934 LSIPHPA22126-2_6_35.tif
# 1935 LSIPHPA22126-2_7_35.tif
# 1936 LSIPHPA22126-2_8_35.tif
# 1937 LSIPHPA22126-2_9_35.tif
# 1938 LSIPHPA22126-3_10_16.tif
# 1939 LSIPHPA22126-3_11_16.tif
# 1940 LSIPHPA22126-3_12_16.tif
# 1941 LSIPHPA22126-3_13_16.tif
# 1942 LSIPHPA22126-3_14_16.tif
# 1943 LSIPHPA22126-3_15_16.tif
# 1944 LSIPHPA22126-3_16_16.tif
# 1945 LSIPHPA22126-3_5_16.tif
# 1946 LSIPHPA22126-3_8_16.tif
# 1947 LSIPHPA22126-3_9_16.tif
# 1948 LSPICAC17073-1_1_11.tif
# 1949 LSPICAC17073-1_10_11.tif
# 1950 LSPICAC17073-1_11_11.tif
# 1951 LSPICAC17073-1_2_11.tif
# 1952 LSPICAC17073-1_3_11.tif
# 1953 LSPICAC17073-1_4_11.tif
# 1954 LSPICAC17073-1_5_11.tif
# 1955 LSPICAC17073-1_6_11.tif
# 1956 LSPICAC17073-1_7_11.tif
# 1957 LSPICAC17073-1_8_11.tif
# 1958 LSPICAC17073-1_9_11.tif
# 1959 LSPICAC17073-2_1_18.tif
# 1960 LSPICAC17073-2_10_18.tif
# 1961 LSPICAC17073-2_11_18.tif
# 1962 LSPICAC17073-2_12_18.tif
# 1963 LSPICAC17073-2_13_18.tif
# 1964 LSPICAC17073-2_14_18.tif
# 1965 LSPICAC17073-2_15_18.tif
# 1966 LSPICAC17073-2_16_18.tif
# 1967 LSPICAC17073-2_17_18.tif
# 1968 LSPICAC17073-2_18_18.tif
# 1969 LSPICAC17073-2_2_18.tif
# 1970 LSPICAC17073-2_3_18.tif
# 1971 LSPICAC17073-2_4_18.tif
# 1972 LSPICAC17073-2_5_18.tif
# 1973 LSPICAC17073-2_6_18.tif
# 1974 LSPICAC17073-2_7_18.tif
# 1975 LSPICAC17073-2_8_18.tif
# 1976 LSPICAC17073-2_9_18.tif
# 1977 LSPICAC17073-3_1_5.tif
# 1978 LSPICAC17073-3_2_5.tif
# 1979 LSPICAC17073-3_3_5.tif
# 1980 LSPICAC17073-3_4_5.tif
# 1981 LSPICAC17073-3_5_5.tif
# 1982 LSPICSH21034-1_1_10.tif
# 1983 LSPICSH21034-1_10_10.tif
# 1984 LSPICSH21034-1_2_10.tif
# 1985 LSPICSH21034-1_3_10.tif
# 1986 LSPICSH21034-1_4_10.tif
# 1987 LSPICSH21034-1_5_10.tif
# 1988 LSPICSH21034-1_6_10.tif
# 1989 LSPICSH21034-1_7_10.tif
# 1990 LSPICSH21034-1_8_10.tif
# 1991 LSPICSH21034-1_9_10.tif
# 1992 LSPICSH21034-2_1_7.tif
# 1993 LSPICSH21034-2_2_7.tif
# 1994 LSPICSH21034-2_3_7.tif
# 1995 LSPICSH21034-2_4_7.tif
# 1996 LSPICSH21034-2_5_7.tif
# 1997 LSPICSH21034-2_6_7.tif
# 1998 LSPICSH21034-2_7_7.tif
# 1999 LSPICSH21034-3_1_7.tif
# 2000 LSPICSH21034-3_2_7.tif
# 2001 LSPICSH21034-3_3_7.tif
# 2002 LSPICSH21034-3_4_7.tif
# 2003 LSPICSH21034-3_5_7.tif
# 2004 LSPICSH21034-3_6_7.tif
# 2005 LSPICSH21034-3_7_7.tif
# 2006 LSPICSH21034-4_1_12.tif
# 2007 LSPICSH21034-4_10_12.tif
# 2008 LSPICSH21034-4_11_12.tif
# 2009 LSPICSH21034-4_12_12.tif
# 2010 LSPICSH21034-4_2_12.tif
# 2011 LSPICSH21034-4_3_12.tif
# 2012 LSPICSH21034-4_4_12.tif
# 2013 LSPICSH21034-4_5_12.tif
# 2014 LSPICSH21034-4_6_12.tif
# 2015 LSPICSH21034-4_7_12.tif
# 2016 LSPICSH21034-4_8_12.tif
# 2017 LSPICSH21034-4_9_12.tif
# 2018 LSPICSH21034-6_1_23.tif
# 2019 LSPICSH21034-6_10_23.tif
# 2020 LSPICSH21034-6_11_23.tif
# 2021 LSPICSH21034-6_12_23.tif
# 2022 LSPICSH21034-6_13_23.tif
# 2023 LSPICSH21034-6_14_23.tif
# 2024 LSPICSH21034-6_15_23.tif
# 2025 LSPICSH21034-6_16_23.tif
# 2026 LSPICSH21034-6_17_23.tif
# 2027 LSPICSH21034-6_18_23.tif
# 2028 LSPICSH21034-6_19_23.tif
# 2029 LSPICSH21034-6_2_23.tif
# 2030 LSPICSH21034-6_20_23.tif
# 2031 LSPICSH21034-6_21_23.tif
# 2032 LSPICSH21034-6_22_23.tif
# 2033 LSPICSH21034-6_23_23.tif
# 2034 LSPICSH21034-6_3_23.tif
# 2035 LSPICSH21034-6_4_23.tif
# 2036 LSPICSH21034-6_5_23.tif
# 2037 LSPICSH21034-6_6_23.tif
# 2038 LSPICSH21034-6_7_23.tif
# 2039 LSPICSH21034-6_8_23.tif
# 2040 LSPICSH21034-6_9_23.tif
# 2041 LSPICSH21034-7_1_9.tif
# 2042 LSPICSH21034-7_2_9.tif
# 2043 LSPICSH21034-7_3_9.tif
# 2044 LSPICSH21034-7_4_9.tif
# 2045 LSPICSH21034-7_5_9.tif
# 2046 LSPICSH21034-7_6_9.tif
# 2047 LSPICSH21034-7_7_9.tif
# 2048 LSPICSH21034-7_8_9.tif
# 2049 LSPICSH21034-7_9_9.tif
# 2050 LSPICSH21036-1_1_3.tif
# 2051 LSPICSH21036-1_2_3.tif
# 2052 LSPICSH21036-1_3_3.tif
# 2053 LSPICSH21036-2_1_7.tif
# 2054 LSPICSH21036-2_2_7.tif
# 2055 LSPICSH21036-2_3_7.tif
# 2056 LSPICSH21036-2_4_7.tif
# 2057 LSPICSH21036-2_5_7.tif
# 2058 LSPICSH21036-2_6_7.tif
# 2059 LSPICSH21036-2_7_7.tif
# 2060 LSPICSH21036-4_1_6.tif
# 2061 LSPICSH21036-4_2_6.tif
# 2062 LSPICSH21036-4_3_6.tif
# 2063 LSPICSH21036-4_4_6.tif
# 2064 LSPICSH21036-4_5_6.tif
# 2065 LSPICSH21036-4_6_6.tif
# 2066 LSPICSH21036-5_1_9.tif
# 2067 LSPICSH21036-5_2_9.tif
# 2068 LSPICSH21036-5_3_9.tif
# 2069 LSPICSH21036-5_4_9.tif
# 2070 LSPICSH21036-5_5_9.tif
# 2071 LSPICSH21036-5_6_9.tif
# 2072 LSPICSH21036-5_7_9.tif
# 2073 LSPICSH21036-5_8_9.tif
# 2074 LSPICSH21036-5_9_9.tif

# %% [markdown]
# # Check by plotting random leaves

# %%
# Plot random leaves and check that it is working

plt.figure(figsize=(10,10)) # set figure size

rand_indices = np.random.randint(0,len(cm_arr),200) # generate random indices of leaves

plot_num = 1 # plot counter number

for i in rand_indices:
    
    plt.subplot(10,20,plot_num) # subplot number
    
    plt.plot(cm_arr[i,:,0], cm_arr[i,:,1], c="k", lw=1) # outline
    plt.fill(cm_arr[i,:,0], cm_arr[i,:,1], c="lightgray", lw=1) # fill
    
    plt.plot([min(cm_arr[i,:,0])-0.1,min(cm_arr[i,:,0])-0.1],
            [cm_arr[i,0,1], cm_arr[i,0,1]+1], c="k", lw=0.5) # cm scale
    
    #plt.scatter(cm_arr[i,:,0], cm_arr[i,:,1], c="k", s=0.1) # points
    plt.scatter(cm_arr[i,0,0], cm_arr[i,0,1], s=20) # base
    plt.scatter(cm_arr[i,res-1,0], cm_arr[i,res-1,1], s=20) # tip
    
    #plt.title(mdata["species"][i], fontsize=6)
    
    plt.gca().set_aspect("equal")
    plt.axis("off")
    
    plot_num += 1
    
plt.suptitle(str(res*2-1) + " pseudo-landmarks")
plt.tight_layout()

# %% [markdown]
# # Analyze leaf dimensions
#
# Using placed pseudo-landmarks representing leaves that are rotated upwards and scaled in centimeters from `cm_arr`, calculate the following:
#
# - `width`: difference in centimeters between minimum and maximum x values in an oriented leaf
# - `length`: difference in centimeters between minimum and maximum y values in an oriented leaf
# - `area`: area of the leaf in centimeters squared
# - `solidity`: the ratio of area to convex hull area
#
# Data is stored in the `mdata` dataframe.

# %%
# lists to store variables
width_list = []
length_list = []
area_list = []
peri_list = []
solidity_list = []
circ_list = []

# for each leaf . . .
for lf in range(len(cm_arr)):
    
    # for calculating dimensions, we need non-scaled leaves in centimeters
    curr_lf = cm_arr[lf,:,:] # select current leaf
    
    ### CALCULATE DIMENSIONS ###
    width = np.max(curr_lf[:,0])-np.min(curr_lf[:,0]) # calculate width
    length = np.max(curr_lf[:,1])-np.min(curr_lf[:,1]) # calculate length
    area = poly_area(curr_lf[:,0],curr_lf[:,1]) # calcualte area
    
    ### CALCULATE SOLIDITY ###
    hull = ConvexHull(curr_lf) # calculate convex hull of current leaf
    vertices = hull.vertices # isolate vertex indices of convex hull
    convex_area = poly_area(curr_lf[vertices,0], curr_lf[vertices,1]) # calculate convex area
    solidity = area / convex_area # calculate solidity

    ### CALCULATE CIRCULARITY ###
    peri = polygon_perimeter(curr_lf) # calculate perimeter
    circ = (4*(math.pi)*area)/(peri)**2

    # store data in lists
    width_list.append(width)
    length_list.append(length)
    area_list.append(area)
    peri_list.append(peri)
    solidity_list.append(solidity)
    circ_list.append(circ)
  
# add data to the mdata dataframe
mdata["width"] = width_list
mdata["length"] = length_list
mdata["area"] = area_list
mdata["perimeter"] = peri_list
mdata["solidity"] = solidity_list
mdata["circularity"] = circ_list
mdata["rel_node"] = mdata["node"]/mdata["count"]

mdata.to_csv('lobelia_dimensions.csv', index=False)

# %% [markdown]
# # Dimensions and allometric models

# %%
sns.pairplot(mdata,
             x_vars=["width", "length", "area","solidity","circularity"],
             y_vars=["width", "length", "area","solidity","circularity"],
             hue="species",
             plot_kws={"s": 10, "alpha":0.5, "lw":0}
            )

# %% [markdown]
# Check how linear and represented each species is before making allometric models

# %%
plt.figure(figsize=(8,10))

count = 1 # set a counter
for spe in mdata["species"].unique(): # for each species
    curr_spe = mdata[mdata["species"]==spe] # get current species

    plt.subplot(6,4,count)
    sns.scatterplot(x=np.log(curr_spe["length"]), y=np.log(curr_spe["width"]), s=10)
    plt.title(spe)
    count+=1

plt.suptitle("ln(width) vs ln(length)")
plt.tight_layout()

# %% [markdown]
# Create linear allometric models

# %%
spes = mdata["species"].unique() # get list of species

coef_list = []
func_list = []
xvals_list = []

for i in range(len(spes)):

    curr_spe = spes[i]

    coefs = np.polyfit(np.log(mdata["width"][mdata["species"]==curr_spe]),
                       np.log(mdata["length"][mdata["species"]==curr_spe]),
                      1)
    func = np.poly1d(coefs)
    xvals = np.linspace(np.log(np.min(mdata["width"][mdata["species"]==curr_spe])),
                             np.log(np.max(mdata["width"][mdata["species"]==curr_spe])), 100)

    coef_list.append(coefs)
    func_list.append(func)
    xvals_list.append(xvals)

# %% [markdown]
# Plot all allometric models

# %%
for i in range(len(spes)):

    curr_func = func_list[i]

    # plot allometric lines
    plt.plot(xvals_list[i], curr_func(xvals_list[i]), label=spes[i])

# plot one-to-one line
plt.plot(xvals, xvals, c="gray", linestyle="dashed")

plt.legend(bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal") # equal aspect ratio
plt.title("allometry, ln length vs. ln width") # title
plt.xlabel("ln width, cm") # x axis title
plt.ylabel("ln length, cm") # y axis title
# Out:
# Text(0, 0.5, 'ln length, cm')

# %% [markdown]
# Only plot models for those species with sufficient counts

# %%
spe_counts = [] # a list of counts of species
for spe in spes: # for each species
    spe_counts.append(len(mdata[mdata["species"]==spe])) # get the count

thresh = 20 # set threshold count to plot

for i in range(len(spes)):
    curr_func = func_list[i]
    if spe_counts[i]>=20:
        # plot allometric lines
        plt.plot(xvals_list[i], curr_func(xvals_list[i]), label=spes[i])
    else:
        continue

# plot one-to-one line
plt.plot(xvals, xvals, c="gray", linestyle="dashed")

plt.legend(bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal") # equal aspect ratio
plt.title("allometry, ln length vs. ln width") # title
plt.xlabel("ln width, cm") # x axis title
plt.ylabel("ln length, cm") # y axis title
# Out:
# Text(0, 0.5, 'ln length, cm')

# %% [markdown]
# # Procrustes analysis
#
# Perform a Procrustes analysis to translate, scale, and rotate leaf shapes
#
# - Select number of pseudo-landmarks and dimensions
# - Calculate the GPA mean leaf shape using the `gpa_mean` function
# - Align all leaves to the GPA mean
# - Store Procrustes super-imposed leaves in an array, `proc_arr`
# - Calculate a PCA for all possible axes and their variance (the number of leaves)
# - Calculate a PCA for just the axes needed for reconstruction of eigenleaves for morphospace (probably 2)

# %%
landmark_num = (res*2)-1 # select number of landmarks
dim_num = 2 # select number of coordinate value dimensions

##########################
### CALCULATE GPA MEAN ###
##########################

mean_shape = gpa_mean(cm_arr, landmark_num, dim_num)

################################
### ALIGN LEAVES TO GPA MEAN ###
################################

# array to store Procrustes aligned shapes
proc_arr = np.zeros(np.shape(cm_arr)) 

for i in range(len(cm_arr)):
    s1, s2, distance = procrustes(mean_shape, cm_arr[i,:,:]) # calculate procrustes adjusted shape to ref for current leaf
    proc_arr[i] = s2 # store procrustes adjusted shape to array

# %% [markdown]
# # Visualize mean leaf and allometry model together

# %%
# get indices of species in order by slope
slope_vals = np.array(coef_list)[:,0]
slope_inds = np.argsort(slope_vals)
# get indices of species in order by intercept
intercept_vals = np.array(coef_list)[:,1]
intercept_inds = np.argsort(intercept_vals)

# get overall x and y value min and max for comparison in plotting
xmin = np.min(np.log(mdata["width"]))
xmax = np.max(np.log(mdata["width"]))
ymin = np.min(np.log(mdata["length"]))
ymax = np.max(np.log(mdata["length"]))

plt.figure(figsize=(6*1.5,10*1.5))

count=1
for i in intercept_inds:
    if spe_counts[i]<thresh: # if under threshold number of samples, continue
        continue

    # plot the mean leaf shape
    plt.subplot(8,4,count)
    spe_inds = mdata[mdata["species"]==spes[i]].index
    proc_mean = np.mean(proc_arr[spe_inds,:,:], axis=0)
    plt.fill(proc_mean[:,0], proc_mean[:,1], c="gray")
    plt.title(spes[i])
    plt.gca().set_aspect("equal")
    plt.axis("off")
    count+=1

    # plot the allometric model
    plt.subplot(8,4,count)
    plt.scatter(x=np.log(mdata["width"].iloc[spe_inds]), y=np.log(mdata["length"].iloc[spe_inds]), c="dodgerblue", s=20)
    plt.scatter(x=np.log(mdata["width"]), y=np.log(mdata["length"]), zorder=0, c="orange", s=1, alpha=0.5)
    curr_func = func_list[i]
    plt.plot( xvals_list[i], curr_func(xvals_list[i]) , c="magenta", lw=4)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin, ymax)
    plt.xlabel("ln(width)")
    plt.ylabel("ln(length)")
    count+=1

plt.suptitle("ln(length) vs ln(width), by y-intercept\n\n")
plt.tight_layout()

# %% [markdown]
# # Principal Component Analysis

# %%
#################################################
### FIRST, CALCULATE PERCENT VARIANCE ALL PCs ###
#################################################

######
PC_NUMBER = 198 # PC number = not number of leaves, but features
#######

# use the reshape function to flatten to 2D
flat_arr = proc_arr.reshape(np.shape(proc_arr)[0], 
                                 np.shape(proc_arr)[1]*np.shape(proc_arr)[2]) 

pca_all = PCA(n_components=PC_NUMBER) 
PCs_all = pca_all.fit_transform(flat_arr) # fit a PCA for all data

# print out explained variance for each PC
print("PC: " + "var, " + "overall ") 
for i in range(len(pca_all.explained_variance_ratio_)):
    print("PC" + str(i+1) + ": " + str(round(pca_all.explained_variance_ratio_[i]*100,1)) + 
          "%, " + str(round(pca_all.explained_variance_ratio_.cumsum()[i]*100,1)) + "%"  )
# Out:
# PC: var, overall
# PC1: 46.7%, 46.7%
# PC2: 16.3%, 63.0%
# PC3: 9.4%, 72.4%
# PC4: 8.4%, 80.9%
# PC5: 6.8%, 87.7%
# PC6: 2.1%, 89.8%
# PC7: 1.8%, 91.7%
# PC8: 1.6%, 93.3%
# PC9: 1.5%, 94.8%
# PC10: 0.8%, 95.6%
# PC11: 0.6%, 96.1%
# PC12: 0.5%, 96.7%
# PC13: 0.4%, 97.1%
# PC14: 0.3%, 97.4%
# PC15: 0.3%, 97.7%
# PC16: 0.3%, 97.9%
# PC17: 0.2%, 98.2%
# PC18: 0.2%, 98.4%
# PC19: 0.1%, 98.5%
# PC20: 0.1%, 98.6%
# PC21: 0.1%, 98.8%
# PC22: 0.1%, 98.9%
# PC23: 0.1%, 98.9%
# PC24: 0.1%, 99.0%
# PC25: 0.1%, 99.1%
# PC26: 0.1%, 99.2%
# PC27: 0.1%, 99.2%
# PC28: 0.0%, 99.3%
# PC29: 0.0%, 99.3%
# PC30: 0.0%, 99.4%
# PC31: 0.0%, 99.4%
# PC32: 0.0%, 99.4%
# PC33: 0.0%, 99.4%
# PC34: 0.0%, 99.5%
# PC35: 0.0%, 99.5%
# PC36: 0.0%, 99.5%
# PC37: 0.0%, 99.6%
# PC38: 0.0%, 99.6%
# PC39: 0.0%, 99.6%
# PC40: 0.0%, 99.6%
# PC41: 0.0%, 99.6%
# PC42: 0.0%, 99.6%
# PC43: 0.0%, 99.7%
# PC44: 0.0%, 99.7%
# PC45: 0.0%, 99.7%
# PC46: 0.0%, 99.7%
# PC47: 0.0%, 99.7%
# PC48: 0.0%, 99.7%
# PC49: 0.0%, 99.7%
# PC50: 0.0%, 99.7%
# PC51: 0.0%, 99.7%
# PC52: 0.0%, 99.8%
# PC53: 0.0%, 99.8%
# PC54: 0.0%, 99.8%
# PC55: 0.0%, 99.8%
# PC56: 0.0%, 99.8%
# PC57: 0.0%, 99.8%
# PC58: 0.0%, 99.8%
# PC59: 0.0%, 99.8%
# PC60: 0.0%, 99.8%
# PC61: 0.0%, 99.8%
# PC62: 0.0%, 99.8%
# PC63: 0.0%, 99.8%
# PC64: 0.0%, 99.8%
# PC65: 0.0%, 99.8%
# PC66: 0.0%, 99.8%
# PC67: 0.0%, 99.8%
# PC68: 0.0%, 99.9%
# PC69: 0.0%, 99.9%
# PC70: 0.0%, 99.9%
# PC71: 0.0%, 99.9%
# PC72: 0.0%, 99.9%
# PC73: 0.0%, 99.9%
# PC74: 0.0%, 99.9%
# PC75: 0.0%, 99.9%
# PC76: 0.0%, 99.9%
# PC77: 0.0%, 99.9%
# PC78: 0.0%, 99.9%
# PC79: 0.0%, 99.9%
# PC80: 0.0%, 99.9%
# PC81: 0.0%, 99.9%
# PC82: 0.0%, 99.9%
# PC83: 0.0%, 99.9%
# PC84: 0.0%, 99.9%
# PC85: 0.0%, 99.9%
# PC86: 0.0%, 99.9%
# PC87: 0.0%, 99.9%
# PC88: 0.0%, 99.9%
# PC89: 0.0%, 99.9%
# PC90: 0.0%, 99.9%
# PC91: 0.0%, 99.9%
# PC92: 0.0%, 99.9%
# PC93: 0.0%, 99.9%
# PC94: 0.0%, 99.9%
# PC95: 0.0%, 99.9%
# PC96: 0.0%, 99.9%
# PC97: 0.0%, 99.9%
# PC98: 0.0%, 99.9%
# PC99: 0.0%, 99.9%
# PC100: 0.0%, 99.9%
# PC101: 0.0%, 99.9%
# PC102: 0.0%, 99.9%
# PC103: 0.0%, 99.9%
# PC104: 0.0%, 99.9%
# PC105: 0.0%, 99.9%
# PC106: 0.0%, 99.9%
# PC107: 0.0%, 99.9%
# PC108: 0.0%, 99.9%
# PC109: 0.0%, 100.0%
# PC110: 0.0%, 100.0%
# PC111: 0.0%, 100.0%
# PC112: 0.0%, 100.0%
# PC113: 0.0%, 100.0%
# PC114: 0.0%, 100.0%
# PC115: 0.0%, 100.0%
# PC116: 0.0%, 100.0%
# PC117: 0.0%, 100.0%
# PC118: 0.0%, 100.0%
# PC119: 0.0%, 100.0%
# PC120: 0.0%, 100.0%
# PC121: 0.0%, 100.0%
# PC122: 0.0%, 100.0%
# PC123: 0.0%, 100.0%
# PC124: 0.0%, 100.0%
# PC125: 0.0%, 100.0%
# PC126: 0.0%, 100.0%
# PC127: 0.0%, 100.0%
# PC128: 0.0%, 100.0%
# PC129: 0.0%, 100.0%
# PC130: 0.0%, 100.0%
# PC131: 0.0%, 100.0%
# PC132: 0.0%, 100.0%
# PC133: 0.0%, 100.0%
# PC134: 0.0%, 100.0%
# PC135: 0.0%, 100.0%
# PC136: 0.0%, 100.0%
# PC137: 0.0%, 100.0%
# PC138: 0.0%, 100.0%
# PC139: 0.0%, 100.0%
# PC140: 0.0%, 100.0%
# PC141: 0.0%, 100.0%
# PC142: 0.0%, 100.0%
# PC143: 0.0%, 100.0%
# PC144: 0.0%, 100.0%
# PC145: 0.0%, 100.0%
# PC146: 0.0%, 100.0%
# PC147: 0.0%, 100.0%
# PC148: 0.0%, 100.0%
# PC149: 0.0%, 100.0%
# PC150: 0.0%, 100.0%
# PC151: 0.0%, 100.0%
# PC152: 0.0%, 100.0%
# PC153: 0.0%, 100.0%
# PC154: 0.0%, 100.0%
# PC155: 0.0%, 100.0%
# PC156: 0.0%, 100.0%
# PC157: 0.0%, 100.0%
# PC158: 0.0%, 100.0%
# PC159: 0.0%, 100.0%
# PC160: 0.0%, 100.0%
# PC161: 0.0%, 100.0%
# PC162: 0.0%, 100.0%
# PC163: 0.0%, 100.0%
# PC164: 0.0%, 100.0%
# PC165: 0.0%, 100.0%
# PC166: 0.0%, 100.0%
# PC167: 0.0%, 100.0%
# PC168: 0.0%, 100.0%
# PC169: 0.0%, 100.0%
# PC170: 0.0%, 100.0%
# PC171: 0.0%, 100.0%
# PC172: 0.0%, 100.0%
# PC173: 0.0%, 100.0%
# PC174: 0.0%, 100.0%
# PC175: 0.0%, 100.0%
# PC176: 0.0%, 100.0%
# PC177: 0.0%, 100.0%
# PC178: 0.0%, 100.0%
# PC179: 0.0%, 100.0%
# PC180: 0.0%, 100.0%
# PC181: 0.0%, 100.0%
# PC182: 0.0%, 100.0%
# PC183: 0.0%, 100.0%
# PC184: 0.0%, 100.0%
# PC185: 0.0%, 100.0%
# PC186: 0.0%, 100.0%
# PC187: 0.0%, 100.0%
# PC188: 0.0%, 100.0%
# PC189: 0.0%, 100.0%
# PC190: 0.0%, 100.0%
# PC191: 0.0%, 100.0%
# PC192: 0.0%, 100.0%
# PC193: 0.0%, 100.0%
# PC194: 0.0%, 100.0%
# PC195: 0.0%, 100.0%
# PC196: 0.0%, 100.0%
# PC197: 0.0%, 100.0%
# PC198: 0.0%, 100.0%

# %%
#################################################
### NEXT, CALCULATE THE DESIRED NUMBER OF PCs ###
#################################################

######
PC_comps = 5 # keep to 5 for now for reconstruction
#######

pca = PCA(n_components=PC_comps) 
PCs = pca.fit_transform(flat_arr) # fit a PCA for only desired PCs

# print out explained variance for each PC
print("PC: " + "var, " + "overall ") 
for i in range(len(pca.explained_variance_ratio_)):
    print("PC" + str(i+1) + ": " + str(round(pca.explained_variance_ratio_[i]*100,1)) + 
          "%, " + str(round(pca.explained_variance_ratio_.cumsum()[i]*100,1)) + "%"  )
    
# add PCs to dataframe for plotting
mdata["PC1"] = PCs[:,0]
mdata["PC2"] = PCs[:,1]
mdata["PC3"] = PCs[:,2]
mdata["PC4"] = PCs[:,3]
mdata["PC5"] = PCs[:,4]
# Out:
# PC: var, overall
# PC1: 46.7%, 46.7%
# PC2: 16.3%, 63.0%
# PC3: 9.4%, 72.4%
# PC4: 8.4%, 80.9%
# PC5: 6.8%, 87.7%

# %%
nstdev = 2 # set number of standard deviations
int = 20 # set interval number

## calculate PC vals for eigenkernels
PCval_arr = np.zeros((PC_comps, int, PC_comps)) # array to hold PC vals for eigenkernels
for i in range(PC_comps): # for each PC
    stdvals = np.linspace(-nstdev,+nstdev,int) # set standard deviation values to calculate eigenkernels
    for j in range(len(stdvals)): # for each stdval
        PCval_arr[i,j,i] =  (np.mean(PCs[:,i]))+np.std(PCs[:,i])*stdvals[j] # store PC vals

## calculate eigenleaf shapes
eigenlf = np.zeros((PC_comps, int, 2*res-1, 2))
for k in range(PC_comps):
    for l in range(int):
        # calculate the inverse eigenkernels
        inv_lf = pca.inverse_transform( PCval_arr[k,l,:] )
        inv_x = inv_lf[0:(2*res-1)*2:2] # select just inverse x vals
        inv_y = inv_lf[1:(2*res-1)*2:2] # select just inverse y vals
        eigenlf[k,l,:,:] = np.column_stack((inv_x, inv_y))

# %%
counter = 1
plt.figure(figsize=(9,3))

for m in range(PC_comps):
    for n in range(int):
        plt.subplot(PC_comps,int,counter)
        plt.fill(eigenlf[m,n,:,0], eigenlf[m,n,:,1], c="#16161d")
        plt.gca().set_aspect("equal")
        counter+=1
        plt.axis("off")
plt.tight_layout()

# %%
plt.subplot(3,1,1)
sns.scatterplot(mdata, x="PC1", y="PC3", hue="species", legend=False)

plt.subplot(3,1,2)
sns.scatterplot(mdata, x="PC1", y="PC4", hue="species", legend=False)

plt.subplot(3,1,3)
sns.scatterplot(mdata, x="PC1", y="PC5", hue="species", legend=False)

plt.tight_layout()

# %%
plt.subplot(5,1,1)
sns.histplot(mdata, x="PC1",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,2)
sns.histplot(mdata, x="PC2",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,3)
sns.histplot(mdata, x="PC3",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,4)
sns.histplot(mdata, x="PC4",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,5)
sns.histplot(mdata, x="PC5",hue="species", multiple="stack", legend=False)
# Out:
# <Axes: xlabel='PC5', ylabel='Count'>

# %% [markdown]
# Save PCA and PC vals for 3D light modeling

# %%
######
PC_comps = 10 
#######

pca = PCA(n_components=PC_comps) 
PCs = pca.fit_transform(flat_arr) # fit a PCA for only desired PCs

import pickle
with open("lobelia_pca.pkl", "wb") as file:
    pickle.dump(pca, file)
np.save('lobelia_pc_vals.npy', PCs)

# %% [markdown]
# # Linear Discriminant Analysis by species

# %%
# get value counts of species
mdata["species"].value_counts()
# Out:
# species
# glandulosa          416
# puberula            334
# elongata            190
# flaccidifolia       150
# dortmanna           149
# spicata             127
# nuttalii            106
# siphilitica          97
# kalmii               88
# cardinalis           85
# paludosa             69
# brevifolia           57
# appendiculata        55
# inflata              33
# canbyi               30
# feayana              30
# apalachicolensis     19
# rogersii             16
# batsonii             11
# amoena                6
# georgiana             3
# gattingerii           2
# floridana             2
# Name: count, dtype: int64

# %%
# create a df for LDA by species
species_df = pd.DataFrame(data=flat_arr[:,:])

# List of factor levels to remove
# remove 5 or lower samples, for K fold stratified sampling of 5
levels_to_remove = []
for i in range(len(spes)):
    if spe_counts[i]<thresh: # if under threshold number of samples, add to species to exclude
        levels_to_remove.append(spes[i])

# list of indices to remove
indices_to_remove = mdata[mdata['species'].isin(levels_to_remove)].index.tolist()

# remove indices from procrustes coordinates
# create input and output variables
X = species_df.iloc[:,0:((res*2)-1)*2]
X = X.drop(indices_to_remove).reset_index(drop=True)
y = mdata["species"].drop(indices_to_remove).reset_index(drop=True)

# fit the LDA model
species_model = LinearDiscriminantAnalysis()

# create a StratifiedKFold object with k=5
skf = StratifiedKFold(n_splits=5)

# initialize an empty confusion matrix
cm = np.zeros( ( len(np.unique(y)), len(np.unique(y))  ))

# perform stratified k-fold cross-validation
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the LDA model on the training data
    species_model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = species_model.predict(X_test)

    # Update the confusion matrix
    cm += confusion_matrix(y_test, y_pred)

row_sums = cm.sum(axis=1, keepdims=True)
cm = cm / row_sums

classes = np.sort(y.unique())

# Confusion matrix

plt.figure(figsize=(10,10))

sns.heatmap(cm, 
            #annot=False, 
            #annot_kws={"fontsize":8}, 
            #fmt="{0:f}", 
            cmap="viridis", 
            square=True, 
            cbar=True,
            xticklabels=classes,
            yticklabels=classes,
            #norm=LogNorm()
           )
plt.title("Confusion matrix by species")
plt.xlabel("Predicted class")
plt.ylabel("Actual class")
# Out:
# Text(95.72222222222221, 0.5, 'Actual class')

# %%
# Create a dataframe to cluster the confusion matrix
cm_df = pd.DataFrame(cm, columns=classes)
cm_df.index = classes

# %%
sns.clustermap(cm_df, row_cluster=True, col_cluster=True)

# %%
# Plot of linear discriminant scores by genotype

data_plot = species_model.fit(X, y).transform(X)
species_plot_df = pd.DataFrame(data=data_plot[:,:])
species_plot_df["species"] = mdata["species"]
species_plot_df = species_plot_df.drop(indices_to_remove).reset_index(drop=True)

species_plot_df = species_plot_df.rename(columns={0:'LD1', 1:'LD2', 2:"LD3", 3:"LD4", 4:"LD5", 5:"LD6"})

sns.scatterplot(data=species_plot_df, x="LD1", y="LD2", hue="species", s=10)
plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left', borderaxespad=0.)

plt.title("Linear Discriminants by species")
# Out:
# Text(0.5, 1.0, 'Linear Discriminants by species')

# %%
groupA = ["spicata","appendiculata","puberula","inflata","siphilitica"]
groupB = ["cardinalis","elongata","feayana"]
groupC = ["brevifolia"]
groupD = ["flaccidifolia","kalmii","nuttalii","paludosa"]
groupE = ["dortmanna","canbyi","glandulosa"]

# %%
morphotype = []

for i in range(len(species_plot_df)):
    curr_spe = species_plot_df["species"].iloc[i]
    if curr_spe in groupA:
        morphotype.append("A")
    elif curr_spe in groupB:
        morphotype.append("B")
    elif curr_spe in groupC:
        morphotype.append("C")
    elif curr_spe in groupD:
        morphotype.append("D")
    elif curr_spe in groupE:
        morphotype.append("E")

species_plot_df["morphotype"] = morphotype

# %%
sns.scatterplot(data=species_plot_df, x="LD1", y="LD2", hue="morphotype", s=20)
plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left', borderaxespad=0.)

plt.title("Linear Discriminants by species")
# Out:
# Text(0.5, 1.0, 'Linear Discriminants by species')

# %%
groupA = ["spicata","appendiculata","puberula","inflata","siphilitica"]
groupB = ["cardinalis","elongata","feayana"]
groupC = ["brevifolia"]
groupD = ["flaccidifolia","kalmii","nuttalii","paludosa"]
groupE = ["dortmanna","canbyi","glandulosa"]


species_list = ["spicata","appendiculata","puberula","inflata","siphilitica",
"cardinalis","elongata","feayana",
"brevifolia",
"flaccidifolia","kalmii","nuttalii","paludosa",
"dortmanna","canbyi","glandulosa"         
               ]

color_list = ["dodgerblue","dodgerblue","dodgerblue","dodgerblue","dodgerblue",
              "red","red","red",
              "orange",
              "purple","purple","purple","purple",
              "green","green","green",]

# %%
plt.figure(figsize=(6,7))

count = 1

for i in range(len(species_list)):

    curr_spe = species_list[i]
    inds = mdata[mdata["species"]==curr_spe].index
    curr_proc = proc_arr[inds,:,:]
    mean_shape = np.mean(curr_proc, axis=0)

    plt.subplot(5,4,count)
    plt.plot(mean_shape[:,0], mean_shape[:,1], c=color_list[i])
    plt.fill(mean_shape[:,0], mean_shape[:,1], c=color_list[i], alpha=0.6)
    plt.gca().set_aspect("equal")
    plt.title(curr_spe)
    plt.axis("off")

    count+=1

plt.tight_layout()

# %% [markdown]
# # Statistical differences in Procrustes distance values

# %%
# get all cultivar names
cult_names = mdata["species"].unique()

# get all pairwise combinations of cultivar names
combinations = list(itertools.combinations(cult_names, 2))

group1_names = [] # a list to store group1 names
group2_names = [] # a list to store group2 names
p_vals = [] # a list to store pvals

for i in range(len(combinations)): # for each combination

    group1 = combinations[i][0] # get the first group name
    group2 = combinations[i][1] # get the second group name
    
    # get the Procrustean coordinates from each group
    group1_lfs = proc_arr[np.array(mdata[mdata["species"]==group1].index)]
    group2_lfs = proc_arr[np.array(mdata[mdata["species"]==group2].index)]
    all_lfs = proc_arr[np.array(mdata[(mdata["species"]==group1) | (mdata["species"]==group2)].index)]
    
    # calculate mean leaf for each group
    group1_mean = np.mean(group1_lfs, axis=0)
    group2_mean = np.mean(group2_lfs, axis=0)
    all_mean = np.mean(all_lfs, axis=0)
    
    # calculate Procrustes distance of each leaf to respective group mean
    group1_dists = []
    for i in range(len(group1_lfs)):
        s1, s2, distance = procrustes(group1_lfs[i,:,:], group1_mean) 
        group1_dists.append(distance)
    
    group2_dists = []
    for i in range(len(group2_lfs)):
        s1, s2, distance = procrustes(group2_lfs[i,:,:], group2_mean) 
        group2_dists.append(distance)
    
    # concatenate arrays to group mean 
    group_mean_dists = np.array(group1_dists+group2_dists)
    
    # calculate Procrustes distance of each leaf to overall mean
    all_dists = []
    for i in range(len(all_lfs)):
        s1, s2, distance = procrustes(all_lfs[i,:,:], all_mean) 
        all_dists.append(distance)
    all_dists = np.array(all_dists)

    # calculate p value
    statistic, p_value = stats.kruskal(group_mean_dists, all_dists)

    # store data
    p_vals.append(p_value)
    group1_names.append(group1)
    group2_names.append(group2)

# Adjust p-values using the FDR BH correction
BH_pvals = multitest.multipletests(p_vals, method='fdr_bh', alpha=0.05)

# create a matrix for clustermap
group_df = pd.DataFrame({

    "group1":group1_names,
    "group2":group2_names,
    "significant":BH_pvals[0],
    "BH":BH_pvals[1]
})

inv_group_df = pd.DataFrame({
    "group1":group2_names,
    "group2":group1_names,
    "significant":BH_pvals[0],
    "BH":BH_pvals[1]
})


pairwise_df = pd.concat([group_df, inv_group_df])

matrix = (pairwise_df.pivot(index='group1', columns='group2', values='BH')
   .fillna(1, downcast='infer')
)

g = sns.clustermap(matrix)
ax = g.ax_heatmap
#[ax.axhline(y=i, color='white', linestyle='-') for i in [4,9]]
#[ax.axvline(x=i, color='white', linestyle='-') for i in [4,9]]

# %%
groupA = ["LCANB","LNUTT","LPALU","LKALM","LGLAN","LDORT","LFLAC"]
groupB = ["LCARD","LPUBE","LFEAY","LROGE","LBREV","LELON","LSPIC","LAPPE","LINFL","LSIPH"]
groupC = ["LAMOE","LBATS","LAPAL","LFLOR"]

# %%
species_list = ["LCANB","LNUTT","LPALU","LKALM","LGLAN","LDORT","LFLAC",
"LCARD","LPUBE","LFEAY","LROGE","LBREV","LELON","LSPIC","LAPPE","LINFL","LSIPH",
"LAMOE","LBATS","LAPAL","LFLOR"]

color_list = ["orange","orange","orange","orange","orange","orange","orange",
              "green","green","green","green","green","green","green","green","green","green",
              "dodgerblue","dodgerblue","dodgerblue","dodgerblue",]

# %%
plt.figure(figsize=(6,7))

count = 1

for i in range(len(species_list)):

    curr_spe = species_list[i]
    inds = mdata[mdata["species"]==curr_spe].index
    curr_proc = proc_arr[inds,:,:]
    mean_shape = np.mean(curr_proc, axis=0)

    plt.subplot(5,5,count)
    plt.plot(mean_shape[:,0], mean_shape[:,1], c=color_list[i])
    plt.fill(mean_shape[:,0], mean_shape[:,1], c=color_list[i], alpha=0.6)
    plt.gca().set_aspect("equal")
    plt.title(curr_spe)
    plt.axis("off")

    count+=1

plt.tight_layout()

# %%
groups = []

for i in range(len(mdata)):
    curr_spe = mdata["species"].iloc[i]
    if curr_spe in groupA:
        groups.append("A")
    elif curr_spe in groupB:
        groups.append("B")
    elif curr_spe in groupC:
        groups.append("C")

mdata["group"] = groups

# %%
# get A, B, and C leaf coords from proc_arr using indices from df all_mdata
A_lfs = proc_arr[np.array(mdata[mdata["group"]=="A"].index)]
B_lfs = proc_arr[np.array(mdata[mdata["group"]=="B"].index)]
C_lfs = proc_arr[np.array(mdata[mdata["group"]=="C"].index)]

# create mean leaves for A, B, and C, pairwise, and overall mean
A_mean = np.mean(A_lfs, axis=0)
B_mean = np.mean(B_lfs, axis=0)
C_mean = np.mean(C_lfs, axis=0)

A_B_mean = np.mean(np.row_stack((A_lfs, B_lfs)), axis=0)
A_C_mean = np.mean(np.row_stack((A_lfs, C_lfs)), axis=0)
B_C_mean = np.mean(np.row_stack((B_lfs, C_lfs)), axis=0)

overall_mean = np.mean(proc_arr, axis=0)

# plot our comparison of A, B, and C procrustean leaves and means
plt.figure(figsize=(20,10))

A_col = "orange"
B_col = "green"
C_col = "dodgerblue"

#########################
# A vs B
#########################

plt.subplot(131)
plt.plot(A_mean[:,0],A_mean[:,1], c=A_col, lw=3, label="A")
plt.plot(B_mean[:,0],B_mean[:,1], c=B_col, lw=3, label="B")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="A":
        col = A_col
    else:
        col = B_col

    plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")

#########################
# A vs C
#########################

plt.subplot(132)
plt.plot(A_mean[:,0],A_mean[:,1], c=A_col, lw=3, label="A")
plt.plot(C_mean[:,0],C_mean[:,1], c=C_col, lw=3, label="C")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="A":
        col = A_col
    else:
        col = C_col

    plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")

#########################
# B vs C
#########################

plt.subplot(133)
plt.plot(B_mean[:,0],B_mean[:,1], c=B_col, lw=3, label="B")
plt.plot(C_mean[:,0],C_mean[:,1], c=C_col, lw=3, label="C")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="B":
        col = B_col
    else:
        col = C_col

    plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")

# %%
#########################
#########################
######## A VS B #########
#########################
#########################

A_B_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_mean[i,0],A_mean[i,1])
    # eulidean distances of B sample to B mean
    B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_mean[i,0],B_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((A_eds, B_eds))

    ## GROUP 2##
    # eulidean distances of A to pairwise mean
    ovr_A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_B_mean[i,0],A_B_mean[i,1])
    # eulidean distances of B sample to pairwise mean
    ovr_B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                A_B_mean[i,0],A_B_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_A_eds, ovr_B_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    A_B_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
A_B_fdrBH_pvals = multitest.multipletests(A_B_p_vals, method='fdr_bh')

# get -log10 p values
A_B_neg_log10 = -np.log10(A_B_fdrBH_pvals[1])


#########################
#########################
######## A VS C #########
#########################
#########################

A_C_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_mean[i,0],A_mean[i,1])
    # eulidean distances of C sample to C mean
    C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                C_mean[i,0],C_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((A_eds, C_eds))

    ## GROUP 2##
    # eulidean distances of A to pairwise mean
    ovr_A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_C_mean[i,0],A_C_mean[i,1])
    # eulidean distances of C sample to overall mean
    ovr_C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                A_C_mean[i,0],A_C_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_A_eds, ovr_C_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    A_C_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
A_C_fdrBH_pvals = multitest.multipletests(A_C_p_vals, method='fdr_bh')

# get -log10 p values
A_C_neg_log10 = -np.log10(A_C_fdrBH_pvals[1])

#########################
#########################
######## B VS C #########
#########################
#########################

B_C_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_mean[i,0],B_mean[i,1])
    # eulidean distances of C sample to C mean
    C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                C_mean[i,0],C_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((B_eds, C_eds))

    ## GROUP 2##
    # eulidean distances of A to overall mean
    ovr_B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_C_mean[i,0],B_C_mean[i,1])
    # eulidean distances of C sample to overall mean
    ovr_C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                B_C_mean[i,0],B_C_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_B_eds, ovr_C_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    B_C_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
B_C_fdrBH_pvals = multitest.multipletests(B_C_p_vals, method='fdr_bh')

# get -log10 p values
B_C_neg_log10 = -np.log10(B_C_fdrBH_pvals[1])

#######################
#######################
### CREATE PVAL DF  ###
#######################
#######################

# create a pandas dataframe with overall mean leaf coordinates for plotting
pval_df = pd.DataFrame({"xval":overall_mean[:,0],
                        "yval":overall_mean[:,1],
                        "A_B_pval":A_B_neg_log10,
                       "A_C_pval":A_C_neg_log10,
                       "B_C_pval":B_C_neg_log10})

# %%
# Reset -log10 p values to -log10(0.05) if equal to or lower than that value for plotting

pval_df["A_B_pval"] = np.where(pval_df["A_B_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["A_B_pval"])
pval_df["A_C_pval"] = np.where(pval_df["A_C_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["A_C_pval"])
pval_df["B_C_pval"] = np.where(pval_df["B_C_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["B_C_pval"])

# %%
# project negative log10 FDR BH pvals on mean leaf

plt.figure(figsize=(20,10))

plt.subplot(131)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="A_B_pval", palette="viridis", s=100, 
                   hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")

plt.subplot(132)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="A_C_pval", palette="viridis", s=100,
                  hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")

plt.subplot(133)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="B_C_pval", palette="viridis", s=100,
                  hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")

# %% [markdown]
# # Node information

# %%
sns.scatterplot(mdata, x="PC1", y="rel_node", hue="rel_node", s=10, palette="inferno")

# %%
sns.scatterplot(mdata, x="PC2", y="rel_node", hue="rel_node", s=10, palette="inferno")

# %%
sns.scatterplot(mdata, x="PC3", y="rel_node", hue="rel_node", s=10, palette="inferno")

# %%
sns.scatterplot(mdata, x="PC4", y="rel_node", hue="rel_node", s=10, palette="inferno")

# %%
sns.scatterplot(mdata, x="PC5", y="rel_node", hue="rel_node", s=10, palette="inferno")
