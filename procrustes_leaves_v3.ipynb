# %%
#######################
### LOAD IN MODULES ###
#######################

import cv2 # to install on mac: pip install opencv-python
from scipy.interpolate import interp1d # for interpolating points
from sklearn.decomposition import PCA # for principal component analysis
from scipy.spatial import procrustes # for Procrustes analysis
from scipy.spatial import ConvexHull # for convex hull
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis # for LDA
from sklearn.metrics import confusion_matrix # for confusion matrix
from os import listdir # for retrieving files from directory
from os.path import isfile, join # for retrieving files from directory
import matplotlib.pyplot as plt # for plotting
import numpy as np # for using arrays
import math # for mathematical operations
import pandas as pd # for using pandas dataframes
import seaborn as sns # for plotting in seaborn
from matplotlib.colors import LogNorm
from sklearn.model_selection import StratifiedKFold
import itertools # for pairwise combinations
import scipy.stats as stats # for kruskal wallis test
import statsmodels.stats.multitest as multitest # multiple test adjustment

# %%
#################
### FUNCTIONS ###
#################

def angle_between(p1, p2, p3):
    """
    define a function to find the angle between 3 points anti-clockwise in degrees, p2 being the vertex
    inputs: three angle points, as tuples
    output: angle in degrees
    """
    x1, y1 = p1
    x2, y2 = p2
    x3, y3 = p3
    deg1 = (360 + math.degrees(math.atan2(x1 - x2, y1 - y2))) % 360
    deg2 = (360 + math.degrees(math.atan2(x3 - x2, y3 - y2))) % 360
    return deg2 - deg1 if deg1 <= deg2 else 360 - (deg1 - deg2)

def rotate_points(xvals, yvals, degrees):
    """"
    define a function to rotate 2D x and y coordinate points around the origin
    inputs: x and y vals (can take pandas dataframe columns) and the degrees (positive, anticlockwise) to rotate
    outputs: rotated and y vals
    """
    angle_to_move = 90-degrees
    rads = np.deg2rad(angle_to_move)
    
    new_xvals = xvals*np.cos(rads)-yvals*np.sin(rads)
    new_yvals = xvals*np.sin(rads)+yvals*np.cos(rads)
    
    return new_xvals, new_yvals

def interpolation(x, y, number): 
    """
    define a function to return equally spaced, interpolated points for a given polyline
    inputs: arrays of x and y values for a polyline, number of points to interpolate
    ouputs: interpolated points along the polyline, inclusive of start and end points
    """
    distance = np.cumsum(np.sqrt( np.ediff1d(x, to_begin=0)**2 + np.ediff1d(y, to_begin=0)**2 ))
    distance = distance/distance[-1]

    fx, fy = interp1d( distance, x ), interp1d( distance, y )

    alpha = np.linspace(0, 1, number)
    x_regular, y_regular = fx(alpha), fy(alpha)
    
    return x_regular, y_regular

def euclid_dist(x1, y1, x2, y2):
    """
    define a function to return the euclidean distance between two points
    inputs: x and y values of the two points
    output: the eulidean distance
    """
    return np.sqrt((x2-x1)**2 + (y2-y1)**2)

def poly_area(x,y):
    """
    define a function to calculate the area of a polygon using the shoelace algorithm
    inputs: separate numpy arrays of x and y coordinate values
    outputs: the area of the polygon
    """
    return 0.5*np.abs(np.dot(x,np.roll(y,1))-np.dot(y,np.roll(x,1)))

def gpa_mean(leaf_arr, landmark_num, dim_num):
    
    """
    define a function that given an array of landmark data returns the Generalized Procrustes Analysis mean
    inputs: a 3 dimensional array of samples by landmarks by coordinate values, number of landmarks, number of dimensions
    output: an array of the Generalized Procrustes Analysis mean shape
    
    """

    ref_ind = 0 # select arbitrary reference index to calculate procrustes distances to
    ref_shape = leaf_arr[ref_ind, :, :] # select the reference shape

    mean_diff = 10**(-30) # set a distance between means to stop the algorithm

    old_mean = ref_shape # for the first comparison between means, set old_mean to an arbitrary reference shape

    d = 1000000 # set d initially arbitraily high

    while d > mean_diff: # set boolean criterion for Procrustes distance between mean to stop calculations

        arr = np.zeros( ((len(leaf_arr)),landmark_num,dim_num) ) # empty 3D array: # samples, landmarks, coord vals

        for i in range(len(leaf_arr)): # for each leaf shape 

            s1, s2, distance = procrustes(old_mean, leaf_arr[i]) # calculate procrustes adjusted shape to ref for current leaf
            arr[i] = s2 # store procrustes adjusted shape to array

        new_mean = np.mean(arr, axis=(0)) # calculate mean of all shapes adjusted to reference

        s1, s2, d = procrustes(old_mean, new_mean) # calculate procrustes distance of new mean to old mean

        old_mean = new_mean # set the old_mean to the new_mea before beginning another iteration

    return new_mean

# %% [markdown]
# # Read in data

# %%
########################
### READ IN METADATA ###
########################

mdata = pd.read_csv("./metadata_v3.csv") # read in csv

mdata.head() # head data to check
# Out:
#                   file  px_cm include  base_x  base_y    tip_x    tip_y
# 0  LAMOEWC23246-1_1_13  116.0       Y   410.0   524.0  426.167  276.833
# 1  LAMOEWC23246-1_2_13  116.0       Y   397.0   553.0  419.500  243.500
# 2  LAMOEWC23246-1_3_13  116.0       Y   381.0   576.0  380.833  224.833
# 3  LAMOEWC23246-1_4_13  116.0       N   390.0   622.0  376.833  176.833
# 4  LAMOEWC23246-1_5_13  116.0       N   430.0   477.0  411.500  323.500

# %%
#######################################
### MAKE A LIST OF IMAGE FILE NAMES ###
#######################################

data_dir = "./binary_leaves_v3/" # set data directory

file_names = [f for f in listdir(data_dir) if isfile(join(data_dir, f))] # create a list of file names

file_names.remove('.DS_Store') # remove .DS_Store file

file_names.sort() # sort the list of file names

file_names # check list of file names
# Out:
# ['LAMOEWC23246-1_10_13.tif',
#  'LAMOEWC23246-1_11_13.tif',
#  'LAMOEWC23246-1_12_13.tif',
#  'LAMOEWC23246-1_13_13.tif',
#  'LAMOEWC23246-1_1_13.tif',
#  'LAMOEWC23246-1_2_13.tif',
#  'LAMOEWC23246-1_3_13.tif',
#  'LAMOEWC23246-1_4_13.tif',
#  'LAMOEWC23246-1_5_13.tif',
#  'LAMOEWC23246-1_6_13.tif',
#  'LAMOEWC23246-1_7_13.tif',
#  'LAMOEWC23246-1_8_13.tif',
#  'LAMOEWC23246-1_9_13.tif',
#  'LAMOEWC23246-2_1_5.tif',
#  'LAMOEWC23246-2_2_5.tif',
#  'LAMOEWC23246-2_3_5.tif',
#  'LAMOEWC23246-2_4_5.tif',
#  'LAMOEWC23246-2_5_5.tif',
#  'LAPALBS17132-1_10_28.tif',
#  'LAPALBS17132-1_11_28.tif',
#  'LAPALBS17132-1_12_28.tif',
#  'LAPALBS17132-1_13_28.tif',
#  'LAPALBS17132-1_14_28.tif',
#  'LAPALBS17132-1_15_28.tif',
#  'LAPALBS17132-1_16_28.tif',
#  'LAPALBS17132-1_17_28.tif',
#  'LAPALBS17132-1_18_28.tif',
#  'LAPALBS17132-1_19_28.tif',
#  'LAPALBS17132-1_1_28.tif',
#  'LAPALBS17132-1_20_28.tif',
#  'LAPALBS17132-1_21_28.tif',
#  'LAPALBS17132-1_22_28.tif',
#  'LAPALBS17132-1_23_28.tif',
#  'LAPALBS17132-1_24_28.tif',
#  'LAPALBS17132-1_25_28.tif',
#  'LAPALBS17132-1_26_28.tif',
#  'LAPALBS17132-1_27_28.tif',
#  'LAPALBS17132-1_28_28.tif',
#  'LAPALBS17132-1_2_28.tif',
#  'LAPALBS17132-1_3_28.tif',
#  'LAPALBS17132-1_4_28.tif',
#  'LAPALBS17132-1_5_28.tif',
#  'LAPALBS17132-1_6_28.tif',
#  'LAPALBS17132-1_7_28.tif',
#  'LAPALBS17132-1_8_28.tif',
#  'LAPALBS17132-1_9_28.tif',
#  'LAPALBS17133-1_10_25.tif',
#  'LAPALBS17133-1_11_25.tif',
#  'LAPALBS17133-1_12_25.tif',
#  'LAPALBS17133-1_13_25.tif',
#  'LAPALBS17133-1_14_25.tif',
#  'LAPALBS17133-1_15_25.tif',
#  'LAPALBS17133-1_16_25.tif',
#  'LAPALBS17133-1_17_25.tif',
#  'LAPALBS17133-1_18_25.tif',
#  'LAPALBS17133-1_19_25.tif',
#  'LAPALBS17133-1_1_25.tif',
#  'LAPALBS17133-1_20_25.tif',
#  'LAPALBS17133-1_21_25.tif',
#  'LAPALBS17133-1_22_25.tif',
#  'LAPALBS17133-1_23_25.tif',
#  'LAPALBS17133-1_24_25.tif',
#  'LAPALBS17133-1_25_25.tif',
#  'LAPALBS17133-1_2_25.tif',
#  'LAPALBS17133-1_3_25.tif',
#  'LAPALBS17133-1_4_25.tif',
#  'LAPALBS17133-1_5_25.tif',
#  'LAPALBS17133-1_6_25.tif',
#  'LAPALBS17133-1_7_25.tif',
#  'LAPALBS17133-1_8_25.tif',
#  'LAPALBS17133-1_9_25.tif',
#  'LAPALMJ21170-1_10_10.tif',
#  'LAPALMJ21170-1_1_10.tif',
#  'LAPALMJ21170-1_2_10.tif',
#  'LAPALMJ21170-1_3_10.tif',
#  'LAPALMJ21170-1_4_10.tif',
#  'LAPALMJ21170-1_5_10.tif',
#  'LAPALMJ21170-1_6_10.tif',
#  'LAPALMJ21170-1_7_10.tif',
#  'LAPALMJ21170-1_8_10.tif',
#  'LAPALMJ21170-1_9_10.tif',
#  'LAPPEAC21008-1_1_5.tif',
#  'LAPPEAC21008-1_2_5.tif',
#  'LAPPEAC21008-1_3_5.tif',
#  'LAPPEAC21008-1_4_5.tif',
#  'LAPPEAC21008-1_5_5.tif',
#  'LAPPEAC21008-2_10_13.tif',
#  'LAPPEAC21008-2_11_13.tif',
#  'LAPPEAC21008-2_12_13.tif',
#  'LAPPEAC21008-2_13_13.tif',
#  'LAPPEAC21008-2_1_13.tif',
#  'LAPPEAC21008-2_2_13.tif',
#  'LAPPEAC21008-2_3_13.tif',
#  'LAPPEAC21008-2_4_13.tif',
#  'LAPPEAC21008-2_5_13.tif',
#  'LAPPEAC21008-2_6_13.tif',
#  'LAPPEAC21008-2_7_13.tif',
#  'LAPPEAC21008-2_8_13.tif',
#  'LAPPEAC21008-2_9_13.tif',
#  'LAPPEAC21008-3_1_8.tif',
#  'LAPPEAC21008-3_2_8.tif',
#  'LAPPEAC21008-3_3_8.tif',
#  'LAPPEAC21008-3_4_8.tif',
#  'LAPPEAC21008-3_5_8.tif',
#  'LAPPEAC21008-3_6_8.tif',
#  'LAPPEAC21008-3_7_8.tif',
#  'LAPPEAC21008-3_8_8.tif',
#  'LAPPEAC21010-1_1_3.tif',
#  'LAPPEAC21010-1_2_3.tif',
#  'LAPPEAC21010-1_3_3.tif',
#  'LAPPEAC21010-2_10_15.tif',
#  'LAPPEAC21010-2_11_15.tif',
#  'LAPPEAC21010-2_12_15.tif',
#  'LAPPEAC21010-2_13_15.tif',
#  'LAPPEAC21010-2_14_15.tif',
#  'LAPPEAC21010-2_15_15.tif',
#  'LAPPEAC21010-2_1_15.tif',
#  'LAPPEAC21010-2_2_15.tif',
#  'LAPPEAC21010-2_3_15.tif',
#  'LAPPEAC21010-2_4_15.tif',
#  'LAPPEAC21010-2_5_15.tif',
#  'LAPPEAC21010-2_6_15.tif',
#  'LAPPEAC21010-2_7_15.tif',
#  'LAPPEAC21010-2_8_15.tif',
#  'LAPPEAC21010-2_9_15.tif',
#  'LAPPEAC21010-3_10_16.tif',
#  'LAPPEAC21010-3_11_16.tif',
#  'LAPPEAC21010-3_12_16.tif',
#  'LAPPEAC21010-3_13_16.tif',
#  'LAPPEAC21010-3_14_16.tif',
#  'LAPPEAC21010-3_15_16.tif',
#  'LAPPEAC21010-3_16_16.tif',
#  'LAPPEAC21010-3_1_16.tif',
#  'LAPPEAC21010-3_2_16.tif',
#  'LAPPEAC21010-3_3_16.tif',
#  'LAPPEAC21010-3_4_16.tif',
#  'LAPPEAC21010-3_5_16.tif',
#  'LAPPEAC21010-3_6_16.tif',
#  'LAPPEAC21010-3_7_16.tif',
#  'LAPPEAC21010-3_8_16.tif',
#  'LAPPEAC21010-3_9_16.tif',
#  'LAPPEAC21010-4_1_7.tif',
#  'LAPPEAC21010-4_2_7.tif',
#  'LAPPEAC21010-4_3_7.tif',
#  'LAPPEAC21010-4_4_7.tif',
#  'LAPPEAC21010-4_5_7.tif',
#  'LAPPEAC21010-4_6_7.tif',
#  'LAPPEAC21010-4_7_7.tif',
#  'LAPPEAC21010-5_1_8.tif',
#  'LAPPEAC21010-5_2_8.tif',
#  'LAPPEAC21010-5_3_8.tif',
#  'LAPPEAC21010-5_4_8.tif',
#  'LAPPEAC21010-5_5_8.tif',
#  'LAPPEAC21010-5_6_8.tif',
#  'LAPPEAC21010-5_7_8.tif',
#  'LAPPEAC21010-5_8_8.tif',
#  'LAPPEAC21010-6_1_6.tif',
#  'LAPPEAC21010-6_2_6.tif',
#  'LAPPEAC21010-6_3_6.tif',
#  'LAPPEAC21010-6_4_6.tif',
#  'LAPPEAC21010-6_5_6.tif',
#  'LAPPEAC21010-6_6_6.tif',
#  'LAPPEAC21010-8_10_17.tif',
#  'LAPPEAC21010-8_11_17.tif',
#  'LAPPEAC21010-8_12_17.tif',
#  'LAPPEAC21010-8_13_17.tif',
#  'LAPPEAC21010-8_14_17.tif',
#  'LAPPEAC21010-8_15_17.tif',
#  'LAPPEAC21010-8_16_17.tif',
#  'LAPPEAC21010-8_17_17.tif',
#  'LAPPEAC21010-8_1_17.tif',
#  'LAPPEAC21010-8_2_17.tif',
#  'LAPPEAC21010-8_3_17.tif',
#  'LAPPEAC21010-8_4_17.tif',
#  'LAPPEAC21010-8_5_17.tif',
#  'LAPPEAC21010-8_6_17.tif',
#  'LAPPEAC21010-8_7_17.tif',
#  'LAPPEAC21010-8_8_17.tif',
#  'LAPPEAC21010-8_9_17.tif',
#  'LBATSPA21164-1_10_42.tif',
#  'LBATSPA21164-1_11_42.tif',
#  'LBATSPA21164-1_12_42.tif',
#  'LBATSPA21164-1_13_42.tif',
#  'LBATSPA21164-1_14_42.tif',
#  'LBATSPA21164-1_15_42.tif',
#  'LBATSPA21164-1_16_42.tif',
#  'LBATSPA21164-1_17_42.tif',
#  'LBATSPA21164-1_18_42.tif',
#  'LBATSPA21164-1_19_42.tif',
#  'LBATSPA21164-1_1_42.tif',
#  'LBATSPA21164-1_20_42.tif',
#  'LBATSPA21164-1_21_42.tif',
#  'LBATSPA21164-1_22_42.tif',
#  'LBATSPA21164-1_23_42.tif',
#  'LBATSPA21164-1_24_42.tif',
#  'LBATSPA21164-1_25_42.tif',
#  'LBATSPA21164-1_26_42.tif',
#  'LBATSPA21164-1_27_42.tif',
#  'LBATSPA21164-1_28_42.tif',
#  'LBATSPA21164-1_29_42.tif',
#  'LBATSPA21164-1_2_42.tif',
#  'LBATSPA21164-1_30_42.tif',
#  'LBATSPA21164-1_31_42.tif',
#  'LBATSPA21164-1_32_42.tif',
#  'LBATSPA21164-1_33_42.tif',
#  'LBATSPA21164-1_34_42.tif',
#  'LBATSPA21164-1_35_42.tif',
#  'LBATSPA21164-1_36_42.tif',
#  'LBATSPA21164-1_37_42.tif',
#  'LBATSPA21164-1_38_42.tif',
#  'LBATSPA21164-1_39_42.tif',
#  'LBATSPA21164-1_3_42.tif',
#  'LBATSPA21164-1_40_42.tif',
#  'LBATSPA21164-1_41_42.tif',
#  'LBATSPA21164-1_42_42.tif',
#  'LBATSPA21164-1_4_42.tif',
#  'LBATSPA21164-1_5_42.tif',
#  'LBATSPA21164-1_6_42.tif',
#  'LBATSPA21164-1_7_42.tif',
#  'LBATSPA21164-1_8_42.tif',
#  'LBATSPA21164-1_9_42.tif',
#  'LBREVAC21171-1_10_89.tif',
#  'LBREVAC21171-1_11_89.tif',
#  'LBREVAC21171-1_12_89.tif',
#  'LBREVAC21171-1_13_89.tif',
#  'LBREVAC21171-1_14_89.tif',
#  'LBREVAC21171-1_15_89.tif',
#  'LBREVAC21171-1_16_89.tif',
#  'LBREVAC21171-1_17_89.tif',
#  'LBREVAC21171-1_18_89.tif',
#  'LBREVAC21171-1_19_89.tif',
#  'LBREVAC21171-1_1_89.tif',
#  'LBREVAC21171-1_20_89.tif',
#  'LBREVAC21171-1_21_89.tif',
#  'LBREVAC21171-1_22_89.tif',
#  'LBREVAC21171-1_23_89.tif',
#  'LBREVAC21171-1_24_89.tif',
#  'LBREVAC21171-1_25_89.tif',
#  'LBREVAC21171-1_26_89.tif',
#  'LBREVAC21171-1_27_89.tif',
#  'LBREVAC21171-1_28_89.tif',
#  'LBREVAC21171-1_29_89.tif',
#  'LBREVAC21171-1_2_89.tif',
#  'LBREVAC21171-1_30_89.tif',
#  'LBREVAC21171-1_31_89.tif',
#  'LBREVAC21171-1_32_89.tif',
#  'LBREVAC21171-1_33_89.tif',
#  'LBREVAC21171-1_34_89.tif',
#  'LBREVAC21171-1_35_89.tif',
#  'LBREVAC21171-1_36_89.tif',
#  'LBREVAC21171-1_37_89.tif',
#  'LBREVAC21171-1_38_89.tif',
#  'LBREVAC21171-1_39_89.tif',
#  'LBREVAC21171-1_3_89.tif',
#  'LBREVAC21171-1_40_89.tif',
#  'LBREVAC21171-1_41_89.tif',
#  'LBREVAC21171-1_42_89.tif',
#  'LBREVAC21171-1_43_89.tif',
#  'LBREVAC21171-1_44_89.tif',
#  'LBREVAC21171-1_45_89.tif',
#  'LBREVAC21171-1_46_89.tif',
#  'LBREVAC21171-1_47_89.tif',
#  'LBREVAC21171-1_48_89.tif',
#  'LBREVAC21171-1_49_89.tif',
#  'LBREVAC21171-1_4_89.tif',
#  'LBREVAC21171-1_50_89.tif',
#  'LBREVAC21171-1_51_89.tif',
#  'LBREVAC21171-1_52_89.tif',
#  'LBREVAC21171-1_53_89.tif',
#  'LBREVAC21171-1_54_89.tif',
#  'LBREVAC21171-1_55_89.tif',
#  'LBREVAC21171-1_56_89.tif',
#  'LBREVAC21171-1_57_89.tif',
#  'LBREVAC21171-1_58_89.tif',
#  'LBREVAC21171-1_59_89.tif',
#  'LBREVAC21171-1_5_89.tif',
#  'LBREVAC21171-1_60_89.tif',
#  'LBREVAC21171-1_61_89.tif',
#  'LBREVAC21171-1_62_89.tif',
#  'LBREVAC21171-1_63_89.tif',
#  'LBREVAC21171-1_64_89.tif',
#  'LBREVAC21171-1_65_89.tif',
#  'LBREVAC21171-1_66_89.tif',
#  'LBREVAC21171-1_67_89.tif',
#  'LBREVAC21171-1_68_89.tif',
#  'LBREVAC21171-1_69_89.tif',
#  'LBREVAC21171-1_6_89.tif',
#  'LBREVAC21171-1_70_89.tif',
#  'LBREVAC21171-1_71_89.tif',
#  'LBREVAC21171-1_72_89.tif',
#  'LBREVAC21171-1_73_89.tif',
#  'LBREVAC21171-1_74_89.tif',
#  'LBREVAC21171-1_75_89.tif',
#  'LBREVAC21171-1_76_89.tif',
#  'LBREVAC21171-1_77_89.tif',
#  'LBREVAC21171-1_78_89.tif',
#  'LBREVAC21171-1_79_89.tif',
#  'LBREVAC21171-1_7_89.tif',
#  'LBREVAC21171-1_80_89.tif',
#  'LBREVAC21171-1_81_89.tif',
#  'LBREVAC21171-1_82_89.tif',
#  'LBREVAC21171-1_83_89.tif',
#  'LBREVAC21171-1_84_89.tif',
#  'LBREVAC21171-1_85_89.tif',
#  'LBREVAC21171-1_86_89.tif',
#  'LBREVAC21171-1_87_89.tif',
#  'LBREVAC21171-1_88_89.tif',
#  'LBREVAC21171-1_89_89.tif',
#  'LBREVAC21171-1_8_89.tif',
#  'LBREVAC21171-1_9_89.tif',
#  'LBREVBS17075-2A_10_37.tif',
#  'LBREVBS17075-2A_11_37.tif',
#  'LBREVBS17075-2A_12_37.tif',
#  'LBREVBS17075-2A_13_37.tif',
#  'LBREVBS17075-2A_14_37.tif',
#  'LBREVBS17075-2A_15_37.tif',
#  'LBREVBS17075-2A_16_37.tif',
#  'LBREVBS17075-2A_17_37.tif',
#  'LBREVBS17075-2A_18_37.tif',
#  'LBREVBS17075-2A_19_37.tif',
#  'LBREVBS17075-2A_1_37.tif',
#  'LBREVBS17075-2A_20_37.tif',
#  'LBREVBS17075-2A_21_37.tif',
#  'LBREVBS17075-2A_22_37.tif',
#  'LBREVBS17075-2A_23_37.tif',
#  'LBREVBS17075-2A_24_37.tif',
#  'LBREVBS17075-2A_25_37.tif',
#  'LBREVBS17075-2A_26_37.tif',
#  'LBREVBS17075-2A_27_37.tif',
#  'LBREVBS17075-2A_28_37.tif',
#  'LBREVBS17075-2A_29_37.tif',
#  'LBREVBS17075-2A_2_37.tif',
#  'LBREVBS17075-2A_30_37.tif',
#  'LBREVBS17075-2A_31_37.tif',
#  'LBREVBS17075-2A_32_37.tif',
#  'LBREVBS17075-2A_33_37.tif',
#  'LBREVBS17075-2A_34_37.tif',
#  'LBREVBS17075-2A_35_37.tif',
#  'LBREVBS17075-2A_36_37.tif',
#  'LBREVBS17075-2A_37_37.tif',
#  'LBREVBS17075-2A_3_37.tif',
#  'LBREVBS17075-2A_4_37.tif',
#  'LBREVBS17075-2A_5_37.tif',
#  'LBREVBS17075-2A_6_37.tif',
#  'LBREVBS17075-2A_7_37.tif',
#  'LBREVBS17075-2A_8_37.tif',
#  'LBREVBS17075-2A_9_37.tif',
#  'LCANBAC21060-1_1_6.tif',
#  'LCANBAC21060-1_2_6.tif',
#  'LCANBAC21060-1_3_6.tif',
#  'LCANBAC21060-1_4_6.tif',
#  'LCANBAC21060-1_5_6.tif',
#  'LCANBAC21060-1_6_6.tif',
#  'LCANBGG21059-1_10_45.tif',
#  'LCANBGG21059-1_11_45.tif',
#  'LCANBGG21059-1_12_45.tif',
#  'LCANBGG21059-1_13_45.tif',
#  'LCANBGG21059-1_14_45.tif',
#  'LCANBGG21059-1_15_45.tif',
#  'LCANBGG21059-1_16_45.tif',
#  'LCANBGG21059-1_17_45.tif',
#  'LCANBGG21059-1_18_45.tif',
#  'LCANBGG21059-1_19_45.tif',
#  'LCANBGG21059-1_1_45.tif',
#  'LCANBGG21059-1_20_45.tif',
#  'LCANBGG21059-1_21_45.tif',
#  'LCANBGG21059-1_22_45.tif',
#  'LCANBGG21059-1_23_45.tif',
#  'LCANBGG21059-1_24_45.tif',
#  'LCANBGG21059-1_25_45.tif',
#  'LCANBGG21059-1_26_45.tif',
#  'LCANBGG21059-1_27_45.tif',
#  'LCANBGG21059-1_28_45.tif',
#  'LCANBGG21059-1_29_45.tif',
#  'LCANBGG21059-1_2_45.tif',
#  'LCANBGG21059-1_30_45.tif',
#  'LCANBGG21059-1_31_45.tif',
#  'LCANBGG21059-1_32_45.tif',
#  'LCANBGG21059-1_33_45.tif',
#  'LCANBGG21059-1_34_45.tif',
#  'LCANBGG21059-1_35_45.tif',
#  'LCANBGG21059-1_36_45.tif',
#  'LCANBGG21059-1_37_45.tif',
#  'LCANBGG21059-1_38_45.tif',
#  'LCANBGG21059-1_39_45.tif',
#  'LCANBGG21059-1_3_45.tif',
#  'LCANBGG21059-1_40_45.tif',
#  'LCANBGG21059-1_41_45.tif',
#  'LCANBGG21059-1_42_45.tif',
#  'LCANBGG21059-1_43_45.tif',
#  'LCANBGG21059-1_44_45.tif',
#  'LCANBGG21059-1_45_45.tif',
#  'LCANBGG21059-1_4_45.tif',
#  'LCANBGG21059-1_5_45.tif',
#  'LCANBGG21059-1_6_45.tif',
#  'LCANBGG21059-1_7_45.tif',
#  'LCANBGG21059-1_8_45.tif',
#  'LCANBGG21059-1_9_45.tif',
#  'LCANBGG21059-3_10_18.tif',
#  'LCANBGG21059-3_11_18.tif',
#  'LCANBGG21059-3_12_18.tif',
#  'LCANBGG21059-3_13_18.tif',
#  'LCANBGG21059-3_14_18.tif',
#  'LCANBGG21059-3_15_18.tif',
#  'LCANBGG21059-3_16_18.tif',
#  'LCANBGG21059-3_17_18.tif',
#  'LCANBGG21059-3_18_18.tif',
#  'LCANBGG21059-3_1_18.tif',
#  'LCANBGG21059-3_2_18.tif',
#  'LCANBGG21059-3_3_18.tif',
#  'LCANBGG21059-3_4_18.tif',
#  'LCANBGG21059-3_5_18.tif',
#  'LCANBGG21059-3_6_18.tif',
#  'LCANBGG21059-3_7_18.tif',
#  'LCANBGG21059-3_8_18.tif',
#  'LCANBGG21059-3_9_18.tif',
#  'LCARDAC23254-1_10_23.tif',
#  'LCARDAC23254-1_11_23.tif',
#  'LCARDAC23254-1_12_23.tif',
#  'LCARDAC23254-1_13_23.tif',
#  'LCARDAC23254-1_14_23.tif',
#  'LCARDAC23254-1_15_23.tif',
#  'LCARDAC23254-1_16_23.tif',
#  'LCARDAC23254-1_17_23.tif',
#  'LCARDAC23254-1_18_23.tif',
#  'LCARDAC23254-1_19_23.tif',
#  'LCARDAC23254-1_1_23.tif',
#  'LCARDAC23254-1_20_23.tif',
#  'LCARDAC23254-1_21_23.tif',
#  'LCARDAC23254-1_22_23.tif',
#  'LCARDAC23254-1_23_23.tif',
#  'LCARDAC23254-1_2_23.tif',
#  'LCARDAC23254-1_3_23.tif',
#  'LCARDAC23254-1_4_23.tif',
#  'LCARDAC23254-1_5_23.tif',
#  'LCARDAC23254-1_6_23.tif',
#  'LCARDAC23254-1_7_23.tif',
#  'LCARDAC23254-1_8_23.tif',
#  'LCARDAC23254-1_9_23.tif',
#  'LCARDAC23254-2_10_29.tif',
#  'LCARDAC23254-2_11_29.tif',
#  'LCARDAC23254-2_12_29.tif',
#  'LCARDAC23254-2_13_29.tif',
#  'LCARDAC23254-2_14_29.tif',
#  'LCARDAC23254-2_15_29.tif',
#  'LCARDAC23254-2_16_29.tif',
#  'LCARDAC23254-2_17_29.tif',
#  'LCARDAC23254-2_18_29.tif',
#  'LCARDAC23254-2_19_29.tif',
#  'LCARDAC23254-2_1_29.tif',
#  'LCARDAC23254-2_20_29.tif',
#  'LCARDAC23254-2_21_29.tif',
#  'LCARDAC23254-2_22_29.tif',
#  'LCARDAC23254-2_23_29.tif',
#  'LCARDAC23254-2_24_29.tif',
#  'LCARDAC23254-2_25_29.tif',
#  'LCARDAC23254-2_26_29.tif',
#  'LCARDAC23254-2_27_29.tif',
#  'LCARDAC23254-2_28_29.tif',
#  'LCARDAC23254-2_29_29.tif',
#  'LCARDAC23254-2_2_29.tif',
#  'LCARDAC23254-2_3_29.tif',
#  'LCARDAC23254-2_4_29.tif',
#  'LCARDAC23254-2_5_29.tif',
#  'LCARDAC23254-2_6_29.tif',
#  'LCARDAC23254-2_7_29.tif',
#  'LCARDAC23254-2_8_29.tif',
#  'LCARDAC23254-2_9_29.tif',
#  'LCARDBS17083-4_10_17.tif',
#  'LCARDBS17083-4_11_17.tif',
#  'LCARDBS17083-4_12_17.tif',
#  'LCARDBS17083-4_13_17.tif',
#  'LCARDBS17083-4_14_17.tif',
#  'LCARDBS17083-4_15_17.tif',
#  'LCARDBS17083-4_16_17.tif',
#  'LCARDBS17083-4_17_17.tif',
#  'LCARDBS17083-4_1_17.tif',
#  'LCARDBS17083-4_2_17.tif',
#  'LCARDBS17083-4_3_17.tif',
#  'LCARDBS17083-4_4_17.tif',
#  'LCARDBS17083-4_5_17.tif',
#  'LCARDBS17083-4_6_17.tif',
#  'LCARDBS17083-4_7_17.tif',
#  'LCARDBS17083-4_8_17.tif',
#  'LCARDBS17083-4_9_17.tif',
#  'LCARDPA23225 (A-L)-1_10_48.tif',
#  'LCARDPA23225 (A-L)-1_11_48.tif',
#  'LCARDPA23225 (A-L)-1_12_48.tif',
#  'LCARDPA23225 (A-L)-1_13_48.tif',
#  'LCARDPA23225 (A-L)-1_14_48.tif',
#  'LCARDPA23225 (A-L)-1_15_48.tif',
#  'LCARDPA23225 (A-L)-1_16_48.tif',
#  'LCARDPA23225 (A-L)-1_17_48.tif',
#  'LCARDPA23225 (A-L)-1_18_48.tif',
#  'LCARDPA23225 (A-L)-1_19_48.tif',
#  'LCARDPA23225 (A-L)-1_1_48.tif',
#  'LCARDPA23225 (A-L)-1_20_48.tif',
#  'LCARDPA23225 (A-L)-1_21_48.tif',
#  'LCARDPA23225 (A-L)-1_22_48.tif',
#  'LCARDPA23225 (A-L)-1_23_48.tif',
#  'LCARDPA23225 (A-L)-1_24_48.tif',
#  'LCARDPA23225 (A-L)-1_25_48.tif',
#  'LCARDPA23225 (A-L)-1_26_48.tif',
#  'LCARDPA23225 (A-L)-1_27_48.tif',
#  'LCARDPA23225 (A-L)-1_28_48.tif',
#  'LCARDPA23225 (A-L)-1_29_48.tif',
#  'LCARDPA23225 (A-L)-1_2_48.tif',
#  'LCARDPA23225 (A-L)-1_30_48.tif',
#  'LCARDPA23225 (A-L)-1_31_48.tif',
#  'LCARDPA23225 (A-L)-1_32_48.tif',
#  'LCARDPA23225 (A-L)-1_33_48.tif',
#  'LCARDPA23225 (A-L)-1_34_48.tif',
#  'LCARDPA23225 (A-L)-1_35_48.tif',
#  'LCARDPA23225 (A-L)-1_36_48.tif',
#  'LCARDPA23225 (A-L)-1_37_48.tif',
#  'LCARDPA23225 (A-L)-1_38_48.tif',
#  'LCARDPA23225 (A-L)-1_39_48.tif',
#  'LCARDPA23225 (A-L)-1_3_48.tif',
#  'LCARDPA23225 (A-L)-1_40_48.tif',
#  'LCARDPA23225 (A-L)-1_41_48.tif',
#  'LCARDPA23225 (A-L)-1_42_48.tif',
#  'LCARDPA23225 (A-L)-1_43_48.tif',
#  'LCARDPA23225 (A-L)-1_44_48.tif',
#  'LCARDPA23225 (A-L)-1_45_48.tif',
#  'LCARDPA23225 (A-L)-1_46_48.tif',
#  'LCARDPA23225 (A-L)-1_47_48.tif',
#  'LCARDPA23225 (A-L)-1_48_48.tif',
#  'LCARDPA23225 (A-L)-1_4_48.tif',
#  'LCARDPA23225 (A-L)-1_5_48.tif',
#  'LCARDPA23225 (A-L)-1_6_48.tif',
#  'LCARDPA23225 (A-L)-1_7_48.tif',
#  'LCARDPA23225 (A-L)-1_8_48.tif',
#  'LCARDPA23225 (A-L)-1_9_48.tif',
#  'LCARDPA23225 (A-L)-2_10_23.tif',
#  'LCARDPA23225 (A-L)-2_11_23.tif',
#  'LCARDPA23225 (A-L)-2_12_23.tif',
#  'LCARDPA23225 (A-L)-2_13_23.tif',
#  'LCARDPA23225 (A-L)-2_14_23.tif',
#  'LCARDPA23225 (A-L)-2_15_23.tif',
#  'LCARDPA23225 (A-L)-2_16_23.tif',
#  'LCARDPA23225 (A-L)-2_17_23.tif',
#  'LCARDPA23225 (A-L)-2_18_23.tif',
#  'LCARDPA23225 (A-L)-2_19_23.tif',
#  'LCARDPA23225 (A-L)-2_1_23.tif',
#  'LCARDPA23225 (A-L)-2_20_23.tif',
#  'LCARDPA23225 (A-L)-2_21_23.tif',
#  'LCARDPA23225 (A-L)-2_22_23.tif',
#  'LCARDPA23225 (A-L)-2_23_23.tif',
#  'LCARDPA23225 (A-L)-2_2_23.tif',
#  'LCARDPA23225 (A-L)-2_3_23.tif',
#  'LCARDPA23225 (A-L)-2_4_23.tif',
#  'LCARDPA23225 (A-L)-2_5_23.tif',
#  'LCARDPA23225 (A-L)-2_6_23.tif',
#  'LCARDPA23225 (A-L)-2_7_23.tif',
#  'LCARDPA23225 (A-L)-2_8_23.tif',
#  'LCARDPA23225 (A-L)-2_9_23.tif',
#  'LCARDPA23225 (A-L)-3_10_45.tif',
#  'LCARDPA23225 (A-L)-3_11_45.tif',
#  'LCARDPA23225 (A-L)-3_12_45.tif',
#  'LCARDPA23225 (A-L)-3_13_45.tif',
#  'LCARDPA23225 (A-L)-3_14_45.tif',
#  'LCARDPA23225 (A-L)-3_15_45.tif',
#  'LCARDPA23225 (A-L)-3_16_45.tif',
#  'LCARDPA23225 (A-L)-3_17_45.tif',
#  'LCARDPA23225 (A-L)-3_18_45.tif',
#  'LCARDPA23225 (A-L)-3_19_45.tif',
#  'LCARDPA23225 (A-L)-3_1_45.tif',
#  'LCARDPA23225 (A-L)-3_20_45.tif',
#  'LCARDPA23225 (A-L)-3_21_45.tif',
#  'LCARDPA23225 (A-L)-3_22_45.tif',
#  'LCARDPA23225 (A-L)-3_23_45.tif',
#  'LCARDPA23225 (A-L)-3_24_45.tif',
#  'LCARDPA23225 (A-L)-3_25_45.tif',
#  'LCARDPA23225 (A-L)-3_26_45.tif',
#  'LCARDPA23225 (A-L)-3_27_45.tif',
#  'LCARDPA23225 (A-L)-3_28_45.tif',
#  'LCARDPA23225 (A-L)-3_29_45.tif',
#  'LCARDPA23225 (A-L)-3_2_45.tif',
#  'LCARDPA23225 (A-L)-3_30_45.tif',
#  'LCARDPA23225 (A-L)-3_31_45.tif',
#  'LCARDPA23225 (A-L)-3_32_45.tif',
#  'LCARDPA23225 (A-L)-3_33_45.tif',
#  'LCARDPA23225 (A-L)-3_34_45.tif',
#  'LCARDPA23225 (A-L)-3_35_45.tif',
#  'LCARDPA23225 (A-L)-3_36_45.tif',
#  'LCARDPA23225 (A-L)-3_37_45.tif',
#  'LCARDPA23225 (A-L)-3_38_45.tif',
#  'LCARDPA23225 (A-L)-3_39_45.tif',
#  'LCARDPA23225 (A-L)-3_3_45.tif',
#  'LCARDPA23225 (A-L)-3_40_45.tif',
#  'LCARDPA23225 (A-L)-3_41_45.tif',
#  'LCARDPA23225 (A-L)-3_42_45.tif',
#  'LCARDPA23225 (A-L)-3_43_45.tif',
#  'LCARDPA23225 (A-L)-3_44_45.tif',
#  'LCARDPA23225 (A-L)-3_45_45.tif',
#  'LCARDPA23225 (A-L)-3_4_45.tif',
#  'LCARDPA23225 (A-L)-3_5_45.tif',
#  'LCARDPA23225 (A-L)-3_6_45.tif',
#  'LCARDPA23225 (A-L)-3_7_45.tif',
#  'LCARDPA23225 (A-L)-3_8_45.tif',
#  'LCARDPA23225 (A-L)-3_9_45.tif',
#  'LCARDPA23225 (A-R)-1_10_19.tif',
#  'LCARDPA23225 (A-R)-1_11_19.tif',
#  'LCARDPA23225 (A-R)-1_12_19.tif',
#  'LCARDPA23225 (A-R)-1_13_19.tif',
#  'LCARDPA23225 (A-R)-1_14_19.tif',
#  'LCARDPA23225 (A-R)-1_15_19.tif',
#  'LCARDPA23225 (A-R)-1_16_19.tif',
#  'LCARDPA23225 (A-R)-1_17_19.tif',
#  'LCARDPA23225 (A-R)-1_18_19.tif',
#  'LCARDPA23225 (A-R)-1_19_19.tif',
#  'LCARDPA23225 (A-R)-1_1_19.tif',
#  'LCARDPA23225 (A-R)-1_2_19.tif',
#  'LCARDPA23225 (A-R)-1_3_19.tif',
#  'LCARDPA23225 (A-R)-1_4_19.tif',
#  'LCARDPA23225 (A-R)-1_5_19.tif',
#  'LCARDPA23225 (A-R)-1_6_19.tif',
#  'LCARDPA23225 (A-R)-1_7_19.tif',
#  'LCARDPA23225 (A-R)-1_8_19.tif',
#  'LCARDPA23225 (A-R)-1_9_19.tif',
#  'LCARDPA23225 (S)-1_10_16.tif',
#  'LCARDPA23225 (S)-1_11_16.tif',
#  'LCARDPA23225 (S)-1_12_16.tif',
#  'LCARDPA23225 (S)-1_13_16.tif',
#  'LCARDPA23225 (S)-1_14_16.tif',
#  'LCARDPA23225 (S)-1_15_16.tif',
#  'LCARDPA23225 (S)-1_16_16.tif',
#  'LCARDPA23225 (S)-1_1_16.tif',
#  'LCARDPA23225 (S)-1_2_16.tif',
#  'LCARDPA23225 (S)-1_3_16.tif',
#  'LCARDPA23225 (S)-1_4_16.tif',
#  'LCARDPA23225 (S)-1_5_16.tif',
#  'LCARDPA23225 (S)-1_6_16.tif',
#  'LCARDPA23225 (S)-1_7_16.tif',
#  'LCARDPA23225 (S)-1_8_16.tif',
#  'LCARDPA23225 (S)-1_9_16.tif',
#  'LCARDST17131-1_1_3.tif',
#  'LCARDST17131-1_2_3.tif',
#  'LCARDST17131-1_3_3.tif',
#  'LDORTCB21050-1_10_33.tif',
#  'LDORTCB21050-1_11_33.tif',
#  'LDORTCB21050-1_12_33.tif',
#  'LDORTCB21050-1_13_33.tif',
#  'LDORTCB21050-1_14_33.tif',
#  'LDORTCB21050-1_15_33.tif',
#  'LDORTCB21050-1_16_33.tif',
#  'LDORTCB21050-1_17_33.tif',
#  'LDORTCB21050-1_18_33.tif',
#  'LDORTCB21050-1_19_33.tif',
#  'LDORTCB21050-1_1_33.tif',
#  'LDORTCB21050-1_20_33.tif',
#  'LDORTCB21050-1_21_33.tif',
#  'LDORTCB21050-1_22_33.tif',
#  'LDORTCB21050-1_23_33.tif',
#  'LDORTCB21050-1_24_33.tif',
#  'LDORTCB21050-1_25_33.tif',
#  'LDORTCB21050-1_26_33.tif',
#  'LDORTCB21050-1_27_33.tif',
#  'LDORTCB21050-1_28_33.tif',
#  'LDORTCB21050-1_29_33.tif',
#  'LDORTCB21050-1_2_33.tif',
#  'LDORTCB21050-1_30_33.tif',
#  'LDORTCB21050-1_31_33.tif',
#  'LDORTCB21050-1_32_33.tif',
#  'LDORTCB21050-1_33_33.tif',
#  'LDORTCB21050-1_3_33.tif',
#  'LDORTCB21050-1_4_33.tif',
#  'LDORTCB21050-1_5_33.tif',
#  'LDORTCB21050-1_6_33.tif',
#  'LDORTCB21050-1_7_33.tif',
#  'LDORTCB21050-1_8_33.tif',
#  'LDORTCB21050-1_9_33.tif',
#  'LDORTCB21050-2_10_20.tif',
#  'LDORTCB21050-2_11_20.tif',
#  'LDORTCB21050-2_12_20.tif',
#  'LDORTCB21050-2_13_20.tif',
#  'LDORTCB21050-2_14_20.tif',
#  'LDORTCB21050-2_15_20.tif',
#  'LDORTCB21050-2_16_20.tif',
#  'LDORTCB21050-2_17_20.tif',
#  'LDORTCB21050-2_18_20.tif',
#  'LDORTCB21050-2_19_20.tif',
#  'LDORTCB21050-2_1_20.tif',
#  'LDORTCB21050-2_20_20.tif',
#  'LDORTCB21050-2_2_20.tif',
#  'LDORTCB21050-2_3_20.tif',
#  'LDORTCB21050-2_4_20.tif',
#  'LDORTCB21050-2_5_20.tif',
#  'LDORTCB21050-2_6_20.tif',
#  'LDORTCB21050-2_7_20.tif',
#  'LDORTCB21050-2_8_20.tif',
#  'LDORTCB21050-2_9_20.tif',
#  'LDORTCB21050-3_10_49.tif',
#  'LDORTCB21050-3_11_49.tif',
#  'LDORTCB21050-3_12_49.tif',
#  'LDORTCB21050-3_13_49.tif',
#  'LDORTCB21050-3_14_49.tif',
#  'LDORTCB21050-3_15_49.tif',
#  'LDORTCB21050-3_16_49.tif',
#  'LDORTCB21050-3_17_49.tif',
#  'LDORTCB21050-3_18_49.tif',
#  'LDORTCB21050-3_19_49.tif',
#  'LDORTCB21050-3_1_49.tif',
#  'LDORTCB21050-3_20_49.tif',
#  'LDORTCB21050-3_21_49.tif',
#  'LDORTCB21050-3_22_49.tif',
#  'LDORTCB21050-3_23_49.tif',
#  'LDORTCB21050-3_24_49.tif',
#  'LDORTCB21050-3_25_49.tif',
#  'LDORTCB21050-3_26_49.tif',
#  'LDORTCB21050-3_27_49.tif',
#  'LDORTCB21050-3_28_49.tif',
#  'LDORTCB21050-3_29_49.tif',
#  'LDORTCB21050-3_2_49.tif',
#  'LDORTCB21050-3_30_49.tif',
#  'LDORTCB21050-3_31_49.tif',
#  'LDORTCB21050-3_32_49.tif',
#  'LDORTCB21050-3_33_49.tif',
#  'LDORTCB21050-3_34_49.tif',
#  'LDORTCB21050-3_35_49.tif',
#  'LDORTCB21050-3_36_49.tif',
#  'LDORTCB21050-3_37_49.tif',
#  'LDORTCB21050-3_38_49.tif',
#  'LDORTCB21050-3_39_49.tif',
#  'LDORTCB21050-3_3_49.tif',
#  'LDORTCB21050-3_40_49.tif',
#  'LDORTCB21050-3_41_49.tif',
#  'LDORTCB21050-3_42_49.tif',
#  'LDORTCB21050-3_43_49.tif',
#  'LDORTCB21050-3_44_49.tif',
#  'LDORTCB21050-3_45_49.tif',
#  'LDORTCB21050-3_46_49.tif',
#  'LDORTCB21050-3_47_49.tif',
#  'LDORTCB21050-3_48_49.tif',
#  'LDORTCB21050-3_49_49.tif',
#  'LDORTCB21050-3_4_49.tif',
#  'LDORTCB21050-3_5_49.tif',
#  'LDORTCB21050-3_6_49.tif',
#  'LDORTCB21050-3_7_49.tif',
#  'LDORTCB21050-3_8_49.tif',
#  'LDORTCB21050-3_9_49.tif',
#  'LDORTCB21050-4_10_18.tif',
#  'LDORTCB21050-4_11_18.tif',
#  'LDORTCB21050-4_12_18.tif',
#  'LDORTCB21050-4_13_18.tif',
#  'LDORTCB21050-4_14_18.tif',
#  'LDORTCB21050-4_15_18.tif',
#  'LDORTCB21050-4_16_18.tif',
#  'LDORTCB21050-4_17_18.tif',
#  'LDORTCB21050-4_18_18.tif',
#  'LDORTCB21050-4_1_18.tif',
#  'LDORTCB21050-4_2_18.tif',
#  'LDORTCB21050-4_3_18.tif',
#  'LDORTCB21050-4_4_18.tif',
#  'LDORTCB21050-4_5_18.tif',
#  'LDORTCB21050-4_6_18.tif',
#  'LDORTCB21050-4_7_18.tif',
#  'LDORTCB21050-4_8_18.tif',
#  'LDORTCB21050-4_9_18.tif',
#  'LDORTCB21050-5_10_12.tif',
#  'LDORTCB21050-5_11_12.tif',
#  'LDORTCB21050-5_12_12.tif',
#  'LDORTCB21050-5_1_12.tif',
#  'LDORTCB21050-5_2_12.tif',
#  'LDORTCB21050-5_3_12.tif',
#  'LDORTCB21050-5_4_12.tif',
#  'LDORTCB21050-5_5_12.tif',
#  'LDORTCB21050-5_6_12.tif',
#  'LDORTCB21050-5_7_12.tif',
#  'LDORTCB21050-5_8_12.tif',
#  'LDORTCB21050-5_9_12.tif',
#  'LDORTCB21050-7_10_17.tif',
#  'LDORTCB21050-7_11_17.tif',
#  'LDORTCB21050-7_12_17.tif',
#  'LDORTCB21050-7_13_17.tif',
#  'LDORTCB21050-7_14_17.tif',
#  'LDORTCB21050-7_15_17.tif',
#  'LDORTCB21050-7_16_17.tif',
#  'LDORTCB21050-7_17_17.tif',
#  'LDORTCB21050-7_1_17.tif',
#  'LDORTCB21050-7_2_17.tif',
#  'LDORTCB21050-7_3_17.tif',
#  'LDORTCB21050-7_4_17.tif',
#  'LDORTCB21050-7_5_17.tif',
#  'LDORTCB21050-7_6_17.tif',
#  'LDORTCB21050-7_7_17.tif',
#  'LDORTCB21050-7_8_17.tif',
#  'LDORTCB21050-7_9_17.tif',
#  'LELONAC21058-2_10_10.tif',
#  'LELONAC21058-2_1_10.tif',
#  'LELONAC21058-2_2_10.tif',
#  'LELONAC21058-2_3_10.tif',
#  'LELONAC21058-2_4_10.tif',
#  'LELONAC21058-2_5_10.tif',
#  'LELONAC21058-2_6_10.tif',
#  'LELONAC21058-2_7_10.tif',
#  'LELONAC21058-2_8_10.tif',
#  'LELONAC21058-2_9_10.tif',
#  'LELONAC21058-3_10_21.tif',
#  'LELONAC21058-3_11_21.tif',
#  'LELONAC21058-3_12_21.tif',
#  'LELONAC21058-3_13_21.tif',
#  'LELONAC21058-3_14_21.tif',
#  'LELONAC21058-3_15_21.tif',
#  'LELONAC21058-3_16_21.tif',
#  'LELONAC21058-3_17_21.tif',
#  'LELONAC21058-3_18_21.tif',
#  'LELONAC21058-3_19_21.tif',
#  'LELONAC21058-3_1_21.tif',
#  'LELONAC21058-3_20_21.tif',
#  'LELONAC21058-3_21_21.tif',
#  'LELONAC21058-3_2_21.tif',
#  'LELONAC21058-3_3_21.tif',
#  'LELONAC21058-3_4_21.tif',
#  'LELONAC21058-3_5_21.tif',
#  'LELONAC21058-3_6_21.tif',
#  'LELONAC21058-3_7_21.tif',
#  'LELONAC21058-3_8_21.tif',
#  'LELONAC21058-3_9_21.tif',
#  'LELONAC21058-4_10_13.tif',
#  'LELONAC21058-4_11_13.tif',
#  'LELONAC21058-4_12_13.tif',
#  'LELONAC21058-4_13_13.tif',
#  'LELONAC21058-4_1_13.tif',
#  'LELONAC21058-4_2_13.tif',
#  'LELONAC21058-4_3_13.tif',
#  'LELONAC21058-4_4_13.tif',
#  'LELONAC21058-4_5_13.tif',
#  'LELONAC21058-4_6_13.tif',
#  'LELONAC21058-4_7_13.tif',
#  'LELONAC21058-4_8_13.tif',
#  'LELONAC21058-4_9_13.tif',
#  'LELONAC21060-1_10_13.tif',
#  'LELONAC21060-1_11_13.tif',
#  'LELONAC21060-1_12_13.tif',
#  'LELONAC21060-1_13_13.tif',
#  'LELONAC21060-1_1_13.tif',
#  'LELONAC21060-1_2_13.tif',
#  'LELONAC21060-1_3_13.tif',
#  'LELONAC21060-1_4_13.tif',
#  'LELONAC21060-1_5_13.tif',
#  'LELONAC21060-1_6_13.tif',
#  'LELONAC21060-1_7_13.tif',
#  'LELONAC21060-1_8_13.tif',
#  'LELONAC21060-1_9_13.tif',
#  'LELONAC21060-3_10_17.tif',
#  'LELONAC21060-3_11_17.tif',
#  'LELONAC21060-3_12_17.tif',
#  'LELONAC21060-3_13_17.tif',
#  'LELONAC21060-3_14_17.tif',
#  'LELONAC21060-3_15_17.tif',
#  'LELONAC21060-3_16_17.tif',
#  'LELONAC21060-3_17_17.tif',
#  'LELONAC21060-3_1_17.tif',
#  'LELONAC21060-3_2_17.tif',
#  'LELONAC21060-3_3_17.tif',
#  'LELONAC21060-3_4_17.tif',
#  'LELONAC21060-3_5_17.tif',
#  'LELONAC21060-3_6_17.tif',
#  'LELONAC21060-3_7_17.tif',
#  'LELONAC21060-3_8_17.tif',
#  'LELONAC21060-3_9_17.tif',
#  'LELONAC21060-4_10_14.tif',
#  'LELONAC21060-4_11_14.tif',
#  'LELONAC21060-4_12_14.tif',
#  'LELONAC21060-4_13_14.tif',
#  'LELONAC21060-4_14_14.tif',
#  'LELONAC21060-4_1_14.tif',
#  'LELONAC21060-4_2_14.tif',
#  'LELONAC21060-4_3_14.tif',
#  'LELONAC21060-4_4_14.tif',
#  'LELONAC21060-4_5_14.tif',
#  'LELONAC21060-4_6_14.tif',
#  'LELONAC21060-4_7_14.tif',
#  'LELONAC21060-4_8_14.tif',
#  'LELONAC21060-4_9_14.tif',
#  'LELONAC21060-5_10_20.tif',
#  'LELONAC21060-5_11_20.tif',
#  'LELONAC21060-5_12_20.tif',
#  'LELONAC21060-5_13_20.tif',
#  'LELONAC21060-5_14_20.tif',
#  'LELONAC21060-5_15_20.tif',
#  'LELONAC21060-5_16_20.tif',
#  'LELONAC21060-5_17_20.tif',
#  'LELONAC21060-5_18_20.tif',
#  'LELONAC21060-5_19_20.tif',
#  'LELONAC21060-5_1_20.tif',
#  'LELONAC21060-5_20_20.tif',
#  'LELONAC21060-5_2_20.tif',
#  'LELONAC21060-5_3_20.tif',
#  'LELONAC21060-5_4_20.tif',
#  'LELONAC21060-5_5_20.tif',
#  'LELONAC21060-5_6_20.tif',
#  'LELONAC21060-5_7_20.tif',
#  'LELONAC21060-5_8_20.tif',
#  'LELONAC21060-5_9_20.tif',
#  'LELONAC21060-6_10_13.tif',
#  'LELONAC21060-6_11_13.tif',
#  'LELONAC21060-6_12_13.tif',
#  'LELONAC21060-6_13_13.tif',
#  'LELONAC21060-6_1_13.tif',
#  'LELONAC21060-6_2_13.tif',
#  'LELONAC21060-6_3_13.tif',
#  'LELONAC21060-6_4_13.tif',
#  'LELONAC21060-6_5_13.tif',
#  'LELONAC21060-6_6_13.tif',
#  'LELONAC21060-6_7_13.tif',
#  'LELONAC21060-6_8_13.tif',
#  'LELONAC21060-6_9_13.tif',
#  'LELONAC21060-7_10_22.tif',
#  'LELONAC21060-7_11_22.tif',
#  'LELONAC21060-7_12_22.tif',
#  'LELONAC21060-7_13_22.tif',
#  'LELONAC21060-7_14_22.tif',
#  'LELONAC21060-7_15_22.tif',
#  'LELONAC21060-7_16_22.tif',
#  'LELONAC21060-7_17_22.tif',
#  'LELONAC21060-7_18_22.tif',
#  'LELONAC21060-7_19_22.tif',
#  'LELONAC21060-7_1_22.tif',
#  'LELONAC21060-7_20_22.tif',
#  'LELONAC21060-7_21_22.tif',
#  'LELONAC21060-7_22_22.tif',
#  'LELONAC21060-7_2_22.tif',
#  'LELONAC21060-7_3_22.tif',
#  'LELONAC21060-7_4_22.tif',
#  'LELONAC21060-7_5_22.tif',
#  'LELONAC21060-7_6_22.tif',
#  'LELONAC21060-7_7_22.tif',
#  'LELONAC21060-7_8_22.tif',
#  'LELONAC21060-7_9_22.tif',
#  'LELONAC21060-8_10_14.tif',
#  'LELONAC21060-8_11_14.tif',
#  'LELONAC21060-8_12_14.tif',
#  'LELONAC21060-8_13_14.tif',
#  'LELONAC21060-8_14_14.tif',
#  'LELONAC21060-8_1_14.tif',
#  'LELONAC21060-8_2_14.tif',
#  'LELONAC21060-8_3_14.tif',
#  'LELONAC21060-8_4_14.tif',
#  'LELONAC21060-8_5_14.tif',
#  'LELONAC21060-8_6_14.tif',
#  'LELONAC21060-8_7_14.tif',
#  'LELONAC21060-8_8_14.tif',
#  'LELONAC21060-8_9_14.tif',
#  'LELONAC21063-1_10_10.tif',
#  'LELONAC21063-1_1_10.tif',
#  'LELONAC21063-1_2_10.tif',
#  'LELONAC21063-1_3_10.tif',
#  'LELONAC21063-1_4_10.tif',
#  'LELONAC21063-1_5_10.tif',
#  'LELONAC21063-1_6_10.tif',
#  'LELONAC21063-1_7_10.tif',
#  'LELONAC21063-1_8_10.tif',
#  'LELONAC21063-1_9_10.tif',
#  'LELONAC21065-2_10_13.tif',
#  'LELONAC21065-2_11_13.tif',
#  'LELONAC21065-2_12_13.tif',
#  'LELONAC21065-2_13_13.tif',
#  'LELONAC21065-2_1_13.tif',
#  'LELONAC21065-2_2_13.tif',
#  'LELONAC21065-2_3_13.tif',
#  'LELONAC21065-2_4_13.tif',
#  'LELONAC21065-2_5_13.tif',
#  'LELONAC21065-2_6_13.tif',
#  'LELONAC21065-2_7_13.tif',
#  'LELONAC21065-2_8_13.tif',
#  'LELONAC21065-2_9_13.tif',
#  'LELONAC21065-3_10_10.tif',
#  'LELONAC21065-3_1_10.tif',
#  'LELONAC21065-3_2_10.tif',
#  'LELONAC21065-3_3_10.tif',
#  'LELONAC21065-3_4_10.tif',
#  'LELONAC21065-3_5_10.tif',
#  'LELONAC21065-3_6_10.tif',
#  'LELONAC21065-3_7_10.tif',
#  'LELONAC21065-3_8_10.tif',
#  'LELONAC21065-3_9_10.tif',
#  'LFEAYAC21001-12_10_17.tif',
#  'LFEAYAC21001-12_11_17.tif',
#  'LFEAYAC21001-12_12_17.tif',
#  'LFEAYAC21001-12_13_17.tif',
#  'LFEAYAC21001-12_14_17.tif',
#  'LFEAYAC21001-12_15_17.tif',
#  'LFEAYAC21001-12_16_17.tif',
#  'LFEAYAC21001-12_17_17.tif',
#  'LFEAYAC21001-12_1_17.tif',
#  'LFEAYAC21001-12_2_17.tif',
#  'LFEAYAC21001-12_3_17.tif',
#  'LFEAYAC21001-12_4_17.tif',
#  'LFEAYAC21001-12_5_17.tif',
#  'LFEAYAC21001-12_6_17.tif',
#  'LFEAYAC21001-12_7_17.tif',
#  'LFEAYAC21001-12_8_17.tif',
#  'LFEAYAC21001-12_9_17.tif',
#  'LFEAYAC21001-4_1_1.tif',
#  'LFEAYAC21001-5_1_5.tif',
#  'LFEAYAC21001-5_2_5.tif',
#  'LFEAYAC21001-5_3_5.tif',
#  'LFEAYAC21001-5_4_5.tif',
#  ...]

# %% [markdown]
# # Process and landmark data
#
# - Read in image in grayscale
# - Select the contour of the largest object (the leaf)
# - Interpolate with a high resolution of pseudo-landmarks
# - Find the base and tip index point on the high resolution contour
# - Reset the base index to zero
# - Interpolate each side with desired number of equidistant pseudo-landmarks
# - Rotate leaves and scale to centimeters
# - Save pseudo-landmarks scaled to centimeters in an array
#
# PARAMETERS AND INDEXING:
# - `high_res_pts` is an arbitrarily high number of points to initially interpolate
# - `res` is the desired number of points to interpolate on each side of the leaf
# - The total number of pseudo-landmarks will be `2*res - 1`
# - The base index will be `0`
# - The tip index will be `res-1`
# - The returned leaves in `cm_arr` are scaled in size to centimeters

# %% [markdown]
# First, find excluded and missing leaves where the metadata file name is not found in the binary files

# %%
exclude_leaves = [] # leaf names to exclude
exclude_inds = [] # indices of leaf names to exclude

missing_leaves = [] # metadata leaf name not in files
missing_inds = [] # indices of metadata leaf names not in files


# for each leaf . . .
for lf in range(len(mdata)):
    if mdata["include"][lf]=="N":
        exclude_leaves.append(mdata["file"][lf])
        exclude_inds.append(lf)

    elif mdata["file"][lf]+".tif" not in file_names:
        missing_leaves.append(mdata["file"][lf])
        missing_inds.append(lf)
        
print("There are", len(exclude_inds), "excluded leaves")
print("There are", len(missing_inds), "missing leaves")

# save the missing leaves
file_path = "missing_leaves.txt"
with open(file_path, 'w') as file:
    for item in missing_leaves:
        file.write(item + '\n')
# Out:
# There are 735 excluded leaves
# There are 60 missing leaves

# %% [markdown]
# Next, remove the indices of excluded or missing leaves before analysis

# %%
remove_inds = exclude_inds + missing_inds # create list of indices to remove from mdata

mdata = mdata.drop(remove_inds, axis=0)

mdata = mdata.reset_index() # Reset the index

# %%
######################
### SET PARAMETERS ###
######################

# the number of equidistant points to create
# an initial high resolution outline of the leaf
high_res_pts = 10000

# the ultimate number of equidistant points on each side of the leaf
# (-1 for the tip)
# the leaf will have res*2-1 pseudo-landmarks
#################
#################
#################
res = 50 ########
#################
#################
#################

# an array to store pseudo-landmarks
cm_arr = np.zeros((len(mdata),(res*2)-1,2))

# for each leaf . . .
for lf in range(len(mdata)):

    ###############################
    ### READ IN GRAYSCALE IMAGE ###
    ###############################

    curr_image = mdata["file"][lf]+".tif" # select the current image

    if mdata["include"][lf]=="N":
        continue

    print(lf, curr_image) # print each leaf in case there are problems later

    # read in image
    # convert to grayscale
    # invert the binary
    img = cv2.bitwise_not(cv2.cvtColor(cv2.imread(data_dir + curr_image),cv2.COLOR_BGR2GRAY))

    # find contours of binary objects
    contours, hierarchy = cv2.findContours(img,  
        cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    ##############################
    ### SELECT LARGEST CONTOUR ###
    ##############################

    # ideally there is only one leaf in the image
    # in the case there are smaller objects
    # this code selects the largest object (the leaf)
    # if there is one and only one object in the image
    # then the following code is not necessary

    x_conts = [] # list of lists of contour x vals
    y_conts = [] # list of lists of contour y vals
    areas_conts = [] # list of bounding box areas of contours
    for c in contours: # for each contour
        x_vals = [] # store x vals for current contour 
        y_vals = [] # store y vals for current contour
        for i in range(len(c)): # for each point in current contour
            x_vals.append(c[i][0][0]) # isolate x val
            y_vals.append(c[i][0][1]) # isolate y val
        area = (max(x_vals) - min(x_vals))*(max(y_vals) - min(y_vals)) # calculate bounding box area of contour
        x_conts.append(x_vals) # append the current contour x vals
        y_conts.append(y_vals) # append the current contour y vals
        areas_conts.append(area) # append the current contour bounding box areas

    area_inds = np.flip(np.argsort(areas_conts)) # get indices to sort contours by area
    sorted_x_conts = np.array(x_conts, dtype=object)[area_inds][0:] # areas sorted largest to smallest, x vals
    sorted_y_conts = np.array(y_conts, dtype=object)[area_inds][0:] # areas sorted largest to smallest, y vals

    ################################################
    ### INTERPOLATE HIGH RES NUMBER OF LANDMARKS ###
    ################################################

    # convert the leaf to high resolution number of landmarks
    # using high_res_pt value
    # need to convert arrays of pixel int to floats first
    high_res_x, high_res_y = interpolation(np.array(sorted_x_conts[0], dtype=np.float32), 
                                           np.array(sorted_y_conts[0], dtype=np.float32), high_res_pts)

    ###############################
    ### FIND BASE AND TIP INDEX ###
    ###############################

    # get the base and tip landmark point values
    base_pt = np.array((mdata["base_x"][lf], mdata["base_y"][lf]))
    tip_pt = np.array((mdata["tip_x"][lf], mdata["tip_y"][lf]))

    base_dists = [] # store distance of each high res point to base
    tip_dists = [] # store distance of each high res point to tip

    for pt in range(len(high_res_x)): # for each of the high resolution points

        # euclidean distance of the current point from the base and tip landmark
        ed_base = euclid_dist(base_pt[0], base_pt[1], high_res_x[pt], high_res_y[pt])
        ed_tip = euclid_dist(tip_pt[0], tip_pt[1], high_res_x[pt], high_res_y[pt])

        # store distance of current point from base/tip
        base_dists.append(ed_base)
        tip_dists.append(ed_tip)

    # get index of base and tip points
    base_ind = np.argmin(base_dists)
    tip_ind = np.argmin(tip_dists)

    ################################
    ### RESET BASE INDEX TO ZERO ###
    ################################

    # reset base index position to zero
    high_res_x = np.concatenate((high_res_x[base_ind:],high_res_x[:base_ind]))
    high_res_y = np.concatenate((high_res_y[base_ind:],high_res_y[:base_ind]))

    # recalculate indices with new indexing
    tip_ind = tip_ind-base_ind # note: negative index if tip_ind<base_ind
    base_ind = base_ind-base_ind

    # create single array for leaf coordinates
    lf_contour = np.column_stack((high_res_x, high_res_y))

    ##############################################################
    ### INTERPOLATE EACH SIDE WITH DESIRED NUMBER OF LANDMARKS ###
    ##############################################################

    # interpolate at desired resolution the left and right sides of the leaf
    left_inter_x, left_inter_y = interpolation(lf_contour[base_ind:tip_ind+1,0],lf_contour[base_ind:tip_ind+1,1],res)
    right_inter_x, right_inter_y = interpolation(lf_contour[tip_ind:,0],lf_contour[tip_ind:,1],res)

    # the start of the right side and end of the left side
    # both contain the tip landmark
    # delete the last point on the left side
    left_inter_x = np.delete(left_inter_x, -1)
    left_inter_y = np.delete(left_inter_y, -1)

    # BASE OF LEAF IS INDEX 0
    # TIP INDEX IS RES-1 IF BOTH LEFT & RIGHT POINTS
    # TOTAL PSEUDOLANDMARKS IS 2*RES-1
    lf_pts_left = np.column_stack((left_inter_x, left_inter_y))
    lf_pts_right = np.column_stack((right_inter_x, right_inter_y))
    lf_pts = np.row_stack((lf_pts_left, lf_pts_right))

    ##########################################################
    ### ROTATE LEAVES UPWARD AND SCALE SIZE TO CENTIMETERS ###
    ##########################################################

    tip_point = lf_pts[res-1,:] # get tip point
    base_point = lf_pts[0,:] # get base point

    # calculate angle between tip. base, and an arbitrary reference
    ang = angle_between(tip_point, base_point, (base_point[0]+1,base_point[1]) )

    # rotate points upwards
    rot_x, rot_y = rotate_points(lf_pts[:,0], lf_pts[:,1], ang) 
    rot_pts = np.column_stack((rot_x, rot_y))
    
    # calculate leaf area in pixels^2
    lf_area_px2 = poly_area(rot_pts[:,0], rot_pts[:,1])
    
    # get px_cm
    px_cm = mdata["px_cm"][lf]

    # scale leaf into cm
    cm_lf = rot_pts/(px_cm)
    
    # store the leaf scaled into cm into the cm_arr
    cm_arr[lf,:,:] = cm_lf
# Out:
# 0 LAMOEWC23246-1_1_13.tif
# 1 LAMOEWC23246-1_2_13.tif
# 2 LAMOEWC23246-1_3_13.tif
# 3 LAMOEWC23246-1_6_13.tif
# 4 LAMOEWC23246-2_3_5.tif
# 5 LAMOEWC23246-2_5_5.tif
# 6 LAPALBS17132-1_1_28.tif
# 7 LAPALBS17132-1_2_28.tif
# 8 LAPALBS17132-1_3_28.tif
# 9 LAPALBS17132-1_4_28.tif
# 10 LAPALMJ21170-1_1_10.tif
# 11 LAPALMJ21170-1_2_10.tif
# 12 LAPALMJ21170-1_3_10.tif
# 13 LAPALMJ21170-1_4_10.tif
# 14 LAPALMJ21170-1_5_10.tif
# 15 LAPALMJ21170-1_6_10.tif
# 16 LAPALMJ21170-1_7_10.tif
# 17 LAPALMJ21170-1_8_10.tif
# 18 LAPALMJ21170-1_9_10.tif
# 19 LAPALMJ21170-1_10_10.tif
# 20 LAPPEAC21008-1_1_5.tif
# 21 LAPPEAC21008-1_2_5.tif
# 22 LAPPEAC21008-1_3_5.tif
# 23 LAPPEAC21008-1_4_5.tif
# 24 LAPPEAC21008-2_4_13.tif
# 25 LAPPEAC21008-2_6_13.tif
# 26 LAPPEAC21008-3_1_8.tif
# 27 LAPPEAC21008-3_4_8.tif
# 28 LAPPEAC21008-3_8_8.tif
# 29 LAPPEAC21010-1_1_3.tif
# 30 LAPPEAC21010-1_2_3.tif
# 31 LAPPEAC21010-1_3_3.tif
# 32 LAPPEAC21010-2_1_15.tif
# 33 LAPPEAC21010-2_2_15.tif
# 34 LAPPEAC21010-2_3_15.tif
# 35 LAPPEAC21010-2_4_15.tif
# 36 LAPPEAC21010-2_5_15.tif
# 37 LAPPEAC21010-2_6_15.tif
# 38 LAPPEAC21010-2_7_15.tif
# 39 LAPPEAC21010-2_8_15.tif
# 40 LAPPEAC21010-2_9_15.tif
# 41 LAPPEAC21010-2_10_15.tif
# 42 LAPPEAC21010-2_11_15.tif
# 43 LAPPEAC21010-2_12_15.tif
# 44 LAPPEAC21010-2_14_15.tif
# 45 LAPPEAC21010-2_15_15.tif
# 46 LAPPEAC21010-3_1_16.tif
# 47 LAPPEAC21010-3_2_16.tif
# 48 LAPPEAC21010-3_4_16.tif
# 49 LAPPEAC21010-3_5_16.tif
# 50 LAPPEAC21010-3_6_16.tif
# 51 LAPPEAC21010-3_7_16.tif
# 52 LAPPEAC21010-3_8_16.tif
# 53 LAPPEAC21010-3_9_16.tif
# 54 LAPPEAC21010-3_10_16.tif
# 55 LAPPEAC21010-3_11_16.tif
# 56 LAPPEAC21010-3_13_16.tif
# 57 LAPPEAC21010-4_1_7.tif
# 58 LAPPEAC21010-4_2_7.tif
# 59 LAPPEAC21010-4_3_7.tif
# 60 LAPPEAC21010-4_4_7.tif
# 61 LAPPEAC21010-4_5_7.tif
# 62 LAPPEAC21010-4_6_7.tif
# 63 LAPPEAC21010-4_7_7.tif
# 64 LAPPEAC21010-5_1_8.tif
# 65 LAPPEAC21010-5_7_8.tif
# 66 LAPPEAC21010-6_4_6.tif
# 67 LAPPEAC21010-6_6_6.tif
# 68 LAPPEAC21010-8_3_17.tif
# 69 LAPPEAC21010-8_7_17.tif
# 70 LAPPEAC21010-8_8_17.tif
# 71 LAPPEAC21010-8_11_17.tif
# 72 LAPPEAC21010-8_13_17.tif
# 73 LAPPEAC21010-8_15_17.tif
# 74 LAPPEAC21010-8_16_17.tif
# 75 LBATSPA21164-1_1_42.tif
# 76 LBATSPA21164-1_2_42.tif
# 77 LBATSPA21164-1_3_42.tif
# 78 LBATSPA21164-1_5_42.tif
# 79 LBATSPA21164-1_6_42.tif
# 80 LBATSPA21164-1_10_42.tif
# 81 LBATSPA21164-1_18_42.tif
# 82 LBATSPA21164-1_19_42.tif
# 83 LBATSPA21164-1_20_42.tif
# 84 LBATSPA21164-1_29_42.tif
# 85 LBATSPA21164-1_30_42.tif
# 86 LBREVAC21171-1_1_89.tif
# 87 LBREVAC21171-1_2_89.tif
# 88 LBREVAC21171-1_3_89.tif
# 89 LBREVAC21171-1_4_89.tif
# 90 LBREVAC21171-1_5_89.tif
# 91 LBREVAC21171-1_6_89.tif
# 92 LBREVAC21171-1_7_89.tif
# 93 LBREVAC21171-1_8_89.tif
# 94 LBREVAC21171-1_9_89.tif
# 95 LBREVAC21171-1_10_89.tif
# 96 LBREVAC21171-1_11_89.tif
# 97 LBREVAC21171-1_12_89.tif
# 98 LBREVAC21171-1_13_89.tif
# 99 LBREVAC21171-1_14_89.tif
# 100 LBREVAC21171-1_15_89.tif
# 101 LBREVAC21171-1_16_89.tif
# 102 LBREVAC21171-1_17_89.tif
# 103 LBREVAC21171-1_18_89.tif
# 104 LBREVAC21171-1_19_89.tif
# 105 LBREVAC21171-1_20_89.tif
# 106 LBREVAC21171-1_21_89.tif
# 107 LBREVAC21171-1_22_89.tif
# 108 LBREVAC21171-1_23_89.tif
# 109 LBREVAC21171-1_24_89.tif
# 110 LBREVAC21171-1_25_89.tif
# 111 LBREVAC21171-1_26_89.tif
# 112 LBREVAC21171-1_27_89.tif
# 113 LBREVAC21171-1_28_89.tif
# 114 LBREVAC21171-1_29_89.tif
# 115 LBREVAC21171-1_30_89.tif
# 116 LBREVAC21171-1_31_89.tif
# 117 LBREVAC21171-1_32_89.tif
# 118 LBREVAC21171-1_33_89.tif
# 119 LBREVAC21171-1_34_89.tif
# 120 LBREVAC21171-1_35_89.tif
# 121 LBREVAC21171-1_36_89.tif
# 122 LBREVAC21171-1_37_89.tif
# 123 LBREVAC21171-1_38_89.tif
# 124 LBREVAC21171-1_39_89.tif
# 125 LBREVAC21171-1_40_89.tif
# 126 LBREVAC21171-1_41_89.tif
# 127 LBREVAC21171-1_42_89.tif
# 128 LBREVAC21171-1_43_89.tif
# 129 LBREVAC21171-1_44_89.tif
# 130 LBREVAC21171-1_45_89.tif
# 131 LBREVAC21171-1_46_89.tif
# 132 LBREVAC21171-1_47_89.tif
# 133 LBREVAC21171-1_48_89.tif
# 134 LBREVAC21171-1_49_89.tif
# 135 LBREVAC21171-1_50_89.tif
# 136 LBREVAC21171-1_51_89.tif
# 137 LBREVAC21171-1_52_89.tif
# 138 LBREVAC21171-1_53_89.tif
# 139 LBREVAC21171-1_54_89.tif
# 140 LBREVAC21171-1_55_89.tif
# 141 LBREVAC21171-1_56_89.tif
# 142 LBREVAC21171-1_57_89.tif
# 143 LBREVAC21171-1_58_89.tif
# 144 LBREVAC21171-1_59_89.tif
# 145 LBREVAC21171-1_60_89.tif
# 146 LBREVAC21171-1_61_89.tif
# 147 LBREVAC21171-1_62_89.tif
# 148 LBREVAC21171-1_63_89.tif
# 149 LBREVAC21171-1_64_89.tif
# 150 LBREVAC21171-1_65_89.tif
# 151 LBREVAC21171-1_66_89.tif
# 152 LBREVAC21171-1_67_89.tif
# 153 LBREVAC21171-1_68_89.tif
# 154 LBREVAC21171-1_69_89.tif
# 155 LBREVAC21171-1_70_89.tif
# 156 LBREVAC21171-1_71_89.tif
# 157 LBREVAC21171-1_72_89.tif
# 158 LBREVAC21171-1_73_89.tif
# 159 LBREVAC21171-1_74_89.tif
# 160 LBREVAC21171-1_75_89.tif
# 161 LBREVAC21171-1_76_89.tif
# 162 LBREVAC21171-1_77_89.tif
# 163 LBREVAC21171-1_78_89.tif
# 164 LBREVAC21171-1_79_89.tif
# 165 LBREVAC21171-1_80_89.tif
# 166 LBREVAC21171-1_81_89.tif
# 167 LBREVAC21171-1_82_89.tif
# 168 LBREVAC21171-1_83_89.tif
# 169 LBREVAC21171-1_84_89.tif
# 170 LBREVAC21171-1_85_89.tif
# 171 LBREVAC21171-1_86_89.tif
# 172 LBREVAC21171-1_87_89.tif
# 173 LBREVAC21171-1_88_89.tif
# 174 LBREVAC21171-1_89_89.tif
# 175 LBREVBS17075-2A_1_37.tif
# 176 LBREVBS17075-2A_2_37.tif
# 177 LBREVBS17075-2A_3_37.tif
# 178 LBREVBS17075-2A_4_37.tif
# 179 LBREVBS17075-2A_5_37.tif
# 180 LBREVBS17075-2A_6_37.tif
# 181 LBREVBS17075-2A_7_37.tif
# 182 LBREVBS17075-2A_8_37.tif
# 183 LBREVBS17075-2A_9_37.tif
# 184 LBREVBS17075-2A_10_37.tif
# 185 LBREVBS17075-2A_11_37.tif
# 186 LBREVBS17075-2A_12_37.tif
# 187 LBREVBS17075-2A_13_37.tif
# 188 LBREVBS17075-2A_14_37.tif
# 189 LBREVBS17075-2A_15_37.tif
# 190 LBREVBS17075-2A_16_37.tif
# 191 LBREVBS17075-2A_17_37.tif
# 192 LBREVBS17075-2A_18_37.tif
# 193 LBREVBS17075-2A_19_37.tif
# 194 LBREVBS17075-2A_20_37.tif
# 195 LBREVBS17075-2A_21_37.tif
# 196 LBREVBS17075-2A_22_37.tif
# 197 LBREVBS17075-2A_23_37.tif
# 198 LBREVBS17075-2A_24_37.tif
# 199 LBREVBS17075-2A_25_37.tif
# 200 LBREVBS17075-2A_26_37.tif
# 201 LBREVBS17075-2A_27_37.tif
# 202 LBREVBS17075-2A_28_37.tif
# 203 LBREVBS17075-2A_29_37.tif
# 204 LBREVBS17075-2A_30_37.tif
# 205 LBREVBS17075-2A_31_37.tif
# 206 LBREVBS17075-2A_32_37.tif
# 207 LBREVBS17075-2A_33_37.tif
# 208 LBREVBS17075-2A_34_37.tif
# 209 LBREVBS17075-2A_35_37.tif
# 210 LBREVBS17075-2A_36_37.tif
# 211 LBREVBS17075-2A_37_37.tif
# 212 LCANBAC21060-1_1_6.tif
# 213 LCANBAC21060-1_2_6.tif
# 214 LCANBAC21060-1_3_6.tif
# 215 LCANBAC21060-1_4_6.tif
# 216 LCANBAC21060-1_5_6.tif
# 217 LCANBAC21060-1_6_6.tif
# 218 LCANBGG21059-1_2_45.tif
# 219 LCANBGG21059-1_4_45.tif
# 220 LCANBGG21059-1_6_45.tif
# 221 LCANBGG21059-1_11_45.tif
# 222 LCANBGG21059-1_22_45.tif
# 223 LCANBGG21059-1_25_45.tif
# 224 LCANBGG21059-1_41_45.tif
# 225 LCANBGG21059-1_42_45.tif
# 226 LCANBGG21059-3_1_18.tif
# 227 LCANBGG21059-3_2_18.tif
# 228 LCANBGG21059-3_3_18.tif
# 229 LCANBGG21059-3_4_18.tif
# 230 LCANBGG21059-3_5_18.tif
# 231 LCANBGG21059-3_6_18.tif
# 232 LCANBGG21059-3_7_18.tif
# 233 LCANBGG21059-3_8_18.tif
# 234 LCANBGG21059-3_9_18.tif
# 235 LCANBGG21059-3_10_18.tif
# 236 LCANBGG21059-3_11_18.tif
# 237 LCANBGG21059-3_12_18.tif
# 238 LCANBGG21059-3_15_18.tif
# 239 LCANBGG21059-3_16_18.tif
# 240 LCANBGG21059-3_17_18.tif
# 241 LCANBGG21059-3_18_18.tif
# 242 LCARDAC23254-1_18_23.tif
# 243 LCARDAC23254-1_21_23.tif
# 244 LCARDAC23254-1_22_23.tif
# 245 LCARDAC23254-2_4_29.tif
# 246 LCARDAC23254-2_8_29.tif
# 247 LCARDAC23254-2_12_29.tif
# 248 LCARDAC23254-2_13_29.tif
# 249 LCARDAC23254-2_23_29.tif
# 250 LCARDAC23254-2_25_29.tif
# 251 LCARDAC23254-2_26_29.tif
# 252 LCARDAC23254-2_28_29.tif
# 253 LCARDPA23225 (A-L)-1_3_48.tif
# 254 LCARDPA23225 (A-L)-1_4_48.tif
# 255 LCARDPA23225 (A-L)-1_6_48.tif
# 256 LCARDPA23225 (A-L)-1_7_48.tif
# 257 LCARDPA23225 (A-L)-1_9_48.tif
# 258 LCARDPA23225 (A-L)-1_11_48.tif
# 259 LCARDPA23225 (A-L)-1_14_48.tif
# 260 LCARDPA23225 (A-L)-1_16_48.tif
# 261 LCARDPA23225 (A-L)-1_18_48.tif
# 262 LCARDPA23225 (A-L)-1_20_48.tif
# 263 LCARDPA23225 (A-L)-1_21_48.tif
# 264 LCARDPA23225 (A-L)-1_23_48.tif
# 265 LCARDPA23225 (A-L)-1_25_48.tif
# 266 LCARDPA23225 (A-L)-1_26_48.tif
# 267 LCARDPA23225 (A-L)-1_33_48.tif
# 268 LCARDPA23225 (A-L)-1_36_48.tif
# 269 LCARDPA23225 (A-L)-1_39_48.tif
# 270 LCARDPA23225 (A-L)-1_48_48.tif
# 271 LCARDPA23225 (A-L)-2_1_23.tif
# 272 LCARDPA23225 (A-L)-2_2_23.tif
# 273 LCARDPA23225 (A-L)-2_3_23.tif
# 274 LCARDPA23225 (A-L)-2_7_23.tif
# 275 LCARDPA23225 (A-L)-2_16_23.tif
# 276 LCARDPA23225 (A-L)-2_17_23.tif
# 277 LCARDPA23225 (A-L)-2_20_23.tif
# 278 LCARDPA23225 (A-L)-2_21_23.tif
# 279 LCARDPA23225 (A-L)-2_22_23.tif
# 280 LCARDPA23225 (A-L)-2_23_23.tif
# 281 LCARDPA23225 (A-L)-3_9_45.tif
# 282 LCARDPA23225 (A-L)-3_10_45.tif
# 283 LCARDPA23225 (A-L)-3_11_45.tif
# 284 LCARDPA23225 (A-L)-3_13_45.tif
# 285 LCARDPA23225 (A-L)-3_14_45.tif
# 286 LCARDPA23225 (A-L)-3_18_45.tif
# 287 LCARDPA23225 (A-L)-3_21_45.tif
# 288 LCARDPA23225 (A-L)-3_23_45.tif
# 289 LCARDPA23225 (A-L)-3_24_45.tif
# 290 LCARDPA23225 (A-L)-3_25_45.tif
# 291 LCARDPA23225 (A-L)-3_26_45.tif
# 292 LCARDPA23225 (A-L)-3_28_45.tif
# 293 LCARDPA23225 (A-L)-3_29_45.tif
# 294 LCARDPA23225 (A-L)-3_30_45.tif
# 295 LCARDPA23225 (A-L)-3_36_45.tif
# 296 LCARDPA23225 (A-L)-3_37_45.tif
# 297 LCARDPA23225 (A-L)-3_38_45.tif
# 298 LCARDPA23225 (A-L)-3_39_45.tif
# 299 LCARDPA23225 (A-L)-3_40_45.tif
# 300 LCARDPA23225 (A-L)-3_42_45.tif
# 301 LCARDPA23225 (A-L)-3_43_45.tif
# 302 LCARDPA23225 (A-L)-3_45_45.tif
# 303 LCARDPA23225 (A-R)-1_1_19.tif
# 304 LCARDPA23225 (A-R)-1_2_19.tif
# 305 LCARDPA23225 (A-R)-1_3_19.tif
# 306 LCARDPA23225 (A-R)-1_4_19.tif
# 307 LCARDPA23225 (A-R)-1_6_19.tif
# 308 LCARDPA23225 (A-R)-1_9_19.tif
# 309 LCARDPA23225 (A-R)-1_10_19.tif
# 310 LCARDPA23225 (A-R)-1_15_19.tif
# 311 LCARDPA23225 (A-R)-1_17_19.tif
# 312 LCARDPA23225 (A-R)-1_19_19.tif
# 313 LCARDPA23225 (S)-1_1_16.tif
# 314 LCARDPA23225 (S)-1_2_16.tif
# 315 LCARDPA23225 (S)-1_3_16.tif
# 316 LCARDPA23225 (S)-1_4_16.tif
# 317 LCARDPA23225 (S)-1_6_16.tif
# 318 LCARDPA23225 (S)-1_7_16.tif
# 319 LCARDPA23225 (S)-1_8_16.tif
# 320 LCARDPA23225 (S)-1_9_16.tif
# 321 LCARDPA23225 (S)-1_12_16.tif
# 322 LCARDPA23225 (S)-1_13_16.tif
# 323 LCARDPA23225 (S)-1_15_16.tif
# 324 LCARDST17131-1_1_3.tif
# 325 LCARDST17131-1_2_3.tif
# 326 LCARDST17131-1_3_3.tif
# 327 LDORTCB21050-1_1_33.tif
# 328 LDORTCB21050-1_2_33.tif
# 329 LDORTCB21050-1_3_33.tif
# 330 LDORTCB21050-1_4_33.tif
# 331 LDORTCB21050-1_5_33.tif
# 332 LDORTCB21050-1_6_33.tif
# 333 LDORTCB21050-1_7_33.tif
# 334 LDORTCB21050-1_8_33.tif
# 335 LDORTCB21050-1_9_33.tif
# 336 LDORTCB21050-1_10_33.tif
# 337 LDORTCB21050-1_11_33.tif
# 338 LDORTCB21050-1_12_33.tif
# 339 LDORTCB21050-1_13_33.tif
# 340 LDORTCB21050-1_14_33.tif
# 341 LDORTCB21050-1_15_33.tif
# 342 LDORTCB21050-1_16_33.tif
# 343 LDORTCB21050-1_17_33.tif
# 344 LDORTCB21050-1_18_33.tif
# 345 LDORTCB21050-1_19_33.tif
# 346 LDORTCB21050-1_20_33.tif
# 347 LDORTCB21050-1_21_33.tif
# 348 LDORTCB21050-1_22_33.tif
# 349 LDORTCB21050-1_23_33.tif
# 350 LDORTCB21050-1_24_33.tif
# 351 LDORTCB21050-1_25_33.tif
# 352 LDORTCB21050-1_26_33.tif
# 353 LDORTCB21050-1_27_33.tif
# 354 LDORTCB21050-1_28_33.tif
# 355 LDORTCB21050-1_29_33.tif
# 356 LDORTCB21050-1_30_33.tif
# 357 LDORTCB21050-1_31_33.tif
# 358 LDORTCB21050-1_32_33.tif
# 359 LDORTCB21050-1_33_33.tif
# 360 LDORTCB21050-2_1_20.tif
# 361 LDORTCB21050-2_2_20.tif
# 362 LDORTCB21050-2_3_20.tif
# 363 LDORTCB21050-2_4_20.tif
# 364 LDORTCB21050-2_5_20.tif
# 365 LDORTCB21050-2_6_20.tif
# 366 LDORTCB21050-2_7_20.tif
# 367 LDORTCB21050-2_8_20.tif
# 368 LDORTCB21050-2_9_20.tif
# 369 LDORTCB21050-2_10_20.tif
# 370 LDORTCB21050-2_11_20.tif
# 371 LDORTCB21050-2_12_20.tif
# 372 LDORTCB21050-2_13_20.tif
# 373 LDORTCB21050-2_14_20.tif
# 374 LDORTCB21050-2_15_20.tif
# 375 LDORTCB21050-2_16_20.tif
# 376 LDORTCB21050-2_17_20.tif
# 377 LDORTCB21050-2_18_20.tif
# 378 LDORTCB21050-2_19_20.tif
# 379 LDORTCB21050-2_20_20.tif
# 380 LDORTCB21050-3_1_49.tif
# 381 LDORTCB21050-3_2_49.tif
# 382 LDORTCB21050-3_3_49.tif
# 383 LDORTCB21050-3_4_49.tif
# 384 LDORTCB21050-3_5_49.tif
# 385 LDORTCB21050-3_6_49.tif
# 386 LDORTCB21050-3_7_49.tif
# 387 LDORTCB21050-3_8_49.tif
# 388 LDORTCB21050-3_9_49.tif
# 389 LDORTCB21050-3_10_49.tif
# 390 LDORTCB21050-3_11_49.tif
# 391 LDORTCB21050-3_12_49.tif
# 392 LDORTCB21050-3_13_49.tif
# 393 LDORTCB21050-3_14_49.tif
# 394 LDORTCB21050-3_15_49.tif
# 395 LDORTCB21050-3_16_49.tif
# 396 LDORTCB21050-3_17_49.tif
# 397 LDORTCB21050-3_18_49.tif
# 398 LDORTCB21050-3_19_49.tif
# 399 LDORTCB21050-3_20_49.tif
# 400 LDORTCB21050-3_21_49.tif
# 401 LDORTCB21050-3_22_49.tif
# 402 LDORTCB21050-3_23_49.tif
# 403 LDORTCB21050-3_24_49.tif
# 404 LDORTCB21050-3_25_49.tif
# 405 LDORTCB21050-3_26_49.tif
# 406 LDORTCB21050-3_27_49.tif
# 407 LDORTCB21050-3_28_49.tif
# 408 LDORTCB21050-3_29_49.tif
# 409 LDORTCB21050-3_30_49.tif
# 410 LDORTCB21050-3_31_49.tif
# 411 LDORTCB21050-3_32_49.tif
# 412 LDORTCB21050-3_33_49.tif
# 413 LDORTCB21050-3_34_49.tif
# 414 LDORTCB21050-3_35_49.tif
# 415 LDORTCB21050-3_36_49.tif
# 416 LDORTCB21050-3_37_49.tif
# 417 LDORTCB21050-3_38_49.tif
# 418 LDORTCB21050-3_39_49.tif
# 419 LDORTCB21050-3_40_49.tif
# 420 LDORTCB21050-3_41_49.tif
# 421 LDORTCB21050-3_42_49.tif
# 422 LDORTCB21050-3_43_49.tif
# 423 LDORTCB21050-3_44_49.tif
# 424 LDORTCB21050-3_45_49.tif
# 425 LDORTCB21050-3_46_49.tif
# 426 LDORTCB21050-3_47_49.tif
# 427 LDORTCB21050-3_48_49.tif
# 428 LDORTCB21050-3_49_49.tif
# 429 LDORTCB21050-4_1_18.tif
# 430 LDORTCB21050-4_2_18.tif
# 431 LDORTCB21050-4_3_18.tif
# 432 LDORTCB21050-4_4_18.tif
# 433 LDORTCB21050-4_5_18.tif
# 434 LDORTCB21050-4_6_18.tif
# 435 LDORTCB21050-4_7_18.tif
# 436 LDORTCB21050-4_8_18.tif
# 437 LDORTCB21050-4_9_18.tif
# 438 LDORTCB21050-4_10_18.tif
# 439 LDORTCB21050-4_11_18.tif
# 440 LDORTCB21050-4_12_18.tif
# 441 LDORTCB21050-4_13_18.tif
# 442 LDORTCB21050-4_14_18.tif
# 443 LDORTCB21050-4_15_18.tif
# 444 LDORTCB21050-4_16_18.tif
# 445 LDORTCB21050-4_17_18.tif
# 446 LDORTCB21050-4_18_18.tif
# 447 LDORTCB21050-5_1_12.tif
# 448 LDORTCB21050-5_2_12.tif
# 449 LDORTCB21050-5_3_12.tif
# 450 LDORTCB21050-5_4_12.tif
# 451 LDORTCB21050-5_5_12.tif
# 452 LDORTCB21050-5_6_12.tif
# 453 LDORTCB21050-5_7_12.tif
# 454 LDORTCB21050-5_8_12.tif
# 455 LDORTCB21050-5_9_12.tif
# 456 LDORTCB21050-5_10_12.tif
# 457 LDORTCB21050-5_11_12.tif
# 458 LDORTCB21050-5_12_12.tif
# 459 LDORTCB21050-7_1_17.tif
# 460 LDORTCB21050-7_2_17.tif
# 461 LDORTCB21050-7_3_17.tif
# 462 LDORTCB21050-7_4_17.tif
# 463 LDORTCB21050-7_5_17.tif
# 464 LDORTCB21050-7_6_17.tif
# 465 LDORTCB21050-7_7_17.tif
# 466 LDORTCB21050-7_8_17.tif
# 467 LDORTCB21050-7_9_17.tif
# 468 LDORTCB21050-7_10_17.tif
# 469 LDORTCB21050-7_11_17.tif
# 470 LDORTCB21050-7_12_17.tif
# 471 LDORTCB21050-7_13_17.tif
# 472 LDORTCB21050-7_14_17.tif
# 473 LDORTCB21050-7_15_17.tif
# 474 LDORTCB21050-7_16_17.tif
# 475 LDORTCB21050-7_17_17.tif
# 476 LELONAC21058-2_1_10.tif
# 477 LELONAC21058-2_2_10.tif
# 478 LELONAC21058-2_3_10.tif
# 479 LELONAC21058-2_4_10.tif
# 480 LELONAC21058-2_5_10.tif
# 481 LELONAC21058-2_6_10.tif
# 482 LELONAC21058-2_7_10.tif
# 483 LELONAC21058-2_8_10.tif
# 484 LELONAC21058-2_9_10.tif
# 485 LELONAC21058-2_10_10.tif
# 486 LELONAC21058-3_1_21.tif
# 487 LELONAC21058-3_2_21.tif
# 488 LELONAC21058-3_3_21.tif
# 489 LELONAC21058-3_4_21.tif
# 490 LELONAC21058-3_5_21.tif
# 491 LELONAC21058-3_6_21.tif
# 492 LELONAC21058-3_7_21.tif
# 493 LELONAC21058-3_8_21.tif
# 494 LELONAC21058-3_9_21.tif
# 495 LELONAC21058-3_10_21.tif
# 496 LELONAC21058-3_11_21.tif
# 497 LELONAC21058-3_12_21.tif
# 498 LELONAC21058-3_13_21.tif
# 499 LELONAC21058-3_14_21.tif
# 500 LELONAC21058-3_15_21.tif
# 501 LELONAC21058-3_16_21.tif
# 502 LELONAC21058-3_17_21.tif
# 503 LELONAC21058-3_18_21.tif
# 504 LELONAC21058-3_19_21.tif
# 505 LELONAC21058-3_20_21.tif
# 506 LELONAC21058-3_21_21.tif
# 507 LELONAC21058-4_1_13.tif
# 508 LELONAC21058-4_2_13.tif
# 509 LELONAC21058-4_3_13.tif
# 510 LELONAC21058-4_4_13.tif
# 511 LELONAC21058-4_5_13.tif
# 512 LELONAC21058-4_6_13.tif
# 513 LELONAC21058-4_7_13.tif
# 514 LELONAC21058-4_8_13.tif
# 515 LELONAC21058-4_9_13.tif
# 516 LELONAC21058-4_10_13.tif
# 517 LELONAC21058-4_11_13.tif
# 518 LELONAC21058-4_12_13.tif
# 519 LELONAC21058-4_13_13.tif
# 520 LELONAC21060-1_1_13.tif
# 521 LELONAC21060-1_2_13.tif
# 522 LELONAC21060-1_3_13.tif
# 523 LELONAC21060-1_4_13.tif
# 524 LELONAC21060-1_5_13.tif
# 525 LELONAC21060-1_6_13.tif
# 526 LELONAC21060-1_7_13.tif
# 527 LELONAC21060-1_8_13.tif
# 528 LELONAC21060-1_9_13.tif
# 529 LELONAC21060-1_10_13.tif
# 530 LELONAC21060-1_11_13.tif
# 531 LELONAC21060-1_12_13.tif
# 532 LELONAC21060-1_13_13.tif
# 533 LELONAC21060-3_1_17.tif
# 534 LELONAC21060-3_2_17.tif
# 535 LELONAC21060-3_3_17.tif
# 536 LELONAC21060-3_4_17.tif
# 537 LELONAC21060-3_5_17.tif
# 538 LELONAC21060-3_6_17.tif
# 539 LELONAC21060-3_7_17.tif
# 540 LELONAC21060-3_8_17.tif
# 541 LELONAC21060-3_9_17.tif
# 542 LELONAC21060-3_10_17.tif
# 543 LELONAC21060-3_11_17.tif
# 544 LELONAC21060-3_12_17.tif
# 545 LELONAC21060-3_13_17.tif
# 546 LELONAC21060-3_14_17.tif
# 547 LELONAC21060-3_15_17.tif
# 548 LELONAC21060-3_16_17.tif
# 549 LELONAC21060-3_17_17.tif
# 550 LELONAC21060-4_1_14.tif
# 551 LELONAC21060-4_2_14.tif
# 552 LELONAC21060-4_3_14.tif
# 553 LELONAC21060-4_4_14.tif
# 554 LELONAC21060-4_5_14.tif
# 555 LELONAC21060-4_6_14.tif
# 556 LELONAC21060-4_7_14.tif
# 557 LELONAC21060-4_8_14.tif
# 558 LELONAC21060-4_9_14.tif
# 559 LELONAC21060-4_10_14.tif
# 560 LELONAC21060-4_11_14.tif
# 561 LELONAC21060-4_12_14.tif
# 562 LELONAC21060-4_13_14.tif
# 563 LELONAC21060-4_14_14.tif
# 564 LELONAC21060-5_1_20.tif
# 565 LELONAC21060-5_2_20.tif
# 566 LELONAC21060-5_3_20.tif
# 567 LELONAC21060-5_4_20.tif
# 568 LELONAC21060-5_5_20.tif
# 569 LELONAC21060-5_6_20.tif
# 570 LELONAC21060-5_7_20.tif
# 571 LELONAC21060-5_8_20.tif
# 572 LELONAC21060-5_9_20.tif
# 573 LELONAC21060-5_10_20.tif
# 574 LELONAC21060-5_11_20.tif
# 575 LELONAC21060-5_12_20.tif
# 576 LELONAC21060-5_13_20.tif
# 577 LELONAC21060-5_14_20.tif
# 578 LELONAC21060-5_15_20.tif
# 579 LELONAC21060-5_16_20.tif
# 580 LELONAC21060-5_17_20.tif
# 581 LELONAC21060-5_18_20.tif
# 582 LELONAC21060-5_19_20.tif
# 583 LELONAC21060-5_20_20.tif
# 584 LELONAC21060-6_1_13.tif
# 585 LELONAC21060-6_2_13.tif
# 586 LELONAC21060-6_3_13.tif
# 587 LELONAC21060-6_4_13.tif
# 588 LELONAC21060-6_5_13.tif
# 589 LELONAC21060-6_6_13.tif
# 590 LELONAC21060-6_7_13.tif
# 591 LELONAC21060-6_8_13.tif
# 592 LELONAC21060-6_9_13.tif
# 593 LELONAC21060-6_10_13.tif
# 594 LELONAC21060-6_11_13.tif
# 595 LELONAC21060-6_12_13.tif
# 596 LELONAC21060-6_13_13.tif
# 597 LELONAC21060-7_1_22.tif
# 598 LELONAC21060-7_2_22.tif
# 599 LELONAC21060-7_3_22.tif
# 600 LELONAC21060-7_4_22.tif
# 601 LELONAC21060-7_5_22.tif
# 602 LELONAC21060-7_6_22.tif
# 603 LELONAC21060-7_7_22.tif
# 604 LELONAC21060-7_8_22.tif
# 605 LELONAC21060-7_9_22.tif
# 606 LELONAC21060-7_10_22.tif
# 607 LELONAC21060-7_11_22.tif
# 608 LELONAC21060-7_12_22.tif
# 609 LELONAC21060-7_13_22.tif
# 610 LELONAC21060-7_14_22.tif
# 611 LELONAC21060-7_15_22.tif
# 612 LELONAC21060-7_16_22.tif
# 613 LELONAC21060-7_17_22.tif
# 614 LELONAC21060-7_18_22.tif
# 615 LELONAC21060-7_19_22.tif
# 616 LELONAC21060-7_20_22.tif
# 617 LELONAC21060-7_21_22.tif
# 618 LELONAC21060-7_22_22.tif
# 619 LELONAC21060-8_1_14.tif
# 620 LELONAC21060-8_2_14.tif
# 621 LELONAC21060-8_3_14.tif
# 622 LELONAC21060-8_4_14.tif
# 623 LELONAC21060-8_5_14.tif
# 624 LELONAC21060-8_6_14.tif
# 625 LELONAC21060-8_7_14.tif
# 626 LELONAC21060-8_8_14.tif
# 627 LELONAC21060-8_9_14.tif
# 628 LELONAC21060-8_10_14.tif
# 629 LELONAC21060-8_11_14.tif
# 630 LELONAC21060-8_12_14.tif
# 631 LELONAC21060-8_13_14.tif
# 632 LELONAC21060-8_14_14.tif
# 633 LELONAC21063-1_1_10.tif
# 634 LELONAC21063-1_2_10.tif
# 635 LELONAC21063-1_3_10.tif
# 636 LELONAC21063-1_4_10.tif
# 637 LELONAC21063-1_5_10.tif
# 638 LELONAC21063-1_6_10.tif
# 639 LELONAC21063-1_7_10.tif
# 640 LELONAC21063-1_8_10.tif
# 641 LELONAC21063-1_9_10.tif
# 642 LELONAC21063-1_10_10.tif
# 643 LELONAC21065-2_1_13.tif
# 644 LELONAC21065-2_2_13.tif
# 645 LELONAC21065-2_3_13.tif
# 646 LELONAC21065-2_4_13.tif
# 647 LELONAC21065-2_5_13.tif
# 648 LELONAC21065-2_6_13.tif
# 649 LELONAC21065-2_7_13.tif
# 650 LELONAC21065-2_8_13.tif
# 651 LELONAC21065-2_9_13.tif
# 652 LELONAC21065-2_10_13.tif
# 653 LELONAC21065-2_11_13.tif
# 654 LELONAC21065-2_12_13.tif
# 655 LELONAC21065-2_13_13.tif
# 656 LELONAC21065-3_1_10.tif
# 657 LELONAC21065-3_2_10.tif
# 658 LELONAC21065-3_3_10.tif
# 659 LELONAC21065-3_4_10.tif
# 660 LELONAC21065-3_5_10.tif
# 661 LELONAC21065-3_6_10.tif
# 662 LELONAC21065-3_7_10.tif
# 663 LELONAC21065-3_8_10.tif
# 664 LELONAC21065-3_9_10.tif
# 665 LELONAC21065-3_10_10.tif
# 666 LFEAYAC21001-4_1_1.tif
# 667 LFEAYAC21001-5_1_5.tif
# 668 LFEAYAC21002-3_10_11.tif
# 669 LFEAYAC21002-8_2_16.tif
# 670 LFEAYAC21002-8_3_16.tif
# 671 LFEAYAC21002-8_6_16.tif
# 672 LFEAYAC21002-9_1_3.tif
# 673 LFEAYAC21002-10_2_7.tif
# 674 LFEAYAC21002-10_3_7.tif
# 675 LFEAYAC21002-10_5_7.tif
# 676 LFEAYAC21002-11_4_7.tif
# 677 LFEAYAC21002-12_1_2.tif
# 678 LFEAYAC21005-4_2_5.tif
# 679 LFEAYAC21005-6_1_7.tif
# 680 LFEAYAC21005-6_3_7.tif
# 681 LFEAYAC21005-6_5_7.tif
# 682 LFEAYAC21005-8_1_5.tif
# 683 LFEAYAC21005-9_1_5.tif
# 684 LFEAYAC21005-9_2_5.tif
# 685 LFEAYAC21005-9_3_5.tif
# 686 LFEAYAC21005-9_5_5.tif
# 687 LFEAYLD21004-6_1_2.tif
# 688 LFEAYLD21004-6_2_2.tif
# 689 LFLACCB21015-1_1_18.tif
# 690 LFLACCB21015-1_2_18.tif
# 691 LFLACCB21015-1_3_18.tif
# 692 LFLACCB21015-1_4_18.tif
# 693 LFLACCB21015-1_5_18.tif
# 694 LFLACCB21015-1_6_18.tif
# 695 LFLACCB21015-1_7_18.tif
# 696 LFLACCB21015-1_8_18.tif
# 697 LFLACCB21015-1_9_18.tif
# 698 LFLACCB21015-1_10_18.tif
# 699 LFLACCB21015-1_11_18.tif
# 700 LFLACCB21015-1_12_18.tif
# 701 LFLACCB21015-1_13_18.tif
# 702 LFLACCB21015-1_14_18.tif
# 703 LFLACCB21015-1_15_18.tif
# 704 LFLACCB21015-1_16_18.tif
# 705 LFLACCB21015-1_17_18.tif
# 706 LFLACCB21015-1_18_18.tif
# 707 LFLACCB21015-2_1_19.tif
# 708 LFLACCB21015-2_2_19.tif
# 709 LFLACCB21015-2_3_19.tif
# 710 LFLACCB21015-2_4_19.tif
# 711 LFLACCB21015-2_5_19.tif
# 712 LFLACCB21015-2_6_19.tif
# 713 LFLACCB21015-2_7_19.tif
# 714 LFLACCB21015-2_8_19.tif
# 715 LFLACCB21015-2_9_19.tif
# 716 LFLACCB21015-2_10_19.tif
# 717 LFLACCB21015-2_11_19.tif
# 718 LFLACCB21015-2_12_19.tif
# 719 LFLACCB21015-2_13_19.tif
# 720 LFLACCB21015-2_14_19.tif
# 721 LFLACCB21015-2_18_19.tif
# 722 LFLACCB21015-2_19_19.tif
# 723 LFLACCB21015-3_1_6.tif
# 724 LFLACCB21015-3_2_6.tif
# 725 LFLACCB21015-3_3_6.tif
# 726 LFLACCB21015-3_4_6.tif
# 727 LFLACCB21015-3_5_6.tif
# 728 LFLACCB21015-3_6_6.tif
# 729 LFLACCB21015-5_1_9.tif
# 730 LFLACCB21015-5_2_9.tif
# 731 LFLACCB21015-5_3_9.tif
# 732 LFLACCB21015-5_4_9.tif
# 733 LFLACCB21015-5_5_9.tif
# 734 LFLACCB21015-5_6_9.tif
# 735 LFLACCB21015-5_7_9.tif
# 736 LFLACCB21015-5_8_9.tif
# 737 LFLACCB21015-5_9_9.tif
# 738 LFLACCB21015-8_1_5.tif
# 739 LFLACCB21015-8_2_5.tif
# 740 LFLACCB21015-8_3_5.tif
# 741 LFLACCB21015-8_4_5.tif
# 742 LFLACCB21015-8_5_5.tif
# 743 LFLACCB21015-9_1_9.tif
# 744 LFLACCB21015-9_2_9.tif
# 745 LFLACCB21015-9_3_9.tif
# 746 LFLACCB21015-9_4_9.tif
# 747 LFLACCB21015-9_5_9.tif
# 748 LFLACCB21015-9_6_9.tif
# 749 LFLACCB21015-9_7_9.tif
# 750 LFLACCB21015-9_8_9.tif
# 751 LFLACCB21015-9_9_9.tif
# 752 LFLACCB21015-10_1_24.tif
# 753 LFLACCB21015-10_2_24.tif
# 754 LFLACCB21015-10_3_24.tif
# 755 LFLACCB21015-10_4_24.tif
# 756 LFLACCB21015-10_5_24.tif
# 757 LFLACCB21015-10_6_24.tif
# 758 LFLACCB21015-10_7_24.tif
# 759 LFLACCB21015-10_8_24.tif
# 760 LFLACCB21015-10_9_24.tif
# 761 LFLACCB21015-10_10_24.tif
# 762 LFLACCB21015-10_11_24.tif
# 763 LFLACCB21015-10_12_24.tif
# 764 LFLACCB21015-10_13_24.tif
# 765 LFLACCB21015-10_14_24.tif
# 766 LFLACCB21015-10_15_24.tif
# 767 LFLACCB21015-10_16_24.tif
# 768 LFLACCB21015-10_17_24.tif
# 769 LFLACCB21015-10_18_24.tif
# 770 LFLACCB21015-10_19_24.tif
# 771 LFLACCB21015-10_20_24.tif
# 772 LFLACCB21015-10_21_24.tif
# 773 LFLACCB21015-10_22_24.tif
# 774 LFLACCB21015-10_23_24.tif
# 775 LFLACCB21015-10_24_24.tif
# 776 LFLACCB21018-1_1_6.tif
# 777 LFLACCB21018-1_2_6.tif
# 778 LFLACCB21018-1_3_6.tif
# 779 LFLACCB21018-1_4_6.tif
# 780 LFLACCB21018-1_5_6.tif
# 781 LFLACCB21018-1_6_6.tif
# 782 LFLACCB21018-2_1_13.tif
# 783 LFLACCB21018-2_2_13.tif
# 784 LFLACCB21018-2_3_13.tif
# 785 LFLACCB21018-2_4_13.tif
# 786 LFLACCB21018-2_5_13.tif
# 787 LFLACCB21018-2_6_13.tif
# 788 LFLACCB21018-2_7_13.tif
# 789 LFLACCB21018-2_8_13.tif
# 790 LFLACCB21018-2_9_13.tif
# 791 LFLACCB21018-2_10_13.tif
# 792 LFLACCB21018-2_11_13.tif
# 793 LFLACCB21018-2_12_13.tif
# 794 LFLACCB21018-4_1_5.tif
# 795 LFLACCB21018-4_2_5.tif
# 796 LFLACCB21018-4_3_5.tif
# 797 LFLACCB21018-4_4_5.tif
# 798 LFLACCB21018-4_5_5.tif
# 799 LFLACCB21018-5_1_8.tif
# 800 LFLACCB21018-5_2_8.tif
# 801 LFLACCB21018-5_3_8.tif
# 802 LFLACCB21018-5_4_8.tif
# 803 LFLACCB21018-5_5_8.tif
# 804 LFLACCB21018-5_6_8.tif
# 805 LFLACCB21018-5_7_8.tif
# 806 LFLACCB21018-5_8_8.tif
# 807 LFLACCB21018-7_1_15.tif
# 808 LFLACCB21018-7_2_15.tif
# 809 LFLACCB21018-7_3_15.tif
# 810 LFLACCB21018-7_4_15.tif
# 811 LFLACCB21018-7_5_15.tif
# 812 LFLACCB21018-7_6_15.tif
# 813 LFLACCB21018-7_7_15.tif
# 814 LFLACCB21018-7_8_15.tif
# 815 LFLACCB21018-7_9_15.tif
# 816 LFLACCB21018-7_10_15.tif
# 817 LFLACCB21018-7_11_15.tif
# 818 LFLACCB21018-7_12_15.tif
# 819 LFLACCB21018-7_13_15.tif
# 820 LFLACCB21018-7_14_15.tif
# 821 LFLACCB21018-7_15_15.tif
# 822 LFLACCB21018-8_1_13.tif
# 823 LFLACCB21018-8_2_13.tif
# 824 LFLACCB21018-8_3_13.tif
# 825 LFLACCB21018-8_4_13.tif
# 826 LFLACCB21018-8_5_13.tif
# 827 LFLACCB21018-8_6_13.tif
# 828 LFLACCB21018-8_7_13.tif
# 829 LFLACCB21018-8_8_13.tif
# 830 LFLACCB21018-8_9_13.tif
# 831 LFLACCB21018-8_10_13.tif
# 832 LFLACCB21018-8_11_13.tif
# 833 LFLACCB21018-8_12_13.tif
# 834 LFLACCB21018-8_13_13.tif
# 835 LFLACLD17116-1_1_4.tif
# 836 LFLACLD17116-1_2_4.tif
# 837 LFLACLD17116-1_3_4.tif
# 838 LFLACLD17116-1_4_4.tif
# 839 LFLORBS17124-1_1_1.tif
# 840 LFLORBS17124-3_1_6.tif
# 841 LGLANAC21060-2_2_12.tif
# 842 LGLANAC21060-2_3_12.tif
# 843 LGLANAC21060-2_4_12.tif
# 844 LGLANAC21060-2_5_12.tif
# 845 LGLANAC21060-2_6_12.tif
# 846 LGLANAC21060-2_7_12.tif
# 847 LGLANAC21060-2_8_12.tif
# 848 LGLANAC21060-2_9_12.tif
# 849 LGLANAC21060-2_10_12.tif
# 850 LGLANAC21060-2_11_12.tif
# 851 LGLANAC21060-2_12_12.tif
# 852 LGLANAC21060-3_1_3.tif
# 853 LGLANAC21060-3_2_3.tif
# 854 LGLANAC21060-3_3_3.tif
# 855 LGLANAC21060-4_6_16.tif
# 856 LGLANAC21060-4_7_16.tif
# 857 LGLANAC21060-4_8_16.tif
# 858 LGLANAC21060-4_9_16.tif
# 859 LGLANAC21060-4_10_16.tif
# 860 LGLANAC21060-4_11_16.tif
# 861 LGLANAC21060-4_12_16.tif
# 862 LGLANAC21060-4_13_16.tif
# 863 LGLANAC21060-4_14_16.tif
# 864 LGLANAC21060-4_15_16.tif
# 865 LGLANAC21060-4_16_16.tif
# 866 LGLANAC21165-1_1_10.tif
# 867 LGLANAC21165-1_2_10.tif
# 868 LGLANAC21165-1_3_10.tif
# 869 LGLANAC21165-1_4_10.tif
# 870 LGLANAC21165-1_5_10.tif
# 871 LGLANAC21165-1_6_10.tif
# 872 LGLANAC21165-1_7_10.tif
# 873 LGLANAC21165-1_8_10.tif
# 874 LGLANAC21165-1_9_10.tif
# 875 LGLANAC21165-1_10_10.tif
# 876 LGLANAC21165-3_1_7.tif
# 877 LGLANAC21165-3_2_7.tif
# 878 LGLANAC21165-3_3_7.tif
# 879 LGLANAC21165-3_4_7.tif
# 880 LGLANAC21165-3_5_7.tif
# 881 LGLANAC21165-3_6_7.tif
# 882 LGLANAC21165-3_7_7.tif
# 883 LGLANAC21165-4_1_10.tif
# 884 LGLANAC21165-4_2_10.tif
# 885 LGLANAC21165-4_3_10.tif
# 886 LGLANAC21165-4_4_10.tif
# 887 LGLANAC21165-4_5_10.tif
# 888 LGLANAC21165-4_6_10.tif
# 889 LGLANAC21165-4_7_10.tif
# 890 LGLANAC21165-4_8_10.tif
# 891 LGLANAC21165-4_9_10.tif
# 892 LGLANAC21165-4_10_10.tif
# 893 LGLANAC21165-5_1_26.tif
# 894 LGLANAC21165-5_2_26.tif
# 895 LGLANAC21165-5_3_26.tif
# 896 LGLANAC21165-5_4_26.tif
# 897 LGLANAC21165-5_5_26.tif
# 898 LGLANAC21165-5_6_26.tif
# 899 LGLANAC21165-5_7_26.tif
# 900 LGLANAC21165-5_8_26.tif
# 901 LGLANAC21165-5_9_26.tif
# 902 LGLANAC21165-5_10_26.tif
# 903 LGLANAC21165-5_11_26.tif
# 904 LGLANAC21165-5_12_26.tif
# 905 LGLANAC21165-5_13_26.tif
# 906 LGLANAC21165-5_14_26.tif
# 907 LGLANAC21165-5_15_26.tif
# 908 LGLANAC21165-5_16_26.tif
# 909 LGLANAC21165-5_17_26.tif
# 910 LGLANAC21165-5_18_26.tif
# 911 LGLANAC21165-5_19_26.tif
# 912 LGLANAC21165-5_20_26.tif
# 913 LGLANAC21165-5_21_26.tif
# 914 LGLANAC21165-5_22_26.tif
# 915 LGLANAC21165-5_23_26.tif
# 916 LGLANAC21165-5_24_26.tif
# 917 LGLANAC21165-5_25_26.tif
# 918 LGLANAC21165-5_26_26.tif
# 919 LGLANAC21165-6_1_20.tif
# 920 LGLANAC21165-6_2_20.tif
# 921 LGLANAC21165-6_3_20.tif
# 922 LGLANAC21165-6_4_20.tif
# 923 LGLANAC21165-6_5_20.tif
# 924 LGLANAC21165-6_6_20.tif
# 925 LGLANAC21165-6_7_20.tif
# 926 LGLANAC21165-6_8_20.tif
# 927 LGLANAC21165-6_9_20.tif
# 928 LGLANAC21165-6_10_20.tif
# 929 LGLANAC21165-6_11_20.tif
# 930 LGLANAC21165-6_12_20.tif
# 931 LGLANAC21165-6_13_20.tif
# 932 LGLANAC21165-6_14_20.tif
# 933 LGLANAC21165-6_15_20.tif
# 934 LGLANAC21165-6_16_20.tif
# 935 LGLANAC21165-6_17_20.tif
# 936 LGLANAC21165-6_18_20.tif
# 937 LGLANAC21165-6_19_20.tif
# 938 LGLANAC21165-6_20_20.tif
# 939 LGLANAC21165-7_1_10.tif
# 940 LGLANAC21165-7_2_10.tif
# 941 LGLANAC21165-7_3_10.tif
# 942 LGLANAC21165-7_4_10.tif
# 943 LGLANAC21165-7_5_10.tif
# 944 LGLANAC21165-7_6_10.tif
# 945 LGLANAC21165-7_7_10.tif
# 946 LGLANAC21165-7_8_10.tif
# 947 LGLANAC21165-7_9_10.tif
# 948 LGLANAC21165-7_10_10.tif
# 949 LGLANAC21166-2_1_21.tif
# 950 LGLANAC21166-2_2_21.tif
# 951 LGLANAC21166-2_3_21.tif
# 952 LGLANAC21166-2_4_21.tif
# 953 LGLANAC21166-2_5_21.tif
# 954 LGLANAC21166-2_6_21.tif
# 955 LGLANAC21166-2_7_21.tif
# 956 LGLANAC21166-2_8_21.tif
# 957 LGLANAC21166-2_9_21.tif
# 958 LGLANAC21166-2_10_21.tif
# 959 LGLANAC21166-2_11_21.tif
# 960 LGLANAC21166-2_12_21.tif
# 961 LGLANAC21166-2_13_21.tif
# 962 LGLANAC21166-2_14_21.tif
# 963 LGLANAC21166-2_15_21.tif
# 964 LGLANAC21166-2_16_21.tif
# 965 LGLANAC21166-2_17_21.tif
# 966 LGLANAC21166-2_18_21.tif
# 967 LGLANAC21166-2_19_21.tif
# 968 LGLANAC21166-2_20_21.tif
# 969 LGLANAC21166-2_21_21.tif
# 970 LGLANAC21166-3_1_22.tif
# 971 LGLANAC21166-3_2_22.tif
# 972 LGLANAC21166-3_3_22.tif
# 973 LGLANAC21166-3_4_22.tif
# 974 LGLANAC21166-3_5_22.tif
# 975 LGLANAC21166-3_6_22.tif
# 976 LGLANAC21166-3_7_22.tif
# 977 LGLANAC21166-3_8_22.tif
# 978 LGLANAC21166-3_9_22.tif
# 979 LGLANAC21166-3_10_22.tif
# 980 LGLANAC21166-3_11_22.tif
# 981 LGLANAC21166-3_12_22.tif
# 982 LGLANAC21166-3_13_22.tif
# 983 LGLANAC21166-3_14_22.tif
# 984 LGLANAC21166-3_15_22.tif
# 985 LGLANAC21166-3_16_22.tif
# 986 LGLANAC21166-3_17_22.tif
# 987 LGLANAC21166-3_18_22.tif
# 988 LGLANAC21166-3_19_22.tif
# 989 LGLANAC21166-3_20_22.tif
# 990 LGLANAC21166-3_21_22.tif
# 991 LGLANAC21166-3_22_22.tif
# 992 LGLANAC21167-1_1_49.tif
# 993 LGLANAC21167-1_2_49.tif
# 994 LGLANAC21167-1_3_49.tif
# 995 LGLANAC21167-1_4_49.tif
# 996 LGLANAC21167-1_5_49.tif
# 997 LGLANAC21167-1_6_49.tif
# 998 LGLANAC21167-1_7_49.tif
# 999 LGLANAC21167-1_8_49.tif
# 1000 LGLANAC21167-1_9_49.tif
# 1001 LGLANAC21167-1_10_49.tif
# 1002 LGLANAC21167-1_11_49.tif
# 1003 LGLANAC21167-1_12_49.tif
# 1004 LGLANAC21167-1_13_49.tif
# 1005 LGLANAC21167-1_14_49.tif
# 1006 LGLANAC21167-1_15_49.tif
# 1007 LGLANAC21167-1_16_49.tif
# 1008 LGLANAC21167-1_17_49.tif
# 1009 LGLANAC21167-1_18_49.tif
# 1010 LGLANAC21167-1_19_49.tif
# 1011 LGLANAC21167-1_20_49.tif
# 1012 LGLANAC21167-1_21_49.tif
# 1013 LGLANAC21167-1_22_49.tif
# 1014 LGLANAC21167-1_27_49.tif
# 1015 LGLANAC21167-1_29_49.tif
# 1016 LGLANAC21167-1_30_49.tif
# 1017 LGLANAC21167-1_31_49.tif
# 1018 LGLANAC21167-1_32_49.tif
# 1019 LGLANAC21167-1_33_49.tif
# 1020 LGLANAC21167-1_34_49.tif
# 1021 LGLANAC21167-1_35_49.tif
# 1022 LGLANAC21167-1_36_49.tif
# 1023 LGLANAC21167-1_37_49.tif
# 1024 LGLANAC21167-1_38_49.tif
# 1025 LGLANAC21167-1_39_49.tif
# 1026 LGLANAC21167-1_40_49.tif
# 1027 LGLANAC21167-1_41_49.tif
# 1028 LGLANAC21167-1_42_49.tif
# 1029 LGLANAC21167-1_45_49.tif
# 1030 LGLANAC21167-1_46_49.tif
# 1031 LGLANAC21167-1_47_49.tif
# 1032 LGLANAC21167-1_48_49.tif
# 1033 LGLANAC21167-1_49_49.tif
# 1034 LGLANAC21167-3_1_18.tif
# 1035 LGLANAC21167-3_2_18.tif
# 1036 LGLANAC21167-3_3_18.tif
# 1037 LGLANAC21167-3_4_18.tif
# 1038 LGLANAC21167-3_5_18.tif
# 1039 LGLANAC21167-3_6_18.tif
# 1040 LGLANAC21167-3_7_18.tif
# 1041 LGLANAC21167-3_8_18.tif
# 1042 LGLANAC21167-3_9_18.tif
# 1043 LGLANAC21167-3_10_18.tif
# 1044 LGLANAC21167-3_11_18.tif
# 1045 LGLANAC21167-3_12_18.tif
# 1046 LGLANAC21167-3_13_18.tif
# 1047 LGLANAC21167-3_14_18.tif
# 1048 LGLANAC21167-3_15_18.tif
# 1049 LGLANAC21167-3_16_18.tif
# 1050 LGLANAC21167-3_17_18.tif
# 1051 LGLANAC21167-3_18_18.tif
# 1052 LGLANAC21169-2_1_15.tif
# 1053 LGLANAC21169-2_2_15.tif
# 1054 LGLANAC21169-2_3_15.tif
# 1055 LGLANAC21169-2_4_15.tif
# 1056 LGLANAC21169-2_5_15.tif
# 1057 LGLANAC21169-2_6_15.tif
# 1058 LGLANAC21169-2_7_15.tif
# 1059 LGLANAC21169-2_8_15.tif
# 1060 LGLANAC21169-2_9_15.tif
# 1061 LGLANAC21169-2_10_15.tif
# 1062 LGLANAC21169-2_11_15.tif
# 1063 LGLANAC21169-2_12_15.tif
# 1064 LGLANAC21169-2_13_15.tif
# 1065 LGLANAC21169-2_14_15.tif
# 1066 LGLANAC21169-2_15_15.tif
# 1067 LGLANAC21169-3_1_8.tif
# 1068 LGLANAC21169-3_2_8.tif
# 1069 LGLANAC21169-3_3_8.tif
# 1070 LGLANAC21169-3_4_8.tif
# 1071 LGLANAC21169-3_5_8.tif
# 1072 LGLANAC21169-3_6_8.tif
# 1073 LGLANAC21169-3_7_8.tif
# 1074 LGLANAC21169-3_8_8.tif
# 1075 LGLANAC21169-4_1_13.tif
# 1076 LGLANAC21169-4_2_13.tif
# 1077 LGLANAC21169-4_3_13.tif
# 1078 LGLANAC21169-4_4_13.tif
# 1079 LGLANAC21169-4_5_13.tif
# 1080 LGLANAC21169-4_6_13.tif
# 1081 LGLANAC21169-4_7_13.tif
# 1082 LGLANAC21169-4_8_13.tif
# 1083 LGLANAC21169-4_9_13.tif
# 1084 LGLANAC21169-4_10_13.tif
# 1085 LGLANAC21169-4_11_13.tif
# 1086 LGLANAC21169-4_12_13.tif
# 1087 LGLANAC21169-4_13_13.tif
# 1088 LGLANAC21169-5_1_18.tif
# 1089 LGLANAC21169-5_2_18.tif
# 1090 LGLANAC21169-5_3_18.tif
# 1091 LGLANAC21169-5_4_18.tif
# 1092 LGLANAC21169-5_5_18.tif
# 1093 LGLANAC21169-5_6_18.tif
# 1094 LGLANAC21169-5_7_18.tif
# 1095 LGLANAC21169-5_8_18.tif
# 1096 LGLANAC21169-5_9_18.tif
# 1097 LGLANAC21169-5_10_18.tif
# 1098 LGLANAC21169-5_11_18.tif
# 1099 LGLANAC21169-5_12_18.tif
# 1100 LGLANAC21169-5_13_18.tif
# 1101 LGLANAC21169-5_14_18.tif
# 1102 LGLANAC21169-5_15_18.tif
# 1103 LGLANAC21169-5_16_18.tif
# 1104 LGLANAC21169-5_17_18.tif
# 1105 LGLANAC21169-5_18_18.tif
# 1106 LGLANAC21169-6_1_10.tif
# 1107 LGLANAC21169-6_2_10.tif
# 1108 LGLANAC21169-6_3_10.tif
# 1109 LGLANAC21169-6_4_10.tif
# 1110 LGLANAC21169-6_5_10.tif
# 1111 LGLANAC21169-6_6_10.tif
# 1112 LGLANAC21169-6_7_10.tif
# 1113 LGLANAC21169-6_8_10.tif
# 1114 LGLANAC21169-6_9_10.tif
# 1115 LGLANAC21169-6_10_10.tif
# 1116 LGLANAC21169-8_1_9.tif
# 1117 LGLANAC21169-8_2_9.tif
# 1118 LGLANAC21169-8_3_9.tif
# 1119 LGLANAC21169-8_4_9.tif
# 1120 LGLANAC21169-8_5_9.tif
# 1121 LGLANAC21169-8_6_9.tif
# 1122 LGLANAC21169-8_7_9.tif
# 1123 LGLANAC21169-8_8_9.tif
# 1124 LGLANAC21169-8_9_9.tif
# 1125 LGLANAC21169-10_1_12.tif
# 1126 LGLANAC21169-10_2_12.tif
# 1127 LGLANAC21169-10_3_12.tif
# 1128 LGLANAC21169-10_4_12.tif
# 1129 LGLANAC21169-10_5_12.tif
# 1130 LGLANAC21169-10_6_12.tif
# 1131 LGLANAC21169-10_7_12.tif
# 1132 LGLANAC21169-10_8_12.tif
# 1133 LGLANAC21169-10_9_12.tif
# 1134 LGLANAC21169-10_10_12.tif
# 1135 LGLANAC21169-10_11_12.tif
# 1136 LGLANAC21169-10_12_12.tif
# 1137 LGLANAC21169-12_1_11.tif
# 1138 LGLANAC21169-12_2_11.tif
# 1139 LGLANAC21169-12_3_11.tif
# 1140 LGLANAC21169-12_4_11.tif
# 1141 LGLANAC21169-12_5_11.tif
# 1142 LGLANAC21169-12_6_11.tif
# 1143 LGLANAC21169-12_7_11.tif
# 1144 LGLANAC21169-12_8_11.tif
# 1145 LGLANAC21169-12_9_11.tif
# 1146 LGLANAC21169-12_10_11.tif
# 1147 LGLANAC21169-12_11_11.tif
# 1148 LGLANAC21171-1_1_7.tif
# 1149 LGLANAC21171-1_2_7.tif
# 1150 LGLANAC21171-1_3_7.tif
# 1151 LGLANAC21171-1_4_7.tif
# 1152 LGLANAC21171-1_5_7.tif
# 1153 LGLANAC21171-1_6_7.tif
# 1154 LGLANAC21171-1_7_7.tif
# 1155 LGLANAC21171-2_1_11.tif
# 1156 LGLANAC21171-2_2_11.tif
# 1157 LGLANAC21171-2_3_11.tif
# 1158 LGLANAC21171-2_4_11.tif
# 1159 LGLANAC21171-2_5_11.tif
# 1160 LGLANAC21171-2_6_11.tif
# 1161 LGLANAC21171-2_7_11.tif
# 1162 LGLANAC21171-2_8_11.tif
# 1163 LGLANAC21171-2_9_11.tif
# 1164 LGLANAC21171-2_10_11.tif
# 1165 LGLANAC21171-2_11_11.tif
# 1166 LGLANAC21171-3_1_12.tif
# 1167 LGLANAC21171-3_2_12.tif
# 1168 LGLANAC21171-3_3_12.tif
# 1169 LGLANAC21171-3_4_12.tif
# 1170 LGLANAC21171-3_5_12.tif
# 1171 LGLANAC21171-3_6_12.tif
# 1172 LGLANAC21171-3_7_12.tif
# 1173 LGLANAC21171-3_8_12.tif
# 1174 LGLANAC21171-3_9_12.tif
# 1175 LGLANAC21171-3_10_12.tif
# 1176 LGLANAC21171-3_11_12.tif
# 1177 LGLANAC21171-6_1_11.tif
# 1178 LGLANAC21171-6_2_11.tif
# 1179 LGLANAC21171-6_3_11.tif
# 1180 LGLANAC21171-6_4_11.tif
# 1181 LGLANAC21171-6_5_11.tif
# 1182 LGLANAC21171-6_6_11.tif
# 1183 LGLANAC21171-6_7_11.tif
# 1184 LGLANAC21171-6_8_11.tif
# 1185 LGLANAC21171-6_9_11.tif
# 1186 LGLANAC21171-6_10_11.tif
# 1187 LGLANAC21171-6_11_11.tif
# 1188 LGLANBS17147-1_1_4.tif
# 1189 LGLANBS17147-1_2_4.tif
# 1190 LGLANBS17147-1_3_4.tif
# 1191 LGLANBS17147-1_4_4.tif
# 1192 LGLANBS17148-1_1_12.tif
# 1193 LGLANBS17148-1_2_12.tif
# 1194 LGLANBS17148-1_3_12.tif
# 1195 LGLANBS17148-1_4_12.tif
# 1196 LGLANBS17148-1_5_12.tif
# 1197 LGLANBS17148-1_6_12.tif
# 1198 LGLANBS17148-1_7_12.tif
# 1199 LGLANBS17148-1_8_12.tif
# 1200 LGLANBS17148-1_9_12.tif
# 1201 LGLANBS17148-1_11_12.tif
# 1202 LGLANBS17148-1_12_12.tif
# 1203 LGLANPA21029-2_1_23.tif
# 1204 LGLANPA21029-2_2_23.tif
# 1205 LGLANPA21029-2_3_23.tif
# 1206 LGLANPA21029-2_4_23.tif
# 1207 LGLANPA21029-2_5_23.tif
# 1208 LGLANPA21029-2_6_23.tif
# 1209 LGLANPA21029-2_7_23.tif
# 1210 LGLANPA21029-2_8_23.tif
# 1211 LGLANPA21029-2_9_23.tif
# 1212 LGLANPA21029-2_10_23.tif
# 1213 LGLANPA21029-2_11_23.tif
# 1214 LGLANPA21029-2_12_23.tif
# 1215 LGLANPA21029-2_13_23.tif
# 1216 LGLANPA21029-2_14_23.tif
# 1217 LGLANPA21029-2_15_23.tif
# 1218 LGLANPA21029-2_16_23.tif
# 1219 LGLANPA21029-2_17_23.tif
# 1220 LGLANPA21029-2_18_23.tif
# 1221 LGLANPA21029-2_19_23.tif
# 1222 LGLANPA21029-2_20_23.tif
# 1223 LGLANPA21029-2_21_23.tif
# 1224 LGLANPA21029-2_22_23.tif
# 1225 LGLANPA21029-2_23_23.tif
# 1226 LGLANPA21029-3_1_15.tif
# 1227 LGLANPA21029-3_2_15.tif
# 1228 LGLANPA21029-3_3_15.tif
# 1229 LGLANPA21029-3_4_15.tif
# 1230 LGLANPA21029-3_5_15.tif
# 1231 LGLANPA21029-3_6_15.tif
# 1232 LGLANPA21029-3_7_15.tif
# 1233 LGLANPA21029-3_8_15.tif
# 1234 LGLANPA21029-3_9_15.tif
# 1235 LGLANPA21029-3_10_15.tif
# 1236 LGLANPA21029-3_11_15.tif
# 1237 LGLANPA21029-3_12_15.tif
# 1238 LGLANPA21029-3_13_15.tif
# 1239 LGLANPA21029-3_14_15.tif
# 1240 LGLANPA21029-3_15_15.tif
# 1241 LGLANPA21029-4_1_16.tif
# 1242 LGLANPA21029-4_2_16.tif
# 1243 LGLANPA21029-4_3_16.tif
# 1244 LGLANPA21029-4_4_16.tif
# 1245 LGLANPA21029-4_5_16.tif
# 1246 LGLANPA21029-4_6_16.tif
# 1247 LGLANPA21029-4_7_16.tif
# 1248 LGLANPA21029-4_8_16.tif
# 1249 LGLANPA21029-4_9_16.tif
# 1250 LGLANPA21029-4_10_16.tif
# 1251 LGLANPA21029-4_11_16.tif
# 1252 LGLANPA21029-4_12_16.tif
# 1253 LGLANPA21029-4_13_16.tif
# 1254 LGLANPA21029-4_14_16.tif
# 1255 LGLANPA21029-4_15_16.tif
# 1256 LGLANPA21029-4_16_16.tif
# 1257 LINFLAC17091-2_1_19.tif
# 1258 LINFLAC17091-2_2_19.tif
# 1259 LINFLAC17091-2_3_19.tif
# 1260 LINFLAC17091-2_4_19.tif
# 1261 LINFLAC17091-2_5_19.tif
# 1262 LINFLAC17091-2_6_19.tif
# 1263 LINFLAC17091-2_7_19.tif
# 1264 LINFLAC17091-2_8_19.tif
# 1265 LINFLAC17091-2_9_19.tif
# 1266 LINFLAC17091-2_10_19.tif
# 1267 LINFLAC17091-2_11_19.tif
# 1268 LINFLAC17091-2_13_19.tif
# 1269 LINFLAC17091-2_14_19.tif
# 1270 LINFLAC17091-2_15_19.tif
# 1271 LINFLAC17091-2_16_19.tif
# 1272 LINFLAC17091-2_17_19.tif
# 1273 LINFLAC17091-2_18_19.tif
# 1274 LINFLAC17091-2_19_19.tif
# 1275 LINFLBS17089-2_1_3.tif
# 1276 LINFLBS17089-2_2_3.tif
# 1277 LINFLBS17089-2_3_3.tif
# 1278 LINFLSH21042-2_1_12.tif
# 1279 LINFLSH21042-2_2_12.tif
# 1280 LINFLSH21042-2_3_12.tif
# 1281 LINFLSH21042-2_4_12.tif
# 1282 LINFLSH21042-2_5_12.tif
# 1283 LINFLSH21042-2_6_12.tif
# 1284 LINFLSH21042-2_7_12.tif
# 1285 LINFLSH21042-2_8_12.tif
# 1286 LINFLSH21042-2_9_12.tif
# 1287 LINFLSH21042-2_10_12.tif
# 1288 LINFLSH21042-2_11_12.tif
# 1289 LINFLSH21042-2_12_12.tif
# 1290 LKALMSH21040-2_1_2.tif
# 1291 LKALMSH21040-2_2_2.tif
# 1292 LKALMSH21040-3_1_28.tif
# 1293 LKALMSH21040-3_2_28.tif
# 1294 LKALMSH21040-3_3_28.tif
# 1295 LKALMSH21040-3_4_28.tif
# 1296 LKALMSH21040-3_5_28.tif
# 1297 LKALMSH21040-3_6_28.tif
# 1298 LKALMSH21040-3_7_28.tif
# 1299 LKALMSH21040-3_8_28.tif
# 1300 LKALMSH21040-3_9_28.tif
# 1301 LKALMSH21040-3_10_28.tif
# 1302 LKALMSH21040-3_11_28.tif
# 1303 LKALMSH21040-3_12_28.tif
# 1304 LKALMSH21040-3_13_28.tif
# 1305 LKALMSH21040-3_14_28.tif
# 1306 LKALMSH21040-3_15_28.tif
# 1307 LKALMSH21040-3_16_28.tif
# 1308 LKALMSH21040-3_17_28.tif
# 1309 LKALMSH21040-3_18_28.tif
# 1310 LKALMSH21040-3_19_28.tif
# 1311 LKALMSH21040-3_20_28.tif
# 1312 LKALMSH21040-3_21_28.tif
# 1313 LKALMSH21040-3_22_28.tif
# 1314 LKALMSH21040-3_23_28.tif
# 1315 LKALMSH21040-3_24_28.tif
# 1316 LKALMSH21040-3_25_28.tif
# 1317 LKALMSH21040-3_26_28.tif
# 1318 LKALMSH21040-3_27_28.tif
# 1319 LKALMSH21040-3_28_28.tif
# 1320 LKALMSH21040-4_1_7.tif
# 1321 LKALMSH21040-4_2_7.tif
# 1322 LKALMSH21040-4_3_7.tif
# 1323 LKALMSH21040-4_4_7.tif
# 1324 LKALMSH21040-4_5_7.tif
# 1325 LKALMSH21040-4_6_7.tif
# 1326 LKALMSH21040-4_7_7.tif
# 1327 LKALMSH21040-5_1_52.tif
# 1328 LKALMSH21040-5_2_52.tif
# 1329 LKALMSH21040-5_3_52.tif
# 1330 LKALMSH21040-5_4_52.tif
# 1331 LKALMSH21040-5_5_52.tif
# 1332 LKALMSH21040-5_6_52.tif
# 1333 LKALMSH21040-5_7_52.tif
# 1334 LKALMSH21040-5_8_52.tif
# 1335 LKALMSH21040-5_9_52.tif
# 1336 LKALMSH21040-5_10_52.tif
# 1337 LKALMSH21040-5_11_52.tif
# 1338 LKALMSH21040-5_12_52.tif
# 1339 LKALMSH21040-5_13_52.tif
# 1340 LKALMSH21040-5_14_52.tif
# 1341 LKALMSH21040-5_15_52.tif
# 1342 LKALMSH21040-5_16_52.tif
# 1343 LKALMSH21040-5_17_52.tif
# 1344 LKALMSH21040-5_18_52.tif
# 1345 LKALMSH21040-5_20_52.tif
# 1346 LKALMSH21040-5_21_52.tif
# 1347 LKALMSH21040-5_22_52.tif
# 1348 LKALMSH21040-5_23_52.tif
# 1349 LKALMSH21040-5_24_52.tif
# 1350 LKALMSH21040-5_25_52.tif
# 1351 LKALMSH21040-5_26_52.tif
# 1352 LKALMSH21040-5_27_52.tif
# 1353 LKALMSH21040-5_28_52.tif
# 1354 LKALMSH21040-5_29_52.tif
# 1355 LKALMSH21040-5_30_52.tif
# 1356 LKALMSH21040-5_31_52.tif
# 1357 LKALMSH21040-5_32_52.tif
# 1358 LKALMSH21040-5_33_52.tif
# 1359 LKALMSH21040-5_34_52.tif
# 1360 LKALMSH21040-5_35_52.tif
# 1361 LKALMSH21040-5_36_52.tif
# 1362 LKALMSH21040-5_37_52.tif
# 1363 LKALMSH21040-5_38_52.tif
# 1364 LKALMSH21040-5_39_52.tif
# 1365 LKALMSH21040-5_40_52.tif
# 1366 LKALMSH21040-5_41_52.tif
# 1367 LKALMSH21040-5_42_52.tif
# 1368 LKALMSH21040-5_43_52.tif
# 1369 LKALMSH21040-5_44_52.tif
# 1370 LKALMSH21040-5_45_52.tif
# 1371 LKALMSH21040-5_46_52.tif
# 1372 LKALMSH21040-5_47_52.tif
# 1373 LKALMSH21040-5_48_52.tif
# 1374 LKALMSH21040-5_49_52.tif
# 1375 LKALMSH21040-5_50_52.tif
# 1376 LKALMSH21040-5_51_52.tif
# 1377 LKALMSH21040-5_52_52.tif
# 1378 LNUTTAC17136-1_1_3.tif
# 1379 LNUTTAC17136-1_2_3.tif
# 1380 LNUTTAC17136-1_3_3.tif
# 1381 LNUTTAC17136-2_1_2.tif
# 1382 LNUTTAC17136-2_2_2.tif
# 1383 LNUTTAC17136-3_1_1.tif
# 1384 LNUTTAC21048-1_1_11.tif
# 1385 LNUTTAC21048-1_2_11.tif
# 1386 LNUTTAC21048-1_3_11.tif
# 1387 LNUTTAC21048-1_4_11.tif
# 1388 LNUTTAC21048-1_5_11.tif
# 1389 LNUTTAC21048-1_6_11.tif
# 1390 LNUTTAC21048-1_7_11.tif
# 1391 LNUTTAC21048-1_8_11.tif
# 1392 LNUTTAC21048-1_9_11.tif
# 1393 LNUTTAC21048-1_10_11.tif
# 1394 LNUTTAC21048-1_11_11.tif
# 1395 LNUTTAC21048-2_1_6.tif
# 1396 LNUTTAC21048-2_2_6.tif
# 1397 LNUTTAC21048-2_3_6.tif
# 1398 LNUTTAC21048-2_4_6.tif
# 1399 LNUTTAC21048-2_5_6.tif
# 1400 LNUTTAC21048-2_6_6.tif
# 1401 LNUTTAC21048-4_1_6.tif
# 1402 LNUTTAC21048-4_2_6.tif
# 1403 LNUTTAC21048-4_3_6.tif
# 1404 LNUTTAC21048-4_4_6.tif
# 1405 LNUTTAC21048-4_5_6.tif
# 1406 LNUTTAC21048-4_6_6.tif
# 1407 LNUTTAC21048-5_1_5.tif
# 1408 LNUTTAC21048-5_2_5.tif
# 1409 LNUTTAC21048-5_3_5.tif
# 1410 LNUTTAC21048-5_4_5.tif
# 1411 LNUTTAC21048-5_5_5.tif
# 1412 LNUTTAC21048-6_1_8.tif
# 1413 LNUTTAC21048-6_2_8.tif
# 1414 LNUTTAC21048-6_3_8.tif
# 1415 LNUTTAC21048-6_4_8.tif
# 1416 LNUTTAC21048-6_5_8.tif
# 1417 LNUTTAC21048-6_6_8.tif
# 1418 LNUTTAC21048-6_7_8.tif
# 1419 LNUTTAC21048-6_8_8.tif
# 1420 LNUTTAC21048-7_1_5.tif
# 1421 LNUTTAC21048-7_2_5.tif
# 1422 LNUTTAC21048-7_3_5.tif
# 1423 LNUTTAC21048-7_4_5.tif
# 1424 LNUTTAC21048-7_5_5.tif
# 1425 LNUTTGG21062-1_1_1.tif
# 1426 LNUTTSH21045-1_1_11.tif
# 1427 LNUTTSH21045-1_2_11.tif
# 1428 LNUTTSH21045-1_3_11.tif
# 1429 LNUTTSH21045-1_4_11.tif
# 1430 LNUTTSH21045-1_5_11.tif
# 1431 LNUTTSH21045-1_6_11.tif
# 1432 LNUTTSH21045-1_7_11.tif
# 1433 LNUTTSH21045-1_8_11.tif
# 1434 LNUTTSH21045-1_9_11.tif
# 1435 LNUTTSH21045-1_11_11.tif
# 1436 LNUTTSH21045-2_1_6.tif
# 1437 LNUTTSH21045-2_2_6.tif
# 1438 LNUTTSH21045-2_3_6.tif
# 1439 LNUTTSH21045-2_4_6.tif
# 1440 LNUTTSH21045-2_5_6.tif
# 1441 LNUTTSH21045-2_6_6.tif
# 1442 LNUTTSH21045-3_1_8.tif
# 1443 LNUTTSH21045-3_2_8.tif
# 1444 LNUTTSH21045-3_3_8.tif
# 1445 LNUTTSH21045-3_4_8.tif
# 1446 LNUTTSH21045-3_5_8.tif
# 1447 LNUTTSH21045-3_6_8.tif
# 1448 LNUTTSH21045-3_7_8.tif
# 1449 LNUTTSH21045-3_8_8.tif
# 1450 LNUTTSH21045-4_1_8.tif
# 1451 LNUTTSH21045-4_2_8.tif
# 1452 LNUTTSH21045-4_3_8.tif
# 1453 LNUTTSH21045-4_4_8.tif
# 1454 LNUTTSH21045-4_5_8.tif
# 1455 LNUTTSH21045-4_6_8.tif
# 1456 LNUTTSH21045-4_7_8.tif
# 1457 LNUTTSH21045-4_8_8.tif
# 1458 LNUTTSH21045-5_1_5.tif
# 1459 LNUTTSH21045-5_2_5.tif
# 1460 LNUTTSH21045-5_3_5.tif
# 1461 LNUTTSH21045-5_4_5.tif
# 1462 LNUTTSH21045-6_2_10.tif
# 1463 LNUTTSH21045-6_5_10.tif
# 1464 LNUTTSH21045-6_6_10.tif
# 1465 LNUTTSH21045-6_7_10.tif
# 1466 LNUTTSH21045-6_8_10.tif
# 1467 LNUTTSH21045-6_9_10.tif
# 1468 LNUTTSH21045-6_10_10.tif
# 1469 LNUTTSH21045-7_1_10.tif
# 1470 LNUTTSH21045-7_2_10.tif
# 1471 LNUTTSH21045-7_3_10.tif
# 1472 LNUTTSH21045-7_4_10.tif
# 1473 LNUTTSH21045-7_5_10.tif
# 1474 LNUTTSH21045-7_6_10.tif
# 1475 LNUTTSH21045-7_7_10.tif
# 1476 LNUTTSH21045-7_8_10.tif
# 1477 LNUTTSH21045-7_9_10.tif
# 1478 LNUTTSH21045-7_10_10.tif
# 1479 LNUTTSH21045-9_1_5.tif
# 1480 LNUTTSH21045-9_2_5.tif
# 1481 LNUTTSH21045-9_3_5.tif
# 1482 LNUTTSH21045-9_4_5.tif
# 1483 LNUTTSH21045-9_5_5.tif
# 1484 LPALUAC21026-1_1_3.tif
# 1485 LPALUAC21026-1_2_3.tif
# 1486 LPALUAC21026-1_3_3.tif
# 1487 LPALUAC21026-3_1_6.tif
# 1488 LPALUAC21026-3_2_6.tif
# 1489 LPALUAC21026-3_3_6.tif
# 1490 LPALUAC21026-3_4_6.tif
# 1491 LPALUAC21026-3_5_6.tif
# 1492 LPALUAC21026-3_6_6.tif
# 1493 LPALUAC21026-4_1_2.tif
# 1494 LPALUAC21026-4_2_2.tif
# 1495 LPALUBS17067-1_1_7.tif
# 1496 LPALUBS17067-1_2_7.tif
# 1497 LPALUBS17067-1_3_7.tif
# 1498 LPALUBS17067-1_4_7.tif
# 1499 LPALUBS17067-1_5_7.tif
# 1500 LPALUBS17067-1_6_7.tif
# 1501 LPALUBS17067-1_7_7.tif
# 1502 LPALUBS17067-2_1_3.tif
# 1503 LPALUBS17067-2_2_3.tif
# 1504 LPALUBS17067-2_3_3.tif
# 1505 LPALUBS17067-3_1_4.tif
# 1506 LPALUBS17067-3_2_4.tif
# 1507 LPALUBS17067-3_3_4.tif
# 1508 LPALUBS17067-3_4_4.tif
# 1509 LPALUBS17067-4_1_4.tif
# 1510 LPALUBS17067-4_2_4.tif
# 1511 LPALUBS17067-4_3_4.tif
# 1512 LPALUBS17067-4_4_4.tif
# 1513 LPALUBS17067-5_1_5.tif
# 1514 LPALUBS17067-5_2_5.tif
# 1515 LPALUBS17067-5_3_5.tif
# 1516 LPALUBS17067-5_4_5.tif
# 1517 LPALUBS17067-5_5_5.tif
# 1518 LPALUBS17068-3_1_4.tif
# 1519 LPALUBS17068-3_2_4.tif
# 1520 LPALUBS17068-3_3_4.tif
# 1521 LPALUBS17068-3_4_4.tif
# 1522 LPALUBS17068-4_1_4.tif
# 1523 LPALUBS17068-4_2_4.tif
# 1524 LPALUBS17068-4_3_4.tif
# 1525 LPALUBS17068-4_4_4.tif
# 1526 LPALUBS17068-5_1_7.tif
# 1527 LPALUBS17068-5_2_7.tif
# 1528 LPALUBS17068-5_3_7.tif
# 1529 LPALUBS17068-5_4_7.tif
# 1530 LPALUBS17068-5_5_7.tif
# 1531 LPALUBS17068-5_6_7.tif
# 1532 LPALUBS17068-5_7_7.tif
# 1533 LPALUBS17068-6_1_2.tif
# 1534 LPALUBS17068-6_2_2.tif
# 1535 LPALUBS17068-7_1_3.tif
# 1536 LPALUBS17068-7_2_3.tif
# 1537 LPALUBS17068-7_3_3.tif
# 1538 LPALUBS17068-8_1_3.tif
# 1539 LPALUBS17068-8_2_3.tif
# 1540 LPALUBS17068-8_3_3.tif
# 1541 LPALUBS17068-9_1_5.tif
# 1542 LPALUBS17068-9_2_5.tif
# 1543 LPALUBS17069-1_1_3.tif
# 1544 LPALUBS17069-1_2_3.tif
# 1545 LPALUBS17069-1_3_3.tif
# 1546 LPALUBS17069-3_3_6.tif
# 1547 LPALUBS17069-4_1_7.tif
# 1548 LPALUBS17069-4_2_7.tif
# 1549 LPALUBS17069-4_3_7.tif
# 1550 LPALUBS17069-4_5_7.tif
# 1551 LPALUBS17069-4_6_7.tif
# 1552 LPALUBS17069-4_7_7.tif
# 1553 LPUBEAC17103-1_1_20.tif
# 1554 LPUBEAC17103-1_2_20.tif
# 1555 LPUBEAC17103-1_3_20.tif
# 1556 LPUBEAC17103-1_4_20.tif
# 1557 LPUBEAC17103-1_5_20.tif
# 1558 LPUBEAC17103-1_6_20.tif
# 1559 LPUBEAC17103-1_7_20.tif
# 1560 LPUBEAC17103-1_8_20.tif
# 1561 LPUBEAC17103-1_9_20.tif
# 1562 LPUBEAC17103-1_10_20.tif
# 1563 LPUBEAC17103-1_11_20.tif
# 1564 LPUBEAC17103-1_12_20.tif
# 1565 LPUBEAC17103-1_13_20.tif
# 1566 LPUBEAC17103-1_14_20.tif
# 1567 LPUBEAC17103-1_15_20.tif
# 1568 LPUBEAC17103-1_16_20.tif
# 1569 LPUBEAC17103-1_17_20.tif
# 1570 LPUBEAC17103-1_18_20.tif
# 1571 LPUBEAC17103-1_19_20.tif
# 1572 LPUBEAC17103-1_20_20.tif
# 1573 LPUBEAC17141-1_1_6.tif
# 1574 LPUBEAC17141-1_2_6.tif
# 1575 LPUBEAC17141-1_3_6.tif
# 1576 LPUBEAC17141-1_4_6.tif
# 1577 LPUBEAC17141-1_5_6.tif
# 1578 LPUBEAC17141-1_6_6.tif
# 1579 LPUBEAC17141-2_1_17.tif
# 1580 LPUBEAC17141-2_2_17.tif
# 1581 LPUBEAC17141-2_3_17.tif
# 1582 LPUBEAC17141-2_4_17.tif
# 1583 LPUBEAC17141-2_5_17.tif
# 1584 LPUBEAC17141-2_6_17.tif
# 1585 LPUBEAC17141-2_7_17.tif
# 1586 LPUBEAC17141-2_8_17.tif
# 1587 LPUBEAC17141-2_9_17.tif
# 1588 LPUBEAC17141-2_10_17.tif
# 1589 LPUBEAC17141-2_11_17.tif
# 1590 LPUBEAC17141-2_12_17.tif
# 1591 LPUBEAC17141-2_13_17.tif
# 1592 LPUBEAC17141-2_14_17.tif
# 1593 LPUBEAC17141-2_15_17.tif
# 1594 LPUBEAC17141-2_16_17.tif
# 1595 LPUBEAC17141-2_17_17.tif
# 1596 LPUBEAC17141-3_1_12.tif
# 1597 LPUBEAC17141-3_2_12.tif
# 1598 LPUBEAC17141-3_3_12.tif
# 1599 LPUBEAC17141-3_4_12.tif
# 1600 LPUBEAC17141-3_5_12.tif
# 1601 LPUBEAC17141-3_6_12.tif
# 1602 LPUBEAC17141-3_7_12.tif
# 1603 LPUBEAC17141-3_8_12.tif
# 1604 LPUBEAC17141-3_9_12.tif
# 1605 LPUBEAC17141-3_10_12.tif
# 1606 LPUBEAC17141-3_11_12.tif
# 1607 LPUBEAC17141-3_12_12.tif
# 1608 LPUBEAC21051-2_1_11.tif
# 1609 LPUBEAC21051-2_2_11.tif
# 1610 LPUBEAC21051-2_3_11.tif
# 1611 LPUBEAC21051-2_4_11.tif
# 1612 LPUBEAC21051-2_5_11.tif
# 1613 LPUBEAC21051-2_6_11.tif
# 1614 LPUBEAC21051-2_7_11.tif
# 1615 LPUBEAC21051-2_8_11.tif
# 1616 LPUBEAC21051-2_9_11.tif
# 1617 LPUBEAC21051-2_10_11.tif
# 1618 LPUBEAC21051-2_11_11.tif
# 1619 LPUBEAC21051-3_1_5.tif
# 1620 LPUBEAC21051-3_2_5.tif
# 1621 LPUBEAC21051-3_3_5.tif
# 1622 LPUBEAC21051-3_4_5.tif
# 1623 LPUBEAC21051-3_5_5.tif
# 1624 LPUBEAC21054-1_1_11.tif
# 1625 LPUBEAC21054-1_2_11.tif
# 1626 LPUBEAC21054-1_3_11.tif
# 1627 LPUBEAC21054-1_4_11.tif
# 1628 LPUBEAC21054-1_5_11.tif
# 1629 LPUBEAC21054-1_6_11.tif
# 1630 LPUBEAC21054-1_7_11.tif
# 1631 LPUBEAC21054-1_8_11.tif
# 1632 LPUBEAC21054-1_9_11.tif
# 1633 LPUBEAC21054-1_10_11.tif
# 1634 LPUBEAC21054-1_11_11.tif
# 1635 LPUBEAC21054-3_1_15.tif
# 1636 LPUBEAC21054-3_2_15.tif
# 1637 LPUBEAC21054-3_3_15.tif
# 1638 LPUBEAC21054-3_4_15.tif
# 1639 LPUBEAC21054-3_5_15.tif
# 1640 LPUBEAC21054-3_6_15.tif
# 1641 LPUBEAC21054-3_7_15.tif
# 1642 LPUBEAC21054-3_8_15.tif
# 1643 LPUBEAC21054-3_9_15.tif
# 1644 LPUBEAC21054-3_10_15.tif
# 1645 LPUBEAC21054-3_11_15.tif
# 1646 LPUBEAC21054-3_12_15.tif
# 1647 LPUBEAC21054-3_13_15.tif
# 1648 LPUBEAC21054-3_14_15.tif
# 1649 LPUBEAC21054-3_15_15.tif
# 1650 LPUBEAC21163-1_1_13.tif
# 1651 LPUBEAC21163-1_2_13.tif
# 1652 LPUBEAC21163-1_3_13.tif
# 1653 LPUBEAC21163-1_4_13.tif
# 1654 LPUBEAC21163-1_5_13.tif
# 1655 LPUBEAC21163-1_6_13.tif
# 1656 LPUBEAC21163-1_7_13.tif
# 1657 LPUBEAC21163-1_8_13.tif
# 1658 LPUBEAC21163-1_9_13.tif
# 1659 LPUBEAC21163-1_10_13.tif
# 1660 LPUBEAC21163-1_11_13.tif
# 1661 LPUBEAC21163-1_12_13.tif
# 1662 LPUBEAC21163-1_13_13.tif
# 1663 LPUBEAC21163-4_1_6.tif
# 1664 LPUBEAC21163-4_2_6.tif
# 1665 LPUBEAC21163-4_3_6.tif
# 1666 LPUBEAC21163-4_4_6.tif
# 1667 LPUBEAC21163-4_5_6.tif
# 1668 LPUBEAC21163-4_6_6.tif
# 1669 LPUBECB21052-1_1_24.tif
# 1670 LPUBECB21052-1_2_24.tif
# 1671 LPUBECB21052-1_3_24.tif
# 1672 LPUBECB21052-1_4_24.tif
# 1673 LPUBECB21052-1_5_24.tif
# 1674 LPUBECB21052-1_6_24.tif
# 1675 LPUBECB21052-1_7_24.tif
# 1676 LPUBECB21052-1_8_24.tif
# 1677 LPUBECB21052-1_9_24.tif
# 1678 LPUBECB21052-1_10_24.tif
# 1679 LPUBECB21052-1_11_24.tif
# 1680 LPUBECB21052-1_12_24.tif
# 1681 LPUBECB21052-1_13_24.tif
# 1682 LPUBECB21052-1_14_24.tif
# 1683 LPUBECB21052-1_15_24.tif
# 1684 LPUBECB21052-1_16_24.tif
# 1685 LPUBECB21052-1_17_24.tif
# 1686 LPUBECB21052-1_18_24.tif
# 1687 LPUBECB21052-1_19_24.tif
# 1688 LPUBECB21052-1_20_24.tif
# 1689 LPUBECB21052-1_21_24.tif
# 1690 LPUBECB21052-1_22_24.tif
# 1691 LPUBECB21052-1_23_24.tif
# 1692 LPUBECB21052-1_24_24.tif
# 1693 LPUBECB21061-1_1_24.tif
# 1694 LPUBECB21061-1_2_24.tif
# 1695 LPUBECB21061-1_3_24.tif
# 1696 LPUBECB21061-1_4_24.tif
# 1697 LPUBECB21061-1_5_24.tif
# 1698 LPUBECB21061-1_6_24.tif
# 1699 LPUBECB21061-1_7_24.tif
# 1700 LPUBECB21061-1_8_24.tif
# 1701 LPUBECB21061-1_9_24.tif
# 1702 LPUBECB21061-1_10_24.tif
# 1703 LPUBECB21061-1_11_24.tif
# 1704 LPUBECB21061-1_12_24.tif
# 1705 LPUBECB21061-1_13_24.tif
# 1706 LPUBECB21061-1_14_24.tif
# 1707 LPUBECB21061-1_15_24.tif
# 1708 LPUBECB21061-1_16_24.tif
# 1709 LPUBECB21061-1_17_24.tif
# 1710 LPUBECB21061-1_18_24.tif
# 1711 LPUBECB21061-1_19_24.tif
# 1712 LPUBECB21061-1_20_24.tif
# 1713 LPUBECB21061-1_21_24.tif
# 1714 LPUBECB21061-1_22_24.tif
# 1715 LPUBECB21061-1_23_24.tif
# 1716 LPUBECB21061-1_24_24.tif
# 1717 LPUBECB21061-3_1_13.tif
# 1718 LPUBECB21061-3_2_13.tif
# 1719 LPUBECB21061-3_3_13.tif
# 1720 LPUBECB21061-3_4_13.tif
# 1721 LPUBECB21061-3_5_13.tif
# 1722 LPUBECB21061-3_6_13.tif
# 1723 LPUBECB21061-3_7_13.tif
# 1724 LPUBECB21061-3_8_13.tif
# 1725 LPUBECB21061-3_9_13.tif
# 1726 LPUBECB21061-3_10_13.tif
# 1727 LPUBECB21061-3_11_13.tif
# 1728 LPUBECB21061-3_12_13.tif
# 1729 LPUBECB21061-3_13_13.tif
# 1730 LPUBECH17102-1_1_103.tif
# 1731 LPUBECH17102-1_2_103.tif
# 1732 LPUBECH17102-1_3_103.tif
# 1733 LPUBECH17102-1_4_103.tif
# 1734 LPUBECH17102-1_5_103.tif
# 1735 LPUBECH17102-1_6_103.tif
# 1736 LPUBECH17102-1_7_103.tif
# 1737 LPUBECH17102-1_8_103.tif
# 1738 LPUBECH17102-1_9_103.tif
# 1739 LPUBECH17102-1_10_103.tif
# 1740 LPUBECH17102-1_11_103.tif
# 1741 LPUBECH17102-1_12_103.tif
# 1742 LPUBECH17102-1_13_103.tif
# 1743 LPUBECH17102-1_14_103.tif
# 1744 LPUBECH17102-1_15_103.tif
# 1745 LPUBECH17102-1_16_103.tif
# 1746 LPUBECH17102-1_17_103.tif
# 1747 LPUBECH17102-1_18_103.tif
# 1748 LPUBECH17102-1_19_103.tif
# 1749 LPUBECH17102-1_20_103.tif
# 1750 LPUBECH17102-1_21_103.tif
# 1751 LPUBECH17102-1_22_103.tif
# 1752 LPUBECH17102-1_23_103.tif
# 1753 LPUBECH17102-1_24_103.tif
# 1754 LPUBECH17102-1_25_103.tif
# 1755 LPUBECH17102-1_26_103.tif
# 1756 LPUBECH17102-1_27_103.tif
# 1757 LPUBECH17102-1_28_103.tif
# 1758 LPUBECH17102-1_29_103.tif
# 1759 LPUBECH17102-1_30_103.tif
# 1760 LPUBECH17102-1_31_103.tif
# 1761 LPUBECH17102-1_32_103.tif
# 1762 LPUBECH17102-1_33_103.tif
# 1763 LPUBECH17102-1_34_103.tif
# 1764 LPUBECH17102-1_35_103.tif
# 1765 LPUBECH17102-1_36_103.tif
# 1766 LPUBECH17102-1_37_103.tif
# 1767 LPUBECH17102-1_38_103.tif
# 1768 LPUBECH17102-1_39_103.tif
# 1769 LPUBECH17102-1_40_103.tif
# 1770 LPUBECH17102-1_41_103.tif
# 1771 LPUBECH17102-1_42_103.tif
# 1772 LPUBECH17102-1_43_103.tif
# 1773 LPUBECH17102-1_44_103.tif
# 1774 LPUBECH17102-1_45_103.tif
# 1775 LPUBECH17102-1_46_103.tif
# 1776 LPUBECH17102-1_47_103.tif
# 1777 LPUBECH17102-1_48_103.tif
# 1778 LPUBECH17102-1_49_103.tif
# 1779 LPUBECH17102-1_50_103.tif
# 1780 LPUBECH17102-1_51_103.tif
# 1781 LPUBECH17102-1_52_103.tif
# 1782 LPUBECH17102-1_53_103.tif
# 1783 LPUBECH17102-1_54_103.tif
# 1784 LPUBECH17102-1_55_103.tif
# 1785 LPUBECH17102-1_56_103.tif
# 1786 LPUBECH17102-1_57_103.tif
# 1787 LPUBECH17102-1_58_103.tif
# 1788 LPUBECH17102-1_59_103.tif
# 1789 LPUBECH17102-1_60_103.tif
# 1790 LPUBECH17102-1_61_103.tif
# 1791 LPUBECH17102-1_62_103.tif
# 1792 LPUBECH17102-1_63_103.tif
# 1793 LPUBECH17102-1_64_103.tif
# 1794 LPUBECH17102-1_65_103.tif
# 1795 LPUBECH17102-1_66_103.tif
# 1796 LPUBECH17102-1_67_103.tif
# 1797 LPUBECH17102-1_68_103.tif
# 1798 LPUBECH17102-1_69_103.tif
# 1799 LPUBECH17102-1_70_103.tif
# 1800 LPUBECH17102-1_71_103.tif
# 1801 LPUBECH17102-1_72_103.tif
# 1802 LPUBECH17102-1_73_103.tif
# 1803 LPUBECH17102-1_74_103.tif
# 1804 LPUBECH17102-1_75_103.tif
# 1805 LPUBECH17102-1_76_103.tif
# 1806 LPUBECH17102-1_77_103.tif
# 1807 LPUBECH17102-1_78_103.tif
# 1808 LPUBECH17102-1_79_103.tif
# 1809 LPUBECH17102-1_80_103.tif
# 1810 LPUBECH17102-1_81_103.tif
# 1811 LPUBECH17102-1_82_103.tif
# 1812 LPUBECH17102-1_83_103.tif
# 1813 LPUBECH17102-1_84_103.tif
# 1814 LPUBECH17102-1_85_103.tif
# 1815 LPUBECH17102-1_86_103.tif
# 1816 LPUBECH17102-1_87_103.tif
# 1817 LPUBECH17102-1_88_103.tif
# 1818 LPUBECH17102-1_89_103.tif
# 1819 LPUBECH17102-1_90_103.tif
# 1820 LPUBECH17102-1_91_103.tif
# 1821 LPUBECH17102-1_92_103.tif
# 1822 LPUBECH17102-1_93_103.tif
# 1823 LPUBECH17102-1_94_103.tif
# 1824 LPUBECH17102-1_95_103.tif
# 1825 LPUBECH17102-1_96_103.tif
# 1826 LPUBECH17102-1_97_103.tif
# 1827 LPUBECH17102-1_98_103.tif
# 1828 LPUBECH17102-1_99_103.tif
# 1829 LPUBECH17102-1_100_103.tif
# 1830 LPUBECH17102-1_101_103.tif
# 1831 LPUBECH17102-1_102_103.tif
# 1832 LPUBECH17102-1_103_103.tif
# 1833 LPUBEGG21062-1_1_16.tif
# 1834 LPUBEGG21062-1_2_16.tif
# 1835 LPUBEGG21062-1_3_16.tif
# 1836 LPUBEGG21062-1_4_16.tif
# 1837 LPUBEGG21062-1_5_16.tif
# 1838 LPUBEGG21062-1_6_16.tif
# 1839 LPUBEGG21062-1_7_16.tif
# 1840 LPUBEGG21062-1_8_16.tif
# 1841 LPUBEGG21062-1_9_16.tif
# 1842 LPUBEGG21062-1_10_16.tif
# 1843 LPUBEGG21062-1_11_16.tif
# 1844 LPUBEGG21062-1_12_16.tif
# 1845 LPUBEGG21062-1_13_16.tif
# 1846 LPUBEGG21062-1_14_16.tif
# 1847 LPUBEGG21062-1_15_16.tif
# 1848 LPUBEGG21062-1_16_16.tif
# 1849 LPUBEMJ21175-2_1_13.tif
# 1850 LPUBEMJ21175-2_2_13.tif
# 1851 LPUBEMJ21175-2_3_13.tif
# 1852 LPUBEMJ21175-2_4_13.tif
# 1853 LPUBEMJ21175-2_5_13.tif
# 1854 LPUBEMJ21175-2_6_13.tif
# 1855 LPUBEMJ21175-2_7_13.tif
# 1856 LPUBEMJ21175-2_8_13.tif
# 1857 LPUBEMJ21175-2_9_13.tif
# 1858 LPUBEMJ21175-2_10_13.tif
# 1859 LPUBEMJ21175-2_11_13.tif
# 1860 LPUBEMJ21175-2_12_13.tif
# 1861 LPUBEMJ21175-2_13_13.tif
# 1862 LPUBEMJ21185-2_1_16.tif
# 1863 LPUBEMJ21185-2_2_16.tif
# 1864 LPUBEMJ21185-2_3_16.tif
# 1865 LPUBEMJ21185-2_4_16.tif
# 1866 LPUBEMJ21185-2_5_16.tif
# 1867 LPUBEMJ21185-2_6_16.tif
# 1868 LPUBEMJ21185-2_7_16.tif
# 1869 LPUBEMJ21185-2_8_16.tif
# 1870 LPUBEMJ21185-2_9_16.tif
# 1871 LPUBEMJ21185-2_10_16.tif
# 1872 LPUBEMJ21185-2_11_16.tif
# 1873 LPUBEMJ21185-2_12_16.tif
# 1874 LPUBEMJ21185-3_1_9.tif
# 1875 LPUBEMJ21185-3_2_9.tif
# 1876 LPUBEMJ21185-3_3_9.tif
# 1877 LPUBEMJ21185-3_4_9.tif
# 1878 LPUBEMJ21185-3_5_9.tif
# 1879 LPUBEMJ21185-3_6_9.tif
# 1880 LPUBEMJ21185-3_7_9.tif
# 1881 LPUBEMJ21185-3_8_9.tif
# 1882 LPUBEMJ21185-3_9_9.tif
# 1883 LROGEAC21176-1_1_2.tif
# 1884 LROGEAC21176-1_2_2.tif
# 1885 LROGEAC21176-2_1_8.tif
# 1886 LROGEAC21176-2_2_8.tif
# 1887 LROGEAC21176-2_3_8.tif
# 1888 LROGEAC21176-2_4_8.tif
# 1889 LROGEAC21176-2_6_8.tif
# 1890 LROGEAC21176-3_1_8.tif
# 1891 LROGEAC21176-3_4_8.tif
# 1892 LROGEAC21176-3_5_8.tif
# 1893 LROGEAC21176-3_6_8.tif
# 1894 LROGEAC21176-3_7_8.tif
# 1895 LROGEAC21176-3_8_8.tif
# 1896 LROGEAC21176-4_1_5.tif
# 1897 LROGEAC21176-4_3_5.tif
# 1898 LROGEAC21176-4_5_5.tif
# 1899 LSIPHAC17142-1_1_8.tif
# 1900 LSIPHAC17142-1_2_8.tif
# 1901 LSIPHAC17142-1_3_8.tif
# 1902 LSIPHAC17142-1_4_8.tif
# 1903 LSIPHAC17142-1_5_8.tif
# 1904 LSIPHAC17142-1_6_8.tif
# 1905 LSIPHAC17142-1_7_8.tif
# 1906 LSIPHAC17142-1_8_8.tif
# 1907 LSIPHAC21046-2_1_22.tif
# 1908 LSIPHAC21046-2_2_22.tif
# 1909 LSIPHAC21046-2_3_22.tif
# 1910 LSIPHAC21046-2_4_22.tif
# 1911 LSIPHAC21046-2_5_22.tif
# 1912 LSIPHAC21046-2_6_22.tif
# 1913 LSIPHAC21046-2_7_22.tif
# 1914 LSIPHAC21046-2_8_22.tif
# 1915 LSIPHAC21046-2_9_22.tif
# 1916 LSIPHAC21046-2_10_22.tif
# 1917 LSIPHAC21046-2_11_22.tif
# 1918 LSIPHAC21046-2_12_22.tif
# 1919 LSIPHAC21046-2_13_22.tif
# 1920 LSIPHAC21046-2_14_22.tif
# 1921 LSIPHAC21046-2_15_22.tif
# 1922 LSIPHAC21046-2_16_22.tif
# 1923 LSIPHAC21046-2_17_22.tif
# 1924 LSIPHAC21046-2_18_22.tif
# 1925 LSIPHPA22126-1_1_112.tif
# 1926 LSIPHPA22126-1_2_112.tif
# 1927 LSIPHPA22126-1_3_112.tif
# 1928 LSIPHPA22126-1_4_112.tif
# 1929 LSIPHPA22126-1_5_112.tif
# 1930 LSIPHPA22126-1_6_112.tif
# 1931 LSIPHPA22126-1_7_112.tif
# 1932 LSIPHPA22126-1_8_112.tif
# 1933 LSIPHPA22126-1_9_112.tif
# 1934 LSIPHPA22126-1_10_112.tif
# 1935 LSIPHPA22126-1_11_112.tif
# 1936 LSIPHPA22126-1_12_112.tif
# 1937 LSIPHPA22126-1_13_112.tif
# 1938 LSIPHPA22126-1_14_112.tif
# 1939 LSIPHPA22126-1_15_112.tif
# 1940 LSIPHPA22126-1_16_112.tif
# 1941 LSIPHPA22126-1_17_112.tif
# 1942 LSIPHPA22126-1_18_112.tif
# 1943 LSIPHPA22126-1_19_112.tif
# 1944 LSIPHPA22126-1_20_112.tif
# 1945 LSIPHPA22126-1_21_112.tif
# 1946 LSIPHPA22126-1_22_112.tif
# 1947 LSIPHPA22126-1_23_112.tif
# 1948 LSIPHPA22126-1_24_112.tif
# 1949 LSIPHPA22126-1_25_112.tif
# 1950 LSIPHPA22126-1_26_112.tif
# 1951 LSIPHPA22126-1_27_112.tif
# 1952 LSIPHPA22126-1_29_112.tif
# 1953 LSIPHPA22126-1_30_112.tif
# 1954 LSIPHPA22126-2_1_35.tif
# 1955 LSIPHPA22126-2_2_35.tif
# 1956 LSIPHPA22126-2_3_35.tif
# 1957 LSIPHPA22126-2_4_35.tif
# 1958 LSIPHPA22126-2_5_35.tif
# 1959 LSIPHPA22126-2_6_35.tif
# 1960 LSIPHPA22126-2_7_35.tif
# 1961 LSIPHPA22126-2_8_35.tif
# 1962 LSIPHPA22126-2_9_35.tif
# 1963 LSIPHPA22126-2_10_35.tif
# 1964 LSIPHPA22126-2_12_35.tif
# 1965 LSIPHPA22126-2_13_35.tif
# 1966 LSIPHPA22126-2_14_35.tif
# 1967 LSIPHPA22126-2_15_35.tif
# 1968 LSIPHPA22126-2_16_35.tif
# 1969 LSIPHPA22126-2_18_35.tif
# 1970 LSIPHPA22126-2_19_35.tif
# 1971 LSIPHPA22126-2_20_35.tif
# 1972 LSIPHPA22126-2_21_35.tif
# 1973 LSIPHPA22126-2_22_35.tif
# 1974 LSIPHPA22126-2_23_35.tif
# 1975 LSIPHPA22126-2_24_35.tif
# 1976 LSIPHPA22126-2_25_35.tif
# 1977 LSIPHPA22126-2_26_35.tif
# 1978 LSIPHPA22126-2_27_35.tif
# 1979 LSIPHPA22126-2_28_35.tif
# 1980 LSIPHPA22126-2_29_35.tif
# 1981 LSIPHPA22126-2_30_35.tif
# 1982 LSIPHPA22126-2_31_35.tif
# 1983 LSIPHPA22126-2_32_35.tif
# 1984 LSIPHPA22126-2_33_35.tif
# 1985 LSIPHPA22126-2_34_35.tif
# 1986 LSIPHPA22126-3_5_16.tif
# 1987 LSIPHPA22126-3_8_16.tif
# 1988 LSIPHPA22126-3_9_16.tif
# 1989 LSIPHPA22126-3_10_16.tif
# 1990 LSIPHPA22126-3_11_16.tif
# 1991 LSIPHPA22126-3_12_16.tif
# 1992 LSIPHPA22126-3_13_16.tif
# 1993 LSIPHPA22126-3_14_16.tif
# 1994 LSIPHPA22126-3_15_16.tif
# 1995 LSIPHPA22126-3_16_16.tif
# 1996 LSPICAC17073-1_1_11.tif
# 1997 LSPICAC17073-1_2_11.tif
# 1998 LSPICAC17073-1_3_11.tif
# 1999 LSPICAC17073-1_4_11.tif
# 2000 LSPICAC17073-1_5_11.tif
# 2001 LSPICAC17073-1_6_11.tif
# 2002 LSPICAC17073-1_7_11.tif
# 2003 LSPICAC17073-1_8_11.tif
# 2004 LSPICAC17073-1_9_11.tif
# 2005 LSPICAC17073-1_10_11.tif
# 2006 LSPICAC17073-1_11_11.tif
# 2007 LSPICAC17073-2_1_18.tif
# 2008 LSPICAC17073-2_2_18.tif
# 2009 LSPICAC17073-2_3_18.tif
# 2010 LSPICAC17073-2_4_18.tif
# 2011 LSPICAC17073-2_5_18.tif
# 2012 LSPICAC17073-2_6_18.tif
# 2013 LSPICAC17073-2_7_18.tif
# 2014 LSPICAC17073-2_8_18.tif
# 2015 LSPICAC17073-2_9_18.tif
# 2016 LSPICAC17073-2_10_18.tif
# 2017 LSPICAC17073-2_11_18.tif
# 2018 LSPICAC17073-2_12_18.tif
# 2019 LSPICAC17073-2_13_18.tif
# 2020 LSPICAC17073-2_14_18.tif
# 2021 LSPICAC17073-2_15_18.tif
# 2022 LSPICAC17073-2_16_18.tif
# 2023 LSPICAC17073-2_17_18.tif
# 2024 LSPICAC17073-2_18_18.tif
# 2025 LSPICAC17073-3_1_5.tif
# 2026 LSPICAC17073-3_2_5.tif
# 2027 LSPICAC17073-3_3_5.tif
# 2028 LSPICAC17073-3_4_5.tif
# 2029 LSPICAC17073-3_5_5.tif
# 2030 LSPICSH21034-1_1_10.tif
# 2031 LSPICSH21034-1_2_10.tif
# 2032 LSPICSH21034-1_3_10.tif
# 2033 LSPICSH21034-1_4_10.tif
# 2034 LSPICSH21034-1_5_10.tif
# 2035 LSPICSH21034-1_6_10.tif
# 2036 LSPICSH21034-1_7_10.tif
# 2037 LSPICSH21034-1_8_10.tif
# 2038 LSPICSH21034-2_1_7.tif
# 2039 LSPICSH21034-2_2_7.tif
# 2040 LSPICSH21034-2_3_7.tif
# 2041 LSPICSH21034-2_4_7.tif
# 2042 LSPICSH21034-2_5_7.tif
# 2043 LSPICSH21034-3_1_7.tif
# 2044 LSPICSH21034-3_2_7.tif
# 2045 LSPICSH21034-3_3_7.tif
# 2046 LSPICSH21034-3_4_7.tif
# 2047 LSPICSH21034-3_5_7.tif
# 2048 LSPICSH21034-4_1_12.tif
# 2049 LSPICSH21034-4_2_12.tif
# 2050 LSPICSH21034-4_3_12.tif
# 2051 LSPICSH21034-4_4_12.tif
# 2052 LSPICSH21034-4_5_12.tif
# 2053 LSPICSH21034-4_6_12.tif
# 2054 LSPICSH21034-4_7_12.tif
# 2055 LSPICSH21034-4_8_12.tif
# 2056 LSPICSH21034-4_9_12.tif
# 2057 LSPICSH21034-4_10_12.tif
# 2058 LSPICSH21034-6_1_23.tif
# 2059 LSPICSH21034-6_2_23.tif
# 2060 LSPICSH21034-6_3_23.tif
# 2061 LSPICSH21034-6_4_23.tif
# 2062 LSPICSH21034-6_5_23.tif
# 2063 LSPICSH21034-6_6_23.tif
# 2064 LSPICSH21034-6_7_23.tif
# 2065 LSPICSH21034-6_8_23.tif
# 2066 LSPICSH21034-6_9_23.tif
# 2067 LSPICSH21034-6_10_23.tif
# 2068 LSPICSH21034-6_11_23.tif
# 2069 LSPICSH21034-6_12_23.tif
# 2070 LSPICSH21034-6_13_23.tif
# 2071 LSPICSH21034-6_14_23.tif
# 2072 LSPICSH21034-6_15_23.tif
# 2073 LSPICSH21034-6_16_23.tif
# 2074 LSPICSH21034-6_17_23.tif
# 2075 LSPICSH21034-6_18_23.tif
# 2076 LSPICSH21034-6_19_23.tif
# 2077 LSPICSH21034-6_20_23.tif
# 2078 LSPICSH21034-6_21_23.tif
# 2079 LSPICSH21034-7_1_9.tif
# 2080 LSPICSH21034-7_2_9.tif
# 2081 LSPICSH21034-7_3_9.tif
# 2082 LSPICSH21034-7_4_9.tif
# 2083 LSPICSH21034-7_5_9.tif
# 2084 LSPICSH21034-7_6_9.tif
# 2085 LSPICSH21034-7_7_9.tif
# 2086 LSPICSH21034-1_9_10.tif
# 2087 LSPICSH21034-1_10_10.tif
# 2088 LSPICSH21034-2_6_7.tif
# 2089 LSPICSH21034-2_7_7.tif
# 2090 LSPICSH21034-3_6_7.tif
# 2091 LSPICSH21034-3_7_7.tif
# 2092 LSPICSH21034-4_11_12.tif
# 2093 LSPICSH21034-4_12_12.tif
# 2094 LSPICSH21034-6_22_23.tif
# 2095 LSPICSH21034-6_23_23.tif
# 2096 LSPICSH21034-7_8_9.tif
# 2097 LSPICSH21034-7_9_9.tif
# 2098 LSPICSH21036-1_1_3.tif
# 2099 LSPICSH21036-1_2_3.tif
# 2100 LSPICSH21036-1_3_3.tif
# 2101 LSPICSH21036-2_1_7.tif
# 2102 LSPICSH21036-2_2_7.tif
# 2103 LSPICSH21036-2_3_7.tif
# 2104 LSPICSH21036-2_4_7.tif
# 2105 LSPICSH21036-2_5_7.tif
# 2106 LSPICSH21036-2_6_7.tif
# 2107 LSPICSH21036-2_7_7.tif
# 2108 LSPICSH21036-4_1_6.tif
# 2109 LSPICSH21036-4_2_6.tif
# 2110 LSPICSH21036-4_3_6.tif
# 2111 LSPICSH21036-4_4_6.tif
# 2112 LSPICSH21036-4_5_6.tif
# 2113 LSPICSH21036-4_6_6.tif
# 2114 LSPICSH21036-5_1_9.tif
# 2115 LSPICSH21036-5_2_9.tif
# 2116 LSPICSH21036-5_3_9.tif
# 2117 LSPICSH21036-5_4_9.tif
# 2118 LSPICSH21036-5_5_9.tif
# 2119 LSPICSH21036-5_6_9.tif
# 2120 LSPICSH21036-5_7_9.tif
# 2121 LSPICSH21036-5_8_9.tif
# 2122 LSPICSH21036-5_9_9.tif

# %% [markdown]
# # Check by plotting random leaves

# %%
# Plot random leaves and check that it is working

plt.figure(figsize=(10,10)) # set figure size

rand_indices = np.random.randint(0,len(cm_arr),200) # generate random indices of leaves

plot_num = 1 # plot counter number

for i in rand_indices:
    
    plt.subplot(10,20,plot_num) # subplot number
    
    plt.plot(cm_arr[i,:,0], cm_arr[i,:,1], c="k", lw=1) # outline
    plt.fill(cm_arr[i,:,0], cm_arr[i,:,1], c="lightgray", lw=1) # fill
    
    plt.plot([min(cm_arr[i,:,0])-0.1,min(cm_arr[i,:,0])-0.1],
            [cm_arr[i,0,1], cm_arr[i,0,1]+1], c="k", lw=0.5) # cm scale
    
    #plt.scatter(cm_arr[i,:,0], cm_arr[i,:,1], c="k", s=0.1) # points
    plt.scatter(cm_arr[i,0,0], cm_arr[i,0,1], s=20) # base
    plt.scatter(cm_arr[i,res-1,0], cm_arr[i,res-1,1], s=20) # tip
    
    #plt.title(mdata["species"][i], fontsize=6)
    
    plt.gca().set_aspect("equal")
    plt.axis("off")
    
    plot_num += 1
    
plt.suptitle(str(res*2-1) + " pseudo-landmarks")
plt.tight_layout()

# %% [markdown]
# # Analyze leaf dimensions
#
# Using placed pseudo-landmarks representing leaves that are rotated upwards and scaled in centimeters from `cm_arr`, calculate the following:
#
# - `width`: difference in centimeters between minimum and maximum x values in an oriented leaf
# - `length`: difference in centimeters between minimum and maximum y values in an oriented leaf
# - `area`: area of the leaf in centimeters squared
# - `solidity`: the ratio of area to convex hull area
# - `asymmetry`: the Procrustes distance between the superimposed left and right sides of a leaf outline. Lower values are more symmetric. Higher values are more asymmetric.
#
# Data is stored in the `mdata` dataframe.

# %%
# lists to store variables
width_list = []
length_list = []
area_list = []
solidity_list = []
species_list = []
node_list = []
totalnode_list = []
#asymmetry_list = []

# for each leaf . . .
for lf in range(len(cm_arr)):
    
    # for calculating dimensions, we need non-scaled leaves in centimeters
    curr_lf = cm_arr[lf,:,:] # select current leaf

    # get species name
    species_list.append(mdata["file"][lf][:5])

    # get the node number
    first_index = mdata["file"][lf].rfind("_")
    second_index = mdata["file"][lf].rfind("_", 0, first_index)
    node_list.append( float(mdata["file"][lf][second_index+1:first_index]) )

    # get total node number
    totalnode_list.append( float(mdata["file"][lf][first_index+1:]) )
    
    ############################
    ### CALCULATE DIMENSIONS ###
    ############################
    
    width = np.max(curr_lf[:,0])-np.min(curr_lf[:,0]) # calculate width
    length = np.max(curr_lf[:,1])-np.min(curr_lf[:,1]) # calculate length
    area = poly_area(curr_lf[:,0],curr_lf[:,1]) # calcualte area
    
    ##########################
    ### CALCULATE SOLIDITY ###
    ##########################
    
    hull = ConvexHull(curr_lf) # calculate convex hull of current leaf
    vertices = hull.vertices # isolate vertex indices of convex hull
    convex_area = poly_area(curr_lf[vertices,0], curr_lf[vertices,1]) # calculate convex area
    solidity = area / convex_area # calculate solidity
    
    ##########################
    ### CALCULATE SYMMETRY ###
    ##########################
    
    #left_side = curr_lf[:(res-1)+1,] # isolate left side of leaf
    #right_side = curr_lf[(res-1):,] # isolate right side of leaf
    #right_side = right_side[::-1] # reverse the right side to align indices with left

    # calculate procrustes distance between left and right side of leaf
    #s1, s2, distance = procrustes(left_side, right_side) 
    
    # store data in lists
    width_list.append(width)
    length_list.append(length)
    area_list.append(area)
    solidity_list.append(solidity)
    
    #asymmetry_list.append(distance)
    
# add data to the mdata dataframe
mdata["width"] = width_list
mdata["length"] = length_list
mdata["area"] = area_list
mdata["solidity"] = solidity_list
mdata["species"] = species_list
mdata["node"] = node_list
mdata["count"] = totalnode_list
mdata["rel_node"] = mdata["node"]/mdata["count"]
mdata["sqrt_area"] = np.sqrt(mdata["area"])
mdata["solidity8"] = (mdata["solidity"])**8
#mdata["asymmetry"] = asymmetry_list

# %% [markdown]
# # Pair plots by species

# %%
sns.pairplot(mdata,
             x_vars=["width", "length", "sqrt_area","solidity8"],
             y_vars=["width", "length", "sqrt_area","solidity8"],
             hue="species",
             plot_kws={"s": 10, "alpha":0.5, "lw":0}
            )

# %% [markdown]
# # Procrustes analysis
#
# Perform a Procrustes analysis to translate, scale, and rotate leaf shapes
#
# - Select number of pseudo-landmarks and dimensions
# - Calculate the GPA mean leaf shape using the `gpa_mean` function
# - Align all leaves to the GPA mean
# - Store Procrustes super-imposed leaves in an array, `proc_arr`
# - Calculate a PCA for all possible axes and their variance (the number of leaves)
# - Calculate a PCA for just the axes needed for reconstruction of eigenleaves for morphospace (probably 2)

# %%
landmark_num = (res*2)-1 # select number of landmarks
dim_num = 2 # select number of coordinate value dimensions

##########################
### CALCULATE GPA MEAN ###
##########################

mean_shape = gpa_mean(cm_arr, landmark_num, dim_num)

################################
### ALIGN LEAVES TO GPA MEAN ###
################################

# array to store Procrustes aligned shapes
proc_arr = np.zeros(np.shape(cm_arr)) 

for i in range(len(cm_arr)):
    s1, s2, distance = procrustes(mean_shape, cm_arr[i,:,:]) # calculate procrustes adjusted shape to ref for current leaf
    proc_arr[i] = s2 # store procrustes adjusted shape to array

# %% [markdown]
# # Principal Component Analysis

# %%
#################################################
### FIRST, CALCULATE PERCENT VARIANCE ALL PCs ###
#################################################

######
PC_NUMBER = 198 # PC number = not number of leaves, but features
#######

# use the reshape function to flatten to 2D
flat_arr = proc_arr.reshape(np.shape(proc_arr)[0], 
                                 np.shape(proc_arr)[1]*np.shape(proc_arr)[2]) 

pca_all = PCA(n_components=PC_NUMBER) 
PCs_all = pca_all.fit_transform(flat_arr) # fit a PCA for all data

# print out explained variance for each PC
print("PC: " + "var, " + "overall ") 
for i in range(len(pca_all.explained_variance_ratio_)):
    print("PC" + str(i+1) + ": " + str(round(pca_all.explained_variance_ratio_[i]*100,1)) + 
          "%, " + str(round(pca_all.explained_variance_ratio_.cumsum()[i]*100,1)) + "%"  )
# Out:
# PC: var, overall
# PC1: 46.9%, 46.9%
# PC2: 14.6%, 61.5%
# PC3: 11.2%, 72.8%
# PC4: 9.9%, 82.7%
# PC5: 6.1%, 88.7%
# PC6: 1.9%, 90.6%
# PC7: 1.7%, 92.4%
# PC8: 1.5%, 93.9%
# PC9: 1.4%, 95.3%
# PC10: 0.7%, 96.0%
# PC11: 0.5%, 96.5%
# PC12: 0.5%, 97.0%
# PC13: 0.4%, 97.4%
# PC14: 0.3%, 97.6%
# PC15: 0.3%, 97.9%
# PC16: 0.2%, 98.1%
# PC17: 0.2%, 98.4%
# PC18: 0.2%, 98.5%
# PC19: 0.1%, 98.7%
# PC20: 0.1%, 98.8%
# PC21: 0.1%, 98.9%
# PC22: 0.1%, 99.0%
# PC23: 0.1%, 99.1%
# PC24: 0.1%, 99.1%
# PC25: 0.1%, 99.2%
# PC26: 0.1%, 99.2%
# PC27: 0.0%, 99.3%
# PC28: 0.0%, 99.3%
# PC29: 0.0%, 99.4%
# PC30: 0.0%, 99.4%
# PC31: 0.0%, 99.4%
# PC32: 0.0%, 99.5%
# PC33: 0.0%, 99.5%
# PC34: 0.0%, 99.5%
# PC35: 0.0%, 99.6%
# PC36: 0.0%, 99.6%
# PC37: 0.0%, 99.6%
# PC38: 0.0%, 99.6%
# PC39: 0.0%, 99.6%
# PC40: 0.0%, 99.7%
# PC41: 0.0%, 99.7%
# PC42: 0.0%, 99.7%
# PC43: 0.0%, 99.7%
# PC44: 0.0%, 99.7%
# PC45: 0.0%, 99.7%
# PC46: 0.0%, 99.7%
# PC47: 0.0%, 99.7%
# PC48: 0.0%, 99.7%
# PC49: 0.0%, 99.8%
# PC50: 0.0%, 99.8%
# PC51: 0.0%, 99.8%
# PC52: 0.0%, 99.8%
# PC53: 0.0%, 99.8%
# PC54: 0.0%, 99.8%
# PC55: 0.0%, 99.8%
# PC56: 0.0%, 99.8%
# PC57: 0.0%, 99.8%
# PC58: 0.0%, 99.8%
# PC59: 0.0%, 99.8%
# PC60: 0.0%, 99.8%
# PC61: 0.0%, 99.8%
# PC62: 0.0%, 99.8%
# PC63: 0.0%, 99.8%
# PC64: 0.0%, 99.9%
# PC65: 0.0%, 99.9%
# PC66: 0.0%, 99.9%
# PC67: 0.0%, 99.9%
# PC68: 0.0%, 99.9%
# PC69: 0.0%, 99.9%
# PC70: 0.0%, 99.9%
# PC71: 0.0%, 99.9%
# PC72: 0.0%, 99.9%
# PC73: 0.0%, 99.9%
# PC74: 0.0%, 99.9%
# PC75: 0.0%, 99.9%
# PC76: 0.0%, 99.9%
# PC77: 0.0%, 99.9%
# PC78: 0.0%, 99.9%
# PC79: 0.0%, 99.9%
# PC80: 0.0%, 99.9%
# PC81: 0.0%, 99.9%
# PC82: 0.0%, 99.9%
# PC83: 0.0%, 99.9%
# PC84: 0.0%, 99.9%
# PC85: 0.0%, 99.9%
# PC86: 0.0%, 99.9%
# PC87: 0.0%, 99.9%
# PC88: 0.0%, 99.9%
# PC89: 0.0%, 99.9%
# PC90: 0.0%, 99.9%
# PC91: 0.0%, 99.9%
# PC92: 0.0%, 99.9%
# PC93: 0.0%, 99.9%
# PC94: 0.0%, 99.9%
# PC95: 0.0%, 99.9%
# PC96: 0.0%, 99.9%
# PC97: 0.0%, 99.9%
# PC98: 0.0%, 99.9%
# PC99: 0.0%, 99.9%
# PC100: 0.0%, 99.9%
# PC101: 0.0%, 99.9%
# PC102: 0.0%, 99.9%
# PC103: 0.0%, 99.9%
# PC104: 0.0%, 99.9%
# PC105: 0.0%, 100.0%
# PC106: 0.0%, 100.0%
# PC107: 0.0%, 100.0%
# PC108: 0.0%, 100.0%
# PC109: 0.0%, 100.0%
# PC110: 0.0%, 100.0%
# PC111: 0.0%, 100.0%
# PC112: 0.0%, 100.0%
# PC113: 0.0%, 100.0%
# PC114: 0.0%, 100.0%
# PC115: 0.0%, 100.0%
# PC116: 0.0%, 100.0%
# PC117: 0.0%, 100.0%
# PC118: 0.0%, 100.0%
# PC119: 0.0%, 100.0%
# PC120: 0.0%, 100.0%
# PC121: 0.0%, 100.0%
# PC122: 0.0%, 100.0%
# PC123: 0.0%, 100.0%
# PC124: 0.0%, 100.0%
# PC125: 0.0%, 100.0%
# PC126: 0.0%, 100.0%
# PC127: 0.0%, 100.0%
# PC128: 0.0%, 100.0%
# PC129: 0.0%, 100.0%
# PC130: 0.0%, 100.0%
# PC131: 0.0%, 100.0%
# PC132: 0.0%, 100.0%
# PC133: 0.0%, 100.0%
# PC134: 0.0%, 100.0%
# PC135: 0.0%, 100.0%
# PC136: 0.0%, 100.0%
# PC137: 0.0%, 100.0%
# PC138: 0.0%, 100.0%
# PC139: 0.0%, 100.0%
# PC140: 0.0%, 100.0%
# PC141: 0.0%, 100.0%
# PC142: 0.0%, 100.0%
# PC143: 0.0%, 100.0%
# PC144: 0.0%, 100.0%
# PC145: 0.0%, 100.0%
# PC146: 0.0%, 100.0%
# PC147: 0.0%, 100.0%
# PC148: 0.0%, 100.0%
# PC149: 0.0%, 100.0%
# PC150: 0.0%, 100.0%
# PC151: 0.0%, 100.0%
# PC152: 0.0%, 100.0%
# PC153: 0.0%, 100.0%
# PC154: 0.0%, 100.0%
# PC155: 0.0%, 100.0%
# PC156: 0.0%, 100.0%
# PC157: 0.0%, 100.0%
# PC158: 0.0%, 100.0%
# PC159: 0.0%, 100.0%
# PC160: 0.0%, 100.0%
# PC161: 0.0%, 100.0%
# PC162: 0.0%, 100.0%
# PC163: 0.0%, 100.0%
# PC164: 0.0%, 100.0%
# PC165: 0.0%, 100.0%
# PC166: 0.0%, 100.0%
# PC167: 0.0%, 100.0%
# PC168: 0.0%, 100.0%
# PC169: 0.0%, 100.0%
# PC170: 0.0%, 100.0%
# PC171: 0.0%, 100.0%
# PC172: 0.0%, 100.0%
# PC173: 0.0%, 100.0%
# PC174: 0.0%, 100.0%
# PC175: 0.0%, 100.0%
# PC176: 0.0%, 100.0%
# PC177: 0.0%, 100.0%
# PC178: 0.0%, 100.0%
# PC179: 0.0%, 100.0%
# PC180: 0.0%, 100.0%
# PC181: 0.0%, 100.0%
# PC182: 0.0%, 100.0%
# PC183: 0.0%, 100.0%
# PC184: 0.0%, 100.0%
# PC185: 0.0%, 100.0%
# PC186: 0.0%, 100.0%
# PC187: 0.0%, 100.0%
# PC188: 0.0%, 100.0%
# PC189: 0.0%, 100.0%
# PC190: 0.0%, 100.0%
# PC191: 0.0%, 100.0%
# PC192: 0.0%, 100.0%
# PC193: 0.0%, 100.0%
# PC194: 0.0%, 100.0%
# PC195: 0.0%, 100.0%
# PC196: 0.0%, 100.0%
# PC197: 0.0%, 100.0%
# PC198: 0.0%, 100.0%

# %%
#################################################
### NEXT, CALCULATE THE DESIRED NUMBER OF PCs ###
#################################################

######
PC_comps = 5 # keep to 5 for now for reconstruction
#######

pca = PCA(n_components=PC_comps) 
PCs = pca.fit_transform(flat_arr) # fit a PCA for only desired PCs

# print out explained variance for each PC
print("PC: " + "var, " + "overall ") 
for i in range(len(pca.explained_variance_ratio_)):
    print("PC" + str(i+1) + ": " + str(round(pca.explained_variance_ratio_[i]*100,1)) + 
          "%, " + str(round(pca.explained_variance_ratio_.cumsum()[i]*100,1)) + "%"  )
    
# add PCs to dataframe for plotting
mdata["PC1"] = PCs[:,0]
mdata["PC2"] = PCs[:,1]
mdata["PC3"] = PCs[:,2]
mdata["PC4"] = PCs[:,3]
mdata["PC5"] = PCs[:,4]
# Out:
# PC: var, overall
# PC1: 46.9%, 46.9%
# PC2: 14.6%, 61.5%
# PC3: 11.2%, 72.8%
# PC4: 9.9%, 82.7%
# PC5: 6.1%, 88.7%

# %%
nstdev = 2 # set number of standard deviations
int = 20 # set interval number

## calculate PC vals for eigenkernels
PCval_arr = np.zeros((PC_comps, int, PC_comps)) # array to hold PC vals for eigenkernels
for i in range(PC_comps): # for each PC
    stdvals = np.linspace(-nstdev,+nstdev,int) # set standard deviation values to calculate eigenkernels
    for j in range(len(stdvals)): # for each stdval
        PCval_arr[i,j,i] =  (np.mean(PCs[:,i]))+np.std(PCs[:,i])*stdvals[j] # store PC vals

## calculate eigenleaf shapes
eigenlf = np.zeros((PC_comps, int, 2*res-1, 2))
for k in range(PC_comps):
    for l in range(int):
        # calculate the inverse eigenkernels
        inv_lf = pca.inverse_transform( PCval_arr[k,l,:] )
        inv_x = inv_lf[0:(2*res-1)*2:2] # select just inverse x vals
        inv_y = inv_lf[1:(2*res-1)*2:2] # select just inverse y vals
        eigenlf[k,l,:,:] = np.column_stack((inv_x, inv_y))

# %%
counter = 1
plt.figure(figsize=(9,3))

for m in range(PC_comps):
    for n in range(int):
        plt.subplot(PC_comps,int,counter)
        plt.fill(eigenlf[m,n,:,0], eigenlf[m,n,:,1], c="#16161d")
        plt.gca().set_aspect("equal")
        counter+=1
        plt.axis("off")
plt.tight_layout()

# %%
plt.subplot(2,1,1)
sns.scatterplot(mdata, x="PC1", y="PC4", hue="species", legend=False)

plt.subplot(2,1,2)
sns.scatterplot(mdata, x="PC1", y="PC5", hue="species", legend=False)

plt.tight_layout()

# %%
plt.subplot(5,1,1)
sns.histplot(mdata, x="PC1",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,2)
sns.histplot(mdata, x="PC2",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,3)
sns.histplot(mdata, x="PC3",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,4)
sns.histplot(mdata, x="PC4",hue="species", multiple="stack", legend=False)

plt.subplot(5,1,5)
sns.histplot(mdata, x="PC5",hue="species", multiple="stack", legend=False)
# Out:
# <Axes: xlabel='PC5', ylabel='Count'>

# %% [markdown]
# # Linear Discriminant Analysis by species

# %%
# get value counts of species
mdata["species"].value_counts()
# Out:
# species
# LGLAN    416
# LPUBE    330
# LELON    190
# LFLAC    150
# LDORT    149
# LSPIC    127
# LBREV    126
# LNUTT    106
# LSIPH     97
# LKALM     88
# LCARD     85
# LPALU     69
# LAPPE     55
# LINFL     33
# LCANB     30
# LFEAY     23
# LROGE     16
# LAPAL     14
# LBATS     11
# LAMOE      6
# LFLOR      2
# Name: count, dtype: int64

# %%
# create a df for LDA by species
species_df = pd.DataFrame(data=flat_arr[:,:])

# List of factor levels to remove
# remove 5 or lower samples, for K fold stratified sampling of 5
levels_to_remove = ['LFLOR']

# list of indices to remove
indices_to_remove = mdata[mdata['species'].isin(levels_to_remove)].index.tolist()

# remove indices from procrustes coordinates
# create input and output variables
X = species_df.iloc[:,0:((res*2)-1)*2]
X = X.drop(indices_to_remove).reset_index(drop=True)
y = mdata["species"].drop(indices_to_remove).reset_index(drop=True)

# fit the LDA model
species_model = LinearDiscriminantAnalysis()

# create a StratifiedKFold object with k=5
skf = StratifiedKFold(n_splits=5)

# initialize an empty confusion matrix
cm = np.zeros( ( len(np.unique(y)), len(np.unique(y))  ))

# perform stratified k-fold cross-validation
for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Fit the LDA model on the training data
    species_model.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = species_model.predict(X_test)

    # Update the confusion matrix
    cm += confusion_matrix(y_test, y_pred)

row_sums = cm.sum(axis=1, keepdims=True)
cm = cm / row_sums

classes = np.sort(y.unique())

# Confusion matrix

plt.figure(figsize=(10,10))

sns.heatmap(cm, 
            #annot=False, 
            #annot_kws={"fontsize":8}, 
            #fmt="{0:f}", 
            cmap="viridis", 
            square=True, 
            cbar=True,
            xticklabels=classes,
            yticklabels=classes,
            #norm=LogNorm()
           )
plt.title("Confusion matrix by species")
plt.xlabel("Predicted class")
plt.ylabel("Actual class")
# Out:
# Text(95.72222222222221, 0.5, 'Actual class')

# %%
# Create a dataframe to cluster the confusion matrix
cm_df = pd.DataFrame(cm, columns=classes)
cm_df.index = classes

# %%
sns.clustermap(cm_df, row_cluster=True, col_cluster=False)

# %%
# Plot of linear discriminant scores by genotype

data_plot = species_model.fit(X, y).transform(X)
species_plot_df = pd.DataFrame(data=data_plot[:,:])
species_plot_df["species"] = mdata["species"]
species_plot_df = species_plot_df.drop(indices_to_remove).reset_index(drop=True)

species_plot_df = species_plot_df.rename(columns={0:'LD1', 1:'LD2', 2:"LD3", 3:"LD4", 4:"LD5", 5:"LD6"})

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(10,5))

sns.scatterplot(data=species_plot_df, x="LD1", y="LD2", hue="species", s=10, ax=ax1)
ax1.get_legend().remove()
sns.scatterplot(data=species_plot_df, x="LD3", y="LD4", hue="species", s=10, ax=ax2)
ax2.get_legend().remove()
sns.scatterplot(data=species_plot_df, x="LD5", y="LD6", hue="species", s=10, ax=ax3)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.suptitle("Linear Discriminants by species")

plt.tight_layout()

# %%
groupA = ["LDORT","LGLAN","LAPAL","LCANB","LNUTT","LPALU","LFLAC","LKALM"]
groupB = ["LBREV"]
groupC = ["LAMOE","LCARD"]
groupD = ["LFEAY","LBATS","LROGE","LINFL","LPUBE","LAPPE","LSPIC","LELON","LSIPH"]

# %%
morphotype = []

for i in range(len(species_plot_df)):
    curr_spe = species_plot_df["species"].iloc[i]
    if curr_spe in groupA:
        morphotype.append("A")
    elif curr_spe in groupB:
        morphotype.append("B")
    elif curr_spe in groupC:
        morphotype.append("C")
    elif curr_spe in groupD:
        morphotype.append("D")

species_plot_df["morphotype"] = morphotype

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, sharey=True, figsize=(10,5))

sns.scatterplot(data=species_plot_df, x="LD1", y="LD2", hue="morphotype", s=10, ax=ax1)
ax1.get_legend().remove()
sns.scatterplot(data=species_plot_df, x="LD3", y="LD4", hue="morphotype", s=10, ax=ax2)
ax2.get_legend().remove()
sns.scatterplot(data=species_plot_df, x="LD5", y="LD6", hue="morphotype", s=10, ax=ax3)
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))

plt.suptitle("Linear Discriminants by morphotype")

plt.tight_layout()

# %%
groupA = ["LDORT","LGLAN","LAPAL","LCANB","LNUTT","LPALU","LFLAC","LKALM"]
groupB = ["LBREV"]
groupC = ["LAMOE","LCARD"]
groupD = ["LFEAY","LBATS","LROGE","LINFL","LPUBE","LAPPE","LSPIC","LELON","LSIPH"]

# %%
species_list = ["LDORT","LGLAN","LAPAL","LCANB","LNUTT","LPALU","LFLAC","LKALM",
"LBREV",
"LAMOE","LCARD",
"LFEAY","LBATS","LROGE","LINFL","LPUBE","LAPPE","LSPIC","LELON","LSIPH"]

color_list = ["orange","orange","orange","orange","orange","orange","orange","orange",
              "red",
              "blue","blue",
              "green","green","green","green","green","green","green","green","green",]

# %%
plt.figure(figsize=(6,7))

count = 1

for i in range(len(species_list)):

    curr_spe = species_list[i]
    inds = mdata[mdata["species"]==curr_spe].index
    curr_proc = proc_arr[inds,:,:]
    mean_shape = np.mean(curr_proc, axis=0)

    plt.subplot(5,4,count)
    plt.plot(mean_shape[:,0], mean_shape[:,1], c=color_list[i])
    plt.fill(mean_shape[:,0], mean_shape[:,1], c=color_list[i], alpha=0.6)
    plt.gca().set_aspect("equal")
    plt.title(curr_spe)
    plt.axis("off")

    count+=1

plt.tight_layout()

# %% [markdown]
# # Statistical differences in Procrustes distance values

# %%
# get all cultivar names
cult_names = mdata["species"].unique()

# get all pairwise combinations of cultivar names
combinations = list(itertools.combinations(cult_names, 2))

group1_names = [] # a list to store group1 names
group2_names = [] # a list to store group2 names
p_vals = [] # a list to store pvals

for i in range(len(combinations)): # for each combination

    group1 = combinations[i][0] # get the first group name
    group2 = combinations[i][1] # get the second group name
    
    # get the Procrustean coordinates from each group
    group1_lfs = proc_arr[np.array(mdata[mdata["species"]==group1].index)]
    group2_lfs = proc_arr[np.array(mdata[mdata["species"]==group2].index)]
    all_lfs = proc_arr[np.array(mdata[(mdata["species"]==group1) | (mdata["species"]==group2)].index)]
    
    # calculate mean leaf for each group
    group1_mean = np.mean(group1_lfs, axis=0)
    group2_mean = np.mean(group2_lfs, axis=0)
    all_mean = np.mean(all_lfs, axis=0)
    
    # calculate Procrustes distance of each leaf to respective group mean
    group1_dists = []
    for i in range(len(group1_lfs)):
        s1, s2, distance = procrustes(group1_lfs[i,:,:], group1_mean) 
        group1_dists.append(distance)
    
    group2_dists = []
    for i in range(len(group2_lfs)):
        s1, s2, distance = procrustes(group2_lfs[i,:,:], group2_mean) 
        group2_dists.append(distance)
    
    # concatenate arrays to group mean 
    group_mean_dists = np.array(group1_dists+group2_dists)
    
    # calculate Procrustes distance of each leaf to overall mean
    all_dists = []
    for i in range(len(all_lfs)):
        s1, s2, distance = procrustes(all_lfs[i,:,:], all_mean) 
        all_dists.append(distance)
    all_dists = np.array(all_dists)

    # calculate p value
    statistic, p_value = stats.kruskal(group_mean_dists, all_dists)

    # store data
    p_vals.append(p_value)
    group1_names.append(group1)
    group2_names.append(group2)

# Adjust p-values using the FDR BH correction
BH_pvals = multitest.multipletests(p_vals, method='fdr_bh', alpha=0.05)

# create a matrix for clustermap
group_df = pd.DataFrame({

    "group1":group1_names,
    "group2":group2_names,
    "significant":BH_pvals[0],
    "BH":BH_pvals[1]
})

inv_group_df = pd.DataFrame({
    "group1":group2_names,
    "group2":group1_names,
    "significant":BH_pvals[0],
    "BH":BH_pvals[1]
})


pairwise_df = pd.concat([group_df, inv_group_df])

matrix = (pairwise_df.pivot(index='group1', columns='group2', values='BH')
   .fillna(1, downcast='infer')
)

g = sns.clustermap(matrix)
ax = g.ax_heatmap
#[ax.axhline(y=i, color='white', linestyle='-') for i in [4,9]]
#[ax.axvline(x=i, color='white', linestyle='-') for i in [4,9]]

# %%
groupA = ["LCANB","LNUTT","LPALU","LKALM","LGLAN","LDORT","LFLAC"]
groupB = ["LCARD","LPUBE","LFEAY","LROGE","LBREV","LELON","LSPIC","LAPPE","LINFL","LSIPH"]
groupC = ["LAMOE","LBATS","LAPAL","LFLOR"]

# %%
species_list = ["LCANB","LNUTT","LPALU","LKALM","LGLAN","LDORT","LFLAC",
"LCARD","LPUBE","LFEAY","LROGE","LBREV","LELON","LSPIC","LAPPE","LINFL","LSIPH",
"LAMOE","LBATS","LAPAL","LFLOR"]

color_list = ["orange","orange","orange","orange","orange","orange","orange",
              "green","green","green","green","green","green","green","green","green","green",
              "dodgerblue","dodgerblue","dodgerblue","dodgerblue",]

# %%
plt.figure(figsize=(6,7))

count = 1

for i in range(len(species_list)):

    curr_spe = species_list[i]
    inds = mdata[mdata["species"]==curr_spe].index
    curr_proc = proc_arr[inds,:,:]
    mean_shape = np.mean(curr_proc, axis=0)

    plt.subplot(5,5,count)
    plt.plot(mean_shape[:,0], mean_shape[:,1], c=color_list[i])
    plt.fill(mean_shape[:,0], mean_shape[:,1], c=color_list[i], alpha=0.6)
    plt.gca().set_aspect("equal")
    plt.title(curr_spe)
    plt.axis("off")

    count+=1

plt.tight_layout()

# %%
groups = []

for i in range(len(mdata)):
    curr_spe = mdata["species"].iloc[i]
    if curr_spe in groupA:
        groups.append("A")
    elif curr_spe in groupB:
        groups.append("B")
    elif curr_spe in groupC:
        groups.append("C")

mdata["group"] = groups

# %%
# get A, B, and C leaf coords from proc_arr using indices from df all_mdata
A_lfs = proc_arr[np.array(mdata[mdata["group"]=="A"].index)]
B_lfs = proc_arr[np.array(mdata[mdata["group"]=="B"].index)]
C_lfs = proc_arr[np.array(mdata[mdata["group"]=="C"].index)]

# create mean leaves for A, B, and C, pairwise, and overall mean
A_mean = np.mean(A_lfs, axis=0)
B_mean = np.mean(B_lfs, axis=0)
C_mean = np.mean(C_lfs, axis=0)

A_B_mean = np.mean(np.row_stack((A_lfs, B_lfs)), axis=0)
A_C_mean = np.mean(np.row_stack((A_lfs, C_lfs)), axis=0)
B_C_mean = np.mean(np.row_stack((B_lfs, C_lfs)), axis=0)

overall_mean = np.mean(proc_arr, axis=0)

# plot our comparison of A, B, and C procrustean leaves and means
plt.figure(figsize=(20,10))

A_col = "orange"
B_col = "green"
C_col = "dodgerblue"

#########################
# A vs B
#########################

plt.subplot(131)
plt.plot(A_mean[:,0],A_mean[:,1], c=A_col, lw=3, label="A")
plt.plot(B_mean[:,0],B_mean[:,1], c=B_col, lw=3, label="B")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="A":
        col = A_col
    else:
        col = B_col

    #plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")

#########################
# A vs C
#########################

plt.subplot(132)
plt.plot(A_mean[:,0],A_mean[:,1], c=A_col, lw=3, label="A")
plt.plot(C_mean[:,0],C_mean[:,1], c=C_col, lw=3, label="C")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="A":
        col = A_col
    else:
        col = C_col

    #plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")

#########################
# B vs C
#########################

plt.subplot(133)
plt.plot(B_mean[:,0],B_mean[:,1], c=B_col, lw=3, label="B")
plt.plot(C_mean[:,0],C_mean[:,1], c=C_col, lw=3, label="C")
plt.legend()

for i in range(len(proc_arr)):

    if mdata["group"].iloc[i]=="B":
        col = B_col
    else:
        col = C_col

    #plt.plot(proc_arr[i,:,0],proc_arr[i,:,1], c=col, lw=0.05, alpha=0.8)
    plt.gca().set_aspect("equal")

plt.axis("off")
# Out:
# (-0.04588605159728686,
#  0.04728382236118123,
#  -0.16863426111500107,
#  0.17158815078302272)

# %%
#########################
#########################
######## A VS B #########
#########################
#########################

A_B_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_mean[i,0],A_mean[i,1])
    # eulidean distances of B sample to B mean
    B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_mean[i,0],B_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((A_eds, B_eds))

    ## GROUP 2##
    # eulidean distances of A to pairwise mean
    ovr_A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_B_mean[i,0],A_B_mean[i,1])
    # eulidean distances of B sample to pairwise mean
    ovr_B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                A_B_mean[i,0],A_B_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_A_eds, ovr_B_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    A_B_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
A_B_fdrBH_pvals = multitest.multipletests(A_B_p_vals, method='fdr_bh')

# get -log10 p values
A_B_neg_log10 = -np.log10(A_B_fdrBH_pvals[1])


#########################
#########################
######## A VS C #########
#########################
#########################

A_C_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_mean[i,0],A_mean[i,1])
    # eulidean distances of C sample to C mean
    C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                C_mean[i,0],C_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((A_eds, C_eds))

    ## GROUP 2##
    # eulidean distances of A to pairwise mean
    ovr_A_eds = euclid_dist(A_lfs[:,i,0],A_lfs[:,i,1],
                A_C_mean[i,0],A_C_mean[i,1])
    # eulidean distances of C sample to overall mean
    ovr_C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                A_C_mean[i,0],A_C_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_A_eds, ovr_C_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    A_C_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
A_C_fdrBH_pvals = multitest.multipletests(A_C_p_vals, method='fdr_bh')

# get -log10 p values
A_C_neg_log10 = -np.log10(A_C_fdrBH_pvals[1])

#########################
#########################
######## B VS C #########
#########################
#########################

B_C_p_vals = [] # store p values for each landmark

for i in range(np.shape(proc_arr)[1]):

    ## GROUP 1##
    # eulidean distances of A sample to A mean
    B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_mean[i,0],B_mean[i,1])
    # eulidean distances of C sample to C mean
    C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                C_mean[i,0],C_mean[i,1])
    # group 1 = euclidean distances to group mean
    group1 = np.concatenate((B_eds, C_eds))

    ## GROUP 2##
    # eulidean distances of A to overall mean
    ovr_B_eds = euclid_dist(B_lfs[:,i,0],B_lfs[:,i,1],
                B_C_mean[i,0],B_C_mean[i,1])
    # eulidean distances of C sample to overall mean
    ovr_C_eds = euclid_dist(C_lfs[:,i,0],C_lfs[:,i,1],
                B_C_mean[i,0],B_C_mean[i,1])
    # group 2 = euclidean distances to group mean
    group2 = np.concatenate((ovr_B_eds, ovr_C_eds))
    
    # perform Kruskal-Wallis test
    statistic, p_value = stats.kruskal(group1, group2)
    # store p value
    B_C_p_vals.append(p_value)
    
# Adjust p-values using the BH correction
B_C_fdrBH_pvals = multitest.multipletests(B_C_p_vals, method='fdr_bh')

# get -log10 p values
B_C_neg_log10 = -np.log10(B_C_fdrBH_pvals[1])

#######################
#######################
### CREATE PVAL DF  ###
#######################
#######################

# create a pandas dataframe with overall mean leaf coordinates for plotting
pval_df = pd.DataFrame({"xval":overall_mean[:,0],
                        "yval":overall_mean[:,1],
                        "A_B_pval":A_B_neg_log10,
                       "A_C_pval":A_C_neg_log10,
                       "B_C_pval":B_C_neg_log10})

# %%
# Reset -log10 p values to -log10(0.05) if equal to or lower than that value for plotting

pval_df["A_B_pval"] = np.where(pval_df["A_B_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["A_B_pval"])
pval_df["A_C_pval"] = np.where(pval_df["A_C_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["A_C_pval"])
pval_df["B_C_pval"] = np.where(pval_df["B_C_pval"]<=-np.log10(0.05), -np.log10(0.05), pval_df["B_C_pval"])

# %%
# project negative log10 FDR BH pvals on mean leaf

plt.figure(figsize=(20,10))

plt.subplot(131)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="A_B_pval", palette="viridis", s=100, 
                   hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")

plt.subplot(132)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="A_C_pval", palette="viridis", s=100,
                  hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")

plt.subplot(133)
plt.plot(pval_df["xval"],pval_df["yval"], c="k", zorder=0) # plot of mean leaf
ax=sns.scatterplot(data=pval_df, x="xval", y="yval", hue="B_C_pval", palette="viridis", s=100,
                  hue_norm=plt.Normalize(-np.log10(0.05), np.max(A_B_neg_log10))
                  ) # pvals
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.gca().set_aspect("equal")
plt.axis("off")
# Out:
# (-0.03263743067294501,
#  0.03367172622074858,
#  -0.16625864227654147,
#  0.166494061909123)

# %% [markdown]
# # Node information

# %%
sns.scatterplot(mdata, x="PC1", y="rel_node", hue="rel_node", s=10, palette="inferno")
# Out:
# <Axes: xlabel='PC1', ylabel='rel_node'>

# %%
sns.scatterplot(mdata, x="PC2", y="rel_node", hue="rel_node", s=10, palette="inferno")
# Out:
# <Axes: xlabel='PC2', ylabel='rel_node'>

# %%
sns.scatterplot(mdata, x="PC3", y="rel_node", hue="rel_node", s=10, palette="inferno")
# Out:
# <Axes: xlabel='PC3', ylabel='rel_node'>

# %%
sns.scatterplot(mdata, x="PC4", y="rel_node", hue="rel_node", s=10, palette="inferno")
# Out:
# <Axes: xlabel='PC4', ylabel='rel_node'>

# %%
sns.scatterplot(mdata, x="PC5", y="rel_node", hue="rel_node", s=10, palette="inferno")
# Out:
# <Axes: xlabel='PC5', ylabel='rel_node'>
